# %%
import glob
import json
import os
from os import cpu_count
import re
import textwrap
import hashlib
from contextlib import contextmanager
from array import array
from concurrent.futures import ThreadPoolExecutor, ProcessPoolExecutor, as_completed
from collections import OrderedDict
from datetime import datetime, timezone
import time
import gc

import numpy as np
import pandas as pd
import uproot
import ROOT
from ROOT import TFile
import matplotlib as mpl
import matplotlib.pyplot as plt
import mplhep as hep
from hist.intervals import poisson_interval
from matplotlib.legend_handler import HandlerTuple

hep.style.use("CMS")

# %%
# =========================
# USER CONFIGURATION CELL
# =========================
# Purpose: Data-vs-MC plotting for ZH→4l+MET ZZ control regions.
# Edit this cell + OBSERVABLES/CATEGORY_CONFIG for most workflows.

ANALYSIS_CONFIG = {
    "config_version": 2,
    "purpose": "Data-vs-MC plotting for DY and ZZ selections in ZH→4l+MET postprocessed trees",
    "notes": "Edit config + OBSERVABLES + CATEGORY_CONFIG only for most workflows",

    "io": {
        "input_mode": "merged",  # "auto", "merged", "unmerged"
        "input_path": "/home/mohammad/ZH/rootfiles/mkShapes__ZH_4lMET_ZZCR_2024_20260421__ALL.root",
        "unmerged_glob": "*.root",
        "unmerged_process_paths": {},
        "output_dir": "plots/",
        "output_file_ext": "png",
        "output_bbox_inches": None,  # use "tight" only for final publication plots
        "output_filename_template": "{title}_{category}_{observable}",
        "write_plot_metadata": False,
        "write_root_histograms": False,
        "root_histogram_file": "plots/histograms.root",
        "merged_tree_roots": ["{tree}", "trees/{tree}"],
        "tree_path_candidates": [
            "{tree}/{proc}/Events",
            "trees/{tree}/{proc}/Events",
            "/{tree}/{proc}/Events",
            "/trees/{tree}/{proc}/Events",
        ],
    },

    "physics": {
        "data_processes": {"DATA"},
        "mc_weight_branch": "weight",
        "data_legend_label": "DATA",
        "total_mc_legend_label": "Total MC",
        "yield_digits": 2,
        "yield_percent_digits": 1,
    },

    "runtime": {
        "enable_parallel_read": True,
        # Use every CPU core visible to the Python process by default.
        # Override these only when intentionally throttling a busy/shared node.
        "parallel_read_workers": max(1, cpu_count() or 1),
        "parallel_profile": "full_cpu",  # "full_cpu"/"batch" use all configured workers; legacy: "auto", "laptop", "shared"
        "array_branch_import_mode": "needed",  # "needed" or "all"
        # "memory"/"arrays": load selected branches into RAM and reuse/cache them.
        # "direct": stream only the branches needed for each histogram from ROOT files
        #           in entry chunks; useful for SSD-backed storage and lower RAM use.
        "data_loading_mode": "direct",
        # Direct mode memory is roughly: chunk_entries × loaded_branches × dtype_size.
        # Tune down on small laptops; tune up when ROOT I/O overhead dominates.
        "direct_chunk_entries": 500_000,
        "direct_step_size": "200 MB",  # set None to use direct_chunk_entries instead
        # Batch several observables per ROOT pass; larger batches reread files less.
        "direct_observable_batch_size": "all",
        # Batch subcategory cuts per ROOT pass.  This avoids rereading the same
        # files once per signal/control-region subcategory while bounding masks.
        "direct_cut_batch_size": "all",
        # Parallelize across ROOT files in direct mode.  This is normally the
        # highest-impact speed knob for unmerged production outputs.
        "direct_parallel_files": True,
        # Outer process/file concurrency is tuned separately from uproot's
        # internal decompression/interpretation pools because histogram filling
        # is memory-bandwidth heavy.  These conservative defaults avoid silently
        # launching 16 outer fill workers for only a handful of process trees.
        "direct_process_workers": min(4, max(1, cpu_count() or 1)),
        "direct_file_read_workers": min(4, max(1, cpu_count() or 1)),
        "uproot_decompression_workers": min(8, max(1, cpu_count() or 1)),
        "uproot_interpretation_workers": min(8, max(1, cpu_count() or 1)),
        "direct_use_threaded_io": True,
        "hist_fill_backend": "bincount",  # "bincount" or debug fallback "histogram"
        "hist_fill_validate_bincount": False,
        "zzcr_stage_engine": True,
        "direct_timing_enabled": True,
        "fast_direct_mode": True,
        "hist_backend": "numpy",
        "hist_production_backend": "uproot",
        "plot_workers": 1,  # optional process-based cache plotting: 1, 2, or 4
        "plot_gc_every": 50,
        "cut_eval_engine": "numexpr",    # eval engine: "numexpr" is usually faster for large arrays
        "strict_cut_syntax": False,
        "allow_dataframe_cut_fallback": False,  # DataFrame fallback can duplicate memory on very large payloads
        "strict_cut_allowed_pattern": r"^[A-Za-z0-9_\s\(\)\.><=+\-*/!&|,:]*$",
        "reuse_uncut_arrays_for_cuts": True,
        "category_loading_strategy": "preload_tree_uncut",  # "preload_tree_uncut" or "preload_tree_or_subcategory_cut"
        # Additional low-level branches to force-load with every payload.
        # Prefer editing ALWAYS_LOAD_BRANCHES in the observable cell below; this
        # config key remains for one-off/legacy branch seeding.
        "explicit_branch_seed": [],
        "auto_include_all_observables_in_seed": False,
        "unknown_observable_policy": "warn",  # "warn", "ignore", "error"
        "log_branch_plan": False,
        "preload_branch_strategy": "union_all",  # "union_all" or "per_observable_chunk"
        "preload_observable_chunk_size": 2,
        "materialize_category_cut_arrays": False,  # avoid duplicating per-category branch arrays in memory
    },

    "cache": {
        # Keep array caches off by default for local 32 GB workflows. Set True
        # only when using data_loading_mode="memory" on a large-RAM machine.
        "arrays_in_memory": False,
        "force_reload_inputs": False,
        "force_reload_array_cache": False,
        "max_entries": 8,
        "max_bytes_mb": 1024,
        "eviction_policy": "lru",
    },

    "filters": {
        "process_allowlist": None,
        "process_blocklist": set(),
        "exclude_top_level_keys": {"trees"},
        "filename_process_strip_pattern": r"_\d+$",
    },

    "style_behavior": {
        "stack_by_group": True,
    },

    "logging": {
        "enabled": True,
        "progress_enabled": True,
        "progress_every": 500,
        "progress_bar_width": 28,
        "emit_process_reports": False,
        "dedupe_repeated": True,
        "hacker_style": True,
        "show_tree_path": True,
        "show_cut": True,
        "show_timestamp": True,
        "timestamp_utc": True,
        "timestamp_fmt": "%Y-%m-%d %H:%M:%S",
        "show_branch_summary": True,
        "max_cut_preview": 120,
    },

    "profiling": {
        "enabled": True,
        "print_memory": True,
        "progress_every_chunks": 20,
    },

    "diagnostics": {
        # Static checks are cheap and catch config/observable mistakes before I/O.
        "run_startup_static_checks": True,
        "raise_on_static_error": True,
        # Branch checks open ROOT metadata only; enable when validating a new ntuple.
        "run_startup_branch_checks": False,
        "raise_on_branch_error": False,
        "branch_check_max_files_per_proc": 1,
        "raise_on_missing_critical_branch": True,
        "validate_array_lengths": True,
        "raise_on_array_length_mismatch": True,
    },

    "execution": {
        "run_default_batch_cell": True,
        "produce_hist_cache": True,
        "plot_from_hist_cache": True,
        "hist_cache_path": "plots/hist_cache.npz",
        "rebuild_hist_cache": False,
        # Bump this when the histogram cache contents/semantics change so
        # stale on-disk caches are rebuilt instead of silently reused.
        "hist_cache_schema_version": 5,
        # Data-vs-MC plots require at least one MC histogram per requested
        # category/observable.  If an old/broken cache only has DATA, rebuild
        # it; if a fresh production still has no MC, raise a clear error.
        "require_mc_histograms": True,
        # Plot every registered observable by default.  Set this to a list of
        # observable names only when you intentionally want a smaller, faster
        # development batch.
        "default_observables": None,
    },
}

os.makedirs(ANALYSIS_CONFIG["io"]["output_dir"], exist_ok=True)

PLOT_STYLE_DEFAULTS = {
    "meta": {
        "title": "",
        "subtitle_separator": " • ",
        "lumi_label": "26.49",
    },
    "figure": {
        "figsize": (10, 7),
        "save_dpi": 100,
        "show_plots": False,
        "facecolor": "white",
    },
    "layout": {
        "width_ratios": [6.8, 3.2],
        "height_ratios": [3, 1],
        "wspace": 0.05,
        "hspace": 0.04,
    },
    "panels": {
        "main_facecolor": "white",
        "ratio_facecolor": "white",
        "legend_facecolor": "white",
    },
    "axes": {
        "x_label": "",
        "y_label": "Events",
        "ratio_y_label": "Data/MC",
        "axis_label_fontsize": 24,
        "axis_labelpad": 6,
        "tick_labelsize": 15,
        "tick_direction": "in",
        "tick_length": 5,
        "tick_width": 1.0,
        "tick_top": True,
        "tick_right": True,
        "title_fontsize": 10,
        "title_fontweight": "normal",
        "title_color": "black",
        "title_x": 0.02,
        "title_y": 0.90,
        "subtitle_enabled": True,
        "subtitle_fontsize": 9,
        "subtitle_fontweight": "normal",
        "subtitle_color": "black",
        "subtitle_fontstyle": "normal",
        "subtitle_y_offset": 0.055,
        "ratio_ylim_default": (0.5, 1.5),
        "spine_linewidth": 1.0,
    },
    "grid": {
        "enabled": True,
        "main_alpha": 0.25,
        "ratio_alpha": 0.25,
        "linestyle": "-",
        "linewidth": 0.6,
        "which": "major",
        "axis": "both",
    },
    "stack": {
        "alpha": 0.82,
        "edgecolor": "none",
        "linewidth": 0.0,
        "align": "center",
        "zorder": 2,
    },
    "mc": {
        "line_color": "red",
        "line_width": 1.5,
        "line_style": "-",
        "line_drawstyle": "steps-mid",
        "line_zorder": 5,
        "band_alpha": 0.12,
        "band_hatch": None,
        "band_step": "mid",
        "band_zorder": 4,
    },
    "data": {
        "marker": "o",
        "marker_size": 4,
        "color": "black",
        "elinewidth": 1.0,
        "capsize": 0,
        "marker_zorder": 6,
    },
    "ratio": {
        "reference_line_value": 1.0,
        "reference_line_color": None,
        "reference_line_width": 1.0,
        "reference_line_style": "-",
        "reference_line_drawstyle": "steps-mid",
        "reference_line_zorder": 3,
        "band_step": "mid",
    },
    "legend": {
        "loc": "upper left",
        "ncol": 2,
        "fontsize": 10,
        "frameon": False,
        "title": "",
        "title_fontsize": 10,
        "handlelength": 1.2,
        "columnspacing": 0.9,
        "labelspacing": 0.35,
        "handletextpad": 0.4,
        "borderaxespad": 0.0,
    },
    "cut_block": {
        "enabled": True,
        "title_text": "Selection:",
        "text_width": 38,
        "title_fontsize": 12,
        "title_fontweight": "bold",
        "title_color": "black",
        "text_fontsize": 8,
        "text_color": "black",
        "block_gap_from_legend": 0.055,
        "title_to_text_gap": 0.03,
        "line_spacing": 1.10,
        "fontfamily": "monospace",
    },
    "cms": {
        "label": "Preliminary",
        "com": 13.6,
        "fontsize": 20,
    },
    "yaxis_scientific": {
        "enabled": True,
        "plain_threshold": 1e3,
        "powerlimits": (-4, 4),
        "manual_multiplier_min_abs_power": 4,
        "multiplier_x": -0.005,
        "multiplier_y": 1.005,
        "multiplier_ha": "right",
        "multiplier_fontsize": 14,
    },
    "scales": {
        "logy": False,
    },
    "text": {
        "selection_title": "Selection:",
        "plot_saved_log": "Saved plot: {path}",
        "no_mc_log": "No MC histogram available for {category}/{observable}",
        "unknown_observable_log": "Skipping unknown observable '{observable}'",
    },
}

# Branch compatibility aliases (canonical -> alternates)
BRANCH_ALIASES = {
    "lZ1_eta": ["__lZ1_eta", "lZ1_Eta"],
    "lZ1_phi": ["__lZ1_phi", "lZ1_Phi"],
    "lZ2_eta": ["__lZ2_eta", "lZ2_Eta"],
    "lZ2_phi": ["__lZ2_phi", "lZ2_Phi"],
    "lX1_eta": ["__lX1_eta", "lX1_Eta"],
    "lX1_phi": ["__lX1_phi", "lX1_Phi"],
    "lX2_eta": ["__lX2_eta", "lX2_Eta"],
    "lX2_phi": ["__lX2_phi", "lX2_Phi"],
}

# %%
# =========================
# BRANCH LOADING + OBSERVABLE MENU
# =========================
# ALWAYS_LOAD_BRANCHES is the explicit memory preload list.  Put branches here
# when they are needed for common cuts, masks, reports, or weights even if they
# are not plotted.  The loader adds these names to every branch plan through
# _branch_seed_from_config(), independent of the selected OBSERVABLES.
#
# OBSERVABLES should stay plot-focused: distributions you actually want to make.
# If a branch is only a flag/cut helper or weight/SF helper, keep it in
# ALWAYS_LOAD_BRANCHES instead of registering it as an observable.

LEPTON_LABELS = ("lZ1", "lZ2", "lX1", "lX2")
LEPTON_PAIRS = (
    ("lZ1", "lZ2"),
    ("lZ1", "lX1"),
    ("lZ1", "lX2"),
    ("lZ2", "lX1"),
    ("lZ2", "lX2"),
    ("lX1", "lX2"),
)

# Branches needed by the standard CATEGORY_CONFIG cuts and common event weights.
# Edit/comment this list to control what is always held in memory.
ALWAYS_LOAD_BRANCHES = [
    # Trigger/cut flags used by the cutflow.
    "Trigger_ElMu",
    "Trigger_sngMu",
    "Trigger_dblMu",
    "Trigger_sngEl",
    "Trigger_dblEl",
    "Z0_isEE",
    "Z0_isMM",
    "X_isEE",
    "X_isMM",
    "bVeto",
    "PassesZZCR4lOrderedPt",

    # Numeric branches appearing in common cuts and region definitions.
    "nJetInHorn",
    "Z0_mass",
    "X_mass",
    "PuppiMET_pt",

    # Nominal event weight used by the plotting stack.
    "weight",
]

# Optional per-lepton selected-WP scale factors.  These are weight ingredients,
# not default plot observables, but keeping them here makes SF reweighting studies
# possible without an extra reload.  Comment out if memory pressure is high.
ALWAYS_LOAD_BRANCHES += [f"{lep}_selWP_TotSF" for lep in LEPTON_LABELS]

_DEFAULT_RATIO_YLIM = (0.5, 1.5)
_WIDE_RATIO_YLIM = (0.4, 1.8)


def _obs(bins, xlabel, ratio_ylim=_DEFAULT_RATIO_YLIM):
    return {"bins": np.asarray(bins, dtype=float), "xlabel": xlabel, "ratio_ylim": ratio_ylim}


def _count_obs(label, max_count=8):
    return _obs(np.arange(-0.5, max_count + 1.5, 1.0), label)


def _phi_obs(label):
    return _obs(np.linspace(-np.pi, np.pi, 33), label, ratio_ylim=_WIDE_RATIO_YLIM)


def _eta_obs(label, max_abs=2.5):
    return _obs(np.linspace(-max_abs, max_abs, 41), label, ratio_ylim=_WIDE_RATIO_YLIM)


def _pt_obs(label, high=250.0, nbins=41):
    return _obs(np.linspace(0.0, high, nbins), label, ratio_ylim=_WIDE_RATIO_YLIM)


OBSERVABLES = OrderedDict()

# Core event kinematics and counts.
OBSERVABLES.update({
    "Z0_mass": _obs(np.linspace(60, 120, 31), r"$m_{Z_0}$ [GeV]"),
    "Z0_pt": _pt_obs(r"$p_T^{Z_0}$ [GeV]", high=250.0),
    "Z0_eta": _eta_obs(r"$\eta^{Z_0}$", max_abs=5.0),
    "Z0_phi": _phi_obs(r"$\phi^{Z_0}$"),
    "X_mass": _obs(np.linspace(0, 160, 33), r"$m_{X}$ [GeV]"),
    "X_pt": _pt_obs(r"$p_T^{X}$ [GeV]", high=250.0),
    "X_eta": _eta_obs(r"$\eta^{X}$", max_abs=5.0),
    "X_phi": _phi_obs(r"$\phi^{X}$"),
    "m4l": _obs(np.linspace(70, 350, 41), r"$m_{4\ell}$ [GeV]"),
    "pT4l": _obs(np.linspace(0, 250, 41), r"$p_{\mathrm{T}}^{4\ell}$ [GeV]"),
    "phi4l": _phi_obs(r"$\phi^{4\ell}$"),
    "PuppiMET_pt": _obs(np.linspace(0, 120, 31), r"$p_{\mathrm{T}}^{\mathrm{miss}}$ [GeV]"),
    "PuppiMET_phi": _phi_obs(r"$\phi^{\mathrm{miss}}$"),
    "PuppiMET_significance": _obs(np.linspace(0, 80, 41), r"$p_T^{\mathrm{miss}}$ significance"),
    "PuppiMET_sumEt": _obs(np.linspace(0, 1200, 49), r"$\sum E_T^{\mathrm{miss}}$ [GeV]"),
    "HT": _obs(np.linspace(0, 600, 41), r"$H_T$ [GeV]"),
    "nCleanJet": _count_obs(r"$N_{\mathrm{clean\ jet}}$", max_count=10),
    "nJetInHorn": _obs(np.arange(-0.5, 5.5, 1.0), r"$N_{\mathrm{jet}}$ in HEM horn"),
    "sumLeptonCharge": _obs(np.arange(-4.5, 5.5, 1.0), r"$\sum q_{\ell}$"),
})

# MC truth MET.  These are useful for MC validation; data fallbacks are defined
# upstream when the trees are produced.
# OBSERVABLES.update({
#     "GenMET_pt": _obs(np.linspace(0, 200, 41), r"generator $p_T^{\mathrm{miss}}$ [GeV]"),
#     "GenMET_phi": _phi_obs(r"generator $\phi^{\mathrm{miss}}$"),
# })

# MET angular separations and pair-lepton angular observables.
for target in ("Z", "X", "lZ1", "lZ2", "lX1", "lX2", "ZplusX"):
    OBSERVABLES[f"dPhi_MET_{target}"] = _phi_obs(rf"$\Delta\phi(p_T^{{miss}}, {target})$")

for lep_a, lep_b in LEPTON_PAIRS:
    OBSERVABLES[f"dPhi_{lep_a}_{lep_b}"] = _phi_obs(rf"$\Delta\phi({lep_a}, {lep_b})$")
    OBSERVABLES[f"dEta_{lep_a}_{lep_b}"] = _obs(np.linspace(-5.0, 5.0, 41), rf"$\Delta\eta({lep_a}, {lep_b})$", ratio_ylim=_WIDE_RATIO_YLIM)
    OBSERVABLES[f"dR_{lep_a}_{lep_b}"] = _obs(np.linspace(0.0, 6.0, 31), rf"$\Delta R({lep_a}, {lep_b})$", ratio_ylim=_WIDE_RATIO_YLIM)

# Recoil components.
OBSERVABLES.update({
    "recoil_ux": _obs(np.linspace(-250, 250, 51), r"$u_x$ [GeV]", ratio_ylim=_WIDE_RATIO_YLIM),
    "recoil_uy": _obs(np.linspace(-250, 250, 51), r"$u_y$ [GeV]", ratio_ylim=_WIDE_RATIO_YLIM),
    "recoil_ut": _obs(np.linspace(0, 250, 41), r"$u_T$ [GeV]", ratio_ylim=_WIDE_RATIO_YLIM),
    "recoil_upar": _obs(np.linspace(-250, 250, 51), r"$u_{\parallel}$ [GeV]", ratio_ylim=_WIDE_RATIO_YLIM),
    "recoil_uperp": _obs(np.linspace(-250, 250, 51), r"$u_{\perp}$ [GeV]", ratio_ylim=_WIDE_RATIO_YLIM),
})

# Per-lepton kinematics.
for lep in LEPTON_LABELS:
    OBSERVABLES.update({
        f"{lep}_pt": _pt_obs(rf"$p_T^{{{lep}}}$ [GeV]", high=250.0),
        f"{lep}_eta": _eta_obs(rf"$\eta^{{{lep}}}$"),
        f"{lep}_phi": _phi_obs(rf"$\phi^{{{lep}}}$"),
        f"{lep}_charge": _obs(np.arange(-1.5, 2.5, 1.0), rf"charge({lep})"),
        # f"{lep}_genPt": _pt_obs(rf"generator $p_T^{{{lep}}}$ [GeV]", high=250.0),
        # f"{lep}_genEta": _eta_obs(rf"generator $\eta^{{{lep}}}$"),
        # f"{lep}_genPhi": _phi_obs(rf"generator $\phi^{{{lep}}}$"),
    })


# Trigger-path and trigger-object matching observables.
# The aggregate Trigger_* flags used by the ZZ_CR production are unpacked below
# into the actual HLT paths from mkShapesRDF.processor.data.TrigMaker_cfg for
# the active 2024 Run-3 era (Full2024v15 in zzcr_year_config.json).  The path
# branches are kept as observables so every trigger-path category can also plot
# the path bit itself.  The l*_trigObj_bits4l branch is the compact per-lepton
# trigger-object match mask produced in ZZ_CR/aliases.py; zero means no stored
# matched trigger object/leg for that selected lepton.
_FLAG_OBSERVABLES = {
    "Trigger_ElMu": "aggregate e$\\mu$ trigger OR",
    "Trigger_sngMu": "aggregate single-$\\mu$ trigger OR",
    "Trigger_dblMu": "aggregate double-$\\mu$ trigger OR",
    "Trigger_sngEl": "aggregate single-e trigger OR",
    "Trigger_dblEl": "aggregate double-e trigger OR",
    "Z0_isEE": r"$Z_0\to ee$ flag",
    "Z0_isMM": r"$Z_0\to \mu\mu$ flag",
    "X_isEE": r"$X\to ee$ flag",
    "X_isMM": r"$X\to \mu\mu$ flag",
    "bVeto": "b-veto flag",
    "PassesZZCR4lOrderedPt": "ordered 4l $p_T$ flag",
}
for name, label in _FLAG_OBSERVABLES.items():
    OBSERVABLES[name] = _obs(np.arange(-0.5, 2.5, 1.0), label)

TRIGGER_PATHS = OrderedDict({
    # Trigger_ElMu = OR of these three paths in Full2024v15 TrigMaker_cfg.
    "HLT_Mu23_TrkIsoVVL_Ele12_CaloIdL_TrackIdL_IsoVL": {
        "family": "EleMu",
        "aggregate": "Trigger_ElMu",
        "title": r"HLT $\mu23e12$",
    },
    "HLT_Mu12_TrkIsoVVL_Ele23_CaloIdL_TrackIdL_IsoVL_DZ": {
        "family": "EleMu",
        "aggregate": "Trigger_ElMu",
        "title": r"HLT $\mu12e23$ DZ",
    },
    "HLT_Mu8_TrkIsoVVL_Ele23_CaloIdL_TrackIdL_IsoVL_DZ": {
        "family": "EleMu",
        "aggregate": "Trigger_ElMu",
        "title": r"HLT $\mu8e23$ DZ",
    },
    # Trigger_dblMu / Trigger_sngMu / Trigger_dblEl / Trigger_sngEl.
    "HLT_Mu17_TrkIsoVVL_Mu8_TrkIsoVVL_DZ_Mass3p8": {
        "family": "DoubleMu",
        "aggregate": "Trigger_dblMu",
        "title": r"HLT $\mu17\mu8$ DZ Mass3p8",
    },
    "HLT_IsoMu24": {
        "family": "SingleMu",
        "aggregate": "Trigger_sngMu",
        "title": r"HLT IsoMu24",
    },
    "HLT_Ele23_Ele12_CaloIdL_TrackIdL_IsoVL": {
        "family": "DoubleEle",
        "aggregate": "Trigger_dblEl",
        "title": r"HLT Ele23Ele12",
    },
    "HLT_Ele30_WPTight_Gsf": {
        "family": "SingleEle",
        "aggregate": "Trigger_sngEl",
        "title": r"HLT Ele30 WPTight",
    },
})

for path_name, path_cfg in TRIGGER_PATHS.items():
    OBSERVABLES[path_name] = _obs(np.arange(-0.5, 2.5, 1.0), path_cfg["title"])

for lep in LEPTON_LABELS:
    OBSERVABLES[f"{lep}_pdgId"] = _obs(np.arange(-25.5, 26.5, 1.0), rf"PDG ID({lep})", ratio_ylim=_WIDE_RATIO_YLIM)
    OBSERVABLES[f"{lep}_selWP_TotSF"] = _obs(np.linspace(0.0, 2.0, 41), rf"selected-WP total SF({lep})", ratio_ylim=_WIDE_RATIO_YLIM)
    OBSERVABLES[f"{lep}_trigObj_pt"] = _obs(np.linspace(-0.5, 120.5, 122), rf"matched trigger-object $p_T$({lep}) [GeV]", ratio_ylim=_WIDE_RATIO_YLIM)
    OBSERVABLES[f"{lep}_trigObj_eta"] = _eta_obs(rf"matched trigger-object $\eta$({lep})")
    OBSERVABLES[f"{lep}_trigObj_phi"] = _phi_obs(rf"matched trigger-object $\phi$({lep})")
    OBSERVABLES[f"{lep}_trigObj_pdgId"] = _obs(np.arange(-15.5, 16.5, 1.0), rf"matched trigger-object PDG ID({lep})", ratio_ylim=_WIDE_RATIO_YLIM)
    OBSERVABLES[f"{lep}_trigObj_filterBits"] = _obs(np.linspace(-0.5, 2**20 - 0.5, 65), rf"matched trigger-object filter bits({lep})", ratio_ylim=_WIDE_RATIO_YLIM)
    OBSERVABLES[f"{lep}_trigObj_bits4l"] = _obs(np.arange(-0.5, 16.5, 1.0), rf"4$\ell$ trigger-match bit mask({lep})")

# Tight-object flags from the selected Run-3 lepton IDs.  The active ZZ_CR year
# uses electron WP mvaWinter22V2Iso_WP90_tthMVA_Run3 and muon WP
# cut_TightID_pfIsoTight_HWW_tthmva_67.  The base variables below are the
# quantities entering those WPs in LeptonSel_cfg.py (MVA scores, isolations,
# impact parameters, conversion/tight-ID flags, etc.).  They are registered with
# the scalar per-selected-lepton branch names expected in postprocessed trees
# that retain/derive these inputs; if an older tree lacks them, either rerun the
# postprocessing with these branches or trim execution.default_observables.
ELECTRON_TIGHT_WPS = (
    "wp90iso",
    "mvaWinter22V2Iso_WP90",
    "mvaWinter22V2Iso_WP90_tthMVA_Run3",
    "mvaWinter22V2Iso_WP90_tthMVA_HWW",
    "cutBased_MediumID_tthMVA_Run3",
    "cutBased_MediumID_tthMVA_HWW",
    "testrecipes",
)
MUON_TIGHT_WPS = (
    "cut_TightID_pfIsoLoose_HWW_PNet",
    "cut_TightID_pfIsoTight_HWW_tthmva_67",
    "cut_TightID_pfIsoLoose_HWW_tthmva_67",
    "cut_Tight_HWW",
    "cut_TightID_POG",
    "cut_TightID_pfIsoLoose_HWW_tthmva_HWW",
)
for wp in ELECTRON_TIGHT_WPS:
    OBSERVABLES[f"nTightElectron_{wp}"] = _count_obs(rf"$N_{{tight\ e}}$ ({wp})", max_count=4)
for wp in MUON_TIGHT_WPS:
    OBSERVABLES[f"nTightMuon_{wp}"] = _count_obs(rf"$N_{{tight\ \mu}}$ ({wp})", max_count=4)

for lep in LEPTON_LABELS:
    for wp in ELECTRON_TIGHT_WPS:
        OBSERVABLES[f"{lep}_isTightElectron_{wp}"] = _obs(np.arange(-0.5, 2.5, 1.0), rf"{lep} tight e ({wp})")
    for wp in MUON_TIGHT_WPS:
        OBSERVABLES[f"{lep}_isTightMuon_{wp}"] = _obs(np.arange(-0.5, 2.5, 1.0), rf"{lep} tight $\mu$ ({wp})")

ID_BASE_OBSERVABLES = OrderedDict({
    "mvaIso_WP90": _obs(np.arange(-0.5, 2.5, 1.0), "electron MVAIso WP90 flag"),
    "convVeto": _obs(np.arange(-0.5, 2.5, 1.0), "electron conversion veto"),
    "pfRelIso03_all": _obs(np.linspace(0.0, 0.30, 31), "electron PF relIso03 all"),
    "promptMVA": _obs(np.linspace(-1.0, 1.0, 41), "prompt/tth MVA score"),
    "dxy": _obs(np.linspace(-0.12, 0.12, 49), "transverse impact parameter dxy [cm]", ratio_ylim=_WIDE_RATIO_YLIM),
    "dz": _obs(np.linspace(-0.25, 0.25, 51), "longitudinal impact parameter dz [cm]", ratio_ylim=_WIDE_RATIO_YLIM),
    "sieie": _obs(np.linspace(0.0, 0.06, 49), r"electron $\sigma_{i\eta i\eta}$", ratio_ylim=_WIDE_RATIO_YLIM),
    "hoe": _obs(np.linspace(0.0, 0.20, 41), "electron H/E", ratio_ylim=_WIDE_RATIO_YLIM),
    "eInvMinusPInv": _obs(np.linspace(-0.20, 0.20, 41), r"electron $1/E-1/p$", ratio_ylim=_WIDE_RATIO_YLIM),
    "lostHits": _obs(np.arange(-0.5, 5.5, 1.0), "electron lost hits"),
    "tightId": _obs(np.arange(-0.5, 2.5, 1.0), "muon tight ID"),
    "pfIsoId": _obs(np.arange(-0.5, 8.5, 1.0), "muon PF iso ID"),
    "pfRelIso04_all": _obs(np.linspace(0.0, 0.50, 51), "muon PF relIso04 all", ratio_ylim=_WIDE_RATIO_YLIM),
    "sip3d": _obs(np.linspace(0.0, 8.0, 41), "3D impact-parameter significance", ratio_ylim=_WIDE_RATIO_YLIM),
    "jetRelIso": _obs(np.linspace(0.0, 1.0, 41), "lepton jet-relative isolation", ratio_ylim=_WIDE_RATIO_YLIM),
    "jetPtRelv2": _obs(np.linspace(0.0, 80.0, 41), r"lepton $p_T^{rel}$ to jet [GeV]", ratio_ylim=_WIDE_RATIO_YLIM),
})
for lep in LEPTON_LABELS:
    for suffix, obs_cfg in ID_BASE_OBSERVABLES.items():
        OBSERVABLES[f"{lep}_{suffix}"] = dict(obs_cfg, xlabel=rf"{lep} {obs_cfg['xlabel']}")

# # Event-level tight-object multiplicities plus per-lepton WP flags are
# # registered so the default batch covers the full ntuple observable menu.
# ELECTRON_TIGHT_WPS = (
#     "testrecipes",
#     "wp90iso",
#     "mvaWinter22V2Iso_WP90",
#     "cutBased_LooseID_tthMVA_Run3",
#     "cutBased_LooseID_tthMVA_HWW",
# )
# MUON_TIGHT_WPS = (
#     "cut_TightID_POG",
#     "cut_Tight_HWW",
#     "cut_TightID_pfIsoTight_HWW_tthmva_67",
#     "cut_TightID_pfIsoLoose_HWW_tthmva_67",
#     "cut_TightID_pfIsoLoose_HWW_tthmva_HWW",
# )
# for wp in ELECTRON_TIGHT_WPS:
#     OBSERVABLES[f"nTightElectron_{wp}"] = _count_obs(rf"$N_{{tight\ e}}$ ({wp})", max_count=4)
# for wp in MUON_TIGHT_WPS:
#     OBSERVABLES[f"nTightMuon_{wp}"] = _count_obs(rf"$N_{{tight\ \mu}}$ ({wp})", max_count=4)

# # Include the cut/helper branches as diagnostic observables too.  The default
# # batch is meant to plot every registered ntuple observable; keeping these out
# # of OBSERVABLES made the all-observable mode silently incomplete.
# _FLAG_OBSERVABLES = {
#     "Trigger_ElMu": "HLT e/mu",
#     "Trigger_sngMu": "single-mu trigger",
#     "Trigger_dblMu": "double-mu trigger",
#     "Trigger_sngEl": "single-e trigger",
#     "Trigger_dblEl": "double-e trigger",
#     "Z0_isEE": r"$Z_0\to ee$ flag",
#     "Z0_isMM": r"$Z_0\to \mu\mu$ flag",
#     "X_isEE": r"$X\to ee$ flag",
#     "X_isMM": r"$X\to \mu\mu$ flag",
#     "bVeto": "b-veto flag",
#     "PassesZZCR4lOrderedPt": "ordered 4l pT flag",
# }
# for name, label in _FLAG_OBSERVABLES.items():
#     OBSERVABLES[name] = _obs(np.arange(-0.5, 2.5, 1.0), label)

# for lep in LEPTON_LABELS:
#     OBSERVABLES[f"{lep}_pdgId"] = _obs(np.arange(-25.5, 26.5, 1.0), rf"PDG ID({lep})", ratio_ylim=_WIDE_RATIO_YLIM)
#     OBSERVABLES[f"{lep}_genPdgId"] = _obs(np.arange(-25.5, 26.5, 1.0), rf"generator PDG ID({lep})", ratio_ylim=_WIDE_RATIO_YLIM)
#     OBSERVABLES[f"{lep}_selWP_TotSF"] = _obs(np.linspace(0.0, 2.0, 41), rf"selected-WP total SF({lep})", ratio_ylim=_WIDE_RATIO_YLIM)
#     for wp in ELECTRON_TIGHT_WPS:
#         OBSERVABLES[f"{lep}_isTightElectron_{wp}"] = _obs(np.arange(-0.5, 2.5, 1.0), rf"{lep} tight e ({wp})")
#     for wp in MUON_TIGHT_WPS:
#         OBSERVABLES[f"{lep}_isTightMuon_{wp}"] = _obs(np.arange(-0.5, 2.5, 1.0), rf"{lep} tight $\mu$ ({wp})")

# OBSERVABLES["weight"] = _obs(np.linspace(-5.0, 5.0, 101), "nominal event weight", ratio_ylim=_WIDE_RATIO_YLIM)

# Leading two clean jets and their matched generator jets.
for jet_idx in range(2):
    OBSERVABLES.update({
        f"CleanJet_pt_{jet_idx}": _pt_obs(rf"clean jet {jet_idx} $p_T$ [GeV]", high=250.0),
        f"CleanJet_eta_{jet_idx}": _eta_obs(rf"clean jet {jet_idx} $\eta$", max_abs=5.0),
        f"CleanJet_phi_{jet_idx}": _phi_obs(rf"clean jet {jet_idx} $\phi$"),
        f"CleanJet_genPt_{jet_idx}": _pt_obs(rf"matched gen jet {jet_idx} $p_T$ [GeV]", high=250.0),
        f"CleanJet_genEta_{jet_idx}": _eta_obs(rf"matched gen jet {jet_idx} $\eta$", max_abs=5.0),
        f"CleanJet_genPhi_{jet_idx}": _phi_obs(rf"matched gen jet {jet_idx} $\phi$"),
    })


SAMPLE_STYLE = {
    "defaults": {"title": None, "color": None},
    "groups": {
        "DY_EE": {"title": r"$Z\to ee$", "color": "#4e79a7"},
        "DY_MM": {"title": r"$Z\to \mu\mu$", "color": "#f28e2b"},
        "DY_TT": {"title": r"$Z\to \tau\tau$", "color": "#76b7b2"},
    },
    "samples": {
        "DATA": {"title": "Data", "color": "black"},
        "DYto2E-2Jets_MLL-10to50": {"title": "", "group": "DY_EE"},
        "DYto2E-2Jets_MLL-50": {"title": "", "group": "DY_EE"},
        "DYto2Mu-2Jets_MLL-10to50": {"title": "", "group": "DY_MM"},
        "DYto2Mu-2Jets_MLL-50": {"title": "", "group": "DY_MM"},
        "DYto2Tau-2Jets_MLL-10to50": {"title": "", "group": "DY_TT"},
        "DYto2Tau-2Jets_MLL-50": {"title": "", "group": "DY_TT"},
        "ZZ": {"title": r"$ZZ$", "color": "#e15759"},
    },
}

# Physics categories for DY and ZZ studies, not a sequential cut flow.
# Baselines mirror ZZ_CR/cuts.py and aliases.py: the production preselection has
# already required the aggregate Trigger_* OR, nLepton>=2, L2TightLeading2, and
# the zz_cr_ALL tree is built from Z0_mass>30 plus lZ1/lZ2 pT>10.  The cuts here
# add study-region requirements and split by the actual HLT path branches used
# to build each aggregate Trigger_* flag in the active Run-3 TrigMaker config.
_CATEGORY_CUTS = {
    "DY_BASE": "(nJetInHorn == 0) && (Z0_mass > 30.) && (lZ1_pt > 10.) && (lZ2_pt > 10.)",
    "ZZ_BASE": "(nJetInHorn == 0) && (Z0_mass > 30.) && (lZ1_pt > 10.) && (lZ2_pt > 10.) && PassesZZCR4lOrderedPt && (abs(Z0_mass - 91.1876) < 15.) && (X_mass > 75.) && (X_mass < 105.) && bVeto && (PuppiMET_pt < 35.)",
}

_FLAVOR_CATEGORIES = OrderedDict({
    "zmm": {"title": r"$Z_0\to\mu\mu$", "cut": "Z0_isMM"},
    "zee": {"title": r"$Z_0\to ee$", "cut": "Z0_isEE"},
    "zmm_xmm": {"title": r"$Z_0\to\mu\mu, X\to\mu\mu$", "cut": "Z0_isMM && X_isMM"},
    "zmm_xee": {"title": r"$Z_0\to\mu\mu, X\to ee$", "cut": "Z0_isMM && X_isEE"},
    "zee_xmm": {"title": r"$Z_0\to ee, X\to\mu\mu$", "cut": "Z0_isEE && X_isMM"},
    "zee_xee": {"title": r"$Z_0\to ee, X\to ee$", "cut": "Z0_isEE && X_isEE"},
})

def _trigger_safe_name(path_name):
    name = path_name.removeprefix("HLT_")
    safe = ''.join(c if c.isalnum() or c in ('-', '_') else '_' for c in str(name))
    while '__' in safe:
        safe = safe.replace('__', '_')
    return (safe.strip('_') or 'trigger').lower()

def _trigger_subtitle(path_name, path_cfg):
    aggregate = path_cfg["aggregate"]
    return f"actual path {path_name}; aggregate flag {aggregate}; family {path_cfg['family']}"

def _build_trigger_path_categories():
    subcats = OrderedDict()
    for region_key, region_title in (("DY", "DY seed"), ("ZZ", "ZZ control region")):
        base_cut = _CATEGORY_CUTS[f"{region_key}_BASE"]
        flavors = ("zmm", "zee") if region_key == "DY" else tuple(_FLAVOR_CATEGORIES.keys())
        for flavor_key in flavors:
            flavor_cfg = _FLAVOR_CATEGORIES[flavor_key]
            for path_name, path_cfg in TRIGGER_PATHS.items():
                subcat_name = f"{region_key.lower()}_{flavor_key}__{_trigger_safe_name(path_name)}"
                subcats[subcat_name] = {
                    "title": f"{region_title}: {flavor_cfg['title']} ({path_cfg['title']})",
                    "subtitle": _trigger_subtitle(path_name, path_cfg),
                    "cut": f"({base_cut}) && ({flavor_cfg['cut']}) && ({path_name})",
                }
    return subcats

CATEGORY_CONFIG = {
    "zz_cr_ALL": {
       "title": r"DY and ZZ selections split by HLT path",
       "subtitle": "Direct study categories (no cut flow); includes Z→ee/μμ and ZZ cross-flavour splits",
       "subcategories": _build_trigger_path_categories(),
    }
}

# %%
# =========================
# CORE ENGINE
# =========================

_LOG_STATE = {"last": None}

def _cut_preview(cut_expr):
    txt = _normalize_cut(cut_expr)
    if not txt:
        return "<none>"
    txt = re.sub(r"\s+", " ", txt).strip()
    mx = int(_cfg("logging", "max_cut_preview", default=120))
    if len(txt) > mx:
        return txt[:mx - 3] + "..."
    return txt


def _log(msg, level="info"):
    if not _cfg("logging", "enabled", default=True):
        return
    lvl = str(level).upper()
    hacker = bool(_cfg("logging", "hacker_style", default=True))
    prefix = f"[{lvl}]" if not hacker else f"[{lvl:>5}]"

    ts = ""
    if bool(_cfg("logging", "show_timestamp", default=True)):
        fmt = _cfg("logging", "timestamp_fmt", default="%Y-%m-%d %H:%M:%S")
        use_utc = bool(_cfg("logging", "timestamp_utc", default=True))
        now = datetime.now(timezone.utc) if use_utc else datetime.now()
        ts = now.strftime(fmt)
        ts = f"[{ts}] "

    line = f"{ts}{prefix} {msg}"

    if bool(_cfg("logging", "dedupe_repeated", default=True)):
        key = (lvl, str(msg))
        if _LOG_STATE.get("last") == key:
            return
        _LOG_STATE["last"] = key

    print(line, flush=True)



def _memory_rss_mb():
    if not bool(_cfg("profiling", "print_memory", default=False)):
        return None
    try:
        import psutil
    except Exception:
        return None
    try:
        return float(psutil.Process(os.getpid()).memory_info().rss) / 1024.0 / 1024.0
    except Exception:
        return None


@contextmanager
def _timer(label, enabled=None, collector=None, key=None, level="debug"):
    active = bool(_cfg("profiling", "enabled", default=True)) if enabled is None else bool(enabled)
    if not active:
        yield None
        return
    t0 = time.perf_counter()
    try:
        yield None
    finally:
        dt = time.perf_counter() - t0
        if collector is not None:
            collector[key or label] = collector.get(key or label, 0.0) + dt
        mem = _memory_rss_mb()
        mem_txt = f" rss={mem:.0f}MB" if mem is not None else ""
        _log(f"timing {label}: {dt:.2f}s{mem_txt}", level=level)


def _progress_bar(i, n, width=None):
    width = int(width or _cfg("logging", "progress_bar_width", default=28))
    width = max(8, width)
    if not n:
        return "[" + "-" * width + "]"
    frac = min(1.0, max(0.0, float(i) / float(n)))
    filled = int(round(width * frac))
    return "[" + "#" * filled + "-" * (width - filled) + "]"


def _progress(stage, i, n, extra=""):
    if not _cfg("logging", "progress_enabled", default=True):
        return
    every_default = _cfg("profiling", "progress_every_chunks", default=None) if "chunk" in str(stage).lower() else None
    every = max(1, int(every_default if every_default is not None else _cfg("logging", "progress_every", default=25)))
    unknown_total = n is None or int(n or 0) <= 0
    if i not in {0, 1, n} and i % every != 0:
        return
    if unknown_total:
        _log(f"{stage}: chunks={i} {extra}", level="progress")
        return
    frac = 100.0 * i / n
    bar = _progress_bar(i, n)
    _log(f"{stage}: {bar} {i}/{n} ({frac:.1f}%) {extra}", level="progress")


def _sanitize(name):
    safe = ''.join(c if c.isalnum() or c in ('-', '_') else '_' for c in str(name))
    while '__' in safe:
        safe = safe.replace('__', '_')
    return safe.strip('_') or 'plot'


def _cfg(*path, default=None):
    node = ANALYSIS_CONFIG
    for p in path:
        if not isinstance(node, dict) or p not in node:
            return default
        node = node[p]
    return node


def _detect_input_mode(path, mode="auto"):
    mode = str(mode).lower().strip()
    if mode in {"merged", "unmerged"}:
        return mode
    if os.path.isdir(path) or any(ch in str(path) for ch in "*?[]"):
        return "unmerged"
    return "merged"


def _discover_input_files(path, mode="auto", unmerged_glob="*.root"):
    resolved = _detect_input_mode(path, mode)
    if resolved == "merged":
        if not os.path.isfile(path):
            raise FileNotFoundError(f"Missing merged ROOT file: {path}")
        return resolved, [path]

    if os.path.isdir(path):
        files = sorted(glob.glob(os.path.join(path, unmerged_glob)))
    else:
        files = sorted(glob.glob(path))
    files = [x for x in files if x.endswith(".root") and os.path.isfile(x)]
    if not files:
        raise FileNotFoundError(f"No ROOT files found for unmerged input: {path}")
    return resolved, files


def _unique_paths(paths):
    """Return unique filesystem paths preserving order, deduping by realpath."""
    out = []
    seen = set()
    for p in paths or []:
        rp = os.path.realpath(p)
        if rp in seen:
            continue
        seen.add(rp)
        out.append(p)
    return out


def _extract_category_process_from_filename(root_file):
    base = os.path.basename(root_file)
    stem = re.sub(r"\.root$", "", base)
    parts = stem.split("__")
    category = parts[-2] if len(parts) >= 2 else "*"
    payload = parts[-1] if parts else stem
    process = re.sub(ANALYSIS_CONFIG["filters"].get("filename_process_strip_pattern", r"_\d+$"), "", payload)
    return (category or "*"), process


def _build_unmerged_index(root_files):
    index = {}
    _progress("index files", 0, len(root_files), "mode=unmerged")
    for i, rf in enumerate(root_files, 1):
        category, proc = _extract_category_process_from_filename(rf)
        index.setdefault(category, {}).setdefault(proc, []).append(rf)
        index.setdefault("*", {}).setdefault(proc, []).append(rf)
        _progress("index files", i, len(root_files), f"mode=unmerged file={os.path.basename(rf)}")
    for cat in list(index):
        for proc in list(index[cat]):
            index[cat][proc] = sorted(set(index[cat][proc]))
    return index

def _normalize_cut(cut_expr):
    expr = str(cut_expr or "").strip()
    if not expr:
        return ""
    expr = re.sub(r"(?<![&])&(?![&])", "&&", expr)
    expr = re.sub(r"(?<![|])\|(?![|])", "||", expr)
    return expr

def _cut_to_pandas(cut_expr):
    expr = _normalize_cut(cut_expr)
    if not expr:
        return ""
    expr = expr.replace("&&", " and ").replace("||", " or ")
    expr = re.sub(r"(?<![=!<>])!(?!=)", " not ", expr)
    return expr



def _validate_cut_expression(cut_expr):
    expr = _normalize_cut(cut_expr)
    if not expr:
        return expr
    if not bool(_cfg("runtime", "strict_cut_syntax", default=False)):
        return expr
    pat = _cfg("runtime", "strict_cut_allowed_pattern", default=r"^[A-Za-z0-9_\s\(\)\.><=+\-*/!&|,:]*$")
    if not re.match(pat, expr):
        raise ValueError(f"Cut expression contains unsupported syntax: {expr}")
    return expr

def _pick_eval_engine():
    # Keep eval-engine configurable, defaulting to safe python semantics.
    engine = str(_cfg("runtime", "cut_eval_engine", default="python")).lower().strip()
    return engine if engine in {"python", "numexpr"} else "python"


def _evaluate_cut_mask(arrays, cut_expr):
    # Fast path: evaluate directly on numpy arrays (avoids DataFrame materialization).
    _validate_cut_expression(cut_expr)
    expr = _cut_to_pandas(cut_expr)
    if not expr:
        return None
    if not arrays:
        return np.array([], dtype=bool)

    try:
        mask = pd.eval(expr, local_dict=arrays, engine=_pick_eval_engine())
    except Exception as exc:
        # Optional compatibility fallback; disabled by default to avoid large memory duplication.
        if bool(_cfg("runtime", "allow_dataframe_cut_fallback", default=False)):
            _log("Cut eval fell back to DataFrame.eval; this may increase memory usage", level="warn")
            mask = pd.DataFrame(arrays).eval(expr, engine="python")
        else:
            raise RuntimeError(
                "Cut evaluation failed without DataFrame fallback. "
                "Set runtime.allow_dataframe_cut_fallback=True if needed. "
                f"expr={expr} error={exc}"
            ) from exc

    mask = np.asarray(mask, dtype=bool)
    if mask.ndim != 1:
        raise ValueError(f"Cut mask must be 1D, got shape={mask.shape}")
    return mask


def _filter_arrays_with_cut(arrays, cut_expr):
    # Shared cut application used everywhere for consistent behavior.
    mask = _evaluate_cut_mask(arrays, cut_expr)
    if mask is None:
        return arrays
    if mask.size == 0:
        return {k: np.asarray(v)[:0] for k, v in arrays.items()}
    return {k: np.asarray(v)[mask] for k, v in arrays.items()}

def _extract_cut_branches(cut_expr):
    _validate_cut_expression(cut_expr)
    toks = set(re.findall(r"\b[A-Za-z_][A-Za-z0-9_]*\b", _normalize_cut(cut_expr)))
    keywords = {
        "and", "or", "not", "true", "false", "abs", "sqrt", "pow", "min", "max", "int", "float", "double"
    }
    return {t for t in toks if t.lower() not in keywords and not t.isdigit()}

def _resolve_requested_branches(required, available):
    resolved = {}
    for b in sorted(set(required)):
        cands = [b] + list(BRANCH_ALIASES.get(b, []))
        src = next((c for c in cands if c in available), None)
        if src is not None:
            resolved[b] = src
    return resolved


def _missing_resolved(required, resolved):
    return sorted(b for b in set(required or []) if b not in set(resolved or {}))


def _handle_missing_critical(missing, context, raise_default=True):
    if not missing:
        return
    msg = f"Missing critical branch(es) {sorted(missing)} for {context}"
    if bool(_cfg("diagnostics", "raise_on_missing_critical_branch", default=raise_default)):
        raise KeyError(msg)
    _log(msg, level="error")


def _validate_array_lengths(arrays, context, raise_default=True):
    if not bool(_cfg("diagnostics", "validate_array_lengths", default=True)):
        return True
    if not arrays:
        return True
    lengths = {k: len(np.asarray(v)) for k, v in arrays.items()}
    unique = sorted(set(lengths.values()))
    if len(unique) <= 1:
        return True
    preview = dict(list(lengths.items())[:12])
    msg = f"Array length mismatch for {context}: lengths={unique} preview={preview}"
    if bool(_cfg("diagnostics", "raise_on_array_length_mismatch", default=raise_default)):
        raise ValueError(msg)
    _log(msg, level="error")
    return False


def _branch_seed_from_config():
    seed = set(_cfg("runtime", "explicit_branch_seed", default=[] ) or [])
    seed |= set(globals().get("ALWAYS_LOAD_BRANCHES", []) or [])
    if bool(_cfg("runtime", "auto_include_all_observables_in_seed", default=False)):
        seed |= set(OBSERVABLES.keys())
    weight_branch = _cfg("physics", "mc_weight_branch")
    if isinstance(weight_branch, str) and weight_branch.strip():
        seed.add(weight_branch)
    return {x for x in seed if isinstance(x, str) and x.strip()}


def _validate_observables(observables):
    known = []
    unknown = []
    for o in (observables or []):
        if o in OBSERVABLES:
            known.append(o)
        else:
            unknown.append(o)

    policy = str(_cfg("runtime", "unknown_observable_policy", default="warn")).lower().strip()
    if policy not in {"warn", "ignore", "error"}:
        policy = "warn"

    if unknown:
        if policy == "error":
            raise KeyError(f"Unknown observables requested: {sorted(set(unknown))}")
        if policy == "warn":
            for u in sorted(set(unknown)):
                _log(f"Skipping unknown observable '{u}'", level="warn")

    return sorted(set(known))

def _plan_required_branches(observables, cut_expr="", include_seed=True):
    needed = set(_branch_seed_from_config()) if include_seed else set()
    needed |= set(observables or [])
    needed |= _extract_cut_branches(cut_expr)
    planned = sorted(needed)
    if bool(_cfg("runtime", "log_branch_plan", default=False)):
        seed_tag = "with_seed" if include_seed else "no_seed"
        _log(f"Branch plan ({seed_tag}): n={len(planned)} -> {planned}")
    return planned



def _validate_plot_style_keys(style_overrides, reference=None, prefix="plot_style"):
    """Warn on unknown style keys to catch misspellings in nested style overrides."""
    if not isinstance(style_overrides, dict):
        return
    reference = reference or PLOT_STYLE_DEFAULTS
    for key, val in style_overrides.items():
        path = f"{prefix}.{key}"
        if key not in reference:
            _log(f"Unknown style key: {path}", level="warn")
            continue
        if isinstance(val, dict) and isinstance(reference.get(key), dict):
            _validate_plot_style_keys(val, reference=reference.get(key), prefix=path)


def _validate_user_payloads(observables, category_config):
    if not isinstance(observables, dict) or not observables:
        raise ValueError("OBSERVABLES must be a non-empty dict")
    for name, cfg in observables.items():
        if not isinstance(cfg, dict) or "bins" not in cfg:
            raise ValueError(f"Observable '{name}' must define bins")
        bins = np.asarray(cfg["bins"], dtype=float)
        if bins.ndim != 1 or bins.size < 2:
            raise ValueError(f"Observable '{name}' bins must be 1D with at least 2 edges")
        if not np.all(np.isfinite(bins)):
            raise ValueError(f"Observable '{name}' bins must be finite")
        if not np.all(np.diff(bins) > 0):
            raise ValueError(f"Observable '{name}' bins must be strictly increasing")

    if not isinstance(category_config, dict) or not category_config:
        raise ValueError("CATEGORY_CONFIG must be a non-empty dict")
    for cat, cat_cfg in category_config.items():
        if not isinstance(cat_cfg, dict):
            raise ValueError(f"Category '{cat}' must map to a dict")
        sub = cat_cfg.get("subcategories", {})
        if not isinstance(sub, dict) or not sub:
            raise ValueError(f"Category '{cat}' must define at least one subcategory")
        _validate_plot_style_keys(cat_cfg.get("plot_style", {}), prefix=f"CATEGORY_CONFIG.{cat}.plot_style")
        for sub_name, sub_cfg in sub.items():
            if not isinstance(sub_cfg, dict):
                raise ValueError(f"Subcategory '{cat}.{sub_name}' must map to a dict")
            _validate_cut_expression(sub_cfg.get("cut", ""))
            _validate_plot_style_keys(sub_cfg.get("plot_style", {}), prefix=f"CATEGORY_CONFIG.{cat}.{sub_name}.plot_style")

def _validate_analysis_config(cfg):
    required_top = {"io", "physics", "runtime", "cache", "filters", "logging", "execution"}
    missing = sorted(required_top - set(cfg.keys()))
    if missing:
        raise KeyError(f"ANALYSIS_CONFIG missing required sections: {missing}")

    if str(_cfg("runtime", "array_branch_import_mode", default="needed")).lower() not in {"needed", "all"}:
        raise ValueError("runtime.array_branch_import_mode must be 'needed' or 'all'")
    if _data_loading_mode() not in {"memory", "direct"}:
        raise ValueError("runtime.data_loading_mode must be memory/arrays or direct/file/ssd")
    if int(_cfg("runtime", "direct_chunk_entries", default=20_000)) < 1:
        raise ValueError("runtime.direct_chunk_entries must be >= 1")
    direct_step_size = _cfg("runtime", "direct_step_size", default=None)
    if direct_step_size is not None and not isinstance(direct_step_size, (str, int, float)):
        raise ValueError("runtime.direct_step_size must be None, a memory-size string, or a numeric entry count")
    for key in ("direct_observable_batch_size", "direct_cut_batch_size"):
        value = _cfg("runtime", key, default=1)
        if isinstance(value, str) and value.lower().strip() == "all":
            continue
        if int(value) < 1:
            raise ValueError(f"runtime.{key} must be >= 1 or 'all'")
    for key in ("direct_process_workers", "direct_file_read_workers", "uproot_decompression_workers", "uproot_interpretation_workers"):
        if int(_cfg("runtime", key, default=1)) < 1:
            raise ValueError(f"runtime.{key} must be >= 1")
    if str(_cfg("runtime", "hist_fill_backend", default="bincount")).lower().strip() not in {"bincount", "histogram"}:
        raise ValueError("runtime.hist_fill_backend must be bincount/histogram")
    if not isinstance(_cfg("runtime", "hist_fill_validate_bincount", default=False), bool):
        raise ValueError("runtime.hist_fill_validate_bincount must be boolean")
    if not isinstance(_cfg("runtime", "zzcr_stage_engine", default=True), bool):
        raise ValueError("runtime.zzcr_stage_engine must be boolean")
    if int(_cfg("runtime", "plot_workers", default=1)) < 1:
        raise ValueError("runtime.plot_workers must be >= 1")
    if not isinstance(_cfg("runtime", "direct_use_threaded_io", default=False), bool):
        raise ValueError("runtime.direct_use_threaded_io must be boolean")
    if not isinstance(_cfg("runtime", "direct_timing_enabled", default=False), bool):
        raise ValueError("runtime.direct_timing_enabled must be boolean")
    if int(_cfg("runtime", "parallel_read_workers", default=1)) < 1:
        raise ValueError("runtime.parallel_read_workers must be >= 1")
    if str(_cfg("runtime", "parallel_profile", default="full_cpu")).lower().strip() not in {"full_cpu", "auto", "laptop", "shared", "batch"}:
        raise ValueError("runtime.parallel_profile must be full_cpu/auto/laptop/shared/batch")
    if str(_cfg("runtime", "hist_backend", default="numpy")).lower().strip() not in {"numpy", "boost_histogram"}:
        raise ValueError("runtime.hist_backend must be numpy/boost_histogram")
    if str(_cfg("runtime", "hist_production_backend", default="uproot")).lower().strip() not in {"uproot", "rdataframe_experimental"}:
        raise ValueError("runtime.hist_production_backend must be uproot/rdataframe_experimental")
    if not isinstance(_cfg("runtime", "fast_direct_mode", default=True), bool):
        raise ValueError("runtime.fast_direct_mode must be boolean")
    if not isinstance(_cfg("profiling", "enabled", default=True), bool):
        raise ValueError("profiling.enabled must be boolean")
    if str(_cfg("runtime", "unknown_observable_policy", default="warn")).lower().strip() not in {"warn", "ignore", "error"}:
        raise ValueError("runtime.unknown_observable_policy must be 'warn', 'ignore', or 'error'")
    if str(_cfg("runtime", "category_loading_strategy", default="preload_tree_uncut")).lower().strip() not in {"preload_tree_uncut", "preload_tree_or_subcategory_cut"}:
        raise ValueError("runtime.category_loading_strategy must be 'preload_tree_uncut' or 'preload_tree_or_subcategory_cut'")
    if str(_cfg("runtime", "preload_branch_strategy", default="union_all")).lower().strip() not in {"union_all", "per_observable_chunk"}:
        raise ValueError("runtime.preload_branch_strategy must be union_all/per_observable_chunk")
    if int(_cfg("cache", "max_entries", default=32)) < 1:
        raise ValueError("cache.max_entries must be >= 1")
    max_mb = _cfg("cache", "max_bytes_mb", default=4096)
    if max_mb is not None and float(max_mb) <= 0:
        raise ValueError("cache.max_bytes_mb must be > 0 when set")
    if str(_cfg("io", "output_file_ext", default="png")).strip() == "":
        raise ValueError("io.output_file_ext must be non-empty")


def run_static_diagnostics(raise_on_error=False, emit_log=True):
    """Run cheap notebook consistency checks that do not open ROOT files."""
    report = {"errors": [], "warnings": []}

    def err(msg):
        report["errors"].append(str(msg))

    def warn(msg):
        report["warnings"].append(str(msg))

    # Observable definitions: repeat the critical checks here so users can call
    # diagnostics independently of the bootstrap validation path.
    for name, cfg in (OBSERVABLES or {}).items():
        if not isinstance(cfg, dict) or "bins" not in cfg:
            err(f"Observable '{name}' must define a bins entry")
            continue
        try:
            bins = np.asarray(cfg["bins"], dtype=float)
            if bins.ndim != 1 or bins.size < 2:
                err(f"Observable '{name}' bins must be 1D with at least 2 edges")
            elif not np.all(np.isfinite(bins)):
                err(f"Observable '{name}' bins contain non-finite values")
            elif not np.all(np.diff(bins) > 0):
                err(f"Observable '{name}' bins must be strictly increasing")
        except Exception as exc:
            err(f"Observable '{name}' bins could not be converted to float: {exc}")

    default_obs = _cfg("execution", "default_observables")
    if default_obs is not None:
        unknown = sorted(set(default_obs) - set(OBSERVABLES.keys()))
        if unknown:
            err(f"execution.default_observables contains unknown observables: {unknown}")

    always = globals().get("ALWAYS_LOAD_BRANCHES", []) or []
    bad_always = [x for x in always if not isinstance(x, str) or not x.strip()]
    if bad_always:
        err(f"ALWAYS_LOAD_BRANCHES contains non-string/empty entries: {bad_always}")
    dup_always = sorted({x for x in always if always.count(x) > 1})
    if dup_always:
        warn(f"ALWAYS_LOAD_BRANCHES contains duplicate entries: {dup_always}")

    diag_bools = [
        "run_startup_static_checks",
        "raise_on_static_error",
        "run_startup_branch_checks",
        "raise_on_branch_error",
        "raise_on_missing_critical_branch",
        "validate_array_lengths",
        "raise_on_array_length_mismatch",
    ]
    for key in diag_bools:
        val = _cfg("diagnostics", key, default=False)
        if not isinstance(val, bool):
            err(f"diagnostics.{key} must be boolean, got {type(val).__name__}")
    try:
        if int(_cfg("diagnostics", "branch_check_max_files_per_proc", default=1)) < 1:
            err("diagnostics.branch_check_max_files_per_proc must be >= 1")
    except Exception as exc:
        err(f"diagnostics.branch_check_max_files_per_proc must be an integer: {exc}")

    mode = _data_loading_mode()
    if mode == "direct" and bool(_cfg("runtime", "auto_include_all_observables_in_seed", default=False)):
        warn("direct mode ignores most seed-branch benefits; consider disabling auto_include_all_observables_in_seed")

    if emit_log:
        for msg in report["warnings"]:
            _log(f"diagnostic warning: {msg}", level="warn")
        for msg in report["errors"]:
            _log(f"diagnostic error: {msg}", level="error")
        _log(f"Static diagnostics: errors={len(report['errors'])} warnings={len(report['warnings'])}")

    if report["errors"] and raise_on_error:
        raise RuntimeError("Static diagnostics failed: " + "; ".join(report["errors"]))
    return report


def _data_loading_mode():
    mode = str(_cfg("runtime", "data_loading_mode", default="memory")).lower().strip()
    if mode in {"arrays", "array", "in_memory", "on_memory", "ram"}:
        return "memory"
    if mode in {"direct", "file", "from_file", "stream", "streaming", "ssd"}:
        return "direct"
    return mode


def _config_snapshot():
    return {
        "mode": _cfg("io", "input_mode"),
        "input": _cfg("io", "input_path"),
        "output": _cfg("io", "output_dir"),
        "branch_mode": _cfg("runtime", "array_branch_import_mode", default="needed"),
        "data_loading_mode": _data_loading_mode(),
        "direct_chunk_entries": int(_cfg("runtime", "direct_chunk_entries", default=20_000)),
        "direct_step_size": _cfg("runtime", "direct_step_size", default=None),
        "direct_observable_batch_size": _cfg("runtime", "direct_observable_batch_size", default=2),
        "direct_cut_batch_size": _cfg("runtime", "direct_cut_batch_size", default=1),
        "reuse_uncut": bool(_cfg("runtime", "reuse_uncut_arrays_for_cuts", default=True)),
        "unknown_obs_policy": str(_cfg("runtime", "unknown_observable_policy", default="warn")),
        "seed_n": len(_cfg("runtime", "explicit_branch_seed", default=[] ) or []),
        "always_load_n": len(globals().get("ALWAYS_LOAD_BRANCHES", []) or []),
        "auto_seed_all_obs": bool(_cfg("runtime", "auto_include_all_observables_in_seed", default=False)),
        "parallel": bool(_cfg("runtime", "enable_parallel_read", default=True)),
        "detected_cpu_cores": max(1, cpu_count() or 1),
        "workers": int(_cfg("runtime", "parallel_read_workers", default=max(1, cpu_count() or 1))),
        "direct_process_workers": int(_cfg("runtime", "direct_process_workers", default=4)),
        "direct_file_workers": int(_cfg("runtime", "direct_file_read_workers", default=_cfg("runtime", "direct_process_workers", default=4))),
        "uproot_decompression_workers": int(_cfg("runtime", "uproot_decompression_workers", default=8)),
        "uproot_interpretation_workers": int(_cfg("runtime", "uproot_interpretation_workers", default=8)),
        "hist_fill_backend": str(_cfg("runtime", "hist_fill_backend", default="bincount")),
        "plot_workers": int(_cfg("runtime", "plot_workers", default=1)),
        "parallel_profile": str(_cfg("runtime", "parallel_profile", default="full_cpu")),
        "cache_arrays": bool(_cfg("cache", "arrays_in_memory", default=True)),
        "category_loading_strategy": str(_cfg("runtime", "category_loading_strategy", default="preload_tree_uncut")),
        "run_default_batch_cell": bool(_cfg("execution", "run_default_batch_cell", default=True)),
        "default_observables": "all" if _cfg("execution", "default_observables", default=None) is None else "custom",
        "default_observables_n": len(OBSERVABLES) if _cfg("execution", "default_observables", default=None) is None else len(_cfg("execution", "default_observables", default=[])),
        "produce_hist_cache": bool(_cfg("execution", "produce_hist_cache", default=True)),
        "plot_from_hist_cache": bool(_cfg("execution", "plot_from_hist_cache", default=True)),
        "hist_cache_schema_version": int(_cfg("execution", "hist_cache_schema_version", default=1)),
        "require_mc_histograms": bool(_cfg("execution", "require_mc_histograms", default=True)),
    }

def _hist_with_flows(values, bins, weights=None):
    x = np.asarray(values)
    if x.size == 0:
        return np.zeros(len(bins) - 1, dtype=float)
    lo = np.nextafter(bins[0], np.inf)
    hi = np.nextafter(bins[-1], -np.inf)
    x = np.clip(x, lo, hi)
    h, _ = np.histogram(x, bins=bins, weights=weights)
    return h


class StyleResolver:
    def __init__(self, sample_style, stack_by_group=True):
        self.sample_style = sample_style or {}
        self.stack_by_group = bool(stack_by_group)

    def _sample(self, name):
        return (self.sample_style.get("samples", {}) or {}).get(name, {})

    def _group(self, name):
        return (self.sample_style.get("groups", {}) or {}).get(name, {})

    def stack_key(self, sample):
        grp = self._sample(sample).get("group")
        return grp if self.stack_by_group and grp else sample

    def display_name(self, proc):
        g = self._group(proc)
        if self.stack_by_group and g.get("title"):
            return g["title"]
        s = self._sample(proc)
        if s.get("title"):
            return s["title"]
        grp = s.get("group")
        if grp and self._group(grp).get("title"):
            return self._group(grp)["title"]
        return proc

    def color(self, proc, idx=0):
        g = self._group(proc)
        if g.get("color"):
            return g["color"]
        s = self._sample(proc)
        if s.get("color"):
            return s["color"]
        grp = s.get("group")
        if grp and self._group(grp).get("color"):
            return self._group(grp)["color"]
        cycle = list(plt.cm.tab20.colors) + list(plt.cm.Set3.colors)
        return cycle[idx % len(cycle)]


class DataMCSession:
    """Interactive, cache-friendly analysis session for spontaneous cuts/plots."""

    def __init__(self):
        self.input_mode = None
        self.input_files = []
        self.unmerged_index = {}
        self.io_pool = None
        self.array_cache = OrderedDict()
        self.array_cache_bytes = 0
        self.uncut_base_cache = {}
        self._process_cache = {}
        self._tree_path_cache = {}
        self._branch_cache = {}
        self.style = StyleResolver(SAMPLE_STYLE, stack_by_group=_cfg("style_behavior", "stack_by_group", default=True))



    def _effective_workers(self):
        if not bool(_cfg("runtime", "enable_parallel_read", default=True)):
            return 1
        configured = max(1, int(_cfg("runtime", "parallel_read_workers", default=max(1, cpu_count() or 1))))
        profile = str(_cfg("runtime", "parallel_profile", default="full_cpu")).lower().strip()
        # The default/full_cpu behavior intentionally uses every configured CPU
        # worker.  Legacy profiles remain available only for explicit throttling.
        if profile == "laptop":
            return min(configured, 4)
        if profile == "shared":
            return min(configured, 8)
        if profile == "auto":
            return min(configured, 16)
        return configured

    def _executor_pool(self, attr_name, workers):
        pool = getattr(self, attr_name, None)
        worker_attr = f"_{attr_name}_workers"
        if pool is None or getattr(self, worker_attr, None) != workers:
            if pool is not None:
                pool.shutdown(wait=False, cancel_futures=False)
            pool = ThreadPoolExecutor(max_workers=workers)
            setattr(self, attr_name, pool)
            setattr(self, worker_attr, workers)
        return pool

    def _pool(self):
        return self._executor_pool("io_pool", self._effective_workers())

    def _direct_file_workers(self, total_files=None):
        if not bool(_cfg("runtime", "enable_parallel_read", default=True)):
            return 1
        if not bool(_cfg("runtime", "direct_parallel_files", default=True)):
            return 1
        configured = max(1, int(_cfg("runtime", "direct_file_read_workers", default=_cfg("runtime", "direct_process_workers", default=4))))
        profile = str(_cfg("runtime", "parallel_profile", default="full_cpu")).lower().strip()
        # Outer direct workers default to direct_process_workers, not cpu_count(),
        # because histogram filling is memory-bandwidth heavy; they are also
        # capped by the number of file/process tasks.
        if profile == "laptop":
            configured = min(configured, 4)
        elif profile == "shared":
            configured = min(configured, 8)
        elif profile == "auto":
            configured = min(configured, 16)
        if total_files is not None:
            configured = min(configured, max(1, int(total_files)))
        return max(1, configured)

    def _estimate_payload_bytes(self, payload):
        total = 0
        for arrs in (payload or {}).get("arrays", {}).values():
            for v in arrs.values():
                a = np.asarray(v)
                total += int(getattr(a, "nbytes", 0))
        return total

    def _cache_put(self, key, payload):
        if _data_loading_mode() == "direct" or not _cfg("cache", "arrays_in_memory", default=True):
            return
        if key in self.array_cache:
            old = self.array_cache.pop(key)
            self.array_cache_bytes -= self._estimate_payload_bytes(old)
        self.array_cache[key] = payload
        self.array_cache.move_to_end(key)
        self.array_cache_bytes += self._estimate_payload_bytes(payload)

        max_entries = int(_cfg("cache", "max_entries", default=32))
        max_bytes_mb = _cfg("cache", "max_bytes_mb", default=4096)
        max_bytes = None if max_bytes_mb is None else int(float(max_bytes_mb) * 1024 * 1024)

        while self.array_cache and (len(self.array_cache) > max_entries or (max_bytes is not None and self.array_cache_bytes > max_bytes)):
            evict_key, evict_payload = self.array_cache.popitem(last=False)
            freed = self._estimate_payload_bytes(evict_payload)
            self.array_cache_bytes -= freed
            _log(f"cache-evict key={evict_key[0]} freed={freed/1024/1024:.1f}MB", level="debug")

    def _seed_uncut_base_cache(self, tree_name, import_mode, payload):
        if _data_loading_mode() == "direct" or not _cfg("cache", "arrays_in_memory", default=True):
            return
        if not isinstance(payload, dict):
            return
        if _normalize_cut(payload.get("cut", "")):
            return
        arrays = payload.get("arrays", {})
        base_branches = set()
        for arrs in arrays.values():
            base_branches |= set(arrs.keys())
        base_key = (
            tree_name,
            import_mode,
            tuple(self.input_files),
            self.input_mode,
        )
        self.uncut_base_cache[base_key] = {
            "payload": payload,
            "branches": base_branches,
        }

    def refresh_inputs(self, force=False, emit_log=True):
        sig = (
            _cfg("io", "input_mode"),
            _cfg("io", "input_path"),
            _cfg("io", "unmerged_glob"),
            repr(_cfg("io", "unmerged_process_paths", default={})),
            _data_loading_mode(),
        )
        cached_sig = getattr(self, "_input_sig", None)
        if (not force) and cached_sig == sig and self.input_files:
            if emit_log:
                _log(f"Reusing discovered inputs ({len(self.input_files)} files)")
            return

        requested_mode = str(_cfg("io", "input_mode", default="auto")).lower().strip()
        with _timer("input discovery"):
            self.input_mode, discovered = _discover_input_files(_cfg("io", "input_path"), requested_mode, _cfg("io", "unmerged_glob") )
        if requested_mode == "auto":
            _log(f"Input mode auto-resolved to {self.input_mode}", level="progress")
        self.input_files = _unique_paths(discovered)
        dropped = max(0, len(discovered) - len(self.input_files))
        if dropped:
            _log(f"Deduplicated input file list: dropped {dropped} duplicate path(s)")
        self.unmerged_index = _build_unmerged_index(self.input_files) if self.input_mode == "unmerged" else {}
        self.uncut_base_cache.clear()
        self._process_cache.clear()
        self._tree_path_cache.clear()
        self._branch_cache.clear()
        self.array_cache.clear()
        self.array_cache_bytes = 0
        self._input_sig = sig
        _log(f"Loaded inputs: mode={self.input_mode}, n_files={len(self.input_files)}")

    def list_categories(self):
        if self.input_mode == "unmerged":
            return sorted(k for k in self.unmerged_index.keys() if k != "*")
        f = TFile.Open(self.input_files[0])
        out = []
        try:
            keys = f.GetListOfKeys()
            for i in range(keys.GetEntries()):
                n = keys.At(i).GetName()
                if n and n not in set(_cfg("filters", "exclude_top_level_keys", default={"trees"})):
                    out.append(n)
        finally:
            f.Close()
        return sorted(set(out))

    def list_processes(self, tree_name):
        if self.input_mode == "unmerged":
            return sorted((self.unmerged_index.get(tree_name) or self.unmerged_index.get("*", {})).keys())
        # merged mode, discover from ROOT dirs
        f = TFile.Open(self.input_files[0])
        procs = set()
        roots = [x.format(tree=tree_name) for x in _cfg("io", "merged_tree_roots", default=["{tree}", "trees/{tree}"])]
        _progress("discover trees", 0, len(roots), f"mode={self.input_mode} tree={tree_name}")
        try:
            for root_idx, pth in enumerate(roots, 1):
                d = f.Get(pth)
                if d and d.InheritsFrom("TDirectory"):
                    keys = d.GetListOfKeys()
                    for i in range(keys.GetEntries()):
                        n = keys.At(i).GetName()
                        if n != "Events":
                            procs.add(n)
                _progress("discover trees", root_idx, len(roots), f"mode={self.input_mode} root={pth} processes={len(procs)}")
        finally:
            f.Close()
        return sorted(procs)

    def _tree_candidates(self, tree_name, proc):
        return [tpl.format(tree=tree_name, proc=proc) for tpl in _cfg("io", "tree_path_candidates", default=["{tree}/{proc}/Events", "trees/{tree}/{proc}/Events", "/{tree}/{proc}/Events", "/trees/{tree}/{proc}/Events"]) ]

    def _get_tree_and_path(self, opened_file, root_file, tree_name, proc):
        cache_key = (os.path.realpath(root_file), tree_name, proc)
        cached_path = self._tree_path_cache.get(cache_key)
        if cached_path and cached_path in opened_file:
            return opened_file[cached_path], cached_path
        with _timer("tree path lookup", level="debug"):
            for p in self._tree_candidates(tree_name, proc):
                if p in opened_file:
                    self._tree_path_cache[cache_key] = p
                    return opened_file[p], p
        return None, None

    def _available_branches(self, tree, root_file, tree_path):
        cache_key = (os.path.realpath(root_file), tree_path)
        cached = self._branch_cache.get(cache_key)
        if cached is not None:
            return set(cached)
        available = set(map(str, tree.keys()))
        self._branch_cache[cache_key] = set(available)
        return available

    def _process_file_items(self, tree_name):
        allow = _cfg("filters", "process_allowlist")
        block = _cfg("filters", "process_blocklist")
        cache_key = (
            tree_name,
            self.input_mode,
            tuple(self.input_files),
            tuple(sorted(allow)) if allow else None,
            tuple(sorted(block)) if block else None,
        )
        cached = self._process_cache.get(cache_key)
        if cached is not None:
            return [(proc, list(files)) for proc, files in cached]

        with _timer("process discovery", level="debug"):
            if self.input_mode == "unmerged":
                proc_map = dict(self.unmerged_index.get(tree_name) or self.unmerged_index.get("*", {}))
            else:
                proc_map = {p: [self.input_files[0]] for p in self.list_processes(tree_name)}

        if allow:
            allow_set = set(allow)
            proc_map = {k: v for k, v in proc_map.items() if k in allow_set}
        if block:
            block_set = set(block)
            proc_map = {k: v for k, v in proc_map.items() if k not in block_set}

        items = [(proc, _unique_paths(files)) for proc, files in sorted(proc_map.items())]
        self._process_cache[cache_key] = [(proc, list(files)) for proc, files in items]
        return [(proc, list(files)) for proc, files in items]

    def _direct_array_kwargs(self):
        kwargs = {"library": "np"}
        if bool(_cfg("runtime", "direct_use_threaded_io", default=False)):
            dec_workers = max(1, int(_cfg("runtime", "uproot_decompression_workers", default=8)))
            int_workers = max(1, int(_cfg("runtime", "uproot_interpretation_workers", default=8)))
            kwargs["decompression_executor"] = self._executor_pool("_uproot_decompression_pool", dec_workers)
            kwargs["interpretation_executor"] = self._executor_pool("_uproot_interpretation_pool", int_workers)
        return kwargs

    def _direct_chunk_iter(self, tree, wanted, entries_total, timings=None):
        step_size = _cfg("runtime", "direct_step_size", default=None)
        max_chunks = _cfg("runtime", "direct_validation_max_chunks", default=None)
        max_chunks = None if max_chunks in {None, ""} else max(1, int(max_chunks))
        if step_size:
            iterator = tree.iterate(wanted, step_size=step_size, **self._direct_array_kwargs())
            produced = 0
            while True:
                if max_chunks is not None and produced >= max_chunks:
                    break
                t_read = time.perf_counter()
                try:
                    arrays = next(iterator)
                except StopIteration:
                    break
                if timings is not None:
                    timings["array_read"] = timings.get("array_read", 0.0) + (time.perf_counter() - t_read)
                produced += 1
                yield None, None, arrays
            return
        step = max(1, int(_cfg("runtime", "direct_chunk_entries", default=20_000)))
        produced = 0
        for start in range(0, entries_total, step):
            if max_chunks is not None and produced >= max_chunks:
                break
            stop = min(entries_total, start + step)
            t_read = time.perf_counter()
            arrays = tree.arrays(wanted, entry_start=start, entry_stop=stop, **self._direct_array_kwargs())
            if timings is not None:
                timings["array_read"] = timings.get("array_read", 0.0) + (time.perf_counter() - t_read)
            produced += 1
            yield start, stop, arrays

    def _direct_total_chunks(self, entries_total):
        if _cfg("runtime", "direct_step_size", default=None):
            return 0
        step = max(1, int(_cfg("runtime", "direct_chunk_entries", default=20_000)))
        return int(np.ceil(entries_total / step)) if entries_total else 0

    def _log_direct_timing(self, label, timings, extra=""):
        if not bool(_cfg("runtime", "direct_timing_enabled", default=False)):
            return
        if not timings:
            return
        parts = []
        for key in ("open_tree", "array_read", "mask_eval", "hist_fill", "total"):
            if key in timings:
                parts.append(f"{key}={float(timings.get(key, 0.0)):.2f}s")
        suffix = f" {extra}" if extra else ""
        _log(f"timing {label}: " + " ".join(parts) + suffix, level="debug")
        detail_keys = (
            "hist_fill_bin_index",
            "hist_fill_mask_apply",
            "hist_fill_histogram_call",
            "hist_fill_sumw",
            "hist_fill_sumw2",
            "hist_fill_stage_compute",
            "hist_store_merge",
        )
        detail_parts = [f"{k}={float(timings.get(k, 0.0)):.2f}s" for k in detail_keys if k in timings]
        if detail_parts:
            _log(f"timing {label} hist-fill-detail: " + " ".join(detail_parts) + suffix, level="debug")

    def _read_hist_one_file_direct(self, root_file, tree_name, proc, observable, bins, required_branches, cut_expr, import_mode):
        weight_branch = _cfg("physics", "mc_weight_branch")
        is_data = proc in _cfg("physics", "data_processes")
        bins = np.asarray(bins, dtype=float)
        hist = np.zeros(len(bins) - 1, dtype=float)
        var = np.zeros(len(bins) - 1, dtype=float)
        timings = {"array_read": 0.0}

        with _timer("ROOT file open", collector=timings, key="open_tree", level="debug"):
            f = uproot.open(root_file)
        with f:
            tree, tree_path = self._get_tree_and_path(f, root_file, tree_name, proc)
            if tree is None:
                return None

            available = self._available_branches(tree, root_file, tree_path)
            entries_total = int(getattr(tree, "num_entries", 0))

            # If the requested observable is absent, no histogram can be filled.
            # Treat this as a critical-branch diagnostic by default; if the user
            # disables raising, return an empty per-file report without reading
            # cut/weight branches unnecessarily.
            obs_resolved = _resolve_requested_branches({observable}, available)
            if observable not in obs_resolved:
                _handle_missing_critical(
                    [observable],
                    f"direct observable tree={tree_name} proc={proc} file={root_file} path={tree_path}",
                )
                return {
                    "proc": proc, "hist": hist, "var": var, "entries_total": entries_total,
                    "entries_after_cut": 0, "file": root_file, "tree_path": tree_path,
                    "loaded_branch_names": [], "chunks": 0,
                }

            requested = set(required_branches or []) | {observable}
            if (not is_data) and isinstance(weight_branch, str) and weight_branch.strip():
                requested.add(weight_branch)

            # Direct mode is intentionally branch-minimal even if import_mode='all':
            # loading every branch defeats the SSD streaming/low-memory purpose.
            resolved = _resolve_requested_branches(requested, available)
            critical = {observable} | set(_extract_cut_branches(cut_expr))
            missing_critical = _missing_resolved(critical, resolved)
            _handle_missing_critical(
                missing_critical,
                f"direct histogram tree={tree_name} proc={proc} file={root_file} path={tree_path}",
            )
            if missing_critical:
                return {
                    "proc": proc, "hist": hist, "var": var, "entries_total": entries_total,
                    "entries_after_cut": 0, "file": root_file, "tree_path": tree_path,
                    "loaded_branch_names": sorted(resolved.keys()), "chunks": 0,
                }
            if (not is_data) and isinstance(weight_branch, str) and weight_branch.strip() and weight_branch not in resolved:
                _log(
                    f"Missing MC weight branch '{weight_branch}' for proc={proc} file={os.path.basename(root_file)}; MC contribution will be skipped",
                    level="warn",
                )
            wanted = sorted(set(resolved.values()))
            if not wanted:
                return {
                    "proc": proc, "hist": hist, "var": var, "entries_total": entries_total,
                    "entries_after_cut": 0, "file": root_file, "tree_path": tree_path,
                    "loaded_branch_names": [], "chunks": 0,
                }

            total_entry_chunks = self._direct_total_chunks(entries_total)
            _progress("direct chunks", 0, total_entry_chunks, f"proc={proc} tree={tree_path} file={os.path.basename(root_file)}")
            entries_after = 0
            chunks = 0
            for start, stop, arrays in self._direct_chunk_iter(tree, wanted, entries_total, timings=timings):
                arr_source = {k: np.asarray(v) for k, v in arrays.items()}
                arrs = {req: arr_source[src] for req, src in resolved.items() if src in arr_source}
                if observable not in arrs:
                    chunks += 1
                    _progress("direct chunks", chunks, total_entry_chunks, f"proc={proc} tree={tree_path} file={os.path.basename(root_file)}")
                    _handle_missing_critical(
                        [observable],
                        f"direct chunk materialization tree={tree_name} proc={proc} file={root_file} path={tree_path}",
                    )
                    continue
                _validate_array_lengths(arrs, f"direct chunk tree={tree_name} proc={proc} file={root_file} entries={start}:{stop}")

                mask = _evaluate_cut_mask(arrs, cut_expr) if cut_expr and arrs else None
                x = np.asarray(arrs[observable])
                if mask is not None:
                    entries_after += int(np.count_nonzero(mask))
                    x = x[mask]
                else:
                    entries_after += int(len(x))

                if is_data:
                    hist += _hist_with_flows(x, bins=bins)
                elif isinstance(weight_branch, str) and weight_branch in arrs:
                    w = np.asarray(arrs[weight_branch])
                    if mask is not None:
                        w = w[mask]
                    hist += _hist_with_flows(x, bins=bins, weights=w)
                    var += _hist_with_flows(x, bins=bins, weights=w * w)
                chunks += 1
                _progress("direct chunks", chunks, total_entry_chunks, f"proc={proc} tree={tree_path} file={os.path.basename(root_file)}")

        return {
            "proc": proc,
            "hist": hist,
            "var": var,
            "entries_total": entries_total,
            "entries_after_cut": entries_after,
            "file": root_file,
            "tree_path": tree_path,
            "loaded_branch_names": sorted(resolved.keys()),
            "chunks": chunks,
        }

    def histogram_direct(self, tree_name, observable, bins, cut_expr="", required_branches=None, import_mode=None, force=False):
        self.refresh_inputs(force=_cfg("cache", "force_reload_inputs", default=False), emit_log=True)
        norm_cut = _normalize_cut(cut_expr)
        final_import_mode = str(import_mode or _cfg("runtime", "array_branch_import_mode", default="needed")).lower().strip()
        if final_import_mode not in {"needed", "all"}:
            final_import_mode = "needed"

        if required_branches is None:
            needed = set(_plan_required_branches([observable], cut_expr=norm_cut, include_seed=False))
        else:
            needed = {b for b in required_branches if isinstance(b, str) and b.strip()}
            needed |= set(_extract_cut_branches(norm_cut))
            needed.add(observable)
        # Weight branches are added per MC process in _read_hist_one_file_direct;
        # do not force them into data reads or the direct-mode branch summary here.

        data = np.zeros(len(bins) - 1, dtype=float)
        mc_h, mc_v = {}, {}
        reports = []
        proc_items = self._process_file_items(tree_name)
        total_files = sum(len(files) for _, files in proc_items)
        done_files = 0
        _progress("direct files", done_files, total_files, f"mode={self.input_mode} tree={tree_name} observable={observable}")

        proc_chunks_by_proc = {proc: [] for proc, _ in proc_items}
        file_tasks = [(proc, rf) for proc, files in proc_items for rf in files]
        workers = self._direct_file_workers(total_files)

        def consume_payload(proc, rf, payload):
            nonlocal data, done_files
            done_files += 1
            tree_info = payload.get("tree_path", "?") if payload else "?"
            _progress("direct files", done_files, total_files, f"proc={proc} tree={tree_info} file={os.path.basename(rf)}")
            if payload is None:
                return
            proc_chunks_by_proc.setdefault(proc, []).append(payload)
            stack_name = self.style.stack_key(proc)
            if proc in _cfg("physics", "data_processes"):
                data += payload["hist"]
            else:
                mc_h[stack_name] = mc_h.get(stack_name, 0.0) + payload["hist"]
                mc_v[stack_name] = mc_v.get(stack_name, 0.0) + payload["var"]

        if workers > 1 and len(file_tasks) > 1:
            _log(f"direct parallel file reads: workers={workers} files={len(file_tasks)} tree={tree_name} obs={observable}")
            with ThreadPoolExecutor(max_workers=workers) as pool:
                fut_to_task = {
                    pool.submit(self._read_hist_one_file_direct, rf, tree_name, proc, observable, bins, needed, norm_cut, final_import_mode): (proc, rf)
                    for proc, rf in file_tasks
                }
                for fut in as_completed(fut_to_task):
                    proc, rf = fut_to_task[fut]
                    consume_payload(proc, rf, fut.result())
        else:
            for proc, rf in file_tasks:
                payload = self._read_hist_one_file_direct(rf, tree_name, proc, observable, bins, needed, norm_cut, final_import_mode)
                consume_payload(proc, rf, payload)

        for proc, files in proc_items:
            proc_chunks = proc_chunks_by_proc.get(proc, [])
            if not proc_chunks:
                continue
            branch_names = sorted(set().union(*(set(x.get("loaded_branch_names", [])) for x in proc_chunks)))
            reports.append({
                "proc": proc,
                "process_key": f"{tree_name}:{proc}",
                "n_files": len(files),
                "entries_total": int(sum(x["entries_total"] for x in proc_chunks)),
                "entries_after_cut": int(sum(x["entries_after_cut"] for x in proc_chunks)),
                "loaded_branches": len(branch_names),
                "branch_names": branch_names,
                "tree_paths": sorted(set(x.get("tree_path", "") for x in proc_chunks if x.get("tree_path"))),
                "chunks": int(sum(x.get("chunks", 0) for x in proc_chunks)),
            })

        if _cfg("logging", "show_branch_summary", default=True):
            total_after = int(sum(r.get("entries_after_cut", 0) for r in reports))
            total_before = int(sum(r.get("entries_total", 0) for r in reports))
            _log(f"direct-summary tree={tree_name} obs={observable} procs={len(reports)} events={total_after}/{total_before} branches={len(needed)} cut={_cut_preview(norm_cut)}")

        return {
            "data_counts": data,
            "mc_h": mc_h,
            "mc_v": mc_v,
            "reports": reports,
            "tree_name": tree_name,
            "cut": norm_cut,
            "observable": observable,
        }

    def _read_hists_one_file_direct(self, root_file, tree_name, proc, observables, bins_by_obs, required_branches, cut_expr, import_mode):
        weight_branch = _cfg("physics", "mc_weight_branch")
        is_data = proc in _cfg("physics", "data_processes")
        active_obs = [o for o in observables if o in bins_by_obs]
        hists = {o: np.zeros(len(np.asarray(bins_by_obs[o], dtype=float)) - 1, dtype=float) for o in active_obs}
        variances = {o: np.zeros_like(hists[o]) for o in active_obs}
        timings = {"array_read": 0.0}

        with uproot.open(root_file) as f:
            tree = None
            tree_path = None
            for p in self._tree_candidates(tree_name, proc):
                if p in f:
                    tree = f[p]
                    tree_path = p
                    break
            if tree is None:
                return None

            available = set(map(str, tree.keys()))
            entries_total = int(getattr(tree, "num_entries", 0))

            obs_resolved = _resolve_requested_branches(active_obs, available)
            missing_obs = _missing_resolved(active_obs, obs_resolved)
            if missing_obs:
                _handle_missing_critical(
                    missing_obs,
                    f"direct multi-observable tree={tree_name} proc={proc} file={root_file} path={tree_path}",
                )
                active_obs = [o for o in active_obs if o in obs_resolved]
            if not active_obs:
                return {
                    "proc": proc,
                    "hists": hists,
                    "vars": variances,
                    "entries_total": entries_total,
                    "entries_after_cut": 0,
                    "file": root_file,
                    "tree_path": tree_path,
                    "loaded_branch_names": [],
                    "chunks": 0,
                }

            requested = set(required_branches or []) | set(active_obs) | set(_extract_cut_branches(cut_expr))
            if (not is_data) and isinstance(weight_branch, str) and weight_branch.strip():
                requested.add(weight_branch)
            resolved = _resolve_requested_branches(requested, available)
            critical = set(active_obs) | set(_extract_cut_branches(cut_expr))
            missing_critical = _missing_resolved(critical, resolved)
            _handle_missing_critical(
                missing_critical,
                f"direct multi-histogram tree={tree_name} proc={proc} file={root_file} path={tree_path}",
            )
            if missing_critical:
                return {
                    "proc": proc,
                    "hists": hists,
                    "vars": variances,
                    "entries_total": entries_total,
                    "entries_after_cut": 0,
                    "file": root_file,
                    "tree_path": tree_path,
                    "loaded_branch_names": sorted(resolved.keys()),
                    "chunks": 0,
                }

            has_weight = is_data or not (isinstance(weight_branch, str) and weight_branch.strip()) or weight_branch in resolved
            if not has_weight:
                _log(
                    f"Missing MC weight branch '{weight_branch}' for proc={proc} file={os.path.basename(root_file)}; MC contribution will be skipped",
                    level="warn",
                )

            wanted = sorted(set(resolved.values()))
            if not wanted:
                return {
                    "proc": proc,
                    "hists": hists,
                    "vars": variances,
                    "entries_total": entries_total,
                    "entries_after_cut": 0,
                    "file": root_file,
                    "tree_path": tree_path,
                    "loaded_branch_names": [],
                    "chunks": 0,
                }

            total_entry_chunks = self._direct_total_chunks(entries_total)
            _progress("direct chunks", 0, total_entry_chunks, f"proc={proc} tree={tree_path} file={os.path.basename(root_file)} obs={len(active_obs)}")
            entries_after = 0
            chunks = 0
            for start, stop, arrays in self._direct_chunk_iter(tree, wanted, entries_total, timings=timings):
                arr_source = {k: np.asarray(v) for k, v in arrays.items()}
                arrs = {req: arr_source[src] for req, src in resolved.items() if src in arr_source}
                _validate_array_lengths(arrs, f"direct multi chunk tree={tree_name} proc={proc} file={root_file} entries={start}:{stop}")

                mask = _evaluate_cut_mask(arrs, cut_expr) if cut_expr and arrs else None
                if active_obs:
                    ref = np.asarray(arrs[active_obs[0]])
                    entries_after += int(np.count_nonzero(mask)) if mask is not None else int(len(ref))

                w = None
                if (not is_data) and has_weight and isinstance(weight_branch, str) and weight_branch in arrs:
                    w = np.asarray(arrs[weight_branch])
                    if mask is not None:
                        w = w[mask]

                for obs in active_obs:
                    if obs not in arrs:
                        _handle_missing_critical(
                            [obs],
                            f"direct multi chunk materialization tree={tree_name} proc={proc} file={root_file} path={tree_path}",
                        )
                        continue
                    x = np.asarray(arrs[obs])
                    if mask is not None:
                        x = x[mask]
                    bins = np.asarray(bins_by_obs[obs], dtype=float)
                    if is_data:
                        hists[obs] += _hist_with_flows(x, bins=bins)
                    elif w is not None:
                        hists[obs] += _hist_with_flows(x, bins=bins, weights=w)
                        variances[obs] += _hist_with_flows(x, bins=bins, weights=w * w)

                chunks += 1
                _progress("direct chunks", chunks, total_entry_chunks, f"proc={proc} tree={tree_path} file={os.path.basename(root_file)} obs={len(active_obs)}")

        return {
            "proc": proc,
            "hists": hists,
            "vars": variances,
            "entries_total": entries_total,
            "entries_after_cut": entries_after,
            "file": root_file,
            "tree_path": tree_path,
            "loaded_branch_names": sorted(resolved.keys()),
            "chunks": chunks,
        }

    def histograms_direct(self, tree_name, observables, bins_by_obs, cut_expr="", required_branches=None, import_mode=None, force=False):
        self.refresh_inputs(force=_cfg("cache", "force_reload_inputs", default=False), emit_log=True)
        norm_cut = _normalize_cut(cut_expr)
        obs = [o for o in _validate_observables(observables) if o in bins_by_obs]
        final_import_mode = str(import_mode or _cfg("runtime", "array_branch_import_mode", default="needed")).lower().strip()
        if final_import_mode not in {"needed", "all"}:
            final_import_mode = "needed"

        if required_branches is None:
            needed = set(_plan_required_branches(obs, cut_expr=norm_cut, include_seed=False))
        else:
            needed = {b for b in required_branches if isinstance(b, str) and b.strip()}
            needed |= set(obs)
            needed |= set(_extract_cut_branches(norm_cut))

        results = {
            o: {
                "data_counts": np.zeros(len(np.asarray(bins_by_obs[o], dtype=float)) - 1, dtype=float),
                "mc_h": {},
                "mc_v": {},
            }
            for o in obs
        }
        reports = []
        proc_items = self._process_file_items(tree_name)
        total_files = sum(len(files) for _, files in proc_items)
        done_files = 0
        _progress("direct files", done_files, total_files, f"mode={self.input_mode} tree={tree_name} observables={len(obs)}")

        proc_chunks_by_proc = {proc: [] for proc, _ in proc_items}
        file_tasks = [(proc, rf) for proc, files in proc_items for rf in files]
        workers = self._direct_file_workers(total_files)

        def consume_payload(proc, rf, payload):
            nonlocal done_files
            done_files += 1
            tree_info = payload.get("tree_path", "?") if payload else "?"
            _progress("direct files", done_files, total_files, f"proc={proc} tree={tree_info} file={os.path.basename(rf)} observables={len(obs)}")
            if payload is None:
                return
            proc_chunks_by_proc.setdefault(proc, []).append(payload)
            stack_name = self.style.stack_key(proc)
            for obs_name in obs:
                if proc in _cfg("physics", "data_processes"):
                    results[obs_name]["data_counts"] += payload["hists"].get(obs_name, 0.0)
                else:
                    results[obs_name]["mc_h"][stack_name] = results[obs_name]["mc_h"].get(stack_name, 0.0) + payload["hists"].get(obs_name, 0.0)
                    results[obs_name]["mc_v"][stack_name] = results[obs_name]["mc_v"].get(stack_name, 0.0) + payload["vars"].get(obs_name, 0.0)

        if workers > 1 and len(file_tasks) > 1:
            _log(f"direct parallel file reads: workers={workers} files={len(file_tasks)} tree={tree_name} obs={len(obs)}")
            with ThreadPoolExecutor(max_workers=workers) as pool:
                fut_to_task = {
                    pool.submit(self._read_hists_one_file_direct, rf, tree_name, proc, obs, bins_by_obs, needed, norm_cut, final_import_mode): (proc, rf)
                    for proc, rf in file_tasks
                }
                for fut in as_completed(fut_to_task):
                    proc, rf = fut_to_task[fut]
                    consume_payload(proc, rf, fut.result())
        else:
            for proc, rf in file_tasks:
                payload = self._read_hists_one_file_direct(rf, tree_name, proc, obs, bins_by_obs, needed, norm_cut, final_import_mode)
                consume_payload(proc, rf, payload)

        for proc, files in proc_items:
            proc_chunks = proc_chunks_by_proc.get(proc, [])
            if not proc_chunks:
                continue
            branch_names = sorted(set().union(*(set(x.get("loaded_branch_names", [])) for x in proc_chunks)))
            reports.append({
                "proc": proc,
                "process_key": f"{tree_name}:{proc}",
                "n_files": len(files),
                "entries_total": int(sum(x["entries_total"] for x in proc_chunks)),
                "entries_after_cut": int(sum(x["entries_after_cut"] for x in proc_chunks)),
                "loaded_branches": len(branch_names),
                "branch_names": branch_names,
                "tree_paths": sorted(set(x.get("tree_path", "") for x in proc_chunks if x.get("tree_path"))),
                "chunks": int(sum(x.get("chunks", 0) for x in proc_chunks)),
            })

        if _cfg("logging", "show_branch_summary", default=True):
            total_after = int(sum(r.get("entries_after_cut", 0) for r in reports))
            total_before = int(sum(r.get("entries_total", 0) for r in reports))
            _log(f"direct-summary tree={tree_name} obs={len(obs)} procs={len(reports)} events={total_after}/{total_before} branches={len(needed)} cut={_cut_preview(norm_cut)}")

        return {
            "histograms": results,
            "reports": reports,
            "tree_name": tree_name,
            "cut": norm_cut,
            "observables": obs,
        }



    def _read_hists_multi_cut_one_file_direct(self, root_file, tree_name, proc, cut_jobs, bins_by_obs, required_branches, import_mode):
        """Read one ROOT file once and fill many cut/observable histogram jobs."""
        weight_branch = _cfg("physics", "mc_weight_branch")
        is_data = proc in _cfg("physics", "data_processes")

        normalized_jobs = []
        all_obs = []
        for idx, job in enumerate(cut_jobs or []):
            job_id = job.get("job_id", idx)
            job_obs = [o for o in job.get("observables", []) if o in bins_by_obs]
            if not job_obs:
                continue
            for obs in job_obs:
                if obs not in all_obs:
                    all_obs.append(obs)
            norm_job = {
                "job_id": job_id,
                "observables": job_obs,
                "cut_expr": _normalize_cut(job.get("cut_expr", job.get("cut", ""))),
            }
            if job.get("zzcr_channel") in {"ee", "mm"} and job.get("zzcr_stage") in set(range(1, 8)):
                norm_job["zzcr_channel"] = job.get("zzcr_channel")
                norm_job["zzcr_stage"] = int(job.get("zzcr_stage"))
            normalized_jobs.append(norm_job)

        job_results = {
            job["job_id"]: {
                "hists": {o: np.zeros(len(np.asarray(bins_by_obs[o], dtype=float)) - 1, dtype=float) for o in job["observables"]},
                "vars": {o: np.zeros(len(np.asarray(bins_by_obs[o], dtype=float)) - 1, dtype=float) for o in job["observables"]},
                "entries_after_cut": 0,
                "observables": list(job["observables"]),
            }
            for job in normalized_jobs
        }

        if not normalized_jobs:
            return None

        timings = {"open_tree": 0.0, "array_read": 0.0, "mask_eval": 0.0, "hist_fill": 0.0}
        use_stage_engine = bool(_cfg("runtime", "zzcr_stage_engine", default=True)) and normalized_jobs and all(
            job.get("zzcr_channel") in {"ee", "mm"} and int(job.get("zzcr_stage", 0)) in range(1, 8)
            for job in normalized_jobs
        )
        t_total = time.perf_counter()
        t_open = time.perf_counter()
        f = uproot.open(root_file)
        timings["open_tree"] += time.perf_counter() - t_open
        with f:
            tree, tree_path = self._get_tree_and_path(f, root_file, tree_name, proc)
            if tree is None:
                return None

            available = self._available_branches(tree, root_file, tree_path)
            entries_total = int(getattr(tree, "num_entries", 0))

            obs_resolved = _resolve_requested_branches(all_obs, available)
            missing_obs = _missing_resolved(all_obs, obs_resolved)
            if missing_obs:
                _handle_missing_critical(
                    missing_obs,
                    f"direct multi-cut observables tree={tree_name} proc={proc} file={root_file} path={tree_path}",
                )
                all_obs = [o for o in all_obs if o in obs_resolved]
                for job in normalized_jobs:
                    job["observables"] = [o for o in job["observables"] if o in obs_resolved]

            normalized_jobs = [job for job in normalized_jobs if job["observables"]]
            if not normalized_jobs:
                return {
                    "proc": proc,
                    "jobs": job_results,
                    "entries_total": entries_total,
                    "file": root_file,
                    "tree_path": tree_path,
                    "loaded_branch_names": [],
                    "chunks": 0,
                }

            requested = set(required_branches or []) | set(all_obs)
            for job in normalized_jobs:
                requested |= set(_extract_cut_branches(job["cut_expr"]))
            if (not is_data) and isinstance(weight_branch, str) and weight_branch.strip():
                requested.add(weight_branch)

            resolved = _resolve_requested_branches(requested, available)
            critical = set(all_obs)
            for job in normalized_jobs:
                critical |= set(_extract_cut_branches(job["cut_expr"]))
            missing_critical = _missing_resolved(critical, resolved)
            _handle_missing_critical(
                missing_critical,
                f"direct multi-cut histograms tree={tree_name} proc={proc} file={root_file} path={tree_path}",
            )
            if missing_critical:
                return {
                    "proc": proc,
                    "jobs": job_results,
                    "entries_total": entries_total,
                    "file": root_file,
                    "tree_path": tree_path,
                    "loaded_branch_names": sorted(resolved.keys()),
                    "chunks": 0,
                }

            has_weight = is_data or not (isinstance(weight_branch, str) and weight_branch.strip()) or weight_branch in resolved
            if not has_weight:
                _log(
                    f"Missing MC weight branch '{weight_branch}' for proc={proc} file={os.path.basename(root_file)}; MC contribution will be skipped",
                    level="warn",
                )

            wanted = sorted(set(resolved.values()))
            if not wanted:
                return {
                    "proc": proc,
                    "jobs": job_results,
                    "entries_total": entries_total,
                    "file": root_file,
                    "tree_path": tree_path,
                    "loaded_branch_names": [],
                    "chunks": 0,
                }

            total_entry_chunks = self._direct_total_chunks(entries_total)
            _progress("direct chunks", 0, total_entry_chunks, f"proc={proc} tree={tree_path} file={os.path.basename(root_file)} jobs={len(normalized_jobs)} obs={len(all_obs)}")
            chunks = 0
            for start, stop, arrays in self._direct_chunk_iter(tree, wanted, entries_total, timings=timings):
                arr_source = {k: np.asarray(v) for k, v in arrays.items()}
                arrs = {req: arr_source[src] for req, src in resolved.items() if src in arr_source}
                _validate_array_lengths(arrs, f"direct multi-cut chunk tree={tree_name} proc={proc} file={root_file} entries={start}:{stop}")

                mask_cache = {}
                cut_masks = {}
                stage_jobs = None
                if use_stage_engine:
                    t_stage_count = time.perf_counter()
                    stage_ee_for_counts, stage_mm_for_counts = compute_zzcr_stages(arrs)
                    timings["mask_eval"] += time.perf_counter() - t_stage_count
                    stage_lookup = {"ee": stage_ee_for_counts, "mm": stage_mm_for_counts}
                    stage_jobs = []
                    for job in normalized_jobs:
                        job_id = job["job_id"]
                        channel = job["zzcr_channel"]
                        stage = int(job["zzcr_stage"])
                        stage_jobs.append((job_id, channel, stage))
                        job_results[job_id]["entries_after_cut"] += int(np.count_nonzero(stage_lookup[channel] >= stage))
                else:
                    for job in normalized_jobs:
                        job_id = job["job_id"]
                        job_obs = job["observables"]
                        cut_expr = job["cut_expr"]
                        if cut_expr:
                            if cut_expr not in mask_cache:
                                t_mask = time.perf_counter()
                                mask_cache[cut_expr] = _evaluate_cut_mask(arrs, cut_expr)
                                timings["mask_eval"] += time.perf_counter() - t_mask
                            mask = mask_cache[cut_expr]
                        else:
                            mask = None
                        cut_masks[job_id] = mask
                        ref = np.asarray(arrs[job_obs[0]])
                        job_results[job_id]["entries_after_cut"] += int(np.count_nonzero(mask)) if mask is not None else int(len(ref))

                w_full = None
                if (not is_data) and has_weight and isinstance(weight_branch, str) and weight_branch in arrs:
                    w_full = np.asarray(arrs[weight_branch])

                t_hist = time.perf_counter()
                fill_histograms_for_chunk(
                    arrs,
                    all_obs,
                    {obs: {"bins": bins_by_obs[obs]} for obs in all_obs if obs in bins_by_obs},
                    cut_masks,
                    w_full,
                    job_results,
                    proc,
                    tree_name,
                    is_data=is_data,
                    timings=timings,
                    stage_jobs=stage_jobs,
                )
                timings["hist_fill"] += time.perf_counter() - t_hist

                chunks += 1
                _progress("direct chunks", chunks, total_entry_chunks, f"proc={proc} tree={tree_path} file={os.path.basename(root_file)} jobs={len(normalized_jobs)} obs={len(all_obs)}")

        timings["total"] = time.perf_counter() - t_total
        return {
            "proc": proc,
            "jobs": job_results,
            "entries_total": entries_total,
            "file": root_file,
            "tree_path": tree_path,
            "loaded_branch_names": sorted(resolved.keys()),
            "chunks": chunks,
            "timings": timings,
        }

    def histograms_direct_multi_cut(self, tree_name, cut_jobs, bins_by_obs, required_branches=None, import_mode=None, force=False):
        """Stream files once per observable batch while filling multiple cut jobs."""
        self.refresh_inputs(force=_cfg("cache", "force_reload_inputs", default=False), emit_log=True)
        final_import_mode = str(import_mode or _cfg("runtime", "array_branch_import_mode", default="needed")).lower().strip()
        if final_import_mode not in {"needed", "all"}:
            final_import_mode = "needed"

        normalized_jobs = []
        for idx, job in enumerate(cut_jobs or []):
            job_id = job.get("job_id", idx)
            job_obs = [o for o in _validate_observables(job.get("observables", [])) if o in bins_by_obs]
            if not job_obs:
                continue
            norm_job = {
                "job_id": job_id,
                "observables": job_obs,
                "cut_expr": _normalize_cut(job.get("cut_expr", job.get("cut", ""))),
            }
            if job.get("zzcr_channel") in {"ee", "mm"} and job.get("zzcr_stage") in set(range(1, 8)):
                norm_job["zzcr_channel"] = job.get("zzcr_channel")
                norm_job["zzcr_stage"] = int(job.get("zzcr_stage"))
            normalized_jobs.append(norm_job)

        results = {
            job["job_id"]: {
                "histograms": {
                    obs: {
                        "data_counts": np.zeros(len(np.asarray(bins_by_obs[obs], dtype=float)) - 1, dtype=float),
                        "mc_h": {},
                        "mc_v": {},
                    }
                    for obs in job["observables"]
                },
                "reports": [],
                "process_histograms": {},
                "cut": job["cut_expr"],
                "observables": list(job["observables"]),
            }
            for job in normalized_jobs
        }

        if not normalized_jobs:
            return {"jobs": results, "reports": [], "tree_name": tree_name}

        if required_branches is None:
            needed = set()
            for job in normalized_jobs:
                needed |= set(_plan_required_branches(job["observables"], cut_expr=job["cut_expr"], include_seed=False))
        else:
            needed = {b for b in required_branches if isinstance(b, str) and b.strip()}
            for job in normalized_jobs:
                needed |= set(job["observables"])
                needed |= set(_extract_cut_branches(job["cut_expr"]))

        proc_items = self._process_file_items(tree_name)
        total_files = sum(len(files) for _, files in proc_items)
        done_files = 0
        _progress("direct files", done_files, total_files, f"mode={self.input_mode} tree={tree_name} cut_jobs={len(normalized_jobs)}")

        proc_chunks_by_job = {job["job_id"]: {proc: [] for proc, _ in proc_items} for job in normalized_jobs}
        file_tasks = [(proc, rf) for proc, files in proc_items for rf in files]
        workers = self._direct_file_workers(total_files)
        total_timings = {"open_tree": 0.0, "array_read": 0.0, "mask_eval": 0.0, "hist_fill": 0.0, "total": 0.0}

        def consume_payload(proc, rf, payload):
            nonlocal done_files
            done_files += 1
            tree_info = payload.get("tree_path", "?") if payload else "?"
            _progress("direct files", done_files, total_files, f"proc={proc} tree={tree_info} file={os.path.basename(rf)} cut_jobs={len(normalized_jobs)}")
            if payload is None:
                return

            for key, value in (payload.get("timings") or {}).items():
                total_timings[key] = total_timings.get(key, 0.0) + float(value or 0.0)

            stack_name = self.style.stack_key(proc)
            for job in normalized_jobs:
                job_id = job["job_id"]
                job_payload = payload.get("jobs", {}).get(job_id)
                if not job_payload:
                    continue
                proc_chunks_by_job.setdefault(job_id, {}).setdefault(proc, []).append({
                    "entries_total": payload.get("entries_total", 0),
                    "entries_after_cut": job_payload.get("entries_after_cut", 0),
                    "loaded_branch_names": payload.get("loaded_branch_names", []),
                    "tree_path": payload.get("tree_path", ""),
                    "chunks": payload.get("chunks", 0),
                })
                t_merge = time.perf_counter()
                proc_store = results[job_id].setdefault("process_histograms", {}).setdefault(proc, {})
                for obs in job["observables"]:
                    if obs not in results[job_id]["histograms"]:
                        continue
                    obs_values = np.asarray(job_payload["hists"].get(obs, np.zeros_like(results[job_id]["histograms"][obs]["data_counts"])), dtype=float)
                    obs_vars = np.asarray(job_payload["vars"].get(obs, obs_values if proc in _cfg("physics", "data_processes") else np.zeros_like(obs_values)), dtype=float)
                    rec = proc_store.setdefault(obs, {"values": np.zeros_like(obs_values), "variances": np.zeros_like(obs_vars), "process_group": stack_name, "is_data": proc in _cfg("physics", "data_processes")})
                    rec["values"] += obs_values
                    rec["variances"] += obs_vars
                    if proc in _cfg("physics", "data_processes"):
                        results[job_id]["histograms"][obs]["data_counts"] += obs_values
                    else:
                        results[job_id]["histograms"][obs]["mc_h"][stack_name] = results[job_id]["histograms"][obs]["mc_h"].get(stack_name, 0.0) + obs_values
                        results[job_id]["histograms"][obs]["mc_v"][stack_name] = results[job_id]["histograms"][obs]["mc_v"].get(stack_name, 0.0) + obs_vars
                total_timings["hist_store_merge"] = total_timings.get("hist_store_merge", 0.0) + (time.perf_counter() - t_merge)

        if workers > 1 and len(file_tasks) > 1:
            _log(f"direct multi-cut parallel file reads: workers={workers} files={len(file_tasks)} tree={tree_name} cut_jobs={len(normalized_jobs)}")
            with ThreadPoolExecutor(max_workers=workers) as pool:
                fut_to_task = {
                    pool.submit(self._read_hists_multi_cut_one_file_direct, rf, tree_name, proc, normalized_jobs, bins_by_obs, needed, final_import_mode): (proc, rf)
                    for proc, rf in file_tasks
                }
                for fut in as_completed(fut_to_task):
                    proc, rf = fut_to_task[fut]
                    consume_payload(proc, rf, fut.result())
        else:
            for proc, rf in file_tasks:
                payload = self._read_hists_multi_cut_one_file_direct(rf, tree_name, proc, normalized_jobs, bins_by_obs, needed, final_import_mode)
                consume_payload(proc, rf, payload)

        for job in normalized_jobs:
            job_id = job["job_id"]
            reports = []
            for proc, files in proc_items:
                proc_chunks = proc_chunks_by_job.get(job_id, {}).get(proc, [])
                if not proc_chunks:
                    continue
                branch_names = sorted(set().union(*(set(x.get("loaded_branch_names", [])) for x in proc_chunks)))
                reports.append({
                    "proc": proc,
                    "process_key": f"{tree_name}:{proc}",
                    "n_files": len(files),
                    "entries_total": int(sum(x.get("entries_total", 0) for x in proc_chunks)),
                    "entries_after_cut": int(sum(x.get("entries_after_cut", 0) for x in proc_chunks)),
                    "loaded_branches": len(branch_names),
                    "branch_names": branch_names,
                    "tree_paths": sorted(set(x.get("tree_path", "") for x in proc_chunks if x.get("tree_path"))),
                    "chunks": int(sum(x.get("chunks", 0) for x in proc_chunks)),
                })
            results[job_id]["reports"] = reports

        if _cfg("logging", "show_branch_summary", default=True):
            total_reports = sum(len(job_result.get("reports", [])) for job_result in results.values())
            _log(f"direct-multicut-summary tree={tree_name} cut_jobs={len(normalized_jobs)} procs/job-reports={total_reports} branches={len(needed)}")
        self._log_direct_timing("direct-multicut", total_timings, extra=f"tree={tree_name} files={total_files} cut_jobs={len(normalized_jobs)}")

        return {
            "jobs": results,
            "reports": [rep for job_result in results.values() for rep in job_result.get("reports", [])],
            "tree_name": tree_name,
            "cut_jobs": normalized_jobs,
            "timings": total_timings,
        }

    def diagnose_branch_availability(self, tree_name, observables=None, cuts=None, include_seed=None, max_files_per_proc=1, raise_on_error=False):
        """Check branch availability from ROOT metadata without reading arrays."""
        self.refresh_inputs(force=_cfg("cache", "force_reload_inputs", default=False), emit_log=False)
        obs = _validate_observables(observables or _cfg("execution", "default_observables") or list(OBSERVABLES.keys()))
        cut_expr = _combine_subcategory_cuts_or(cuts or [])
        if include_seed is None:
            include_seed = _data_loading_mode() != "direct"
        required = set(_plan_required_branches(obs, cut_expr=cut_expr, include_seed=include_seed))
        critical = set(obs) | set(_extract_cut_branches(cut_expr))

        report = {"tree_name": tree_name, "checked": [], "errors": [], "warnings": []}
        max_files = max(1, int(max_files_per_proc or 1))

        for proc, files in self._process_file_items(tree_name):
            for rf in files[:max_files]:
                with uproot.open(rf) as f:
                    tree = None
                    tree_path = None
                    for p in self._tree_candidates(tree_name, proc):
                        if p in f:
                            tree = f[p]
                            tree_path = p
                            break
                    if tree is None:
                        msg = f"No Events tree found for tree={tree_name} proc={proc} file={rf}"
                        report["errors"].append(msg)
                        continue
                    available = self._available_branches(tree, rf, tree_path)
                    resolved = _resolve_requested_branches(required, available)
                    missing_critical = _missing_resolved(critical, resolved)
                    missing_optional = sorted(required - critical - set(resolved.keys()))
                    item = {
                        "proc": proc,
                        "file": rf,
                        "tree_path": tree_path,
                        "required": len(required),
                        "resolved": len(resolved),
                        "missing_critical": missing_critical,
                        "missing_optional": missing_optional,
                    }
                    report["checked"].append(item)
                    if missing_critical:
                        report["errors"].append(
                            f"Missing critical branches for tree={tree_name} proc={proc} file={os.path.basename(rf)}: {missing_critical}"
                        )
                    if missing_optional:
                        report["warnings"].append(
                            f"Missing optional branches for tree={tree_name} proc={proc} file={os.path.basename(rf)}: {missing_optional[:20]}"
                        )

        for msg in report["warnings"]:
            _log(f"branch diagnostic warning: {msg}", level="warn")
        for msg in report["errors"]:
            _log(f"branch diagnostic error: {msg}", level="error")
        _log(
            f"Branch diagnostics tree={tree_name}: checked={len(report['checked'])} "
            f"errors={len(report['errors'])} warnings={len(report['warnings'])}"
        )
        if report["errors"] and raise_on_error:
            raise RuntimeError("Branch diagnostics failed: " + "; ".join(report["errors"]))
        return report

    def _get_tree_and_path(self, opened_file, root_file, tree_name, proc):
        cache_key = (os.path.realpath(root_file), tree_name, proc)
        cached_path = self._tree_path_cache.get(cache_key)
        if cached_path and cached_path in opened_file:
            return opened_file[cached_path], cached_path
        with _timer("tree path lookup", level="debug"):
            for p in self._tree_candidates(tree_name, proc):
                if p in opened_file:
                    self._tree_path_cache[cache_key] = p
                    return opened_file[p], p
        return None, None

    def _available_branches(self, tree, root_file, tree_path):
        cache_key = (os.path.realpath(root_file), tree_path)
        cached = self._branch_cache.get(cache_key)
        if cached is not None:
            return set(cached)
        available = set(map(str, tree.keys()))
        self._branch_cache[cache_key] = set(available)
        return available

    def _process_file_items(self, tree_name):
        allow = _cfg("filters", "process_allowlist")
        block = _cfg("filters", "process_blocklist")
        cache_key = (
            tree_name,
            self.input_mode,
            tuple(self.input_files),
            tuple(sorted(allow)) if allow else None,
            tuple(sorted(block)) if block else None,
        )
        cached = self._process_cache.get(cache_key)
        if cached is not None:
            return [(proc, list(files)) for proc, files in cached]

        with _timer("process discovery", level="debug"):
            if self.input_mode == "unmerged":
                proc_map = dict(self.unmerged_index.get(tree_name) or self.unmerged_index.get("*", {}))
            else:
                proc_map = {p: [self.input_files[0]] for p in self.list_processes(tree_name)}

        if allow:
            allow_set = set(allow)
            proc_map = {k: v for k, v in proc_map.items() if k in allow_set}
        if block:
            block_set = set(block)
            proc_map = {k: v for k, v in proc_map.items() if k not in block_set}

        items = [(proc, _unique_paths(files)) for proc, files in sorted(proc_map.items())]
        self._process_cache[cache_key] = [(proc, list(files)) for proc, files in items]
        return [(proc, list(files)) for proc, files in items]

    def _direct_array_kwargs(self):
        kwargs = {"library": "np"}
        if bool(_cfg("runtime", "direct_use_threaded_io", default=False)):
            dec_workers = max(1, int(_cfg("runtime", "uproot_decompression_workers", default=8)))
            int_workers = max(1, int(_cfg("runtime", "uproot_interpretation_workers", default=8)))
            kwargs["decompression_executor"] = self._executor_pool("_uproot_decompression_pool", dec_workers)
            kwargs["interpretation_executor"] = self._executor_pool("_uproot_interpretation_pool", int_workers)
        return kwargs

    def _direct_chunk_iter(self, tree, wanted, entries_total, timings=None):
        step_size = _cfg("runtime", "direct_step_size", default=None)
        max_chunks = _cfg("runtime", "direct_validation_max_chunks", default=None)
        max_chunks = None if max_chunks in {None, ""} else max(1, int(max_chunks))
        if step_size:
            iterator = tree.iterate(wanted, step_size=step_size, **self._direct_array_kwargs())
            produced = 0
            while True:
                if max_chunks is not None and produced >= max_chunks:
                    break
                t_read = time.perf_counter()
                try:
                    arrays = next(iterator)
                except StopIteration:
                    break
                if timings is not None:
                    timings["array_read"] = timings.get("array_read", 0.0) + (time.perf_counter() - t_read)
                produced += 1
                yield None, None, arrays
            return
        step = max(1, int(_cfg("runtime", "direct_chunk_entries", default=20_000)))
        produced = 0
        for start in range(0, entries_total, step):
            if max_chunks is not None and produced >= max_chunks:
                break
            stop = min(entries_total, start + step)
            t_read = time.perf_counter()
            arrays = tree.arrays(wanted, entry_start=start, entry_stop=stop, **self._direct_array_kwargs())
            if timings is not None:
                timings["array_read"] = timings.get("array_read", 0.0) + (time.perf_counter() - t_read)
            produced += 1
            yield start, stop, arrays

    def _direct_total_chunks(self, entries_total):
        if _cfg("runtime", "direct_step_size", default=None):
            return 0
        step = max(1, int(_cfg("runtime", "direct_chunk_entries", default=20_000)))
        return int(np.ceil(entries_total / step)) if entries_total else 0

    def _log_direct_timing(self, label, timings, extra=""):
        if not bool(_cfg("runtime", "direct_timing_enabled", default=False)):
            return
        if not timings:
            return
        parts = []
        for key in ("open_tree", "array_read", "mask_eval", "hist_fill", "total"):
            if key in timings:
                parts.append(f"{key}={float(timings.get(key, 0.0)):.2f}s")
        suffix = f" {extra}" if extra else ""
        _log(f"timing {label}: " + " ".join(parts) + suffix, level="debug")
        detail_keys = (
            "hist_fill_bin_index",
            "hist_fill_mask_apply",
            "hist_fill_histogram_call",
            "hist_fill_sumw",
            "hist_fill_sumw2",
            "hist_fill_stage_compute",
            "hist_store_merge",
        )
        detail_parts = [f"{k}={float(timings.get(k, 0.0)):.2f}s" for k in detail_keys if k in timings]
        if detail_parts:
            _log(f"timing {label} hist-fill-detail: " + " ".join(detail_parts) + suffix, level="debug")

    def _read_hist_one_file_direct(self, root_file, tree_name, proc, observable, bins, required_branches, cut_expr, import_mode):
        weight_branch = _cfg("physics", "mc_weight_branch")
        is_data = proc in _cfg("physics", "data_processes")
        bins = np.asarray(bins, dtype=float)
        hist = np.zeros(len(bins) - 1, dtype=float)
        var = np.zeros(len(bins) - 1, dtype=float)
        timings = {"array_read": 0.0}

        with _timer("ROOT file open", collector=timings, key="open_tree", level="debug"):
            f = uproot.open(root_file)
        with f:
            tree, tree_path = self._get_tree_and_path(f, root_file, tree_name, proc)
            if tree is None:
                return None

            available = self._available_branches(tree, root_file, tree_path)
            entries_total = int(getattr(tree, "num_entries", 0))

            # If the requested observable is absent, no histogram can be filled.
            # Treat this as a critical-branch diagnostic by default; if the user
            # disables raising, return an empty per-file report without reading
            # cut/weight branches unnecessarily.
            obs_resolved = _resolve_requested_branches({observable}, available)
            if observable not in obs_resolved:
                _handle_missing_critical(
                    [observable],
                    f"direct observable tree={tree_name} proc={proc} file={root_file} path={tree_path}",
                )
                return {
                    "proc": proc, "hist": hist, "var": var, "entries_total": entries_total,
                    "entries_after_cut": 0, "file": root_file, "tree_path": tree_path,
                    "loaded_branch_names": [], "chunks": 0,
                }

            requested = set(required_branches or []) | {observable}
            if (not is_data) and isinstance(weight_branch, str) and weight_branch.strip():
                requested.add(weight_branch)

            # Direct mode is intentionally branch-minimal even if import_mode='all':
            # loading every branch defeats the SSD streaming/low-memory purpose.
            resolved = _resolve_requested_branches(requested, available)
            critical = {observable} | set(_extract_cut_branches(cut_expr))
            missing_critical = _missing_resolved(critical, resolved)
            _handle_missing_critical(
                missing_critical,
                f"direct histogram tree={tree_name} proc={proc} file={root_file} path={tree_path}",
            )
            if missing_critical:
                return {
                    "proc": proc, "hist": hist, "var": var, "entries_total": entries_total,
                    "entries_after_cut": 0, "file": root_file, "tree_path": tree_path,
                    "loaded_branch_names": sorted(resolved.keys()), "chunks": 0,
                }
            if (not is_data) and isinstance(weight_branch, str) and weight_branch.strip() and weight_branch not in resolved:
                _log(
                    f"Missing MC weight branch '{weight_branch}' for proc={proc} file={os.path.basename(root_file)}; MC contribution will be skipped",
                    level="warn",
                )
            wanted = sorted(set(resolved.values()))
            if not wanted:
                return {
                    "proc": proc, "hist": hist, "var": var, "entries_total": entries_total,
                    "entries_after_cut": 0, "file": root_file, "tree_path": tree_path,
                    "loaded_branch_names": [], "chunks": 0,
                }

            total_entry_chunks = self._direct_total_chunks(entries_total)
            _progress("direct chunks", 0, total_entry_chunks, f"proc={proc} tree={tree_path} file={os.path.basename(root_file)}")
            entries_after = 0
            chunks = 0
            for start, stop, arrays in self._direct_chunk_iter(tree, wanted, entries_total, timings=timings):
                arr_source = {k: np.asarray(v) for k, v in arrays.items()}
                arrs = {req: arr_source[src] for req, src in resolved.items() if src in arr_source}
                if observable not in arrs:
                    chunks += 1
                    _progress("direct chunks", chunks, total_entry_chunks, f"proc={proc} tree={tree_path} file={os.path.basename(root_file)}")
                    _handle_missing_critical(
                        [observable],
                        f"direct chunk materialization tree={tree_name} proc={proc} file={root_file} path={tree_path}",
                    )
                    continue
                _validate_array_lengths(arrs, f"direct chunk tree={tree_name} proc={proc} file={root_file} entries={start}:{stop}")

                mask = _evaluate_cut_mask(arrs, cut_expr) if cut_expr and arrs else None
                x = np.asarray(arrs[observable])
                if mask is not None:
                    entries_after += int(np.count_nonzero(mask))
                    x = x[mask]
                else:
                    entries_after += int(len(x))

                if is_data:
                    hist += _hist_with_flows(x, bins=bins)
                elif isinstance(weight_branch, str) and weight_branch in arrs:
                    w = np.asarray(arrs[weight_branch])
                    if mask is not None:
                        w = w[mask]
                    hist += _hist_with_flows(x, bins=bins, weights=w)
                    var += _hist_with_flows(x, bins=bins, weights=w * w)
                chunks += 1
                _progress("direct chunks", chunks, total_entry_chunks, f"proc={proc} tree={tree_path} file={os.path.basename(root_file)}")

        return {
            "proc": proc,
            "hist": hist,
            "var": var,
            "entries_total": entries_total,
            "entries_after_cut": entries_after,
            "file": root_file,
            "tree_path": tree_path,
            "loaded_branch_names": sorted(resolved.keys()),
            "chunks": chunks,
        }

    def histogram_direct(self, tree_name, observable, bins, cut_expr="", required_branches=None, import_mode=None, force=False):
        self.refresh_inputs(force=_cfg("cache", "force_reload_inputs", default=False), emit_log=True)
        norm_cut = _normalize_cut(cut_expr)
        final_import_mode = str(import_mode or _cfg("runtime", "array_branch_import_mode", default="needed")).lower().strip()
        if final_import_mode not in {"needed", "all"}:
            final_import_mode = "needed"

        if required_branches is None:
            needed = set(_plan_required_branches([observable], cut_expr=norm_cut, include_seed=False))
        else:
            needed = {b for b in required_branches if isinstance(b, str) and b.strip()}
            needed |= set(_extract_cut_branches(norm_cut))
            needed.add(observable)
        # Weight branches are added per MC process in _read_hist_one_file_direct;
        # do not force them into data reads or the direct-mode branch summary here.

        data = np.zeros(len(bins) - 1, dtype=float)
        mc_h, mc_v = {}, {}
        reports = []
        proc_items = self._process_file_items(tree_name)
        total_files = sum(len(files) for _, files in proc_items)
        done_files = 0
        _progress("direct files", done_files, total_files, f"mode={self.input_mode} tree={tree_name} observable={observable}")

        proc_chunks_by_proc = {proc: [] for proc, _ in proc_items}
        file_tasks = [(proc, rf) for proc, files in proc_items for rf in files]
        workers = self._direct_file_workers(total_files)

        def consume_payload(proc, rf, payload):
            nonlocal data, done_files
            done_files += 1
            tree_info = payload.get("tree_path", "?") if payload else "?"
            _progress("direct files", done_files, total_files, f"proc={proc} tree={tree_info} file={os.path.basename(rf)}")
            if payload is None:
                return
            proc_chunks_by_proc.setdefault(proc, []).append(payload)
            stack_name = self.style.stack_key(proc)
            if proc in _cfg("physics", "data_processes"):
                data += payload["hist"]
            else:
                mc_h[stack_name] = mc_h.get(stack_name, 0.0) + payload["hist"]
                mc_v[stack_name] = mc_v.get(stack_name, 0.0) + payload["var"]

        if workers > 1 and len(file_tasks) > 1:
            _log(f"direct parallel file reads: workers={workers} files={len(file_tasks)} tree={tree_name} obs={observable}")
            with ThreadPoolExecutor(max_workers=workers) as pool:
                fut_to_task = {
                    pool.submit(self._read_hist_one_file_direct, rf, tree_name, proc, observable, bins, needed, norm_cut, final_import_mode): (proc, rf)
                    for proc, rf in file_tasks
                }
                for fut in as_completed(fut_to_task):
                    proc, rf = fut_to_task[fut]
                    consume_payload(proc, rf, fut.result())
        else:
            for proc, rf in file_tasks:
                payload = self._read_hist_one_file_direct(rf, tree_name, proc, observable, bins, needed, norm_cut, final_import_mode)
                consume_payload(proc, rf, payload)

        for proc, files in proc_items:
            proc_chunks = proc_chunks_by_proc.get(proc, [])
            if not proc_chunks:
                continue
            branch_names = sorted(set().union(*(set(x.get("loaded_branch_names", [])) for x in proc_chunks)))
            reports.append({
                "proc": proc,
                "process_key": f"{tree_name}:{proc}",
                "n_files": len(files),
                "entries_total": int(sum(x["entries_total"] for x in proc_chunks)),
                "entries_after_cut": int(sum(x["entries_after_cut"] for x in proc_chunks)),
                "loaded_branches": len(branch_names),
                "branch_names": branch_names,
                "tree_paths": sorted(set(x.get("tree_path", "") for x in proc_chunks if x.get("tree_path"))),
                "chunks": int(sum(x.get("chunks", 0) for x in proc_chunks)),
            })

        if _cfg("logging", "show_branch_summary", default=True):
            total_after = int(sum(r.get("entries_after_cut", 0) for r in reports))
            total_before = int(sum(r.get("entries_total", 0) for r in reports))
            _log(f"direct-summary tree={tree_name} obs={observable} procs={len(reports)} events={total_after}/{total_before} branches={len(needed)} cut={_cut_preview(norm_cut)}")

        return {
            "data_counts": data,
            "mc_h": mc_h,
            "mc_v": mc_v,
            "reports": reports,
            "tree_name": tree_name,
            "cut": norm_cut,
            "observable": observable,
        }

    def _read_hists_one_file_direct(self, root_file, tree_name, proc, observables, bins_by_obs, required_branches, cut_expr, import_mode):
        weight_branch = _cfg("physics", "mc_weight_branch")
        is_data = proc in _cfg("physics", "data_processes")
        active_obs = [o for o in observables if o in bins_by_obs]
        hists = {o: np.zeros(len(np.asarray(bins_by_obs[o], dtype=float)) - 1, dtype=float) for o in active_obs}
        variances = {o: np.zeros_like(hists[o]) for o in active_obs}
        timings = {"array_read": 0.0}

        with uproot.open(root_file) as f:
            tree = None
            tree_path = None
            for p in self._tree_candidates(tree_name, proc):
                if p in f:
                    tree = f[p]
                    tree_path = p
                    break
            if tree is None:
                return None

            available = set(map(str, tree.keys()))
            entries_total = int(getattr(tree, "num_entries", 0))

            obs_resolved = _resolve_requested_branches(active_obs, available)
            missing_obs = _missing_resolved(active_obs, obs_resolved)
            if missing_obs:
                _handle_missing_critical(
                    missing_obs,
                    f"direct multi-observable tree={tree_name} proc={proc} file={root_file} path={tree_path}",
                )
                active_obs = [o for o in active_obs if o in obs_resolved]
            if not active_obs:
                return {
                    "proc": proc,
                    "hists": hists,
                    "vars": variances,
                    "entries_total": entries_total,
                    "entries_after_cut": 0,
                    "file": root_file,
                    "tree_path": tree_path,
                    "loaded_branch_names": [],
                    "chunks": 0,
                }

            requested = set(required_branches or []) | set(active_obs) | set(_extract_cut_branches(cut_expr))
            if (not is_data) and isinstance(weight_branch, str) and weight_branch.strip():
                requested.add(weight_branch)
            resolved = _resolve_requested_branches(requested, available)
            critical = set(active_obs) | set(_extract_cut_branches(cut_expr))
            missing_critical = _missing_resolved(critical, resolved)
            _handle_missing_critical(
                missing_critical,
                f"direct multi-histogram tree={tree_name} proc={proc} file={root_file} path={tree_path}",
            )
            if missing_critical:
                return {
                    "proc": proc,
                    "hists": hists,
                    "vars": variances,
                    "entries_total": entries_total,
                    "entries_after_cut": 0,
                    "file": root_file,
                    "tree_path": tree_path,
                    "loaded_branch_names": sorted(resolved.keys()),
                    "chunks": 0,
                }

            has_weight = is_data or not (isinstance(weight_branch, str) and weight_branch.strip()) or weight_branch in resolved
            if not has_weight:
                _log(
                    f"Missing MC weight branch '{weight_branch}' for proc={proc} file={os.path.basename(root_file)}; MC contribution will be skipped",
                    level="warn",
                )

            wanted = sorted(set(resolved.values()))
            if not wanted:
                return {
                    "proc": proc,
                    "hists": hists,
                    "vars": variances,
                    "entries_total": entries_total,
                    "entries_after_cut": 0,
                    "file": root_file,
                    "tree_path": tree_path,
                    "loaded_branch_names": [],
                    "chunks": 0,
                }

            total_entry_chunks = self._direct_total_chunks(entries_total)
            _progress("direct chunks", 0, total_entry_chunks, f"proc={proc} tree={tree_path} file={os.path.basename(root_file)} obs={len(active_obs)}")
            entries_after = 0
            chunks = 0
            for start, stop, arrays in self._direct_chunk_iter(tree, wanted, entries_total, timings=timings):
                arr_source = {k: np.asarray(v) for k, v in arrays.items()}
                arrs = {req: arr_source[src] for req, src in resolved.items() if src in arr_source}
                _validate_array_lengths(arrs, f"direct multi chunk tree={tree_name} proc={proc} file={root_file} entries={start}:{stop}")

                mask = _evaluate_cut_mask(arrs, cut_expr) if cut_expr and arrs else None
                if active_obs:
                    ref = np.asarray(arrs[active_obs[0]])
                    entries_after += int(np.count_nonzero(mask)) if mask is not None else int(len(ref))

                w = None
                if (not is_data) and has_weight and isinstance(weight_branch, str) and weight_branch in arrs:
                    w = np.asarray(arrs[weight_branch])
                    if mask is not None:
                        w = w[mask]

                for obs in active_obs:
                    if obs not in arrs:
                        _handle_missing_critical(
                            [obs],
                            f"direct multi chunk materialization tree={tree_name} proc={proc} file={root_file} path={tree_path}",
                        )
                        continue
                    x = np.asarray(arrs[obs])
                    if mask is not None:
                        x = x[mask]
                    bins = np.asarray(bins_by_obs[obs], dtype=float)
                    if is_data:
                        hists[obs] += _hist_with_flows(x, bins=bins)
                    elif w is not None:
                        hists[obs] += _hist_with_flows(x, bins=bins, weights=w)
                        variances[obs] += _hist_with_flows(x, bins=bins, weights=w * w)

                chunks += 1
                _progress("direct chunks", chunks, total_entry_chunks, f"proc={proc} tree={tree_path} file={os.path.basename(root_file)} obs={len(active_obs)}")

        return {
            "proc": proc,
            "hists": hists,
            "vars": variances,
            "entries_total": entries_total,
            "entries_after_cut": entries_after,
            "file": root_file,
            "tree_path": tree_path,
            "loaded_branch_names": sorted(resolved.keys()),
            "chunks": chunks,
        }

    def histograms_direct(self, tree_name, observables, bins_by_obs, cut_expr="", required_branches=None, import_mode=None, force=False):
        self.refresh_inputs(force=_cfg("cache", "force_reload_inputs", default=False), emit_log=True)
        norm_cut = _normalize_cut(cut_expr)
        obs = [o for o in _validate_observables(observables) if o in bins_by_obs]
        final_import_mode = str(import_mode or _cfg("runtime", "array_branch_import_mode", default="needed")).lower().strip()
        if final_import_mode not in {"needed", "all"}:
            final_import_mode = "needed"

        if required_branches is None:
            needed = set(_plan_required_branches(obs, cut_expr=norm_cut, include_seed=False))
        else:
            needed = {b for b in required_branches if isinstance(b, str) and b.strip()}
            needed |= set(obs)
            needed |= set(_extract_cut_branches(norm_cut))

        results = {
            o: {
                "data_counts": np.zeros(len(np.asarray(bins_by_obs[o], dtype=float)) - 1, dtype=float),
                "mc_h": {},
                "mc_v": {},
            }
            for o in obs
        }
        reports = []
        proc_items = self._process_file_items(tree_name)
        total_files = sum(len(files) for _, files in proc_items)
        done_files = 0
        _progress("direct files", done_files, total_files, f"mode={self.input_mode} tree={tree_name} observables={len(obs)}")

        proc_chunks_by_proc = {proc: [] for proc, _ in proc_items}
        file_tasks = [(proc, rf) for proc, files in proc_items for rf in files]
        workers = self._direct_file_workers(total_files)

        def consume_payload(proc, rf, payload):
            nonlocal done_files
            done_files += 1
            tree_info = payload.get("tree_path", "?") if payload else "?"
            _progress("direct files", done_files, total_files, f"proc={proc} tree={tree_info} file={os.path.basename(rf)} observables={len(obs)}")
            if payload is None:
                return
            proc_chunks_by_proc.setdefault(proc, []).append(payload)
            stack_name = self.style.stack_key(proc)
            for obs_name in obs:
                if proc in _cfg("physics", "data_processes"):
                    results[obs_name]["data_counts"] += payload["hists"].get(obs_name, 0.0)
                else:
                    results[obs_name]["mc_h"][stack_name] = results[obs_name]["mc_h"].get(stack_name, 0.0) + payload["hists"].get(obs_name, 0.0)
                    results[obs_name]["mc_v"][stack_name] = results[obs_name]["mc_v"].get(stack_name, 0.0) + payload["vars"].get(obs_name, 0.0)

        if workers > 1 and len(file_tasks) > 1:
            _log(f"direct parallel file reads: workers={workers} files={len(file_tasks)} tree={tree_name} obs={len(obs)}")
            with ThreadPoolExecutor(max_workers=workers) as pool:
                fut_to_task = {
                    pool.submit(self._read_hists_one_file_direct, rf, tree_name, proc, obs, bins_by_obs, needed, norm_cut, final_import_mode): (proc, rf)
                    for proc, rf in file_tasks
                }
                for fut in as_completed(fut_to_task):
                    proc, rf = fut_to_task[fut]
                    consume_payload(proc, rf, fut.result())
        else:
            for proc, rf in file_tasks:
                payload = self._read_hists_one_file_direct(rf, tree_name, proc, obs, bins_by_obs, needed, norm_cut, final_import_mode)
                consume_payload(proc, rf, payload)

        for proc, files in proc_items:
            proc_chunks = proc_chunks_by_proc.get(proc, [])
            if not proc_chunks:
                continue
            branch_names = sorted(set().union(*(set(x.get("loaded_branch_names", [])) for x in proc_chunks)))
            reports.append({
                "proc": proc,
                "process_key": f"{tree_name}:{proc}",
                "n_files": len(files),
                "entries_total": int(sum(x["entries_total"] for x in proc_chunks)),
                "entries_after_cut": int(sum(x["entries_after_cut"] for x in proc_chunks)),
                "loaded_branches": len(branch_names),
                "branch_names": branch_names,
                "tree_paths": sorted(set(x.get("tree_path", "") for x in proc_chunks if x.get("tree_path"))),
                "chunks": int(sum(x.get("chunks", 0) for x in proc_chunks)),
            })

        if _cfg("logging", "show_branch_summary", default=True):
            total_after = int(sum(r.get("entries_after_cut", 0) for r in reports))
            total_before = int(sum(r.get("entries_total", 0) for r in reports))
            _log(f"direct-summary tree={tree_name} obs={len(obs)} procs={len(reports)} events={total_after}/{total_before} branches={len(needed)} cut={_cut_preview(norm_cut)}")

        return {
            "histograms": results,
            "reports": reports,
            "tree_name": tree_name,
            "cut": norm_cut,
            "observables": obs,
        }



    def _read_hists_multi_cut_one_file_direct(self, root_file, tree_name, proc, cut_jobs, bins_by_obs, required_branches, import_mode):
        """Read one ROOT file once and fill many cut/observable histogram jobs."""
        weight_branch = _cfg("physics", "mc_weight_branch")
        is_data = proc in _cfg("physics", "data_processes")

        normalized_jobs = []
        all_obs = []
        for idx, job in enumerate(cut_jobs or []):
            job_id = job.get("job_id", idx)
            job_obs = [o for o in job.get("observables", []) if o in bins_by_obs]
            if not job_obs:
                continue
            for obs in job_obs:
                if obs not in all_obs:
                    all_obs.append(obs)
            norm_job = {
                "job_id": job_id,
                "observables": job_obs,
                "cut_expr": _normalize_cut(job.get("cut_expr", job.get("cut", ""))),
            }
            if job.get("zzcr_channel") in {"ee", "mm"} and job.get("zzcr_stage") in set(range(1, 8)):
                norm_job["zzcr_channel"] = job.get("zzcr_channel")
                norm_job["zzcr_stage"] = int(job.get("zzcr_stage"))
            normalized_jobs.append(norm_job)

        job_results = {
            job["job_id"]: {
                "hists": {o: np.zeros(len(np.asarray(bins_by_obs[o], dtype=float)) - 1, dtype=float) for o in job["observables"]},
                "vars": {o: np.zeros(len(np.asarray(bins_by_obs[o], dtype=float)) - 1, dtype=float) for o in job["observables"]},
                "entries_after_cut": 0,
                "observables": list(job["observables"]),
            }
            for job in normalized_jobs
        }

        if not normalized_jobs:
            return None

        timings = {"open_tree": 0.0, "array_read": 0.0, "mask_eval": 0.0, "hist_fill": 0.0}
        use_stage_engine = bool(_cfg("runtime", "zzcr_stage_engine", default=True)) and normalized_jobs and all(
            job.get("zzcr_channel") in {"ee", "mm"} and int(job.get("zzcr_stage", 0)) in range(1, 8)
            for job in normalized_jobs
        )
        t_total = time.perf_counter()
        t_open = time.perf_counter()
        f = uproot.open(root_file)
        timings["open_tree"] += time.perf_counter() - t_open
        with f:
            tree, tree_path = self._get_tree_and_path(f, root_file, tree_name, proc)
            if tree is None:
                return None

            available = self._available_branches(tree, root_file, tree_path)
            entries_total = int(getattr(tree, "num_entries", 0))

            obs_resolved = _resolve_requested_branches(all_obs, available)
            missing_obs = _missing_resolved(all_obs, obs_resolved)
            if missing_obs:
                _handle_missing_critical(
                    missing_obs,
                    f"direct multi-cut observables tree={tree_name} proc={proc} file={root_file} path={tree_path}",
                )
                all_obs = [o for o in all_obs if o in obs_resolved]
                for job in normalized_jobs:
                    job["observables"] = [o for o in job["observables"] if o in obs_resolved]

            normalized_jobs = [job for job in normalized_jobs if job["observables"]]
            if not normalized_jobs:
                return {
                    "proc": proc,
                    "jobs": job_results,
                    "entries_total": entries_total,
                    "file": root_file,
                    "tree_path": tree_path,
                    "loaded_branch_names": [],
                    "chunks": 0,
                }

            requested = set(required_branches or []) | set(all_obs)
            for job in normalized_jobs:
                requested |= set(_extract_cut_branches(job["cut_expr"]))
            if (not is_data) and isinstance(weight_branch, str) and weight_branch.strip():
                requested.add(weight_branch)

            resolved = _resolve_requested_branches(requested, available)
            critical = set(all_obs)
            for job in normalized_jobs:
                critical |= set(_extract_cut_branches(job["cut_expr"]))
            missing_critical = _missing_resolved(critical, resolved)
            _handle_missing_critical(
                missing_critical,
                f"direct multi-cut histograms tree={tree_name} proc={proc} file={root_file} path={tree_path}",
            )
            if missing_critical:
                return {
                    "proc": proc,
                    "jobs": job_results,
                    "entries_total": entries_total,
                    "file": root_file,
                    "tree_path": tree_path,
                    "loaded_branch_names": sorted(resolved.keys()),
                    "chunks": 0,
                }

            has_weight = is_data or not (isinstance(weight_branch, str) and weight_branch.strip()) or weight_branch in resolved
            if not has_weight:
                _log(
                    f"Missing MC weight branch '{weight_branch}' for proc={proc} file={os.path.basename(root_file)}; MC contribution will be skipped",
                    level="warn",
                )

            wanted = sorted(set(resolved.values()))
            if not wanted:
                return {
                    "proc": proc,
                    "jobs": job_results,
                    "entries_total": entries_total,
                    "file": root_file,
                    "tree_path": tree_path,
                    "loaded_branch_names": [],
                    "chunks": 0,
                }

            total_entry_chunks = self._direct_total_chunks(entries_total)
            _progress("direct chunks", 0, total_entry_chunks, f"proc={proc} tree={tree_path} file={os.path.basename(root_file)} jobs={len(normalized_jobs)} obs={len(all_obs)}")
            chunks = 0
            for start, stop, arrays in self._direct_chunk_iter(tree, wanted, entries_total, timings=timings):
                arr_source = {k: np.asarray(v) for k, v in arrays.items()}
                arrs = {req: arr_source[src] for req, src in resolved.items() if src in arr_source}
                _validate_array_lengths(arrs, f"direct multi-cut chunk tree={tree_name} proc={proc} file={root_file} entries={start}:{stop}")

                mask_cache = {}
                cut_masks = {}
                stage_jobs = None
                if use_stage_engine:
                    t_stage_count = time.perf_counter()
                    stage_ee_for_counts, stage_mm_for_counts = compute_zzcr_stages(arrs)
                    timings["hist_fill_stage_compute"] = timings.get("hist_fill_stage_compute", 0.0) + (time.perf_counter() - t_stage_count)
                    stage_lookup = {"ee": stage_ee_for_counts, "mm": stage_mm_for_counts}
                    stage_jobs = []
                    for job in normalized_jobs:
                        job_id = job["job_id"]
                        channel = job["zzcr_channel"]
                        stage = int(job["zzcr_stage"])
                        stage_jobs.append((job_id, channel, stage))
                        job_results[job_id]["entries_after_cut"] += int(np.count_nonzero(stage_lookup[channel] >= stage))
                else:
                    for job in normalized_jobs:
                        job_id = job["job_id"]
                        job_obs = job["observables"]
                        cut_expr = job["cut_expr"]
                        if cut_expr:
                            if cut_expr not in mask_cache:
                                t_mask = time.perf_counter()
                                mask_cache[cut_expr] = _evaluate_cut_mask(arrs, cut_expr)
                                timings["mask_eval"] += time.perf_counter() - t_mask
                            mask = mask_cache[cut_expr]
                        else:
                            mask = None
                        cut_masks[job_id] = mask
                        ref = np.asarray(arrs[job_obs[0]])
                        job_results[job_id]["entries_after_cut"] += int(np.count_nonzero(mask)) if mask is not None else int(len(ref))

                w_full = None
                if (not is_data) and has_weight and isinstance(weight_branch, str) and weight_branch in arrs:
                    w_full = np.asarray(arrs[weight_branch])

                t_hist = time.perf_counter()
                fill_histograms_for_chunk(
                    arrs,
                    all_obs,
                    {obs: {"bins": bins_by_obs[obs]} for obs in all_obs if obs in bins_by_obs},
                    cut_masks,
                    w_full,
                    job_results,
                    proc,
                    tree_name,
                    is_data=is_data,
                    timings=timings,
                    stage_jobs=stage_jobs,
                    stage_cache=stage_lookup if use_stage_engine else None,
                )
                timings["hist_fill"] += time.perf_counter() - t_hist

                chunks += 1
                _progress("direct chunks", chunks, total_entry_chunks, f"proc={proc} tree={tree_path} file={os.path.basename(root_file)} jobs={len(normalized_jobs)} obs={len(all_obs)}")

        timings["total"] = time.perf_counter() - t_total
        return {
            "proc": proc,
            "jobs": job_results,
            "entries_total": entries_total,
            "file": root_file,
            "tree_path": tree_path,
            "loaded_branch_names": sorted(resolved.keys()),
            "chunks": chunks,
            "timings": timings,
        }

    def histograms_direct_multi_cut(self, tree_name, cut_jobs, bins_by_obs, required_branches=None, import_mode=None, force=False):
        """Stream files once per observable batch while filling multiple cut jobs."""
        self.refresh_inputs(force=_cfg("cache", "force_reload_inputs", default=False), emit_log=True)
        final_import_mode = str(import_mode or _cfg("runtime", "array_branch_import_mode", default="needed")).lower().strip()
        if final_import_mode not in {"needed", "all"}:
            final_import_mode = "needed"

        normalized_jobs = []
        for idx, job in enumerate(cut_jobs or []):
            job_id = job.get("job_id", idx)
            job_obs = [o for o in _validate_observables(job.get("observables", [])) if o in bins_by_obs]
            if not job_obs:
                continue
            norm_job = {
                "job_id": job_id,
                "observables": job_obs,
                "cut_expr": _normalize_cut(job.get("cut_expr", job.get("cut", ""))),
            }
            if job.get("zzcr_channel") in {"ee", "mm"} and job.get("zzcr_stage") in set(range(1, 8)):
                norm_job["zzcr_channel"] = job.get("zzcr_channel")
                norm_job["zzcr_stage"] = int(job.get("zzcr_stage"))
            normalized_jobs.append(norm_job)

        results = {
            job["job_id"]: {
                "histograms": {
                    obs: {
                        "data_counts": np.zeros(len(np.asarray(bins_by_obs[obs], dtype=float)) - 1, dtype=float),
                        "mc_h": {},
                        "mc_v": {},
                    }
                    for obs in job["observables"]
                },
                "reports": [],
                "process_histograms": {},
                "cut": job["cut_expr"],
                "observables": list(job["observables"]),
            }
            for job in normalized_jobs
        }

        if not normalized_jobs:
            return {"jobs": results, "reports": [], "tree_name": tree_name}

        if required_branches is None:
            needed = set()
            for job in normalized_jobs:
                needed |= set(_plan_required_branches(job["observables"], cut_expr=job["cut_expr"], include_seed=False))
        else:
            needed = {b for b in required_branches if isinstance(b, str) and b.strip()}
            for job in normalized_jobs:
                needed |= set(job["observables"])
                needed |= set(_extract_cut_branches(job["cut_expr"]))

        proc_items = self._process_file_items(tree_name)
        total_files = sum(len(files) for _, files in proc_items)
        done_files = 0
        _progress("direct files", done_files, total_files, f"mode={self.input_mode} tree={tree_name} cut_jobs={len(normalized_jobs)}")

        proc_chunks_by_job = {job["job_id"]: {proc: [] for proc, _ in proc_items} for job in normalized_jobs}
        file_tasks = [(proc, rf) for proc, files in proc_items for rf in files]
        workers = self._direct_file_workers(total_files)
        total_timings = {"open_tree": 0.0, "array_read": 0.0, "mask_eval": 0.0, "hist_fill": 0.0, "total": 0.0}

        def consume_payload(proc, rf, payload):
            nonlocal done_files
            done_files += 1
            tree_info = payload.get("tree_path", "?") if payload else "?"
            _progress("direct files", done_files, total_files, f"proc={proc} tree={tree_info} file={os.path.basename(rf)} cut_jobs={len(normalized_jobs)}")
            if payload is None:
                return

            for key, value in (payload.get("timings") or {}).items():
                total_timings[key] = total_timings.get(key, 0.0) + float(value or 0.0)

            stack_name = self.style.stack_key(proc)
            for job in normalized_jobs:
                job_id = job["job_id"]
                job_payload = payload.get("jobs", {}).get(job_id)
                if not job_payload:
                    continue
                proc_chunks_by_job.setdefault(job_id, {}).setdefault(proc, []).append({
                    "entries_total": payload.get("entries_total", 0),
                    "entries_after_cut": job_payload.get("entries_after_cut", 0),
                    "loaded_branch_names": payload.get("loaded_branch_names", []),
                    "tree_path": payload.get("tree_path", ""),
                    "chunks": payload.get("chunks", 0),
                })
                t_merge = time.perf_counter()
                proc_store = results[job_id].setdefault("process_histograms", {}).setdefault(proc, {})
                for obs in job["observables"]:
                    if obs not in results[job_id]["histograms"]:
                        continue
                    obs_values = np.asarray(job_payload["hists"].get(obs, np.zeros_like(results[job_id]["histograms"][obs]["data_counts"])), dtype=float)
                    obs_vars = np.asarray(job_payload["vars"].get(obs, obs_values if proc in _cfg("physics", "data_processes") else np.zeros_like(obs_values)), dtype=float)
                    rec = proc_store.setdefault(obs, {"values": np.zeros_like(obs_values), "variances": np.zeros_like(obs_vars), "process_group": stack_name, "is_data": proc in _cfg("physics", "data_processes")})
                    rec["values"] += obs_values
                    rec["variances"] += obs_vars
                    if proc in _cfg("physics", "data_processes"):
                        results[job_id]["histograms"][obs]["data_counts"] += obs_values
                    else:
                        results[job_id]["histograms"][obs]["mc_h"][stack_name] = results[job_id]["histograms"][obs]["mc_h"].get(stack_name, 0.0) + obs_values
                        results[job_id]["histograms"][obs]["mc_v"][stack_name] = results[job_id]["histograms"][obs]["mc_v"].get(stack_name, 0.0) + obs_vars
                total_timings["hist_store_merge"] = total_timings.get("hist_store_merge", 0.0) + (time.perf_counter() - t_merge)

        if workers > 1 and len(file_tasks) > 1:
            _log(f"direct multi-cut parallel file reads: workers={workers} files={len(file_tasks)} tree={tree_name} cut_jobs={len(normalized_jobs)}")
            with ThreadPoolExecutor(max_workers=workers) as pool:
                fut_to_task = {
                    pool.submit(self._read_hists_multi_cut_one_file_direct, rf, tree_name, proc, normalized_jobs, bins_by_obs, needed, final_import_mode): (proc, rf)
                    for proc, rf in file_tasks
                }
                for fut in as_completed(fut_to_task):
                    proc, rf = fut_to_task[fut]
                    consume_payload(proc, rf, fut.result())
        else:
            for proc, rf in file_tasks:
                payload = self._read_hists_multi_cut_one_file_direct(rf, tree_name, proc, normalized_jobs, bins_by_obs, needed, final_import_mode)
                consume_payload(proc, rf, payload)

        for job in normalized_jobs:
            job_id = job["job_id"]
            reports = []
            for proc, files in proc_items:
                proc_chunks = proc_chunks_by_job.get(job_id, {}).get(proc, [])
                if not proc_chunks:
                    continue
                branch_names = sorted(set().union(*(set(x.get("loaded_branch_names", [])) for x in proc_chunks)))
                reports.append({
                    "proc": proc,
                    "process_key": f"{tree_name}:{proc}",
                    "n_files": len(files),
                    "entries_total": int(sum(x.get("entries_total", 0) for x in proc_chunks)),
                    "entries_after_cut": int(sum(x.get("entries_after_cut", 0) for x in proc_chunks)),
                    "loaded_branches": len(branch_names),
                    "branch_names": branch_names,
                    "tree_paths": sorted(set(x.get("tree_path", "") for x in proc_chunks if x.get("tree_path"))),
                    "chunks": int(sum(x.get("chunks", 0) for x in proc_chunks)),
                })
            results[job_id]["reports"] = reports

        if _cfg("logging", "show_branch_summary", default=True):
            total_reports = sum(len(job_result.get("reports", [])) for job_result in results.values())
            _log(f"direct-multicut-summary tree={tree_name} cut_jobs={len(normalized_jobs)} procs/job-reports={total_reports} branches={len(needed)}")
        self._log_direct_timing("direct-multicut", total_timings, extra=f"tree={tree_name} files={total_files} cut_jobs={len(normalized_jobs)}")

        return {
            "jobs": results,
            "reports": [rep for job_result in results.values() for rep in job_result.get("reports", [])],
            "tree_name": tree_name,
            "cut_jobs": normalized_jobs,
            "timings": total_timings,
        }

    def diagnose_branch_availability(self, tree_name, observables=None, cuts=None, include_seed=None, max_files_per_proc=1, raise_on_error=False):
        """Check branch availability from ROOT metadata without reading arrays."""
        self.refresh_inputs(force=_cfg("cache", "force_reload_inputs", default=False), emit_log=False)
        obs = _validate_observables(observables or _cfg("execution", "default_observables") or list(OBSERVABLES.keys()))
        cut_expr = _combine_subcategory_cuts_or(cuts or [])
        if include_seed is None:
            include_seed = _data_loading_mode() != "direct"
        required = set(_plan_required_branches(obs, cut_expr=cut_expr, include_seed=include_seed))
        critical = set(obs) | set(_extract_cut_branches(cut_expr))

        report = {"tree_name": tree_name, "checked": [], "errors": [], "warnings": []}
        max_files = max(1, int(max_files_per_proc or 1))

        for proc, files in self._process_file_items(tree_name):
            for rf in files[:max_files]:
                with uproot.open(rf) as f:
                    tree = None
                    tree_path = None
                    for p in self._tree_candidates(tree_name, proc):
                        if p in f:
                            tree = f[p]
                            tree_path = p
                            break
                    if tree is None:
                        msg = f"No Events tree found for tree={tree_name} proc={proc} file={rf}"
                        report["errors"].append(msg)
                        continue
                    available = self._available_branches(tree, rf, tree_path)
                    resolved = _resolve_requested_branches(required, available)
                    missing_critical = _missing_resolved(critical, resolved)
                    missing_optional = sorted(required - critical - set(resolved.keys()))
                    item = {
                        "proc": proc,
                        "file": rf,
                        "tree_path": tree_path,
                        "required": len(required),
                        "resolved": len(resolved),
                        "missing_critical": missing_critical,
                        "missing_optional": missing_optional,
                    }
                    report["checked"].append(item)
                    if missing_critical:
                        report["errors"].append(
                            f"Missing critical branches for tree={tree_name} proc={proc} file={os.path.basename(rf)}: {missing_critical}"
                        )
                    if missing_optional:
                        report["warnings"].append(
                            f"Missing optional branches for tree={tree_name} proc={proc} file={os.path.basename(rf)}: {missing_optional[:20]}"
                        )

        for msg in report["warnings"]:
            _log(f"branch diagnostic warning: {msg}", level="warn")
        for msg in report["errors"]:
            _log(f"branch diagnostic error: {msg}", level="error")
        _log(
            f"Branch diagnostics tree={tree_name}: checked={len(report['checked'])} "
            f"errors={len(report['errors'])} warnings={len(report['warnings'])}"
        )
        if report["errors"] and raise_on_error:
            raise RuntimeError("Branch diagnostics failed: " + "; ".join(report["errors"]))
        return report


    def _read_one_file(self, root_file, tree_name, proc, required_branches, cut_expr, import_mode, critical_branches=None):
        with uproot.open(root_file) as f:
            tree = None
            tree_path = None
            for p in self._tree_candidates(tree_name, proc):
                if p in f:
                    tree = f[p]
                    tree_path = p
                    break
            if tree is None:
                return None

            available = set(map(str, tree.keys()))
            if str(import_mode).lower().strip() == "all":
                resolved = {k: k for k in available}
                wanted = sorted(available)
            else:
                resolved = _resolve_requested_branches(required_branches, available)
                wanted = sorted(set(resolved.values()))
            missing_critical = _missing_resolved(critical_branches or [], resolved)
            _handle_missing_critical(
                missing_critical,
                f"array load tree={tree_name} proc={proc} file={root_file}",
            )
            if missing_critical:
                return {
                    "proc": proc,
                    "arrays": {},
                    "entries_total": int(getattr(tree, "num_entries", 0)),
                    "entries_after_cut": 0,
                    "file": root_file,
                    "tree_path": tree_path,
                    "loaded_branch_names": sorted(resolved.keys()),
                }
            if not wanted:
                return {"proc": proc, "arrays": {}, "entries_total": 0, "entries_after_cut": 0, "file": root_file}

            arrays = tree.arrays(
                wanted,
                library="np",
                decompression_executor=self._pool(),
                interpretation_executor=self._pool(),
            )

        arr_source = {k: np.asarray(v) for k, v in arrays.items()}
        entries_total = len(next(iter(arr_source.values()))) if arr_source else 0

        if cut_expr:
            arr_source = _filter_arrays_with_cut(arr_source, cut_expr)

        arr_final = {req: arr_source[src] for req, src in resolved.items() if src in arr_source}
        _validate_array_lengths(arr_final, f"array load tree={tree_name} proc={proc} file={root_file}")
        entries_after = len(next(iter(arr_final.values()))) if arr_final else 0
        return {
            "proc": proc,
            "arrays": arr_final,
            "entries_total": int(entries_total),
            "entries_after_cut": int(entries_after),
            "file": root_file,
            "tree_path": tree_path,
            "loaded_branch_names": sorted(arr_final.keys()),
        }

    def load_arrays(self, tree_name, cut_expr="", observables=None, required_branches=None, force=False, import_mode=None, _internal_skip_cut_reuse=False, _internal_refresh_inputs=True, _internal_emit_load_log=True, _internal_emit_summary_log=True):
        if _internal_refresh_inputs:
            self.refresh_inputs(force=_cfg("cache", "force_reload_inputs", default=False), emit_log=not _internal_skip_cut_reuse)

        if required_branches is None:
            obs_in = list(observables) if observables is not None else list(OBSERVABLES.keys())
            obs = _validate_observables(obs_in)
            needed = set(_plan_required_branches(obs, cut_expr=cut_expr))
        else:
            obs = sorted(set(observables or []))
            needed = {b for b in required_branches if isinstance(b, str) and b.strip()}
            w = _cfg("physics", "mc_weight_branch")
            if isinstance(w, str) and w.strip():
                needed.add(w)

        # Preserve branch-import configurability: honor both "needed" and "all".
        final_import_mode = str(import_mode or _cfg("runtime", "array_branch_import_mode", default="needed")).lower().strip()
        if final_import_mode not in {"needed", "all"}:
            _log(f"Unknown import_mode='{final_import_mode}', using 'needed'", level="warn")
            final_import_mode = "needed"
        norm_cut = _normalize_cut(cut_expr)
        critical_branches = set(obs) | set(_extract_cut_branches(norm_cut))

        if _internal_emit_load_log and _cfg("logging", "show_cut", default=True):
            _log(f"load_arrays tree={tree_name} cut={_cut_preview(norm_cut)}")

        cache_key = (
            tree_name,
            tuple(sorted(needed)),
            norm_cut,
            final_import_mode,
            tuple(self.input_files),
            self.input_mode,
        )
        if _cfg("cache", "arrays_in_memory", default=True) and (not force) and cache_key in self.array_cache:
            _log(f"cache-hit tree={tree_name} cut={_cut_preview(norm_cut)} branches={len(needed)}")
            cached = self.array_cache[cache_key]
            self.array_cache.move_to_end(cache_key)
            if not norm_cut:
                self._seed_uncut_base_cache(tree_name, final_import_mode, cached)
            return cached

        # Optimization path: load uncut arrays once, then apply cut masks in-memory.
        if (not _internal_skip_cut_reuse) and _cfg("runtime", "reuse_uncut_arrays_for_cuts", default=True) and norm_cut:
            base_key = (
                tree_name,
                final_import_mode,
                tuple(self.input_files),
                self.input_mode,
            )
            required_uncut = set(needed)
            entry = self.uncut_base_cache.get(base_key)

            if entry:
                target_branches = set(entry.get("branches", set())) | required_uncut
                cache_hits = (not force) and required_uncut.issubset(set(entry.get("branches", set())))
            else:
                target_branches = set(required_uncut)
                cache_hits = False

            if cache_hits:
                base_payload = entry["payload"]
            else:
                base_payload = self.load_arrays(
                    tree_name=tree_name,
                    cut_expr="",
                    observables=obs,
                    required_branches=sorted(target_branches),
                    force=force,
                    import_mode=final_import_mode,
                    _internal_skip_cut_reuse=True,
                    _internal_refresh_inputs=False,
                    _internal_emit_load_log=False,
                    _internal_emit_summary_log=False,
                )
                self._seed_uncut_base_cache(tree_name, final_import_mode, base_payload)

            out = {}
            reports = []
            base_report_by_proc = {r["proc"]: r for r in base_payload.get("reports", [])}
            expr = _cut_to_pandas(norm_cut)
            for proc, arrs in sorted(base_payload["arrays"].items()):
                total = len(next(iter(arrs.values()))) if arrs else 0
                filtered = arrs
                if expr and arrs:
                    filtered = _filter_arrays_with_cut(arrs, norm_cut)

                if filtered:
                    out[proc] = filtered
                reports.append({
                    "proc": proc,
                    "n_files": int(base_report_by_proc.get(proc, {}).get("n_files", 0)),
                    "entries_total": int(total),
                    "entries_after_cut": int(len(next(iter(filtered.values()))) if filtered else 0),
                    "loaded_branches": len(filtered),
                })

            result = {"arrays": out, "reports": reports, "tree_name": tree_name, "cut": norm_cut, "observables": obs}
            self._cache_put(cache_key, result)
            return result

        out = {}
        reports = []
        proc_items = self._process_file_items(tree_name)
        total_chunks = sum(len(files) for _, files in proc_items)
        completed_chunks = 0
        _progress("load chunks", completed_chunks, total_chunks, f"mode={self.input_mode} tree={tree_name} processes={len(proc_items)}")

        for proc, files in proc_items:
            futures = {}
            chunks = []
            if _cfg("runtime", "enable_parallel_read", default=True) and len(files) > 1:
                for rf in files:
                    fut = self._pool().submit(self._read_one_file, rf, tree_name, proc, needed, cut_expr, final_import_mode, critical_branches)
                    futures[fut] = rf
                for fut in as_completed(futures):
                    rf = futures[fut]
                    payload = fut.result()
                    completed_chunks += 1
                    tree_info = payload.get("tree_path", "?") if (payload is not None and _cfg("logging", "show_tree_path", default=True)) else "?"
                    _progress("load chunks", completed_chunks, total_chunks, f"mode={self.input_mode} proc={proc} tree={tree_info} file={os.path.basename(rf)}")
                    if payload is not None:
                        chunks.append(payload)
            else:
                for rf in files:
                    payload = self._read_one_file(rf, tree_name, proc, needed, cut_expr, final_import_mode, critical_branches)
                    completed_chunks += 1
                    tree_info = payload.get("tree_path", "?") if (payload is not None and _cfg("logging", "show_tree_path", default=True)) else "?"
                    _progress("load chunks", completed_chunks, total_chunks, f"mode={self.input_mode} proc={proc} tree={tree_info} file={os.path.basename(rf)}")
                    if payload is not None:
                        chunks.append(payload)

            if not chunks:
                continue

            merged = {}
            keys = sorted(set().union(*(set(x["arrays"].keys()) for x in chunks)))
            for k in keys:
                vals = [x["arrays"][k] for x in chunks if k in x["arrays"]]
                if vals:
                    merged[k] = np.concatenate(vals) if len(vals) > 1 else vals[0]

            if merged:
                _validate_array_lengths(merged, f"merged payload tree={tree_name} proc={proc}")
                out[proc] = merged
            branch_names = sorted(set().union(*(set(x.get("loaded_branch_names", [])) for x in chunks)))
            reports.append({
                "proc": proc,
                "process_key": f"{tree_name}:{proc}",
                "n_files": len(files),
                "entries_total": int(sum(x["entries_total"] for x in chunks)),
                "entries_after_cut": int(sum(x["entries_after_cut"] for x in chunks)),
                "loaded_branches": len(merged),
                "branch_names": branch_names,
                "tree_paths": sorted(set(x.get("tree_path", "") for x in chunks if x.get("tree_path"))),
            })

        result = {"arrays": out, "reports": reports, "tree_name": tree_name, "cut": norm_cut, "observables": obs}
        if _internal_emit_summary_log and _cfg("logging", "show_branch_summary", default=True):
            total_after = int(sum(r.get("entries_after_cut", 0) for r in reports))
            total_before = int(sum(r.get("entries_total", 0) for r in reports))
            _log(f"summary tree={tree_name} procs={len(reports)} events={total_after}/{total_before} branches={len(needed)} cut={_cut_preview(norm_cut)}")
        self._cache_put(cache_key, result)
        if not norm_cut:
            self._seed_uncut_base_cache(tree_name, final_import_mode, result)
        return result

# %%
# =========================
# PLOTTING + HIGH-LEVEL API
# =========================


def _poisson_err(data_counts):
    lo, hi = poisson_interval(np.asarray(data_counts, dtype=float))
    return np.asarray(data_counts) - lo, hi - np.asarray(data_counts)


def _weighted_poisson_errors(sumw, sumw2):
    sumw = np.asarray(sumw, dtype=float)
    sumw2 = np.asarray(sumw2, dtype=float)
    neff = np.divide(sumw**2, sumw2, out=np.zeros_like(sumw), where=sumw2 > 0)
    lo_eff, hi_eff = poisson_interval(neff)
    err_lo = np.divide(sumw * (neff - lo_eff), neff, out=np.zeros_like(sumw), where=neff > 0)
    err_hi = np.divide(sumw * (hi_eff - neff), neff, out=np.zeros_like(sumw), where=neff > 0)
    return err_lo, err_hi


def _yield_label(vals, vars_, label):
    ysum = float(np.sum(vals))
    vsum = float(np.sum(vars_))
    eff = ysum**2 / vsum if vsum > 0 else 0.0
    lo, hi = poisson_interval(np.array([eff]))
    err_lo = ysum * (eff - lo[0]) / eff if eff > 0 else 0.0
    err_hi = ysum * (hi[0] - eff) / eff if eff > 0 else 0.0
    nd = int(_cfg("physics", "yield_digits", default=2))
    fmt = lambda x: f"{x:.{nd}f}"
    return f"{label}\n" + rf"$\mathrm{{{fmt(ysum)}}}^{{+{fmt(err_hi)}}}_{{-{fmt(err_lo)}}}$"


def _stack_from_arrays(session, proc_arrays, observable, bins):
    data = np.zeros(len(bins) - 1, dtype=float)
    mc_h, mc_v = {}, {}
    for proc, arrs in proc_arrays.items():
        if observable not in arrs:
            continue
        x = arrs[observable]
        stack_name = session.style.stack_key(proc)

        if proc in _cfg("physics", "data_processes"):
            data += _hist_with_flows(x, bins=bins)
            continue

        if _cfg("physics", "mc_weight_branch") not in arrs:
            continue
        w = arrs[_cfg("physics", "mc_weight_branch")]
        h = _hist_with_flows(x, bins=bins, weights=w)
        v = _hist_with_flows(x, bins=bins, weights=w * w)
        mc_h[stack_name] = mc_h.get(stack_name, 0.0) + h
        mc_v[stack_name] = mc_v.get(stack_name, 0.0) + v
    return data, mc_h, mc_v


def _build_cut_reports_without_materialization(payload, norm_cut, mask_cache=None):
    base_report_by_proc = {r["proc"]: r for r in payload.get("reports", [])}
    reports = []

    for proc, arrs in sorted(payload.get("arrays", {}).items()):
        total = len(next(iter(arrs.values()))) if arrs else 0
        if norm_cut and arrs:
            if mask_cache is not None and proc in mask_cache:
                mask = mask_cache[proc]
            else:
                mask = _evaluate_cut_mask(arrs, norm_cut)
                if mask_cache is not None:
                    mask_cache[proc] = mask
            entries_after = int(np.count_nonzero(mask)) if mask is not None else int(total)
        else:
            entries_after = int(total)

        rep0 = base_report_by_proc.get(proc, {})
        reports.append({
            "proc": proc,
            "process_key": rep0.get("process_key", f"{payload.get('tree_name','?')}:{proc}"),
            "n_files": int(rep0.get("n_files", 0)),
            "entries_total": int(total),
            "entries_after_cut": entries_after,
            "loaded_branches": len(arrs),
            "branch_names": sorted(arrs.keys()),
            "tree_paths": rep0.get("tree_paths", []),
        })
    return reports


def _stack_from_payload_with_cut(session, base_arrays, observable, bins, norm_cut, mask_cache=None):
    data = np.zeros(len(bins) - 1, dtype=float)
    mc_h, mc_v = {}, {}
    weight_branch = _cfg("physics", "mc_weight_branch")

    for proc, arrs in base_arrays.items():
        if observable not in arrs:
            continue

        mask = None
        if norm_cut and arrs:
            if mask_cache is not None and proc in mask_cache:
                mask = mask_cache[proc]
            else:
                mask = _evaluate_cut_mask(arrs, norm_cut)
                if mask_cache is not None:
                    mask_cache[proc] = mask

        x = arrs[observable]
        if mask is not None:
            x = np.asarray(x)[mask]

        stack_name = session.style.stack_key(proc)
        if proc in _cfg("physics", "data_processes"):
            data += _hist_with_flows(x, bins=bins)
            continue

        if weight_branch not in arrs:
            continue

        w = arrs[weight_branch]
        if mask is not None:
            w = np.asarray(w)[mask]

        h = _hist_with_flows(x, bins=bins, weights=w)
        v = _hist_with_flows(x, bins=bins, weights=w * w)
        mc_h[stack_name] = mc_h.get(stack_name, 0.0) + h
        mc_v[stack_name] = mc_v.get(stack_name, 0.0) + v

    return data, mc_h, mc_v


def _deep_merge_dict(base, overrides):
    out = dict(base or {})
    for k, v in (overrides or {}).items():
        if isinstance(v, dict) and isinstance(out.get(k), dict):
            out[k] = _deep_merge_dict(out[k], v)
        else:
            out[k] = v
    return out


def _merge_plot_style(base=None, overrides=None):
    style = _deep_merge_dict(PLOT_STYLE_DEFAULTS, base or {})
    style = _deep_merge_dict(style, overrides or {})

    # backward compatibility shim for older flat overrides
    flat_to_nested = {
        "title": ("meta", "title"),
        "lumi_label": ("meta", "lumi_label"),
        "save_dpi": ("figure", "save_dpi"),
        "show_plots": ("figure", "show_plots"),
        "figsize": ("figure", "figsize"),
        "logy": ("scales", "logy"),
    }
    for old_key, path in flat_to_nested.items():
        if old_key in (overrides or {}):
            node = style
            for p in path[:-1]:
                node = node.setdefault(p, {})
            node[path[-1]] = (overrides or {})[old_key]
    return style


def _style_get(style, *path, default=None):
    node = style
    for p in path:
        if not isinstance(node, dict) or p not in node:
            return default
        node = node[p]
    return node


def _format_cut_text(cut_text, width=52):
    expr = _normalize_cut(cut_text)
    if not expr:
        return ""

    expr = re.sub(r"\s+", " ", expr).strip()
    expr = expr.replace(" && ", "\n&& ").replace(" || ", "\n|| ")

    lines = []
    for piece in expr.splitlines():
        wrapped = textwrap.wrap(piece, width=width, break_long_words=False, break_on_hyphens=False)
        lines.extend(wrapped if wrapped else [""])
    return "\n".join(lines)


def _format_y_axis_like_ticks(ax, style):
    sci = _style_get(style, "yaxis_scientific", default={})
    if not bool(sci.get("enabled", True)):
        return
    if ax.get_yscale() == "log":
        return

    ax.figure.canvas.draw()
    yticks = np.asarray(ax.get_yticks(), dtype=float)
    if yticks.size == 0:
        return

    finite = np.isfinite(yticks)
    max_abs = float(np.nanmax(np.abs(yticks[finite]))) if np.any(finite) else 0.0
    if max_abs <= float(sci.get("plain_threshold", 1e3)):
        ax.yaxis.set_major_formatter(mpl.ticker.StrMethodFormatter("{x:.0f}"))
        ax.yaxis.offsetText.set_visible(False)
        return

    fmt = mpl.ticker.ScalarFormatter(useMathText=True)
    fmt.set_scientific(True)
    fmt.set_powerlimits(tuple(sci.get("powerlimits", (-4, 4))))
    fmt.set_useOffset(False)
    ax.yaxis.set_major_formatter(fmt)

    ax.figure.canvas.draw()
    ax.yaxis.offsetText.set_visible(False)

    k = int(getattr(fmt, "orderOfMagnitude", 0))
    if abs(k) < int(sci.get("manual_multiplier_min_abs_power", 4)):
        return

    if hasattr(ax, "_manual_y_multiplier") and ax._manual_y_multiplier is not None:
        ax._manual_y_multiplier.remove()

    fp = next((t.get_fontproperties() for t in ax.yaxis.get_ticklabels() if t.get_text()), ax.yaxis.get_label().get_fontproperties())
    ax._manual_y_multiplier = ax.text(
        float(sci.get("multiplier_x", -0.005)),
        float(sci.get("multiplier_y", 1.005)),
        rf"$\times 10^{{{k}}}$",
        transform=ax.transAxes,
        ha=sci.get("multiplier_ha", "right"),
        va="bottom",
        fontsize=float(sci.get("multiplier_fontsize", 14)),
        fontproperties=fp,
        clip_on=False,
    )


def _draw_datamc(session, category_key, observable, obs_cfg, data_counts, mc_hists, mc_vars, plot_label=None, subtitle=None, cut_text=None, plot_style=None, output_dir=None):
    style = _merge_plot_style(plot_style)

    bins = np.asarray(obs_cfg["bins"], dtype=float)
    centers = 0.5 * (bins[1:] + bins[:-1])
    widths = np.diff(bins)

    text_cfg = _style_get(style, "text", default={})
    fig_cfg = _style_get(style, "figure", default={})
    layout_cfg = _style_get(style, "layout", default={})
    panel_cfg = _style_get(style, "panels", default={})
    axes_cfg = _style_get(style, "axes", default={})
    grid_cfg = _style_get(style, "grid", default={})
    stack_cfg = _style_get(style, "stack", default={})
    mc_cfg = _style_get(style, "mc", default={})
    data_cfg = _style_get(style, "data", default={})
    ratio_cfg = _style_get(style, "ratio", default={})
    legend_cfg = _style_get(style, "legend", default={})
    cut_cfg = _style_get(style, "cut_block", default={})
    cms_cfg = _style_get(style, "cms", default={})
    meta_cfg = _style_get(style, "meta", default={})

    if not mc_hists:
        _log(text_cfg.get("no_mc_log", "No MC histogram available for {category}/{observable}").format(category=category_key, observable=observable), level="warn")
        return None

    procs = sorted(mc_hists, key=lambda p: float(np.sum(mc_hists[p])))
    mc_total = np.sum([mc_hists[p] for p in procs], axis=0)
    mc_total_var = np.sum([mc_vars[p] for p in procs], axis=0)
    mc_lo, mc_hi = _weighted_poisson_errors(mc_total, mc_total_var)
    d_lo, d_hi = _poisson_err(data_counts)

    fig = plt.figure(figsize=tuple(fig_cfg.get("figsize", (10, 7))), facecolor=fig_cfg.get("facecolor", "white"))
    gs = fig.add_gridspec(
        2,
        2,
        width_ratios=layout_cfg.get("width_ratios", [6.8, 3.2]),
        height_ratios=layout_cfg.get("height_ratios", [3, 1]),
        wspace=float(layout_cfg.get("wspace", 0.05)),
        hspace=float(layout_cfg.get("hspace", 0.04)),
    )
    ax = fig.add_subplot(gs[0, 0])
    rax = fig.add_subplot(gs[1, 0], sharex=ax)
    lax = fig.add_subplot(gs[:, 1])
    ax.set_facecolor(panel_cfg.get("main_facecolor", "white"))
    rax.set_facecolor(panel_cfg.get("ratio_facecolor", "white"))
    lax.set_facecolor(panel_cfg.get("legend_facecolor", "white"))
    lax.axis("off")

    ax.tick_params(labelbottom=False)
    tick_size = axes_cfg.get("tick_labelsize")
    tick_params = dict(
        axis="both",
        which="both",
        direction=axes_cfg.get("tick_direction", "in"),
        length=float(axes_cfg.get("tick_length", 5)),
        width=float(axes_cfg.get("tick_width", 1.0)),
        top=bool(axes_cfg.get("tick_top", True)),
        right=bool(axes_cfg.get("tick_right", True)),
    )
    ax.tick_params(labelsize=tick_size, **tick_params)
    rax.tick_params(labelsize=tick_size, **tick_params)

    for axis in [ax, rax]:
        for spine in axis.spines.values():
            spine.set_linewidth(float(axes_cfg.get("spine_linewidth", 1.0)))

    if bool(grid_cfg.get("enabled", True)):
        ax.grid(alpha=float(grid_cfg.get("main_alpha", 0.25)), linestyle=grid_cfg.get("linestyle", "-"), linewidth=float(grid_cfg.get("linewidth", 0.6)), which=grid_cfg.get("which", "major"), axis=grid_cfg.get("axis", "both"))
        rax.grid(alpha=float(grid_cfg.get("ratio_alpha", 0.25)), linestyle=grid_cfg.get("linestyle", "-"), linewidth=float(grid_cfg.get("linewidth", 0.6)), which=grid_cfg.get("which", "major"), axis=grid_cfg.get("axis", "both"))

    bottoms = np.zeros_like(centers)
    stack_handles, stack_payload = [], []
    for i, p in enumerate(procs):
        vals = mc_hists[p]
        vars_ = mc_vars[p]
        h = ax.bar(
            centers,
            vals,
            width=widths,
            bottom=bottoms,
            align=stack_cfg.get("align", "center"),
            color=session.style.color(p, i),
            alpha=float(stack_cfg.get("alpha", 0.82)),
            edgecolor=stack_cfg.get("edgecolor", "none"),
            linewidth=float(stack_cfg.get("linewidth", 0.0)),
            zorder=float(stack_cfg.get("zorder", 2)),
        )
        bottoms = bottoms + vals
        stack_handles.append(h[0])
        stack_payload.append((p, vals, vars_))

    step_x = np.repeat(bins, 2)[1:-1]
    step_y = np.repeat(mc_total, 2)
    mc_color = mc_cfg.get("line_color", "red")
    mc_line = ax.plot(
        step_x,
        step_y,
        color=mc_color,
        lw=float(mc_cfg.get("line_width", 1.5)),
        linestyle=mc_cfg.get("line_style", "-"),
        drawstyle=mc_cfg.get("line_drawstyle", "steps-mid"),
        zorder=float(mc_cfg.get("line_zorder", 5)),
    )[0]
    mc_band = ax.fill_between(
        step_x,
        step_y - np.repeat(mc_lo, 2),
        step_y + np.repeat(mc_hi, 2),
        step=mc_cfg.get("band_step", "mid"),
        color=mc_color,
        alpha=float(mc_cfg.get("band_alpha", 0.12)),
        hatch=mc_cfg.get("band_hatch", None),
        zorder=float(mc_cfg.get("band_zorder", 4)),
    )

    data_marker = data_cfg.get("marker", "o")
    data_color = data_cfg.get("color", "black")
    data_ms = float(data_cfg.get("marker_size", 4))
    data_eb = ax.errorbar(
        centers,
        data_counts,
        yerr=[d_lo, d_hi],
        fmt=data_marker,
        color=data_color,
        ms=data_ms,
        elinewidth=float(data_cfg.get("elinewidth", 1.0)),
        capsize=float(data_cfg.get("capsize", 0)),
        zorder=float(data_cfg.get("marker_zorder", 6)),
    )
    data_markers = ax.plot(centers, data_counts, data_marker, color=data_color, ms=data_ms, zorder=float(data_cfg.get("marker_zorder", 6)))[0]

    axis_fs = axes_cfg.get("axis_label_fontsize", None)
    axis_pad = float(axes_cfg.get("axis_labelpad", 6))
    ax.set_ylabel(axes_cfg.get("y_label", "Events"), fontsize=axis_fs, labelpad=axis_pad)
    if bool(_style_get(style, "scales", "logy", default=False)):
        ax.set_yscale("log")
    _format_y_axis_like_ticks(ax, style)

    title_prefix = str(meta_cfg.get("title", "")).strip()
    title_label = plot_label or category_key
    title_text = str(meta_cfg.get("subtitle_separator", " • ")).join(x for x in [title_prefix, title_label] if x)
    title_x = float(axes_cfg.get("title_x", 0.02))
    title_y = float(axes_cfg.get("title_y", 0.90))
    ax.text(
        title_x,
        title_y,
        title_text,
        transform=ax.transAxes,
        fontsize=float(axes_cfg.get("title_fontsize", 10)),
        fontweight=axes_cfg.get("title_fontweight", "normal"),
        color=axes_cfg.get("title_color", "black"),
        ha="left",
        va="top",
    )

    subtitle_txt = str(subtitle or "").strip()
    if subtitle_txt and bool(axes_cfg.get("subtitle_enabled", True)):
        ax.text(
            title_x,
            title_y - float(axes_cfg.get("subtitle_y_offset", 0.055)),
            subtitle_txt,
            transform=ax.transAxes,
            fontsize=float(axes_cfg.get("subtitle_fontsize", 9)),
            color=axes_cfg.get("subtitle_color", "black"),
            fontstyle=axes_cfg.get("subtitle_fontstyle", "normal"),
            fontweight=axes_cfg.get("subtitle_fontweight", "normal"),
            ha="left",
            va="top",
        )

    cms_objs = hep.cms.label(
        cms_cfg.get("label", "Preliminary"),
        data=True,
        lumi=str(meta_cfg.get("lumi_label", "")),
        ax=ax,
        com=float(cms_cfg.get("com", 13.6)),
        fontsize=float(cms_cfg.get("fontsize", 20)),
    )
    cms_texts = [t for t in (cms_objs if isinstance(cms_objs, (list, tuple)) else [cms_objs]) if isinstance(t, mpl.text.Text)]
    for t in cms_texts:
        t.set_clip_on(False)

    with np.errstate(divide="ignore", invalid="ignore"):
        ratio = np.divide(data_counts, mc_total, out=np.zeros_like(data_counts), where=mc_total > 0)
        rlo = np.divide(d_lo, mc_total, out=np.zeros_like(data_counts), where=mc_total > 0)
        rhi = np.divide(d_hi, mc_total, out=np.zeros_like(data_counts), where=mc_total > 0)
        mc_rel_lo = np.divide(mc_lo, mc_total, out=np.zeros_like(mc_total), where=mc_total > 0)
        mc_rel_hi = np.divide(mc_hi, mc_total, out=np.zeros_like(mc_total), where=mc_total > 0)

    rax.errorbar(
        centers,
        ratio,
        yerr=[rlo, rhi],
        fmt=data_marker,
        color=data_color,
        ms=data_ms,
        elinewidth=float(data_cfg.get("elinewidth", 1.0)),
        capsize=float(data_cfg.get("capsize", 0)),
        zorder=float(data_cfg.get("marker_zorder", 6)),
    )
    ratio_ref = float(ratio_cfg.get("reference_line_value", 1.0))
    ratio_ref_color = ratio_cfg.get("reference_line_color", None) or mc_color
    rax.plot(
        step_x,
        np.full_like(step_y, ratio_ref),
        color=ratio_ref_color,
        lw=float(ratio_cfg.get("reference_line_width", 1.0)),
        linestyle=ratio_cfg.get("reference_line_style", "-"),
        drawstyle=ratio_cfg.get("reference_line_drawstyle", "steps-mid"),
        zorder=float(ratio_cfg.get("reference_line_zorder", 3)),
    )
    rax.fill_between(
        step_x,
        1 - np.repeat(mc_rel_lo, 2),
        1 + np.repeat(mc_rel_hi, 2),
        step=ratio_cfg.get("band_step", "mid"),
        color=mc_color,
        alpha=float(mc_cfg.get("band_alpha", 0.12)),
        hatch=mc_cfg.get("band_hatch", None),
        zorder=float(mc_cfg.get("band_zorder", 4)),
    )

    rax.set_ylabel(axes_cfg.get("ratio_y_label", "Data/MC"), fontsize=axis_fs, labelpad=axis_pad)
    x_label_override = axes_cfg.get("x_label", "")
    rax.set_xlabel(x_label_override or obs_cfg.get("xlabel", observable), fontsize=axis_fs, labelpad=axis_pad)
    rax.set_ylim(*obs_cfg.get("ratio_ylim", tuple(axes_cfg.get("ratio_ylim_default", (0.5, 1.5)))))

    data_label = _yield_label(data_counts, np.maximum(data_counts, 1e-6), session.style.display_name(_cfg("physics", "data_legend_label", default="DATA")))
    mc_label = _yield_label(mc_total, mc_total_var, _cfg("physics", "total_mc_legend_label", default="Total MC"))

    tot = float(np.sum(mc_total))
    stack_labels = []
    for p, vals, vars_ in stack_payload[::-1]:
        frac = 100.0 * (np.sum(vals) / tot) if tot > 0 else 0.0
        pnd = int(_cfg("physics", "yield_percent_digits", default=1))
        stack_labels.append(_yield_label(vals, vars_, f"{session.style.display_name(p)} ({frac:.{pnd}f}%)"))

    handles = [(data_eb, data_markers), (mc_line, mc_band)] + stack_handles[::-1]
    labels = [data_label, mc_label] + stack_labels
    leg = lax.legend(
        handles,
        labels,
        loc=legend_cfg.get("loc", "upper left"),
        fontsize=float(legend_cfg.get("fontsize", 10)),
        frameon=bool(legend_cfg.get("frameon", False)),
        ncol=int(legend_cfg.get("ncol", 2)),
        title=legend_cfg.get("title", ""),
        title_fontsize=float(legend_cfg.get("title_fontsize", 10)),
        handlelength=float(legend_cfg.get("handlelength", 1.2)),
        columnspacing=float(legend_cfg.get("columnspacing", 0.9)),
        labelspacing=float(legend_cfg.get("labelspacing", 0.35)),
        handletextpad=float(legend_cfg.get("handletextpad", 0.4)),
        borderaxespad=float(legend_cfg.get("borderaxespad", 0.0)),
    )

    if cut_text and bool(cut_cfg.get("enabled", True)):
        fig.canvas.draw()
        renderer = fig.canvas.get_renderer()
        leg_bbox = leg.get_window_extent(renderer=renderer).transformed(lax.transAxes.inverted())
        y_top = max(0.02, leg_bbox.y0 - float(cut_cfg.get("block_gap_from_legend", 0.055)))

        cut_title_artist = lax.text(
            0.0,
            y_top,
            cut_cfg.get("title_text", text_cfg.get("selection_title", "Selection:")),
            transform=lax.transAxes,
            ha="left",
            va="top",
            fontsize=float(cut_cfg.get("title_fontsize", 12)),
            fontweight=cut_cfg.get("title_fontweight", "bold"),
            color=cut_cfg.get("title_color", "black"),
            clip_on=False,
        )

        fig.canvas.draw()
        title_bbox = cut_title_artist.get_window_extent(renderer=renderer).transformed(lax.transAxes.inverted())
        lax.text(
            0.0,
            title_bbox.y0 - float(cut_cfg.get("title_to_text_gap", 0.03)),
            _format_cut_text(cut_text, width=int(cut_cfg.get("text_width", 38))),
            transform=lax.transAxes,
            ha="left",
            va="top",
            fontsize=float(cut_cfg.get("text_fontsize", 8)),
            color=cut_cfg.get("text_color", "black"),
            family=cut_cfg.get("fontfamily", "monospace"),
            linespacing=float(cut_cfg.get("line_spacing", 1.10)),
            clip_on=False,
        )

    out_root = output_dir or _cfg("io", "output_dir")
    out_cat = os.path.join(out_root, _sanitize(category_key))
    os.makedirs(out_cat, exist_ok=True)
    fname_template = _cfg("io", "output_filename_template", default="{title}_{category}_{observable}")
    fname = fname_template.format(title=_sanitize(meta_cfg.get("title", "")), category=_sanitize(category_key), observable=_sanitize(observable)).strip("_")
    ext = _cfg("io", "output_file_ext", default="png").lstrip(".")

    out_png = os.path.join(out_cat, f"{fname}.{ext}")
    fig.savefig(out_png, dpi=int(fig_cfg.get("save_dpi", 180)), bbox_inches=_cfg("io", "output_bbox_inches", default="tight"))

    if bool(_cfg("io", "write_plot_metadata", default=True)):
        out_meta = out_png + ".json"
        meta_payload = {
            "category": category_key,
            "observable": observable,
            "cut": _normalize_cut(cut_text or ""),
            "plot_label": plot_label,
            "subtitle": subtitle,
            "output_png": out_png,
            "generated_utc": datetime.now(timezone.utc).isoformat(),
            "config_snapshot": _config_snapshot(),
            "yields": {
                "data": float(np.sum(data_counts)),
                "mc_total": float(np.sum(mc_total)),
                "mc_processes": {str(k): float(np.sum(v)) for k, v in mc_hists.items()},
            },
        }
        with open(out_meta, "w") as fmeta:
            json.dump(meta_payload, fmeta, indent=2)

    if bool(fig_cfg.get("show_plots", False)):
        plt.show()
    plt.close(fig)
    del fig, ax, rax, lax

    _log(text_cfg.get("plot_saved_log", "Saved plot: {path}").format(path=out_png), level="io")
    return out_png


def quick_plot(session, tree_name, observable, bins=None, cut_expr="", label=None, subtitle=None, force_reload=False, import_mode=None, plot_style=None, output_dir=None, payload=None, proc_arrays=None, subcategory_name=None, in_memory_only=False):
    """Single-command plotting API for spontaneous exploration.

    Data source priority:
      1) proc_arrays (already in memory)
      2) payload    (already in memory; optional extra cut applied in memory)
      3) tree_name  (loads arrays from files/cache via session.load_arrays)

    Set in_memory_only=True to forbid file/cache reads for this call.
    """
    if bins is None:
        cfg = OBSERVABLES.get(observable)
        if not cfg:
            raise KeyError(f"Observable '{observable}' not in OBSERVABLES and bins not provided.")
        obs_cfg = cfg
    else:
        obs_cfg = {
            "bins": np.asarray(bins, dtype=float),
            "xlabel": observable,
            "ratio_ylim": tuple(_style_get(PLOT_STYLE_DEFAULTS, "axes", "ratio_ylim_default", default=(0.5, 1.5))),
        }

    used_in_memory = False
    if proc_arrays is not None:
        final_proc_arrays = proc_arrays
        used_in_memory = True
    elif payload is not None:
        if not isinstance(payload, dict) or "arrays" not in payload:
            raise TypeError("payload must be a dict with an 'arrays' key")
        payload_cut = _normalize_cut(str(payload.get("cut", "")))
        requested_cut = _normalize_cut(cut_expr)
        if requested_cut and requested_cut != payload_cut:
            payload = _apply_cut_to_payload(payload, requested_cut, subcategory_name=subcategory_name)
        final_proc_arrays = payload["arrays"]
        used_in_memory = True
    else:
        if in_memory_only:
            raise ValueError("in_memory_only=True requires either 'payload' or 'proc_arrays'.")
        if _data_loading_mode() == "direct":
            direct = session.histogram_direct(
                tree_name=tree_name,
                observable=observable,
                bins=np.asarray(obs_cfg["bins"], dtype=float),
                cut_expr=cut_expr,
                force=force_reload or _cfg("cache", "force_reload_array_cache", default=False),
                import_mode=import_mode,
            )
            category_key = subcategory_name or label or tree_name or "direct"
            plot_label = label or subcategory_name or tree_name
            return _draw_datamc(
                session,
                category_key,
                observable,
                obs_cfg,
                direct["data_counts"],
                direct["mc_h"],
                direct["mc_v"],
                plot_label=plot_label,
                subtitle=subtitle,
                cut_text=cut_expr,
                plot_style=plot_style,
                output_dir=output_dir,
            )
        payload = session.load_arrays(
            tree_name=tree_name,
            cut_expr=cut_expr,
            observables=[observable],
            force=force_reload or _cfg("cache", "force_reload_array_cache", default=False),
            import_mode=import_mode,
        )
        final_proc_arrays = payload["arrays"]

    category_key = subcategory_name or label or tree_name or "in_memory"
    plot_label = label or subcategory_name or ("in_memory" if used_in_memory else tree_name)

    data_counts, mc_h, mc_v = _stack_from_arrays(session, final_proc_arrays, observable, np.asarray(obs_cfg["bins"], dtype=float))
    return _draw_datamc(
        session,
        category_key,
        observable,
        obs_cfg,
        data_counts,
        mc_h,
        mc_v,
        plot_label=plot_label,
        subtitle=subtitle,
        cut_text=cut_expr,
        plot_style=plot_style,
        output_dir=output_dir,
    )


def prepare_quick_plot_payload(session, tree_name, observables, cut_exprs=None, base_cut="", required_branches=None, import_mode=None, registry=None, registry_namespace="quick_plot", force_reload=False):
    """Build or reuse a base payload for quick-plot jobs.

    Reuse order:
      1) explicit in-memory registry (if provided)
      2) session.uncut_base_cache (compatible branch superset)
      3) load_arrays fallback
    """
    obs_list = [str(o) for o in (observables or []) if isinstance(o, str) and str(o).strip()]
    cuts = [str(c) for c in (cut_exprs or []) if isinstance(c, str) and str(c).strip()]
    planned_cut = _combine_subcategory_cuts_or(cuts)

    required = set(_plan_required_branches(obs_list, cut_expr=planned_cut))
    if required_branches is not None:
        required |= {b for b in required_branches if isinstance(b, str) and b.strip()}

    norm_base_cut = _normalize_cut(base_cut)
    final_import_mode = str(import_mode or _cfg("runtime", "array_branch_import_mode", default="needed")).lower().strip()

    payload_key = (
        registry_namespace,
        id(session),
        tree_name,
        norm_base_cut,
        tuple(sorted(obs_list)),
        tuple(sorted(required)),
        final_import_mode,
    )

    if registry is not None and (not force_reload) and payload_key in registry:
        _log(f"Payload reuse: registry-hit tree={tree_name} branches={len(required)}")
        return registry[payload_key]

    session.refresh_inputs(force=_cfg("cache", "force_reload_inputs", default=False), emit_log=False)

    payload = None
    if not norm_base_cut and (not force_reload):
        base_key = (
            tree_name,
            final_import_mode,
            tuple(session.input_files),
            session.input_mode,
        )
        entry = session.uncut_base_cache.get(base_key)
        if entry and set(required).issubset(set(entry.get("branches", set()))):
            payload = entry.get("payload")
            _log(f"Payload reuse: session-uncut-hit tree={tree_name} branches={len(required)}")

    if payload is None:
        payload = session.load_arrays(
            tree_name=tree_name,
            cut_expr=norm_base_cut,
            observables=obs_list,
            required_branches=sorted(required),
            force=bool(force_reload),
            import_mode=final_import_mode,
        )
        _log(f"Payload build: load_arrays tree={tree_name} branches={len(required)}")

    if registry is not None:
        registry[payload_key] = payload
    return payload


def _coerce_quick_plot_job(job):
    if isinstance(job, str):
        job = json.loads(job)
    if not isinstance(job, dict):
        raise TypeError("job must be a dict or JSON string")
    return dict(job)


def _derive_shared_payload_recipe(jobs):
    """Infer a single shared-payload recipe when job set is compatible."""
    tree_names = set()
    import_modes = set()
    base_cuts = set()
    force_reload = False
    observables = set()
    cut_exprs = []
    required = set()

    for job in jobs:
        if job.get("payload") is not None or job.get("proc_arrays") is not None:
            continue
        t = job.get("tree_name")
        o = job.get("observable")
        if not t or not o:
            continue
        tree_names.add(str(t))
        import_modes.add(str(job.get("import_mode") or _cfg("runtime", "array_branch_import_mode", default="needed")))
        base_cuts.add(_normalize_cut(job.get("base_cut", "")))
        force_reload = force_reload or bool(job.get("force_reload", False))
        observables.add(str(o))
        c = _normalize_cut(job.get("cut_expr", ""))
        if c:
            cut_exprs.append(c)
        required |= {b for b in job.get("required_branches", []) if isinstance(b, str) and b.strip()}

    if not observables:
        return None
    if len(tree_names) != 1 or len(import_modes) != 1 or len(base_cuts) != 1:
        return None

    return {
        "tree_name": next(iter(tree_names)),
        "observables": sorted(observables),
        "cut_exprs": cut_exprs,
        "required_branches": sorted(required),
        "import_mode": next(iter(import_modes)),
        "base_cut": next(iter(base_cuts)),
        "force_reload": force_reload,
    }


def quick_plot_job(session, job):
    """Run one quick-plot job from a dict/JSON specification."""
    job = _coerce_quick_plot_job(job)

    tree_name = job.get("tree_name")
    observable = job.get("observable")
    payload = job.get("payload")
    proc_arrays = job.get("proc_arrays")

    if not observable:
        raise KeyError("job must include 'observable'")
    if not any([tree_name, payload is not None, proc_arrays is not None]):
        raise KeyError("job must include one of: 'tree_name', 'payload', or 'proc_arrays'")

    bins = job.get("bins")
    if bins is not None:
        bins = np.asarray(bins, dtype=float)

    plot_style = job.get("plot_style") or {}
    if job.get("title") is not None:
        plot_style = _deep_merge_dict(plot_style, {"meta": {"title": str(job.get("title"))}})

    return quick_plot(
        session=session,
        tree_name=tree_name,
        observable=observable,
        bins=bins,
        cut_expr=job.get("cut_expr", ""),
        label=job.get("label"),
        subtitle=job.get("subtitle"),
        force_reload=bool(job.get("force_reload", False)),
        import_mode=job.get("import_mode"),
        plot_style=plot_style,
        output_dir=job.get("output_dir"),
        payload=payload,
        proc_arrays=proc_arrays,
        subcategory_name=job.get("subcategory_name") or job.get("sub_name"),
        in_memory_only=bool(job.get("in_memory_only", False)),
    )


def run_plot_jobs(session, jobs, shared_payload=False, payload=None, registry=None, registry_namespace="quick_plot_jobs"):
    """Run many quick-plot jobs.

    Options:
      - payload: explicit payload injected into jobs missing payload/proc_arrays.
      - shared_payload=True: infer a single shared recipe and preload/reuse once.
    """
    norm_jobs = [_coerce_quick_plot_job(j) for j in jobs]

    shared = payload
    if shared is None and shared_payload:
        recipe = _derive_shared_payload_recipe(norm_jobs)
        if recipe is None:
            raise ValueError("shared_payload=True requires compatible jobs (single tree/import_mode/base_cut and defined observables)")
        shared = prepare_quick_plot_payload(
            session,
            tree_name=recipe["tree_name"],
            observables=recipe["observables"],
            cut_exprs=recipe["cut_exprs"],
            base_cut=recipe["base_cut"],
            required_branches=recipe["required_branches"],
            import_mode=recipe["import_mode"],
            registry=registry,
            registry_namespace=registry_namespace,
            force_reload=recipe["force_reload"],
        )

    outputs = []
    for i, job in enumerate(norm_jobs, 1):
        run_job = dict(job)
        if shared is not None and run_job.get("payload") is None and run_job.get("proc_arrays") is None:
            run_job["payload"] = shared
            run_job.setdefault("in_memory_only", True)

        _log(f"Running job {i}/{len(norm_jobs)} :: {run_job.get('observable', 'unknown')} @ {run_job.get('tree_name', 'in_memory')}")
        out = quick_plot_job(session, run_job)
        outputs.append(out)
    return outputs




def _zzcr_stage_metadata(sub_name):
    m = re.search(r"cutflow_(ee|mm)_step0?([1-7])", str(sub_name or ""))
    if not m:
        return None
    return {"zzcr_channel": m.group(1), "zzcr_stage": int(m.group(2))}


def build_category_jobs(category_config, observables=None):
    targets = list(observables) if observables is not None else list(OBSERVABLES.keys())
    jobs = []
    for category, cat_cfg in category_config.items():
        tree_name = str(cat_cfg.get("tree", category))
        base_cut = _normalize_cut(cat_cfg.get("cut", ""))
        cat_plot_style = cat_cfg.get("plot_style", {})
        cat_output_dir = cat_cfg.get("output_dir")
        subcats = cat_cfg.get("subcategories", {})
        for sub_name, sub_cfg in subcats.items():
            sub_cut = _normalize_cut(sub_cfg.get("cut", ""))
            full_cut = " && ".join([f"({x})" for x in [base_cut, sub_cut] if x])
            job = {
                "tree_name": tree_name,
                "sub_name": sub_name,
                "title": sub_cfg.get("title", sub_name),
                "subtitle": sub_cfg.get("subtitle", cat_cfg.get("subtitle", "")),
                "cut": full_cut,
                "plot_style": _merge_plot_style(cat_plot_style, sub_cfg.get("plot_style", {})),
                "output_dir": sub_cfg.get("output_dir", cat_output_dir),
                "observables": list(targets),
            }
            job.update(_zzcr_stage_metadata(sub_name) or {})
            jobs.append(job)
    return jobs
def _split_top_level(expr, sep):
    expr = str(expr or "").strip()
    if not expr:
        return []
    out = []
    depth = 0
    i = 0
    token = []
    n = len(expr)
    while i < n:
        ch = expr[i]
        if ch == '(':
            depth += 1
            token.append(ch)
            i += 1
            continue
        if ch == ')':
            depth = max(0, depth - 1)
            token.append(ch)
            i += 1
            continue
        if depth == 0 and expr.startswith(sep, i):
            part = ''.join(token).strip()
            if part:
                out.append(part)
            token = []
            i += len(sep)
            continue
        token.append(ch)
        i += 1
    tail = ''.join(token).strip()
    if tail:
        out.append(tail)
    return out


def _strip_outer_parens(expr):
    s = str(expr or "").strip()
    changed = True
    while changed and s.startswith('(') and s.endswith(')'):
        changed = False
        depth = 0
        ok = True
        for i, ch in enumerate(s):
            if ch == '(':
                depth += 1
            elif ch == ')':
                depth -= 1
                if depth == 0 and i != len(s) - 1:
                    ok = False
                    break
            if depth < 0:
                ok = False
                break
        if ok and depth == 0:
            s = s[1:-1].strip()
            changed = True
    return s


def _combine_subcategory_cuts_or(cuts):
    clauses = []
    seen = set()
    for c in cuts or []:
        norm = _normalize_cut(c)
        if not norm:
            continue
        norm = _strip_outer_parens(norm)
        if norm in seen:
            continue
        seen.add(norm)
        clauses.append(norm)

    if not clauses:
        return ""
    if len(clauses) == 1:
        return clauses[0]

    and_terms = []
    for cl in clauses:
        parts = [_strip_outer_parens(x) for x in _split_top_level(cl, '&&')]
        and_terms.append([p for p in parts if p])

    common = []
    if and_terms:
        first = and_terms[0]
        for term in first:
            if all(term in terms for terms in and_terms[1:]):
                common.append(term)

    if common:
        common_set = set(common)
        residual = []
        for terms in and_terms:
            rem = [t for t in terms if t not in common_set]
            if not rem:
                return ' && '.join(f'({x})' for x in common)
            residual.append(' && '.join(f'({x})' for x in rem))
        unique_res = []
        seen_res = set()
        for r in residual:
            rr = _strip_outer_parens(r)
            if rr not in seen_res:
                seen_res.add(rr)
                unique_res.append(rr)
        lhs = ' && '.join(f'({x})' for x in common)
        rhs = ' || '.join(f'({x})' for x in unique_res)
        return f'({lhs}) && ({rhs})'

    return ' || '.join(f'({x})' for x in clauses)


def _apply_cut_to_payload(payload, cut_expr, subcategory_name=None):
    norm_cut = _normalize_cut(cut_expr)
    expr = _cut_to_pandas(norm_cut)
    out = {}
    reports = []

    base_report_by_proc = {r["proc"]: r for r in payload.get("reports", [])}
    for proc, arrs in sorted(payload.get("arrays", {}).items()):
        total = len(next(iter(arrs.values()))) if arrs else 0
        filtered = arrs
        if expr and arrs:
            filtered = _filter_arrays_with_cut(arrs, norm_cut)

        if filtered:
            out[proc] = filtered

        rep0 = base_report_by_proc.get(proc, {})
        reports.append({
            "proc": proc,
            "process_key": rep0.get("process_key", f"{payload.get('tree_name','?')}:{proc}"),
            "n_files": int(rep0.get("n_files", 0)),
            "entries_total": int(total),
            "entries_after_cut": int(len(next(iter(filtered.values()))) if filtered else 0),
            "loaded_branches": len(filtered),
            "branch_names": sorted(filtered.keys()),
            "tree_paths": rep0.get("tree_paths", []),
        })

    return {
        "arrays": out,
        "reports": reports,
        "tree_name": payload.get("tree_name"),
        "cut": norm_cut,
        "observables": payload.get("observables", []),
        "subcategory_name": subcategory_name,
    }



# =========================
# FAST HISTOGRAM PRODUCTION + CACHE
# =========================

def _json_safe(obj):
    if isinstance(obj, dict):
        return {str(k): _json_safe(v) for k, v in sorted(obj.items(), key=lambda kv: str(kv[0]))}
    if isinstance(obj, (list, tuple)):
        return [_json_safe(v) for v in obj]
    if isinstance(obj, set):
        return sorted(_json_safe(v) for v in obj)
    if isinstance(obj, np.ndarray):
        return obj.tolist()
    if isinstance(obj, (np.integer,)):
        return int(obj)
    if isinstance(obj, (np.floating,)):
        return float(obj)
    if isinstance(obj, (np.bool_,)):
        return bool(obj)
    try:
        json.dumps(obj)
        return obj
    except Exception:
        return str(obj)


def _config_hash(*payloads):
    txt = json.dumps(_json_safe(payloads), sort_keys=True, separators=(",", ":"))
    return hashlib.sha256(txt.encode("utf-8")).hexdigest()[:16]


class HistogramStore:
    """Small array-backed histogram cache for fast replotting without ROOT I/O."""

    def __init__(self, metadata=None):
        self.metadata = dict(metadata or {})
        self.hists = OrderedDict()

    @staticmethod
    def make_key(tree_name, subcategory_name, observable, process, process_group=None, is_data=False):
        return (
            str(tree_name),
            str(subcategory_name),
            str(observable),
            str(process),
            str(process_group if process_group is not None else process),
            bool(is_data),
        )

    @staticmethod
    def key_to_string(key):
        return json.dumps(list(key), separators=(",", ":"), sort_keys=False)

    @staticmethod
    def key_from_string(text):
        vals = json.loads(text)
        return (vals[0], vals[1], vals[2], vals[3], vals[4], bool(vals[5]))

    def add_hist(self, key, edges, values, variances=None, entries=None, metadata=None):
        values = np.asarray(values, dtype=float)
        if variances is None:
            variances = np.zeros_like(values, dtype=float)
        meta = dict(metadata or {})
        meta.setdefault("flow_policy", "underflow/overflow folded into edge bins via _hist_with_flows")
        self.hists[tuple(key)] = {
            "edges": np.asarray(edges, dtype=float),
            "values": values,
            "variances": np.asarray(variances, dtype=float),
            "entries": int(entries) if entries is not None else int(np.sum(values)),
            "underflow": meta.get("underflow"),
            "overflow": meta.get("overflow"),
            "metadata": meta,
        }

    def get_hist(self, key):
        return self.hists.get(tuple(key))

    def iter_hists(self):
        return self.hists.items()

    def write_npz(self, path):
        os.makedirs(os.path.dirname(path) or ".", exist_ok=True)
        manifest = []
        arrays = {}
        with _timer(f"hist cache write {path}"):
            for i, (key, rec) in enumerate(self.hists.items()):
                prefix = f"h{i}"
                arrays[f"{prefix}_edges"] = np.asarray(rec["edges"], dtype=float)
                arrays[f"{prefix}_values"] = np.asarray(rec["values"], dtype=float)
                arrays[f"{prefix}_variances"] = np.asarray(rec["variances"], dtype=float)
                manifest.append({
                    "key": self.key_to_string(key),
                    "edges": f"{prefix}_edges",
                    "values": f"{prefix}_values",
                    "variances": f"{prefix}_variances",
                    "entries": int(rec.get("entries", 0)),
                    "underflow": rec.get("underflow"),
                    "overflow": rec.get("overflow"),
                    "metadata": _json_safe(rec.get("metadata", {})),
                })
            arrays["__manifest__"] = np.asarray(json.dumps(manifest), dtype=object)
            arrays["__metadata__"] = np.asarray(json.dumps(_json_safe(self.metadata)), dtype=object)
            np.savez_compressed(path, **arrays)
        self.write_metadata_json(path + ".json")
        return path

    @classmethod
    def read_npz(cls, path):
        with _timer(f"hist cache read {path}"):
            data = np.load(path, allow_pickle=True)
            metadata = json.loads(str(data["__metadata__"].item())) if "__metadata__" in data else {}
            store = cls(metadata=metadata)
            manifest = json.loads(str(data["__manifest__"].item()))
            for item in manifest:
                key = cls.key_from_string(item["key"])
                store.add_hist(
                    key,
                    data[item["edges"]],
                    data[item["values"]],
                    data[item["variances"]],
                    entries=item.get("entries"),
                    metadata=item.get("metadata", {}),
                )
        return store

    def write_metadata_json(self, path):
        os.makedirs(os.path.dirname(path) or ".", exist_ok=True)
        payload = {
            "metadata": _json_safe(self.metadata),
            "n_histograms": len(self.hists),
            "keys": [self.key_to_string(k) for k in self.hists.keys()],
        }
        with open(path, "w") as f:
            json.dump(payload, f, indent=2, sort_keys=True)
        return path

    def category_histograms(self, tree_name, subcategory_name, observable):
        data = None
        mc_h, mc_v = {}, {}
        for key, rec in self.hists.items():
            k_tree, k_sub, k_obs, _proc, group, is_data = key
            if (k_tree, k_sub, k_obs) != (str(tree_name), str(subcategory_name), str(observable)):
                continue
            if is_data:
                data = np.asarray(rec["values"], dtype=float) if data is None else data + np.asarray(rec["values"], dtype=float)
            else:
                mc_h[group] = mc_h.get(group, 0.0) + np.asarray(rec["values"], dtype=float)
                mc_v[group] = mc_v.get(group, 0.0) + np.asarray(rec["variances"], dtype=float)
        return data, mc_h, mc_v


def _hist_with_flows_backend(values, bins, weights=None):
    backend = str(_cfg("runtime", "hist_backend", default="numpy")).lower().strip()
    if backend != "boost_histogram":
        return _hist_with_flows(values, bins=bins, weights=weights)
    try:
        import boost_histogram as bh
    except Exception:
        _log("boost_histogram requested but unavailable; falling back to numpy histogramming", level="warn")
        return _hist_with_flows(values, bins=bins, weights=weights)
    x = np.asarray(values)
    if x.size == 0:
        return np.zeros(len(bins) - 1, dtype=float)
    lo = np.nextafter(bins[0], np.inf)
    hi = np.nextafter(bins[-1], -np.inf)
    x = np.clip(x, lo, hi)
    axis = bh.axis.Variable(np.asarray(bins, dtype=float))
    if weights is None:
        h = bh.Histogram(axis, storage=bh.storage.Double())
        h.fill(x)
        return np.asarray(h.values(), dtype=float)
    h = bh.Histogram(axis, storage=bh.storage.Weight())
    h.fill(x, weight=np.asarray(weights))
    return np.asarray(h.values(), dtype=float)


def _timer_add(timings, key, dt):
    if timings is not None:
        timings[key] = timings.get(key, 0.0) + float(dt)


def _is_uniform_bins(edges, rtol=1e-10, atol=1e-12):
    e = np.asarray(edges, dtype=float)
    if e.ndim != 1 or e.size < 2:
        return False
    d = np.diff(e)
    return bool(np.all(np.isfinite(e)) and np.all(d > 0) and np.allclose(d, d[0], rtol=rtol, atol=atol))


def compute_bin_indices(values, edges, timings=None):
    """Return folded-flow bin indices matching _hist_with_flows/np.histogram.

    Underflow is folded into bin 0, overflow into the last bin, and non-finite
    values are marked invalid with -1.  Uniform bins use arithmetic indexing;
    non-uniform bins fall back to searchsorted.
    """
    t0 = time.perf_counter()
    x = np.asarray(values)
    e = np.asarray(edges, dtype=float)
    nbins = max(0, len(e) - 1)
    idx = np.full(x.shape, -1, dtype=np.int64)
    if nbins <= 0 or x.size == 0:
        _timer_add(timings, "hist_fill_bin_index", time.perf_counter() - t0)
        return idx
    finite = np.isfinite(x)
    if np.any(finite):
        xf = x[finite]
        if _is_uniform_bins(e):
            low = e[0]
            high = e[-1]
            scale = float(nbins) / float(high - low)
            raw = np.floor((xf - low) * scale).astype(np.int64)
        else:
            raw = np.searchsorted(e, xf, side="right") - 1
        idx[finite] = np.clip(raw, 0, nbins - 1)
    _timer_add(timings, "hist_fill_bin_index", time.perf_counter() - t0)
    return idx


def _bincount_by_index(idx, weights, nbins, timings=None, timing_key="hist_fill_sumw"):
    t0 = time.perf_counter()
    valid = idx >= 0
    if not np.any(valid):
        out = np.zeros(nbins, dtype=float)
    else:
        out = np.bincount(idx[valid], weights=None if weights is None else np.asarray(weights)[valid], minlength=nbins).astype(float)[:nbins]
    _timer_add(timings, timing_key, time.perf_counter() - t0)
    return out



def _validate_bincount_against_histogram(x, bins, valid, weights, sumw, sumw2, is_data, context, atol=1e-8, rtol=1e-8):
    """Optional debug check for the optimized bincount backend."""
    if not bool(_cfg("runtime", "hist_fill_validate_bincount", default=False)):
        return
    x_sel = np.asarray(x)[valid]
    if is_data:
        ref = _hist_with_flows_backend(x_sel, bins=bins)
        ref2 = ref
    else:
        w_sel = np.asarray(weights)[valid]
        ref = _hist_with_flows_backend(x_sel, bins=bins, weights=w_sel)
        ref2 = _hist_with_flows_backend(x_sel, bins=bins, weights=w_sel * w_sel)
    if not np.allclose(ref, sumw, atol=atol, rtol=rtol) or not np.allclose(ref2, sumw2, atol=atol, rtol=rtol):
        raise AssertionError(f"bincount histogram validation failed for {context}")


def compute_zzcr_stages(arrays):
    """Compute nested cumulative ZZCR stages for ee and mm channels."""
    required = {"nJetInHorn", "Z0_mass", "Z0_isEE", "Z0_isMM", "Trigger_sngMu", "Trigger_dblMu", "Trigger_sngEl", "Trigger_dblEl", "Trigger_ElMu", "PassesZZCR4lOrderedPt", "X_mass", "bVeto", "PuppiMET_pt"}
    missing = sorted(required - set(arrays.keys()))
    if missing:
        raise KeyError(f"Cannot compute ZZCR stages; missing branches: {missing}")

    n = len(np.asarray(arrays["Z0_mass"]))
    hlt = (
        np.asarray(arrays["Trigger_sngMu"]).astype(bool)
        | np.asarray(arrays["Trigger_dblMu"]).astype(bool)
        | np.asarray(arrays["Trigger_sngEl"]).astype(bool)
        | np.asarray(arrays["Trigger_dblEl"]).astype(bool)
        | np.asarray(arrays["Trigger_ElMu"]).astype(bool)
    )
    baseline = (np.asarray(arrays["nJetInHorn"]) == 0) & (np.asarray(arrays["Z0_mass"]) > 30)
    ordered = np.asarray(arrays["PassesZZCR4lOrderedPt"]).astype(bool)
    z0win = np.abs(np.asarray(arrays["Z0_mass"]) - 91.1876) < 15
    xwin = (np.asarray(arrays["X_mass"]) > 75) & (np.asarray(arrays["X_mass"]) < 105)
    bveto = np.asarray(arrays["bVeto"]).astype(bool)
    met35 = np.asarray(arrays["PuppiMET_pt"]) < 35

    out = {}
    for channel, seed_name in (("ee", "Z0_isEE"), ("mm", "Z0_isMM")):
        stage = np.zeros(n, dtype=np.int8)
        m = baseline & np.asarray(arrays[seed_name]).astype(bool)
        stage[m] = 1
        for stage_id, clause in ((2, hlt), (3, ordered), (4, z0win), (5, xwin), (6, bveto), (7, met35)):
            m = m & clause
            stage[m] = stage_id
        out[channel] = stage
    return out["ee"], out["mm"]


def _fill_stage_histograms_for_chunk(arrays, observables, obs_configs, weights, accumulators, stage_jobs, is_data=False, timings=None, stage_cache=None):
    if stage_cache is None:
        t_stage = time.perf_counter()
        stage_ee, stage_mm = compute_zzcr_stages(arrays)
        _timer_add(timings, "hist_fill_stage_compute", time.perf_counter() - t_stage)
        stage_cache = {"ee": stage_ee, "mm": stage_mm}
    stages_by_channel = stage_cache
    w_full = None if is_data or weights is None else np.asarray(weights)
    nstage = 8

    for obs in observables:
        if obs not in arrays or obs not in obs_configs:
            continue
        bins = np.asarray(obs_configs[obs]["bins"], dtype=float)
        nbins = len(bins) - 1
        idx = compute_bin_indices(arrays[obs], bins, timings=timings)
        valid_idx = idx >= 0
        for channel, stage_arr in stages_by_channel.items():
            valid = valid_idx & (stage_arr > 0)
            if not np.any(valid):
                continue
            flat = np.asarray(stage_arr[valid], dtype=np.int64) * nbins + idx[valid]
            if is_data:
                exclusive_sumw = _bincount_by_index(flat, None, nstage * nbins, timings, "hist_fill_sumw").reshape(nstage, nbins)
                exclusive_sumw2 = exclusive_sumw
            else:
                if w_full is None:
                    continue
                wv = w_full[valid]
                exclusive_sumw = _bincount_by_index(flat, wv, nstage * nbins, timings, "hist_fill_sumw").reshape(nstage, nbins)
                exclusive_sumw2 = _bincount_by_index(flat, wv * wv, nstage * nbins, timings, "hist_fill_sumw2").reshape(nstage, nbins)
            cumulative_sumw = np.cumsum(exclusive_sumw[::-1], axis=0)[::-1]
            cumulative_sumw2 = np.cumsum(exclusive_sumw2[::-1], axis=0)[::-1]
            for job_id, job_channel, job_stage in stage_jobs:
                if job_channel != channel or obs not in accumulators[job_id]["hists"]:
                    continue
                accumulators[job_id]["hists"][obs] += cumulative_sumw[job_stage]
                accumulators[job_id]["vars"][obs] += cumulative_sumw2[job_stage]
    return accumulators


def fill_histograms_for_chunk(arrays, observables, obs_configs, cut_masks, weights, accumulators, process, tree_name, is_data=False, timings=None, stage_jobs=None, stage_cache=None):
    """Fill many observable/subcategory histograms from one array chunk.

    Default backend uses one full-chunk bin-index computation per observable and
    np.bincount for sumw/sumw2, avoiding repeated np.histogram(x[mask]) arrays.
    The previous np.histogram path remains available with runtime.hist_fill_backend='histogram'.
    """
    if not arrays or not observables:
        return accumulators
    if stage_jobs:
        return _fill_stage_histograms_for_chunk(arrays, observables, obs_configs, weights, accumulators, stage_jobs, is_data=is_data, timings=timings, stage_cache=stage_cache)

    if not cut_masks:
        return accumulators
    backend = str(_cfg("runtime", "hist_fill_backend", default="bincount")).lower().strip()
    w_full = None if is_data or weights is None else np.asarray(weights)

    for obs in observables:
        if obs not in arrays or obs not in obs_configs:
            continue
        x = np.asarray(arrays[obs])
        bins = np.asarray(obs_configs[obs]["bins"], dtype=float)
        nbins = len(bins) - 1
        if backend == "histogram":
            for cut_key, mask in cut_masks.items():
                t_mask = time.perf_counter()
                mask_arr = None if mask is None else np.asarray(mask, dtype=bool)
                if mask_arr is not None:
                    if mask_arr.size == 0 or not np.any(mask_arr):
                        _timer_add(timings, "hist_fill_mask_apply", time.perf_counter() - t_mask)
                        continue
                    x_sel = x[mask_arr]
                else:
                    x_sel = x
                _timer_add(timings, "hist_fill_mask_apply", time.perf_counter() - t_mask)
                acc = accumulators[cut_key]
                t_hist = time.perf_counter()
                if is_data:
                    h = _hist_with_flows_backend(x_sel, bins=bins)
                    _timer_add(timings, "hist_fill_histogram_call", time.perf_counter() - t_hist)
                    acc["hists"][obs] += h
                    acc["vars"][obs] += h
                else:
                    if w_full is None:
                        continue
                    w_sel = w_full[mask_arr] if mask_arr is not None else w_full
                    h = _hist_with_flows_backend(x_sel, bins=bins, weights=w_sel)
                    v = _hist_with_flows_backend(x_sel, bins=bins, weights=w_sel * w_sel)
                    _timer_add(timings, "hist_fill_histogram_call", time.perf_counter() - t_hist)
                    acc["hists"][obs] += h
                    acc["vars"][obs] += v
            continue

        idx = compute_bin_indices(x, bins, timings=timings)
        for cut_key, mask in cut_masks.items():
            t_mask = time.perf_counter()
            if mask is None:
                valid = idx >= 0
            else:
                mask_arr = np.asarray(mask, dtype=bool)
                valid = (idx >= 0) & mask_arr
            _timer_add(timings, "hist_fill_mask_apply", time.perf_counter() - t_mask)
            if not np.any(valid):
                continue
            acc = accumulators[cut_key]
            if is_data:
                h = _bincount_by_index(idx[valid], None, nbins, timings, "hist_fill_sumw")
                _validate_bincount_against_histogram(x, bins, valid, None, h, h, True, f"{tree_name}/{process}/{cut_key}/{obs}")
                acc["hists"][obs] += h
                acc["vars"][obs] += h
            else:
                if w_full is None:
                    continue
                w_sel = w_full[valid]
                h = _bincount_by_index(idx[valid], w_sel, nbins, timings, "hist_fill_sumw")
                v = _bincount_by_index(idx[valid], w_sel * w_sel, nbins, timings, "hist_fill_sumw2")
                _validate_bincount_against_histogram(x, bins, valid, w_full, h, v, False, f"{tree_name}/{process}/{cut_key}/{obs}")
                acc["hists"][obs] += h
                acc["vars"][obs] += v
    return accumulators


def _build_fast_direct_batches(jobs_by_tree, job_obs_map, obs_batch_size_cfg, cut_batch_size_cfg):
    batches = []
    for tree_name, tree_jobs in jobs_by_tree.items():
        tree_obs = []
        for job in tree_jobs:
            for obs in job_obs_map.get(id(job), []):
                if obs not in tree_obs:
                    tree_obs.append(obs)
        obs_batch_size = _resolve_direct_batch_size(obs_batch_size_cfg, len(tree_obs), default=2)
        for obs_start in range(0, len(tree_obs), obs_batch_size):
            obs_chunk = tree_obs[obs_start:obs_start + obs_batch_size]
            eligible_jobs = [job for job in tree_jobs if any(obs in obs_chunk for obs in job_obs_map.get(id(job), []))]
            cut_batch_size = _resolve_direct_batch_size(cut_batch_size_cfg, len(eligible_jobs), default=1)
            for cut_start in range(0, len(eligible_jobs), cut_batch_size):
                batches.append((tree_name, obs_chunk, eligible_jobs[cut_start:cut_start + cut_batch_size]))
    return batches



def _hist_production_signature(category_config, observables=None):
    jobs = build_category_jobs(category_config, observables=observables)
    selected_observables = sorted(set(o for j in jobs for o in j.get("observables", []) if o in OBSERVABLES))
    selected_cuts = {j.get("sub_name"): _normalize_cut(j.get("cut", "")) for j in jobs}
    bins = {obs: np.asarray(OBSERVABLES[obs]["bins"], dtype=float).tolist() for obs in selected_observables}
    payload = {
        "input_path": _cfg("io", "input_path"),
        "input_mode": _cfg("io", "input_mode"),
        "unmerged_glob": _cfg("io", "unmerged_glob"),
        "mc_weight_branch": _cfg("physics", "mc_weight_branch"),
        "data_processes": sorted(_cfg("physics", "data_processes", default=set())),
        "selected_observables": selected_observables,
        "selected_cuts": selected_cuts,
        "bins": bins,
        "category_config": _json_safe(category_config),
        "config_version": _cfg("config_version"),
        "hist_cache_schema_version": int(_cfg("execution", "hist_cache_schema_version", default=1)),
    }
    payload["config_hash"] = _config_hash(payload)
    return payload


def _hist_store_missing_mc_targets(store, category_config, observables=None):
    """Return requested category/observable targets that have no cached MC histogram."""
    jobs = build_category_jobs(category_config, observables=observables)
    expected = {
        (str(job["tree_name"]), str(job["sub_name"]), str(obs))
        for job in jobs
        for obs in job.get("observables", [])
        if obs in OBSERVABLES
    }
    if not expected:
        return []

    has_mc = set()
    for key, _rec in store.iter_hists():
        k_tree, k_sub, k_obs, _proc, _group, is_data = key
        if not is_data:
            has_mc.add((str(k_tree), str(k_sub), str(k_obs)))
    return sorted(expected - has_mc)


def _hist_cache_has_required_content(cache_path, category_config, observables=None):
    """Validate that a cache can actually back the requested Data-vs-MC plots."""
    if not bool(_cfg("execution", "require_mc_histograms", default=True)):
        return True
    try:
        store = HistogramStore.read_npz(cache_path)
    except Exception as exc:
        _log(f"Ignoring unreadable histogram cache {cache_path}: {exc}", level="warn")
        return False
    missing = _hist_store_missing_mc_targets(store, category_config, observables=observables)
    if missing:
        preview = ", ".join(f"{sub}/{obs}" for _tree, sub, obs in missing[:5])
        more = "" if len(missing) <= 5 else f", ... (+{len(missing) - 5} more)"
        _log(
            f"Ignoring histogram cache {cache_path}: missing MC histograms for {len(missing)} requested plot(s): {preview}{more}",
            level="warn",
        )
        return False
    return True


def _hist_cache_matches(cache_path, signature):
    if not cache_path or not os.path.exists(cache_path):
        return False
    try:
        data = np.load(cache_path, allow_pickle=True)
        metadata = json.loads(str(data["__metadata__"].item())) if "__metadata__" in data else {}
        return metadata.get("config_hash") == signature.get("config_hash")
    except Exception as exc:
        _log(f"Ignoring unreadable/stale histogram cache {cache_path}: {exc}", level="warn")
        return False


def produce_histograms_from_category_config(session, category_config, observables=None, cache_path=None, force=False, import_mode=None):
    jobs = build_category_jobs(category_config, observables=observables)
    job_ids = {id(job): idx for idx, job in enumerate(jobs)}
    jobs_by_tree = {}
    job_obs_map = {}
    selected_cuts = {}
    for job in jobs:
        jobs_by_tree.setdefault(job["tree_name"], []).append(job)
        valid_obs = [obs for obs in job.get("observables", []) if obs in OBSERVABLES]
        job_obs_map[id(job)] = valid_obs
        selected_cuts[job.get("sub_name")] = _normalize_cut(job.get("cut", ""))

    meta = _hist_production_signature(category_config, observables=observables)
    meta["created_utc"] = datetime.now(timezone.utc).isoformat()
    store = HistogramStore(metadata=meta)
    obs_batch_size_cfg = _cfg("runtime", "direct_observable_batch_size", default="all")
    cut_batch_size_cfg = _cfg("runtime", "direct_cut_batch_size", default="all")
    batches = _build_fast_direct_batches(jobs_by_tree, job_obs_map, obs_batch_size_cfg, cut_batch_size_cfg)
    _progress("produce hist batches", 0, len(batches), f"trees={len(jobs_by_tree)}")

    for i, (tree_name, obs_chunk, batch_jobs) in enumerate(batches, 1):
        if not obs_chunk or not batch_jobs:
            continue
        bins_by_obs = {obs: np.asarray(OBSERVABLES[obs]["bins"], dtype=float) for obs in obs_chunk}
        cut_jobs = []
        for job in batch_jobs:
            job_obs = [obs for obs in job_obs_map.get(id(job), []) if obs in obs_chunk]
            if job_obs:
                cut_job = {"job_id": job_ids[id(job)], "observables": job_obs, "cut_expr": _normalize_cut(job["cut"])}
                if "zzcr_channel" in job and "zzcr_stage" in job:
                    cut_job.update({"zzcr_channel": job["zzcr_channel"], "zzcr_stage": job["zzcr_stage"]})
                cut_jobs.append(cut_job)
        if not cut_jobs:
            continue
        _progress("produce hist batches", i, len(batches), f"tree={tree_name} jobs={len(cut_jobs)} obs={len(obs_chunk)}")
        direct = session.histograms_direct_multi_cut(tree_name, cut_jobs, bins_by_obs, import_mode=import_mode, force=force)
        for job in batch_jobs:
            job_id = job_ids[id(job)]
            job_result = direct.get("jobs", {}).get(job_id)
            if not job_result:
                continue
            process_histograms = job_result.get("process_histograms", {})
            if process_histograms:
                for proc, proc_obs in process_histograms.items():
                    for obs in [o for o in job_obs_map.get(id(job), []) if o in obs_chunk and o in proc_obs]:
                        rec = proc_obs[obs]
                        edges = np.asarray(OBSERVABLES[obs]["bins"], dtype=float)
                        key = HistogramStore.make_key(
                            tree_name,
                            job["sub_name"],
                            obs,
                            proc,
                            rec.get("process_group", proc),
                            bool(rec.get("is_data", False)),
                        )
                        store.add_hist(key, edges, rec["values"], rec["variances"], metadata={"cut": _normalize_cut(job["cut"]), "plot_label": job.get("title")})
            else:
                for obs in [o for o in job_obs_map.get(id(job), []) if o in obs_chunk]:
                    hist = job_result["histograms"][obs]
                    edges = np.asarray(OBSERVABLES[obs]["bins"], dtype=float)
                    data_key = HistogramStore.make_key(tree_name, job["sub_name"], obs, _cfg("physics", "data_legend_label", default="DATA"), _cfg("physics", "data_legend_label", default="DATA"), True)
                    store.add_hist(data_key, edges, hist["data_counts"], hist["data_counts"], metadata={"cut": _normalize_cut(job["cut"]), "plot_label": job.get("title")})
                    for group, values in hist["mc_h"].items():
                        key = HistogramStore.make_key(tree_name, job["sub_name"], obs, group, group, False)
                        store.add_hist(key, edges, values, hist["mc_v"].get(group, np.zeros_like(values)), metadata={"cut": _normalize_cut(job["cut"]), "plot_label": job.get("title")})
    if cache_path:
        store.write_npz(cache_path)
    if bool(_cfg("io", "write_root_histograms", default=False)):
        export_hist_cache_to_root(store, _cfg("io", "root_histogram_file", default="plots/histograms.root"))
    return store


def _plot_hist_record(record):
    session = DataMCSession()
    return _draw_datamc(
        session,
        record["category_key"],
        record["observable"],
        record["obs_cfg"],
        record["data_counts"],
        record["mc_h"],
        record["mc_v"],
        plot_label=record.get("plot_label"),
        subtitle=record.get("subtitle"),
        cut_text=record.get("cut_text"),
        plot_style=record.get("plot_style"),
        output_dir=record.get("output_dir"),
    )


def plot_category_config_from_hist_store(store, category_config, observables=None, session=None):
    session = session or DataMCSession()
    jobs = build_category_jobs(category_config, observables=observables)
    records = []
    for job in jobs:
        for obs in [o for o in job.get("observables", []) if o in OBSERVABLES]:
            data_counts, mc_h, mc_v = store.category_histograms(job["tree_name"], job["sub_name"], obs)
            if data_counts is None:
                data_counts = np.zeros(len(np.asarray(OBSERVABLES[obs]["bins"], dtype=float)) - 1, dtype=float)
            records.append({
                "category_key": job["sub_name"],
                "observable": obs,
                "obs_cfg": OBSERVABLES[obs],
                "data_counts": data_counts,
                "mc_h": mc_h,
                "mc_v": mc_v,
                "plot_label": job["title"],
                "subtitle": job.get("subtitle"),
                "cut_text": _normalize_cut(job["cut"]),
                "plot_style": job.get("plot_style"),
                "output_dir": job.get("output_dir"),
            })

    produced = []
    plot_workers = max(1, int(_cfg("runtime", "plot_workers", default=1)))
    plot_workers = min(plot_workers, 4)
    if plot_workers > 1 and len(records) > 1:
        _log(f"plotting from cache with process workers={plot_workers} plots={len(records)}")
        with ProcessPoolExecutor(max_workers=plot_workers) as pool:
            for out in pool.map(_plot_hist_record, records):
                if out:
                    produced.append(out)
        gc.collect()
        return produced

    gc_every = max(0, int(_cfg("runtime", "plot_gc_every", default=50)))
    for i, record in enumerate(records, 1):
        with _timer(f"plot {record['category_key']} {record['observable']}", level="debug"):
            out = _draw_datamc(
                session,
                record["category_key"],
                record["observable"],
                record["obs_cfg"],
                record["data_counts"],
                record["mc_h"],
                record["mc_v"],
                plot_label=record.get("plot_label"),
                subtitle=record.get("subtitle"),
                cut_text=record.get("cut_text"),
                plot_style=record.get("plot_style"),
                output_dir=record.get("output_dir"),
            )
        if out:
            produced.append(out)
        if gc_every and i % gc_every == 0:
            gc.collect()
    return produced


def plot_category_config_from_hist_cache(cache_path, category_config, observables=None, session=None):
    store = HistogramStore.read_npz(cache_path)
    return plot_category_config_from_hist_store(store, category_config, observables=observables, session=session)


produce_histograms = produce_histograms_from_category_config
plot_from_histograms = plot_category_config_from_hist_cache
run_category_config_fast_direct = produce_histograms_from_category_config


def export_hist_cache_to_root(store_or_path, root_path=None):
    store = HistogramStore.read_npz(store_or_path) if isinstance(store_or_path, str) else store_or_path
    root_path = root_path or _cfg("io", "root_histogram_file", default="plots/histograms.root")
    os.makedirs(os.path.dirname(root_path) or ".", exist_ok=True)
    with _timer(f"ROOT histogram export {root_path}"):
        f = ROOT.TFile.Open(root_path, "RECREATE")
        try:
            for key, rec in store.iter_hists():
                tree_name, subcat, obs, proc, group, is_data = key
                name = _sanitize(f"{tree_name}__{subcat}__{obs}__{proc}")
                edges = np.asarray(rec["edges"], dtype=float)
                h = ROOT.TH1D(name, name, len(edges) - 1, edges.astype(float))
                h.Sumw2()
                vals = np.asarray(rec["values"], dtype=float)
                vars_ = np.asarray(rec["variances"], dtype=float)
                for i, val in enumerate(vals, 1):
                    h.SetBinContent(i, float(val))
                    h.SetBinError(i, float(np.sqrt(max(vars_[i - 1], 0.0))))
                h.Write()
        finally:
            f.Close()
    return root_path


def produce_histograms_rdataframe(session, category_config, observables=None, root_path=None, workers=None):
    """Experimental ROOT RDataFrame producer that books TH1D actions first.

    Limitations: cuts and observables must be valid ROOT/C++ expressions or
    branch names.  This is intentionally opt-in via
    runtime.hist_production_backend='rdataframe_experimental'.
    """
    root_path = root_path or _cfg("io", "root_histogram_file", default="plots/histograms.root")
    os.makedirs(os.path.dirname(root_path) or ".", exist_ok=True)
    workers = int(workers or _cfg("runtime", "parallel_read_workers", default=1))
    if workers > 1:
        ROOT.EnableImplicitMT(workers)
    session.refresh_inputs(force=_cfg("cache", "force_reload_inputs", default=False), emit_log=False)
    jobs = build_category_jobs(category_config, observables=observables)
    actions = []
    output = ROOT.TFile.Open(root_path, "RECREATE")
    try:
        for tree_name in sorted(set(j["tree_name"] for j in jobs)):
            proc_items = session._process_file_items(tree_name)
            for proc, files in proc_items:
                is_data = proc in _cfg("physics", "data_processes")
                for rf in files:
                    # Resolve the tree path with uproot metadata so RDataFrame gets an exact path.
                    with uproot.open(rf) as f:
                        _tree, tree_path = session._get_tree_and_path(f, rf, tree_name, proc)
                    if not tree_path:
                        continue
                    df = ROOT.RDataFrame(tree_path, rf)
                    for job in [j for j in jobs if j["tree_name"] == tree_name]:
                        cut = _normalize_cut(job.get("cut", ""))
                        df_cut = df.Filter(cut) if cut else df
                        for obs in [o for o in job.get("observables", []) if o in OBSERVABLES]:
                            bins = np.asarray(OBSERVABLES[obs]["bins"], dtype=float)
                            hname = _sanitize(f"{tree_name}__{job['sub_name']}__{obs}__{proc}")
                            model = ROOT.RDF.TH1DModel(hname, hname, len(bins) - 1, array('d', bins.tolist()))
                            if (not is_data) and isinstance(_cfg("physics", "mc_weight_branch"), str):
                                actions.append(df_cut.Histo1D(model, obs, _cfg("physics", "mc_weight_branch")))
                            else:
                                actions.append(df_cut.Histo1D(model, obs))
        output.cd()
        for h in actions:
            h.GetValue().Write()
    finally:
        output.Close()
    return root_path


def compute_zzcr_cutflow_stage(arrays, channel):
    """Compute highest passed ZZ CR nested cutflow stage for ee/mm channels."""
    ch = str(channel).lower()
    flag = "Z0_isEE" if ch in {"ee", "electron", "ele"} else "Z0_isMM"
    required = {"nJetInHorn", "Z0_mass", flag, "Trigger_sngMu", "Trigger_dblMu", "Trigger_sngEl", "Trigger_dblEl", "Trigger_ElMu", "PassesZZCR4lOrderedPt", "X_mass", "bVeto", "PuppiMET_pt"}
    missing = sorted(required - set(arrays.keys()))
    if missing:
        raise KeyError(f"Cannot compute ZZ CR cutflow stage; missing branches: {missing}")
    n = len(np.asarray(arrays["Z0_mass"]))
    stage = np.zeros(n, dtype=np.int8)
    hlt = (np.asarray(arrays["Trigger_sngMu"]).astype(bool) | np.asarray(arrays["Trigger_dblMu"]).astype(bool) | np.asarray(arrays["Trigger_sngEl"]).astype(bool) | np.asarray(arrays["Trigger_dblEl"]).astype(bool) | np.asarray(arrays["Trigger_ElMu"]).astype(bool))
    m = (np.asarray(arrays["nJetInHorn"]) == 0) & (np.asarray(arrays["Z0_mass"]) > 30) & np.asarray(arrays[flag]).astype(bool)
    stage[m] = 1
    m = m & hlt
    stage[m] = 2
    m = m & np.asarray(arrays["PassesZZCR4lOrderedPt"]).astype(bool)
    stage[m] = 3
    m = m & (np.abs(np.asarray(arrays["Z0_mass"]) - 91.1876) < 15)
    stage[m] = 4
    m = m & (np.asarray(arrays["X_mass"]) > 75) & (np.asarray(arrays["X_mass"]) < 105)
    stage[m] = 5
    m = m & np.asarray(arrays["bVeto"]).astype(bool)
    stage[m] = 6
    m = m & (np.asarray(arrays["PuppiMET_pt"]) < 35)
    stage[m] = 7
    return stage



def validate_zzcr_stage_against_generic(arrays, channel):
    """Validate stage helper against explicit cumulative masks for one in-memory chunk."""
    stage = compute_zzcr_cutflow_stage(arrays, channel)
    ch = str(channel).lower()
    flag = "Z0_isEE" if ch in {"ee", "electron", "ele"} else "Z0_isMM"
    hlt = (np.asarray(arrays["Trigger_sngMu"]).astype(bool) | np.asarray(arrays["Trigger_dblMu"]).astype(bool) | np.asarray(arrays["Trigger_sngEl"]).astype(bool) | np.asarray(arrays["Trigger_dblEl"]).astype(bool) | np.asarray(arrays["Trigger_ElMu"]).astype(bool))
    masks = []
    m = (np.asarray(arrays["nJetInHorn"]) == 0) & (np.asarray(arrays["Z0_mass"]) > 30) & np.asarray(arrays[flag]).astype(bool)
    masks.append(m.copy())
    for clause in [
        hlt,
        np.asarray(arrays["PassesZZCR4lOrderedPt"]).astype(bool),
        (np.abs(np.asarray(arrays["Z0_mass"]) - 91.1876) < 15),
        ((np.asarray(arrays["X_mass"]) > 75) & (np.asarray(arrays["X_mass"]) < 105)),
        np.asarray(arrays["bVeto"]).astype(bool),
        (np.asarray(arrays["PuppiMET_pt"]) < 35),
    ]:
        m = m & clause
        masks.append(m.copy())
    failures = []
    for i, mask in enumerate(masks, 1):
        stage_mask = stage >= i
        if not np.array_equal(mask, stage_mask):
            failures.append({"stage": i, "n_diff": int(np.count_nonzero(mask != stage_mask))})
    ok = not failures
    _log(f"ZZ CR stage validation {'PASS' if ok else 'FAIL'} channel={channel} failures={len(failures)}", level="info" if ok else "error")
    return {"ok": ok, "failures": failures}


def _array_differences(label, legacy, fast, atol, rtol, max_bins=10):
    legacy = np.asarray(legacy, dtype=float)
    fast = np.asarray(fast, dtype=float)
    if np.allclose(legacy, fast, atol=atol, rtol=rtol):
        return []
    bad = np.where(~np.isclose(legacy, fast, atol=atol, rtol=rtol))[0]
    return [{
        "where": label,
        "bin": int(i),
        "legacy": float(legacy[i]),
        "fast": float(fast[i]),
        "delta": float(fast[i] - legacy[i]),
    } for i in bad[:max_bins]]




def validate_zzcr_stage_engine_against_generic(session, category_config, observables=None, max_observables=5, atol=1e-6, rtol=1e-6):
    """Validate specialized ZZCR stage mode against generic cut-mask mode."""
    obs = list(observables or _cfg("execution", "default_observables") or list(OBSERVABLES.keys()))[:max(1, int(max_observables))]
    old_stage = _cfg("runtime", "zzcr_stage_engine", default=True)
    old_cache = _cfg("execution", "produce_hist_cache", default=True)
    old_plot = _cfg("execution", "plot_from_hist_cache", default=True)
    try:
        ANALYSIS_CONFIG["execution"]["produce_hist_cache"] = False
        ANALYSIS_CONFIG["execution"]["plot_from_hist_cache"] = False
        ANALYSIS_CONFIG["runtime"]["zzcr_stage_engine"] = False
        generic = produce_histograms_from_category_config(session, category_config, observables=obs, cache_path=None, force=True)
        ANALYSIS_CONFIG["runtime"]["zzcr_stage_engine"] = True
        staged = produce_histograms_from_category_config(session, category_config, observables=obs, cache_path=None, force=True)
    finally:
        ANALYSIS_CONFIG["runtime"]["zzcr_stage_engine"] = old_stage
        ANALYSIS_CONFIG["execution"]["produce_hist_cache"] = old_cache
        ANALYSIS_CONFIG["execution"]["plot_from_hist_cache"] = old_plot

    diffs = []
    keys = sorted(set(generic.hists.keys()) | set(staged.hists.keys()))
    for key in keys:
        g = generic.hists.get(key)
        s = staged.hists.get(key)
        if g is None or s is None:
            diffs.append({"key": HistogramStore.key_to_string(key), "missing": "generic" if g is None else "stage"})
            continue
        if not np.allclose(g["values"], s["values"], atol=atol, rtol=rtol):
            diffs.append({"key": HistogramStore.key_to_string(key), "field": "values", "max_abs": float(np.max(np.abs(g["values"] - s["values"])))})
        if not np.allclose(g["variances"], s["variances"], atol=atol, rtol=rtol):
            diffs.append({"key": HistogramStore.key_to_string(key), "field": "variances", "max_abs": float(np.max(np.abs(g["variances"] - s["variances"])))})
    ok = not diffs
    _log(f"ZZCR stage-engine validation {'PASS' if ok else 'FAIL'} observables={len(obs)} diffs={len(diffs)}", level="info" if ok else "error")
    return {"ok": ok, "observables": obs, "differences": diffs}

def benchmark_direct_process_workers(session, category_config, observables=None, worker_values=(1, 2, 4, 8), max_observables=3, rebuild_each=True):
    """Benchmark direct_process_workers choices on the same small production job.

    Returns sorted results by wall time; choose the lowest wall time rather than
    highest CPU usage.  Intended for local tuning before a full 39x14 run.
    """
    old_workers = _cfg("runtime", "direct_process_workers", default=4)
    old_file_workers = _cfg("runtime", "direct_file_read_workers", default=old_workers)
    old_cache = _cfg("execution", "produce_hist_cache", default=True)
    old_plot = _cfg("execution", "plot_from_hist_cache", default=True)
    obs = list(observables or _cfg("execution", "default_observables") or list(OBSERVABLES.keys()))[:max(1, int(max_observables))]
    results = []
    try:
        ANALYSIS_CONFIG["execution"]["produce_hist_cache"] = False
        ANALYSIS_CONFIG["execution"]["plot_from_hist_cache"] = False
        for workers in worker_values:
            workers = max(1, int(workers))
            ANALYSIS_CONFIG["runtime"]["direct_process_workers"] = workers
            ANALYSIS_CONFIG["runtime"]["direct_file_read_workers"] = workers
            t0 = time.perf_counter()
            store = produce_histograms_from_category_config(
                session,
                category_config,
                observables=obs,
                cache_path=None,
                force=bool(rebuild_each),
                import_mode=_cfg("runtime", "array_branch_import_mode", default="needed"),
            )
            wall = time.perf_counter() - t0
            results.append({"direct_process_workers": workers, "wall_s": wall, "n_histograms": len(store.hists), "observables": list(obs)})
            _log(f"benchmark direct_process_workers={workers}: wall={wall:.2f}s hists={len(store.hists)}")
    finally:
        ANALYSIS_CONFIG["runtime"]["direct_process_workers"] = old_workers
        ANALYSIS_CONFIG["runtime"]["direct_file_read_workers"] = old_file_workers
        ANALYSIS_CONFIG["execution"]["produce_hist_cache"] = old_cache
        ANALYSIS_CONFIG["execution"]["plot_from_hist_cache"] = old_plot
    return sorted(results, key=lambda x: x["wall_s"])


def benchmark_histogram_backends(session, category_config, observables=None, backends=("bincount", "histogram"), max_observables=3):
    """Compare optimized numpy-bincount fill against the legacy histogram backend."""
    old_backend = _cfg("runtime", "hist_fill_backend", default="bincount")
    out = []
    try:
        for backend in backends:
            ANALYSIS_CONFIG["runtime"]["hist_fill_backend"] = backend
            t0 = time.perf_counter()
            store = produce_histograms_from_category_config(session, category_config, observables=list(observables or OBSERVABLES.keys())[:max_observables], cache_path=None, force=True)
            out.append({"backend": backend, "wall_s": time.perf_counter() - t0, "n_histograms": len(store.hists)})
    finally:
        ANALYSIS_CONFIG["runtime"]["hist_fill_backend"] = old_backend
    return sorted(out, key=lambda x: x["wall_s"])


def benchmark_rdataframe_backend(session, category_config, observables=None, workers=None):
    """Optional RDataFrame benchmark helper; does not replace the numpy backend."""
    t0 = time.perf_counter()
    root_path = produce_histograms_rdataframe(session, category_config, observables=observables, workers=workers)
    return {"backend": "rdataframe_experimental", "wall_s": time.perf_counter() - t0, "root_path": root_path, "workers": workers or _cfg("runtime", "parallel_read_workers", default=1)}

def validate_fast_direct_against_legacy(session, category_config, observables, max_processes=2, max_chunks=2, atol=1e-6, rtol=1e-6):
    """Compact smoke checker for fast-direct vs legacy direct on a tiny selection."""
    jobs = build_category_jobs(category_config, observables=observables)
    if not jobs:
        return {"ok": True, "checked": 0, "differences": []}
    job = jobs[0]
    obs = [o for o in job.get("observables", []) if o in OBSERVABLES][:1]
    if not obs:
        return {"ok": True, "checked": 0, "differences": []}
    old_allow = _cfg("filters", "process_allowlist")
    old_max_chunks = _cfg("runtime", "direct_validation_max_chunks", default=None)
    session.refresh_inputs(force=_cfg("cache", "force_reload_inputs", default=False), emit_log=False)
    first_tree = jobs[0]["tree_name"]
    if max_processes is not None:
        ANALYSIS_CONFIG["filters"]["process_allowlist"] = set(session.list_processes(first_tree)[:max(1, int(max_processes))])
        session._process_cache.clear()
    if max_chunks is not None:
        ANALYSIS_CONFIG["runtime"]["direct_validation_max_chunks"] = max(1, int(max_chunks))
    obs = obs[0]
    bins = np.asarray(OBSERVABLES[obs]["bins"], dtype=float)
    try:
        legacy = session.histograms_direct(job["tree_name"], [obs], {obs: bins}, cut_expr=_normalize_cut(job["cut"]))
        store = produce_histograms_from_category_config(session, {job["tree_name"]: {"subcategories": {job["sub_name"]: {"cut": job["cut"], "label": job.get("title", job["sub_name"])}}}}, observables=[obs])
    finally:
        ANALYSIS_CONFIG["filters"]["process_allowlist"] = old_allow
        if old_max_chunks is None:
            ANALYSIS_CONFIG["runtime"].pop("direct_validation_max_chunks", None)
        else:
            ANALYSIS_CONFIG["runtime"]["direct_validation_max_chunks"] = old_max_chunks
        session._process_cache.clear()
    data, mc_h, mc_v = store.category_histograms(job["tree_name"], job["sub_name"], obs)
    if data is None:
        data = np.zeros_like(legacy["histograms"][obs]["data_counts"])
    fast = {"data_counts": data, "mc_h": mc_h, "mc_v": mc_v}
    differences = []
    differences.extend(_array_differences("data_counts", legacy["histograms"][obs]["data_counts"], fast["data_counts"], atol, rtol))
    for group, vals in legacy["histograms"][obs]["mc_h"].items():
        differences.extend(_array_differences(f"mc_h:{group}", vals, fast["mc_h"].get(group, np.zeros_like(vals)), atol, rtol))
        differences.extend(_array_differences(f"mc_v:{group}", legacy["histograms"][obs]["mc_v"].get(group, np.zeros_like(vals)), fast["mc_v"].get(group, np.zeros_like(vals)), atol, rtol))
    ok = not differences
    _log(f"fast-direct validation {'PASS' if ok else 'FAIL'} checked=1 differences={len(differences)}", level="info" if ok else "error")
    return {"ok": ok, "checked": 1, "differences": differences}


def _resolve_direct_batch_size(value, n_items, default=1):
    if isinstance(value, str) and value.lower().strip() == "all":
        return max(1, int(n_items or 1))
    try:
        return max(1, int(value))
    except Exception:
        return max(1, int(default))


def run_category_config(session, category_config, observables=None, force_reload=False, import_mode=None):
    jobs = build_category_jobs(category_config, observables=observables)
    if not jobs:
        _log("No category plotting jobs were built. Check CATEGORY_CONFIG has non-empty subcategories and execution.default_observables selects known OBSERVABLES.", level="warn")
        return []
    force = force_reload or _cfg("cache", "force_reload_array_cache", default=False)
    if _data_loading_mode() == "direct" and bool(_cfg("runtime", "fast_direct_mode", default=True)):
        cache_path = _cfg("execution", "hist_cache_path", default="plots/hist_cache.npz")
        produce_cache = bool(_cfg("execution", "produce_hist_cache", default=True))
        plot_cache = bool(_cfg("execution", "plot_from_hist_cache", default=True))
        rebuild_cache = bool(_cfg("execution", "rebuild_hist_cache", default=False))
        signature = _hist_production_signature(category_config, observables=observables)
        use_existing = plot_cache and cache_path and (not force) and (not rebuild_cache) and _hist_cache_matches(cache_path, signature)
        if use_existing:
            use_existing = _hist_cache_has_required_content(cache_path, category_config, observables=observables)
        if use_existing:
            _log(f"Using histogram cache without ROOT I/O: {cache_path}")
            return plot_category_config_from_hist_cache(cache_path, category_config, observables=observables, session=session)
        store = produce_histograms_from_category_config(
            session,
            category_config,
            observables=observables,
            cache_path=cache_path if produce_cache else None,
            force=force,
            import_mode=import_mode,
        )
        missing_mc = _hist_store_missing_mc_targets(store, category_config, observables=observables) if bool(_cfg("execution", "require_mc_histograms", default=True)) else []
        if missing_mc:
            preview = ", ".join(f"{sub}/{obs}" for _tree, sub, obs in missing_mc[:10])
            more = "" if len(missing_mc) <= 10 else f", ... (+{len(missing_mc) - 10} more)"
            raise RuntimeError(
                "Histogram production completed but no MC histograms were available "
                f"for {len(missing_mc)} requested plot(s): {preview}{more}. "
                "Check that the input contains MC processes, that physics.data_processes only lists real data process names, "
                "and that the MC weight branch is present; delete/rebuild plots/hist_cache.npz after fixing inputs."
            )
        if plot_cache:
            return plot_category_config_from_hist_store(store, category_config, observables=observables, session=session)
        return store

    produced = []

    jobs_by_tree = {}
    for job in jobs:
        jobs_by_tree.setdefault(job["tree_name"], []).append(job)

    strategy = str(_cfg("runtime", "category_loading_strategy", default="preload_tree_uncut")).lower().strip()
    branch_strategy = str(_cfg("runtime", "preload_branch_strategy", default="union_all")).lower().strip()
    chunk_size = max(1, int(_cfg("runtime", "preload_observable_chunk_size", default=2)))

    if _data_loading_mode() == "direct":
        obs_batch_size_cfg = _cfg("runtime", "direct_observable_batch_size", default=2)
        cut_batch_size_cfg = _cfg("runtime", "direct_cut_batch_size", default=1)
        job_ids = {id(job): idx for idx, job in enumerate(jobs)}
        valid_obs_by_job = {}
        direct_batches = []

        for tree_name, tree_jobs in jobs_by_tree.items():
            tree_obs = []
            for job in tree_jobs:
                valid_obs = [obs for obs in job.get("observables", []) if obs in OBSERVABLES]
                valid_obs_by_job[id(job)] = valid_obs
                unknown = sorted(set(job.get("observables", [])) - set(valid_obs))
                for obs in unknown:
                    _log(_style_get(PLOT_STYLE_DEFAULTS, "text", "unknown_observable_log", default="Skipping unknown observable '{observable}'").format(observable=obs), level="warn")
                for obs in valid_obs:
                    if obs not in tree_obs:
                        tree_obs.append(obs)

            obs_batch_size = _resolve_direct_batch_size(obs_batch_size_cfg, len(tree_obs), default=2)
            for obs_start in range(0, len(tree_obs), obs_batch_size):
                obs_chunk = tree_obs[obs_start:obs_start + obs_batch_size]
                eligible_jobs = [
                    job for job in tree_jobs
                    if any(obs in obs_chunk for obs in valid_obs_by_job.get(id(job), []))
                ]
                cut_batch_size = _resolve_direct_batch_size(cut_batch_size_cfg, len(eligible_jobs), default=1)
                for cut_start in range(0, len(eligible_jobs), cut_batch_size):
                    direct_batches.append((tree_name, obs_chunk, eligible_jobs[cut_start:cut_start + cut_batch_size]))

        _progress("direct plot batches", 0, len(direct_batches), f"trees={len(jobs_by_tree)} obs_batch_size={obs_batch_size_cfg} cut_batch_size={cut_batch_size_cfg}")
        for i, (tree_name, obs_chunk, batch_jobs) in enumerate(direct_batches, 1):
            if not obs_chunk or not batch_jobs:
                continue

            bins_by_obs = {obs: np.asarray(OBSERVABLES[obs]["bins"], dtype=float) for obs in obs_chunk}
            cut_jobs = []
            for job in batch_jobs:
                job_obs = [obs for obs in valid_obs_by_job.get(id(job), []) if obs in obs_chunk]
                if not job_obs:
                    continue
                cut_job = {
                    "job_id": job_ids[id(job)],
                    "observables": job_obs,
                    "cut_expr": _normalize_cut(job["cut"]),
                }
                if "zzcr_channel" in job and "zzcr_stage" in job:
                    cut_job.update({"zzcr_channel": job["zzcr_channel"], "zzcr_stage": job["zzcr_stage"]})
                cut_jobs.append(cut_job)
            if not cut_jobs:
                continue

            _progress("direct plot batches", i, len(direct_batches), f"tree={tree_name} jobs={len(cut_jobs)} observables={len(obs_chunk)}")
            direct = session.histograms_direct_multi_cut(
                tree_name=tree_name,
                cut_jobs=cut_jobs,
                bins_by_obs=bins_by_obs,
                force=force,
                import_mode=import_mode,
            )

            for job in batch_jobs:
                job_id = job_ids[id(job)]
                job_result = direct.get("jobs", {}).get(job_id)
                if not job_result:
                    continue
                norm_job_cut = _normalize_cut(job["cut"])
                job_obs = [obs for obs in valid_obs_by_job.get(id(job), []) if obs in obs_chunk]

                if _cfg("logging", "emit_process_reports", default=True):
                    cut_preview = _cut_preview(norm_job_cut)
                    for rep in job_result.get("reports", []):
                        path_info = ",".join(rep.get("tree_paths", [])) if rep.get("tree_paths") else "?"
                        branch_info = ",".join(rep.get("branch_names", [])[:8])
                        if len(rep.get("branch_names", [])) > 8:
                            branch_info += ",..."
                        _log(
                            f"{job['sub_name']} :: proc={rep['proc']} files={rep['n_files']} tree={path_info} "
                            f"events={rep['entries_after_cut']}/{rep['entries_total']} chunks={rep.get('chunks', 0)} "
                            f"branches={rep['loaded_branches']} cut={cut_preview} direct-loaded=[{branch_info}]"
                        )

                for obs in job_obs:
                    cfg = OBSERVABLES[obs]
                    hist = job_result["histograms"][obs]
                    out = _draw_datamc(
                        session,
                        job["sub_name"],
                        obs,
                        cfg,
                        hist["data_counts"],
                        hist["mc_h"],
                        hist["mc_v"],
                        plot_label=job["title"],
                        subtitle=job.get("subtitle"),
                        cut_text=norm_job_cut,
                        plot_style=job.get("plot_style"),
                        output_dir=job.get("output_dir"),
                    )
                    if out:
                        produced.append(out)
        return produced

    total_preload_chunks = 0
    for tree_jobs in jobs_by_tree.values():
        tree_obs = sorted(set(o for j in tree_jobs for o in j.get("observables", [])))
        total_preload_chunks += len([tree_obs[i:i+chunk_size] for i in range(0, len(tree_obs), chunk_size)]) if branch_strategy == "per_observable_chunk" else 1
    preload_chunk_i = 0
    _progress("preload tree chunks", preload_chunk_i, total_preload_chunks, f"trees={len(jobs_by_tree)} branch_strategy={branch_strategy}")

    for tree_name, tree_jobs in jobs_by_tree.items():
        all_obs = sorted(set(o for j in tree_jobs for o in j.get("observables", [])))

        if branch_strategy == "per_observable_chunk":
            chunks = [all_obs[i:i+chunk_size] for i in range(0, len(all_obs), chunk_size)]
        else:
            chunks = [all_obs]

        preload_cut = ""
        if strategy == "preload_tree_or_subcategory_cut":
            preload_cut = _combine_subcategory_cuts_or([j.get("cut", "") for j in tree_jobs])

        for obs_chunk in chunks:
            obs_chunk_set = set(obs_chunk)
            required_branches = set()
            for j in tree_jobs:
                required_branches |= set(_plan_required_branches(obs_chunk, cut_expr=j.get("cut", "")))

            preload_desc = _cut_preview(preload_cut) if preload_cut else "<none>"
            preload_chunk_i += 1
            _progress(
                "preload tree chunks",
                preload_chunk_i,
                total_preload_chunks,
                f"tree={tree_name} chunk_obs={len(obs_chunk)} branches={len(required_branches)} preload_cut={preload_desc}",
            )
            _log(
                f"Preloading tree chunk tree={tree_name} jobs={len(tree_jobs)} chunk_obs={len(obs_chunk)} branches={len(required_branches)} preload_cut={preload_desc}"
            )

            base_payload = session.load_arrays(
                tree_name=tree_name,
                cut_expr=preload_cut,
                observables=obs_chunk,
                required_branches=sorted(required_branches),
                force=force,
                import_mode=import_mode,
            )

            for job in tree_jobs:
                job_obs = [o for o in job["observables"] if o in obs_chunk_set]
                if not job_obs:
                    continue

                materialize_cut_arrays = bool(_cfg("runtime", "materialize_category_cut_arrays", default=False))
                norm_job_cut = _normalize_cut(job["cut"])
                if materialize_cut_arrays:
                    payload = _apply_cut_to_payload(base_payload, norm_job_cut)
                    proc_arrays_for_plot = payload["arrays"]
                    reports = payload["reports"]
                    mask_cache = None
                else:
                    proc_arrays_for_plot = base_payload["arrays"]
                    mask_cache = {}
                    reports = _build_cut_reports_without_materialization(base_payload, norm_job_cut, mask_cache=mask_cache)

                if _cfg("logging", "emit_process_reports", default=True):
                    cut_preview = _cut_preview(norm_job_cut)
                    for rep in reports:
                        path_info = ",".join(rep.get("tree_paths", [])) if rep.get("tree_paths") else "?"
                        branch_info = ",".join(rep.get("branch_names", [])[:8])
                        if len(rep.get("branch_names", [])) > 8:
                            branch_info += ",..."
                        _log(
                            f"{job['sub_name']} :: proc={rep['proc']} files={rep['n_files']} tree={path_info} "
                            f"events={rep['entries_after_cut']}/{rep['entries_total']} branches={rep['loaded_branches']} "
                            f"cut={cut_preview} loaded=[{branch_info}]"
                        )

                for obs in job_obs:
                    if obs not in OBSERVABLES:
                        _log(_style_get(PLOT_STYLE_DEFAULTS, "text", "unknown_observable_log", default="Skipping unknown observable '{observable}'").format(observable=obs), level="warn")
                        continue
                    cfg = OBSERVABLES[obs]
                    if materialize_cut_arrays:
                        data_counts, mc_h, mc_v = _stack_from_arrays(session, proc_arrays_for_plot, obs, np.asarray(cfg["bins"], dtype=float))
                    else:
                        data_counts, mc_h, mc_v = _stack_from_payload_with_cut(
                            session,
                            proc_arrays_for_plot,
                            obs,
                            np.asarray(cfg["bins"], dtype=float),
                            norm_job_cut,
                            mask_cache=mask_cache,
                        )
                    out = _draw_datamc(
                        session,
                        job["sub_name"],
                        obs,
                        cfg,
                        data_counts,
                        mc_h,
                        mc_v,
                        plot_label=job["title"],
                        subtitle=job["subtitle"],
                        cut_text=job["cut"],
                        plot_style=job["plot_style"],
                        output_dir=job["output_dir"],
                    )
                    if out:
                        produced.append(out)
    return produced

# %%
# =========================
# SESSION BOOTSTRAP
# =========================
_validate_analysis_config(ANALYSIS_CONFIG)
_validate_user_payloads(OBSERVABLES, CATEGORY_CONFIG)
if bool(_cfg("diagnostics", "run_startup_static_checks", default=True)):
    run_static_diagnostics(raise_on_error=bool(_cfg("diagnostics", "raise_on_static_error", default=True)))
_log(f"Config snapshot: {_config_snapshot()}")

SESSION = DataMCSession()
SESSION.refresh_inputs(force=_cfg("cache", "force_reload_inputs", default=False))

if bool(_cfg("diagnostics", "run_startup_branch_checks", default=False)):
    default_obs_for_check = _cfg("execution", "default_observables") or list(OBSERVABLES.keys())
    for _tree_name, _cat_cfg in CATEGORY_CONFIG.items():
        tree_cuts_for_check = [
            sub_cfg.get("cut", "")
            for sub_cfg in ((_cat_cfg or {}).get("subcategories", {}) or {}).values()
            if isinstance(sub_cfg, dict)
        ]
        SESSION.diagnose_branch_availability(
            _tree_name,
            observables=default_obs_for_check,
            cuts=tree_cuts_for_check,
            max_files_per_proc=_cfg("diagnostics", "branch_check_max_files_per_proc", default=1),
            raise_on_error=bool(_cfg("diagnostics", "raise_on_branch_error", default=False)),
        )

_log(f"Discovered categories (first 20): {SESSION.list_categories()[:20]}")

# Quick usability helpers for interactive work:
# 1) quick_plot(SESSION, tree_name="zz_cr_ALL", observable="Z0_mass", cut_expr="Z0_isEE")
# 2) quick_plot(..., bins=np.linspace(0,300,61))  # ad-hoc variable with custom binning
# 3) payload = SESSION.load_arrays("zz_cr_ALL", cut_expr="Z0_isEE", observables=["Z0_mass", "lZ1_pt"], import_mode="all")

# Quick-start decision guide:
# - One plot quickly -> quick_plot(...)
# - Many ad-hoc jobs -> run_plot_jobs(...)
# - Full category batch -> run_category_config(...) or default execution cell

# %%
# =========================
# DEFAULT EXECUTION (batch over CATEGORY_CONFIG)
# =========================
default_observables = _cfg("execution", "default_observables")
if default_observables is None:
    default_observables = list(OBSERVABLES.keys())

produced_plots = []
if _cfg("execution", "run_default_batch_cell", default=True):
    produced_plots = run_category_config(
        SESSION,
        CATEGORY_CONFIG,
        observables=default_observables,
        force_reload=_cfg("cache", "force_reload_array_cache", default=False),
        import_mode=_cfg("runtime", "array_branch_import_mode", default="needed"),
    )
else:
    _log("Default batch cell is disabled by execution.run_default_batch_cell=False; no plots will be produced by this cell.", level="warn")

_log(f"Done. Produced {len(produced_plots)} plots.")

# %%
# =========================
# JOB-STYLE QUICK-PLOT EXAMPLES
# =========================
# These are templates; set RUN_JOB_EXAMPLES = True to execute.
# Goal: preload once, then derive cut-defined sub-categories fully in memory.

RUN_JOB_EXAMPLES = False

if "_JOB_PAYLOAD_REGISTRY" not in globals() or not isinstance(_JOB_PAYLOAD_REGISTRY, dict):
    _JOB_PAYLOAD_REGISTRY = {}

JOB_EXAMPLES = [
    {
        "tree_name": "zz_cr_ALL",
        "observable": "Z0_mass",
        "cut_expr": "Z0_isEE && bVeto && (PuppiMET_pt < 40.)",
        "subcategory_name": "zz_cr_ALL__ee_metlt40",
        "label": "Z→ee",
        "title": "ZZ CR",
        "subtitle": "In-memory cut from shared payload",
        "output_dir": "plots/jobs_in_memory",
    },
    {
        "tree_name": "zz_cr_ALL",
        "observable": "lZ1_pt",
        "cut_expr": "Z0_isMM && bVeto && (PuppiMET_pt < 40.)",
        "subcategory_name": "zz_cr_ALL__mm_metlt40",
        "label": "Z→μμ",
        "title": "ZZ CR custom",
        "subtitle": "In-memory custom style",
        "output_dir": "plots/jobs_in_memory",
        "plot_style": {
            "scales": {"logy": True},
            "legend": {"ncol": 1},
            "cut_block": {"text_width": 44},
            "layout": {"width_ratios": [7.1, 2.9]},
            "yaxis_scientific": {"manual_multiplier_min_abs_power": 3},
        },
    },
]
