# %%
import glob
import json
import os
from os import cpu_count
import re
import textwrap
from concurrent.futures import ThreadPoolExecutor, as_completed
from collections import OrderedDict
from datetime import datetime, timezone

import numpy as np
import pandas as pd
import uproot
import ROOT
from ROOT import TFile
import matplotlib as mpl
import matplotlib.pyplot as plt
import mplhep as hep
from hist.intervals import poisson_interval
from matplotlib.legend_handler import HandlerTuple

hep.style.use("CMS")

# %%
# =========================
# USER CONFIGURATION CELL
# =========================
# Purpose: Data-vs-MC plotting for ZH→4l+MET ZZ control regions.
# Edit this cell + OBSERVABLES/CATEGORY_CONFIG for most workflows.

ANALYSIS_CONFIG = {
    "config_version": 1,
    "purpose": "Data-vs-MC plotting and fast cut/observable iteration for ZH→4l+MET control regions",
    "notes": "Edit config + OBSERVABLES + CATEGORY_CONFIG only for most workflows",

    "io": {
        "input_mode": "merged",  # "auto", "merged", "unmerged"
        "input_path": "/uscmst1b_scratch/lpc1/3DayLifetime/mwadud/mkShapesRDF_rootfiles/ZH_4lMET_ZZCR_2024v15_fnal/rootFile/mkShapes__ZH_4lMET_ZZCR_2024v15_fnal__ALL.root",
        "unmerged_glob": "*.root",
        "unmerged_process_paths": {},
        "output_dir": "plots_zzcr_datamc",
        "output_file_ext": "png",
        "output_bbox_inches": "tight",
        "output_filename_template": "{title}_{category}_{observable}",
        "write_plot_metadata": True,
        "merged_tree_roots": ["{tree}", "trees/{tree}"],
        "tree_path_candidates": [
            "{tree}/{proc}/Events",
            "trees/{tree}/{proc}/Events",
            "/{tree}/{proc}/Events",
            "/trees/{tree}/{proc}/Events",
        ],
    },

    "physics": {
        "data_processes": {"DATA"},
        "mc_weight_branch": "weight",
        "data_legend_label": "DATA",
        "total_mc_legend_label": "Total MC",
        "yield_digits": 2,
        "yield_percent_digits": 1,
    },

    "runtime": {
        "enable_parallel_read": True,
        "parallel_read_workers": min(48, max(1, cpu_count() or 1)),
        "parallel_profile": "auto",  # "auto", "laptop", "shared", "batch"
        "array_branch_import_mode": "needed",  # "needed" or "all"
        "data_loading_mode": "arrays",  # reserved for future non-array loading mode
        "cut_eval_engine": "python",    # pandas eval engine
        "strict_cut_syntax": False,
        "strict_cut_allowed_pattern": r"^[A-Za-z0-9_\s\(\)\.><=+\-*/!&|,:]*$",
        "reuse_uncut_arrays_for_cuts": True,
        "category_loading_strategy": "preload_tree_uncut",  # "preload_tree_uncut" or "preload_tree_or_subcategory_cut"
        "explicit_branch_seed": [
            "Z0_isEE", "Z0_isMM", "bVeto", "PuppiMET_pt", "nJetInHorn",
        ],
        "auto_include_all_observables_in_seed": False,
        "unknown_observable_policy": "error",  # "warn", "ignore", "error"
        "log_branch_plan": False,
        "preload_branch_strategy": "union_all",  # "union_all" or "per_observable_chunk"
        "preload_observable_chunk_size": 2,
    },

    "cache": {
        "arrays_in_memory": True,
        "force_reload_inputs": False,
        "force_reload_array_cache": False,
        "max_entries": 32,
        "max_bytes_mb": 4096,
        "eviction_policy": "lru",
    },

    "filters": {
        "process_allowlist": None,
        "process_blocklist": set(),
        "exclude_top_level_keys": {"trees"},
        "filename_process_strip_pattern": r"_\d+$",
    },

    "style_behavior": {
        "stack_by_group": True,
    },

    "logging": {
        "enabled": True,
        "progress_enabled": True,
        "progress_every": 25,
        "emit_process_reports": True,
        "dedupe_repeated": True,
        "hacker_style": True,
        "show_tree_path": True,
        "show_cut": True,
        "show_timestamp": True,
        "timestamp_utc": True,
        "timestamp_fmt": "%Y-%m-%d %H:%M:%S",
        "show_branch_summary": True,
        "max_cut_preview": 120,
    },

    "execution": {
        "run_default_batch_cell": True,
        "default_observables": None,  # None -> OBSERVABLES keys
    },
}

os.makedirs(ANALYSIS_CONFIG["io"]["output_dir"], exist_ok=True)

PLOT_STYLE_DEFAULTS = {
    "meta": {
        "title": "",
        "subtitle_separator": " • ",
        "lumi_label": "26.49",
    },
    "figure": {
        "figsize": (10, 7),
        "save_dpi": 180,
        "show_plots": False,
        "facecolor": "white",
    },
    "layout": {
        "width_ratios": [6.8, 3.2],
        "height_ratios": [3, 1],
        "wspace": 0.05,
        "hspace": 0.04,
    },
    "panels": {
        "main_facecolor": "white",
        "ratio_facecolor": "white",
        "legend_facecolor": "white",
    },
    "axes": {
        "x_label": "",
        "y_label": "Events",
        "ratio_y_label": "Data/MC",
        "axis_label_fontsize": 24,
        "axis_labelpad": 6,
        "tick_labelsize": 15,
        "tick_direction": "in",
        "tick_length": 5,
        "tick_width": 1.0,
        "tick_top": True,
        "tick_right": True,
        "title_fontsize": 10,
        "title_fontweight": "normal",
        "title_color": "black",
        "title_x": 0.02,
        "title_y": 0.90,
        "subtitle_enabled": True,
        "subtitle_fontsize": 9,
        "subtitle_fontweight": "normal",
        "subtitle_color": "black",
        "subtitle_fontstyle": "normal",
        "subtitle_y_offset": 0.055,
        "ratio_ylim_default": (0.5, 1.5),
        "spine_linewidth": 1.0,
    },
    "grid": {
        "enabled": True,
        "main_alpha": 0.25,
        "ratio_alpha": 0.25,
        "linestyle": "-",
        "linewidth": 0.6,
        "which": "major",
        "axis": "both",
    },
    "stack": {
        "alpha": 0.82,
        "edgecolor": "none",
        "linewidth": 0.0,
        "align": "center",
        "zorder": 2,
    },
    "mc": {
        "line_color": "red",
        "line_width": 1.5,
        "line_style": "-",
        "line_drawstyle": "steps-mid",
        "line_zorder": 5,
        "band_alpha": 0.12,
        "band_hatch": None,
        "band_step": "mid",
        "band_zorder": 4,
    },
    "data": {
        "marker": "o",
        "marker_size": 4,
        "color": "black",
        "elinewidth": 1.0,
        "capsize": 0,
        "marker_zorder": 6,
    },
    "ratio": {
        "reference_line_value": 1.0,
        "reference_line_color": None,
        "reference_line_width": 1.0,
        "reference_line_style": "-",
        "reference_line_drawstyle": "steps-mid",
        "reference_line_zorder": 3,
        "band_step": "mid",
    },
    "legend": {
        "loc": "upper left",
        "ncol": 2,
        "fontsize": 10,
        "frameon": False,
        "title": "",
        "title_fontsize": 10,
        "handlelength": 1.2,
        "columnspacing": 0.9,
        "labelspacing": 0.35,
        "handletextpad": 0.4,
        "borderaxespad": 0.0,
    },
    "cut_block": {
        "enabled": True,
        "title_text": "Selection:",
        "text_width": 38,
        "title_fontsize": 12,
        "title_fontweight": "bold",
        "title_color": "black",
        "text_fontsize": 8,
        "text_color": "black",
        "block_gap_from_legend": 0.055,
        "title_to_text_gap": 0.03,
        "line_spacing": 1.10,
        "fontfamily": "monospace",
    },
    "cms": {
        "label": "Preliminary",
        "com": 13.6,
        "fontsize": 20,
    },
    "yaxis_scientific": {
        "enabled": True,
        "plain_threshold": 1e3,
        "powerlimits": (-4, 4),
        "manual_multiplier_min_abs_power": 4,
        "multiplier_x": -0.005,
        "multiplier_y": 1.005,
        "multiplier_ha": "right",
        "multiplier_fontsize": 14,
    },
    "scales": {
        "logy": False,
    },
    "text": {
        "selection_title": "Selection:",
        "plot_saved_log": "Saved plot: {path}",
        "no_mc_log": "No MC histogram available for {category}/{observable}",
        "unknown_observable_log": "Skipping unknown observable '{observable}'",
    },
}

# Branch compatibility aliases (canonical -> alternates)
BRANCH_ALIASES = {
    "lZ1_eta": ["__lZ1_eta", "lZ1_Eta"],
    "lZ1_phi": ["__lZ1_phi", "lZ1_Phi"],
    "lZ2_eta": ["__lZ2_eta", "lZ2_Eta"],
    "lZ2_phi": ["__lZ2_phi", "lZ2_Phi"],
    "lX1_eta": ["__lX1_eta", "lX1_Eta"],
    "lX1_phi": ["__lX1_phi", "lX1_Phi"],
    "lX2_eta": ["__lX2_eta", "lX2_Eta"],
    "lX2_phi": ["__lX2_phi", "lX2_Phi"],
}


# ZZ_CR reference notes (kept as comments for quick onboarding):
# - Trigger gate used in ZZ_CR preselections:
#   (Trigger_ElMu || Trigger_sngMu || Trigger_dblMu || Trigger_sngEl || Trigger_dblEl)
# - Core ZZ_CR staged selections used in this notebook:
#   DY    : bVeto && (Z0_mass > 30.) && (nJetInHorn == 0)
#   Z0WIN : abs(Z0_mass - 91.1876) < 15.
#   XZWIN : abs(X_mass - 91.1876) < 15.
#   MET35 : PuppiMET_pt < 35.
# - Pairings used for pairwise angular observables:
#   (lZ1,lZ2), (lZ1,lX1), (lZ1,lX2), (lZ2,lX1), (lZ2,lX2), (lX1,lX2)
# - Full ZZ_CR tree output branch list (from ZZ_CR/variables.py) for reference:
#   Trigger_ElMu
#   Trigger_sngMu
#   Trigger_dblMu
#   Trigger_sngEl
#   Trigger_dblEl
#   nCleanJet
#   Z0_mass
#   Z0_pt
#   Z0_eta
#   Z0_phi
#   X_mass
#   X_pt
#   X_eta
#   X_phi
#   m4l
#   pT4l
#   phi4l
#   PuppiMET_pt
#   PuppiMET_phi
#   PuppiMET_significance
#   PuppiMET_sumEt
#   HT
#   nJetInHorn
#   dPhi_MET_Z
#   dPhi_MET_X
#   dPhi_MET_lZ1
#   dPhi_MET_lZ2
#   dPhi_MET_lX1
#   dPhi_MET_lX2
#   dPhi_MET_ZplusX
#   dPhi_lZ1_lZ2
#   dPhi_lZ1_lX1
#   dPhi_lZ1_lX2
#   dPhi_lZ2_lX1
#   dPhi_lZ2_lX2
#   dPhi_lX1_lX2
#   dEta_lZ1_lZ2
#   dEta_lZ1_lX1
#   dEta_lZ1_lX2
#   dEta_lZ2_lX1
#   dEta_lZ2_lX2
#   dEta_lX1_lX2
#   dR_lZ1_lZ2
#   dR_lZ1_lX1
#   dR_lZ1_lX2
#   dR_lZ2_lX1
#   dR_lZ2_lX2
#   dR_lX1_lX2
#   recoil_ux
#   recoil_uy
#   recoil_ut
#   recoil_upar
#   recoil_uperp
#   sumLeptonCharge
#   Z0_isEE
#   Z0_isMM
#   X_isEE
#   X_isMM
#   GenMET_pt
#   GenMET_phi
#   bVeto
#   PassesZZCR4lOrderedPt
#   lZ1_pt
#   lZ1_eta
#   lZ1_phi
#   lZ1_pdgId
#   lZ1_charge
#   lZ1_genPdgId
#   lZ1_genPt
#   lZ1_genEta
#   lZ1_genPhi
#   lZ1_trigObj_pt
#   lZ1_trigObj_eta
#   lZ1_trigObj_phi
#   lZ1_trigObj_pdgId
#   lZ1_trigObj_filterBits
#   lZ1_trigObj_bits4l
#   lZ1_isTightElectron_testrecipes
#   lZ1_isTightElectron_wp90iso
#   lZ1_isTightElectron_mvaWinter22V2Iso_WP90
#   lZ1_isTightElectron_cutBased_LooseID_tthMVA_Run3
#   lZ1_isTightElectron_cutBased_LooseID_tthMVA_HWW
#   lZ1_isTightMuon_cut_TightID_POG
#   lZ1_isTightMuon_cut_Tight_HWW
#   lZ1_isTightMuon_cut_TightID_pfIsoTight_HWW_tthmva_67
#   lZ1_isTightMuon_cut_TightID_pfIsoLoose_HWW_tthmva_67
#   lZ1_isTightMuon_cut_TightID_pfIsoLoose_HWW_tthmva_HWW
#   lZ2_pt
#   lZ2_eta
#   lZ2_phi
#   lZ2_pdgId
#   lZ2_charge
#   lZ2_genPdgId
#   lZ2_genPt
#   lZ2_genEta
#   lZ2_genPhi
#   lZ2_trigObj_pt
#   lZ2_trigObj_eta
#   lZ2_trigObj_phi
#   lZ2_trigObj_pdgId
#   lZ2_trigObj_filterBits
#   lZ2_trigObj_bits4l
#   lZ2_isTightElectron_testrecipes
#   lZ2_isTightElectron_wp90iso
#   lZ2_isTightElectron_mvaWinter22V2Iso_WP90
#   lZ2_isTightElectron_cutBased_LooseID_tthMVA_Run3
#   lZ2_isTightElectron_cutBased_LooseID_tthMVA_HWW
#   lZ2_isTightMuon_cut_TightID_POG
#   lZ2_isTightMuon_cut_Tight_HWW
#   lZ2_isTightMuon_cut_TightID_pfIsoTight_HWW_tthmva_67
#   lZ2_isTightMuon_cut_TightID_pfIsoLoose_HWW_tthmva_67
#   lZ2_isTightMuon_cut_TightID_pfIsoLoose_HWW_tthmva_HWW
#   lX1_pt
#   lX1_eta
#   lX1_phi
#   lX1_pdgId
#   lX1_charge
#   lX1_genPdgId
#   lX1_genPt
#   lX1_genEta
#   lX1_genPhi
#   lX1_trigObj_pt
#   lX1_trigObj_eta
#   lX1_trigObj_phi
#   lX1_trigObj_pdgId
#   lX1_trigObj_filterBits
#   lX1_trigObj_bits4l
#   lX1_isTightElectron_testrecipes
#   lX1_isTightElectron_wp90iso
#   lX1_isTightElectron_mvaWinter22V2Iso_WP90
#   lX1_isTightElectron_cutBased_LooseID_tthMVA_Run3
#   lX1_isTightElectron_cutBased_LooseID_tthMVA_HWW
#   lX1_isTightMuon_cut_TightID_POG
#   lX1_isTightMuon_cut_Tight_HWW
#   lX1_isTightMuon_cut_TightID_pfIsoTight_HWW_tthmva_67
#   lX1_isTightMuon_cut_TightID_pfIsoLoose_HWW_tthmva_67
#   lX1_isTightMuon_cut_TightID_pfIsoLoose_HWW_tthmva_HWW
#   lX2_pt
#   lX2_eta
#   lX2_phi
#   lX2_pdgId
#   lX2_charge
#   lX2_genPdgId
#   lX2_genPt
#   lX2_genEta
#   lX2_genPhi
#   lX2_trigObj_pt
#   lX2_trigObj_eta
#   lX2_trigObj_phi
#   lX2_trigObj_pdgId
#   lX2_trigObj_filterBits
#   lX2_trigObj_bits4l
#   lX2_isTightElectron_testrecipes
#   lX2_isTightElectron_wp90iso
#   lX2_isTightElectron_mvaWinter22V2Iso_WP90
#   lX2_isTightElectron_cutBased_LooseID_tthMVA_Run3
#   lX2_isTightElectron_cutBased_LooseID_tthMVA_HWW
#   lX2_isTightMuon_cut_TightID_POG
#   lX2_isTightMuon_cut_Tight_HWW
#   lX2_isTightMuon_cut_TightID_pfIsoTight_HWW_tthmva_67
#   lX2_isTightMuon_cut_TightID_pfIsoLoose_HWW_tthmva_67
#   lX2_isTightMuon_cut_TightID_pfIsoLoose_HWW_tthmva_HWW
#   nTightElectron_testrecipes
#   nTightElectron_wp90iso
#   nTightElectron_mvaWinter22V2Iso_WP90
#   nTightElectron_cutBased_LooseID_tthMVA_Run3
#   nTightElectron_cutBased_LooseID_tthMVA_HWW
#   nTightMuon_cut_TightID_POG
#   nTightMuon_cut_Tight_HWW
#   nTightMuon_cut_TightID_pfIsoTight_HWW_tthmva_67
#   nTightMuon_cut_TightID_pfIsoLoose_HWW_tthmva_67
#   nTightMuon_cut_TightID_pfIsoLoose_HWW_tthmva_HWW
#   lZ1_selWP_TotSF
#   lZ2_selWP_TotSF
#   lX1_selWP_TotSF
#   lX2_selWP_TotSF
#   CleanJet_pt_0
#   CleanJet_eta_0
#   CleanJet_phi_0
#   CleanJet_genPt_0
#   CleanJet_genEta_0
#   CleanJet_genPhi_0
#   CleanJet_pt_1
#   CleanJet_eta_1
#   CleanJet_phi_1
#   CleanJet_genPt_1
#   CleanJet_genEta_1
#   CleanJet_genPhi_1

# %%
OBSERVABLES = {
    "Z0_mass": {"bins": np.linspace(60, 120, 31), "xlabel": r"$m_{Z_0}$ [GeV]", "ratio_ylim": (0.5, 1.5)},
    "X_mass": {"bins": np.linspace(0, 160, 33), "xlabel": r"$m_{X}$ [GeV]", "ratio_ylim": (0.5, 1.5)},
    "PuppiMET_pt": {"bins": np.linspace(0, 120, 31), "xlabel": r"$p_{\mathrm{T}}^{\mathrm{miss}}$ [GeV]", "ratio_ylim": (0.5, 1.5)},
    "nJetInHorn": {"bins": np.arange(-0.5, 5.5, 1.0), "xlabel": r"$N_{\mathrm{jet}}$", "ratio_ylim": (0.5, 1.5)},
    "m4l": {"bins": np.linspace(70, 350, 41), "xlabel": r"$m_{4\ell}$ [GeV]", "ratio_ylim": (0.5, 1.5)},
    "pT4l": {"bins": np.linspace(0, 250, 41), "xlabel": r"$p_{\mathrm{T}}^{4\ell}$ [GeV]", "ratio_ylim": (0.5, 1.5)},
    "lZ1_pt":  {"bins": np.linspace(0, 250, 41), "xlabel": r"$p_{\mathrm{T}}^{\ell_{Z1}}$ [GeV]", "ratio_ylim": (0.4, 1.8)},
    "lZ1_eta": {"bins": np.linspace(-2.5, 2.5, 41), "xlabel": r"$\eta^{\ell_{Z1}}$", "ratio_ylim": (0.4, 1.8)},
    "lZ2_pt":  {"bins": np.linspace(0, 250, 41), "xlabel": r"$p_{\mathrm{T}}^{\ell_{Z2}}$ [GeV]", "ratio_ylim": (0.4, 1.8)},
    "lZ2_eta": {"bins": np.linspace(-2.5, 2.5, 41), "xlabel": r"$\eta^{\ell_{Z2}}$", "ratio_ylim": (0.4, 1.8)},
    "lX1_pt":  {"bins": np.linspace(0, 250, 41), "xlabel": r"$p_{\mathrm{T}}^{\ell_{X1}}$ [GeV]", "ratio_ylim": (0.4, 1.8)},
    "lX1_eta": {"bins": np.linspace(-2.5, 2.5, 41), "xlabel": r"$\eta^{\ell_{X1}}$", "ratio_ylim": (0.4, 1.8)},
    "lX2_pt":  {"bins": np.linspace(0, 250, 41), "xlabel": r"$p_{\mathrm{T}}^{\ell_{X2}}$ [GeV]", "ratio_ylim": (0.4, 1.8)},
    "lX2_eta": {"bins": np.linspace(-2.5, 2.5, 41), "xlabel": r"$\eta^{\ell_{X2}}$", "ratio_ylim": (0.4, 1.8)},

    # --- ZZ_CR optional observables (commented out) ---
    # Enable entries below as needed for trigger/selection/pairing validation studies.
    # "Trigger_ElMu": {"bins": np.arange(-0.5, 2.5, 1.0), "xlabel": r"Trigger_ElMu", "ratio_ylim": (0.0, 2.0)},
    # "Trigger_sngMu": {"bins": np.arange(-0.5, 2.5, 1.0), "xlabel": r"Trigger_sngMu", "ratio_ylim": (0.0, 2.0)},
    # "Trigger_dblMu": {"bins": np.arange(-0.5, 2.5, 1.0), "xlabel": r"Trigger_dblMu", "ratio_ylim": (0.0, 2.0)},
    # "Trigger_sngEl": {"bins": np.arange(-0.5, 2.5, 1.0), "xlabel": r"Trigger_sngEl", "ratio_ylim": (0.0, 2.0)},
    # "Trigger_dblEl": {"bins": np.arange(-0.5, 2.5, 1.0), "xlabel": r"Trigger_dblEl", "ratio_ylim": (0.0, 2.0)},
    # "nCleanJet": {"bins": np.arange(-0.5, 8.5, 1.0), "xlabel": r"nCleanJet", "ratio_ylim": (0.0, 2.0)},
    # "Z0_pt": {"bins": np.linspace(0, 250, 41), "xlabel": r"Z0_pt", "ratio_ylim": (0.5, 1.5)},
    # "Z0_eta": {"bins": np.linspace(-2.5, 2.5, 41), "xlabel": r"Z0_eta", "ratio_ylim": (0.4, 1.8)},
    # "Z0_phi": {"bins": np.linspace(-np.pi, np.pi, 51), "xlabel": r"Z0_phi", "ratio_ylim": (0.5, 1.5)},
    # "X_pt": {"bins": np.linspace(0, 250, 41), "xlabel": r"X_pt", "ratio_ylim": (0.5, 1.5)},
    # "X_eta": {"bins": np.linspace(-2.5, 2.5, 41), "xlabel": r"X_eta", "ratio_ylim": (0.4, 1.8)},
    # "X_phi": {"bins": np.linspace(-np.pi, np.pi, 51), "xlabel": r"X_phi", "ratio_ylim": (0.5, 1.5)},
    # "phi4l": {"bins": np.linspace(-np.pi, np.pi, 51), "xlabel": r"phi4l", "ratio_ylim": (0.5, 1.5)},
    # "PuppiMET_phi": {"bins": np.linspace(-np.pi, np.pi, 51), "xlabel": r"PuppiMET_phi", "ratio_ylim": (0.5, 1.5)},
    # "PuppiMET_significance": {"bins": np.linspace(0, 40, 41), "xlabel": r"PuppiMET_significance", "ratio_ylim": (0.5, 1.5)},
    # "PuppiMET_sumEt": {"bins": np.linspace(0, 300, 41), "xlabel": r"PuppiMET_sumEt", "ratio_ylim": (0.5, 1.5)},
    # "HT": {"bins": np.linspace(0, 300, 41), "xlabel": r"HT", "ratio_ylim": (0.5, 1.5)},
    # "dPhi_MET_Z": {"bins": np.linspace(-np.pi, np.pi, 51), "xlabel": r"dPhi_MET_Z", "ratio_ylim": (0.5, 1.5)},
    # "dPhi_MET_X": {"bins": np.linspace(-np.pi, np.pi, 51), "xlabel": r"dPhi_MET_X", "ratio_ylim": (0.5, 1.5)},
    # "dPhi_MET_lZ1": {"bins": np.linspace(-np.pi, np.pi, 51), "xlabel": r"dPhi_MET_lZ1", "ratio_ylim": (0.5, 1.5)},
    # "dPhi_MET_lZ2": {"bins": np.linspace(-np.pi, np.pi, 51), "xlabel": r"dPhi_MET_lZ2", "ratio_ylim": (0.5, 1.5)},
    # "dPhi_MET_lX1": {"bins": np.linspace(-np.pi, np.pi, 51), "xlabel": r"dPhi_MET_lX1", "ratio_ylim": (0.5, 1.5)},
    # "dPhi_MET_lX2": {"bins": np.linspace(-np.pi, np.pi, 51), "xlabel": r"dPhi_MET_lX2", "ratio_ylim": (0.5, 1.5)},
    # "dPhi_MET_ZplusX": {"bins": np.linspace(-np.pi, np.pi, 51), "xlabel": r"dPhi_MET_ZplusX", "ratio_ylim": (0.5, 1.5)},
    # "dPhi_lZ1_lZ2": {"bins": np.linspace(-np.pi, np.pi, 51), "xlabel": r"dPhi_lZ1_lZ2", "ratio_ylim": (0.5, 1.5)},
    # "dPhi_lZ1_lX1": {"bins": np.linspace(-np.pi, np.pi, 51), "xlabel": r"dPhi_lZ1_lX1", "ratio_ylim": (0.5, 1.5)},
    # "dPhi_lZ1_lX2": {"bins": np.linspace(-np.pi, np.pi, 51), "xlabel": r"dPhi_lZ1_lX2", "ratio_ylim": (0.5, 1.5)},
    # "dPhi_lZ2_lX1": {"bins": np.linspace(-np.pi, np.pi, 51), "xlabel": r"dPhi_lZ2_lX1", "ratio_ylim": (0.5, 1.5)},
    # "dPhi_lZ2_lX2": {"bins": np.linspace(-np.pi, np.pi, 51), "xlabel": r"dPhi_lZ2_lX2", "ratio_ylim": (0.5, 1.5)},
    # "dPhi_lX1_lX2": {"bins": np.linspace(-np.pi, np.pi, 51), "xlabel": r"dPhi_lX1_lX2", "ratio_ylim": (0.5, 1.5)},
    # "dEta_lZ1_lZ2": {"bins": np.linspace(-5.0, 5.0, 51), "xlabel": r"dEta_lZ1_lZ2", "ratio_ylim": (0.5, 1.5)},
    # "dEta_lZ1_lX1": {"bins": np.linspace(-5.0, 5.0, 51), "xlabel": r"dEta_lZ1_lX1", "ratio_ylim": (0.5, 1.5)},
    # "dEta_lZ1_lX2": {"bins": np.linspace(-5.0, 5.0, 51), "xlabel": r"dEta_lZ1_lX2", "ratio_ylim": (0.5, 1.5)},
    # "dEta_lZ2_lX1": {"bins": np.linspace(-5.0, 5.0, 51), "xlabel": r"dEta_lZ2_lX1", "ratio_ylim": (0.5, 1.5)},
    # "dEta_lZ2_lX2": {"bins": np.linspace(-5.0, 5.0, 51), "xlabel": r"dEta_lZ2_lX2", "ratio_ylim": (0.5, 1.5)},
    # "dEta_lX1_lX2": {"bins": np.linspace(-5.0, 5.0, 51), "xlabel": r"dEta_lX1_lX2", "ratio_ylim": (0.5, 1.5)},
    # "dR_lZ1_lZ2": {"bins": np.linspace(0.0, 6.0, 49), "xlabel": r"dR_lZ1_lZ2", "ratio_ylim": (0.5, 1.5)},
    # "dR_lZ1_lX1": {"bins": np.linspace(0.0, 6.0, 49), "xlabel": r"dR_lZ1_lX1", "ratio_ylim": (0.5, 1.5)},
    # "dR_lZ1_lX2": {"bins": np.linspace(0.0, 6.0, 49), "xlabel": r"dR_lZ1_lX2", "ratio_ylim": (0.5, 1.5)},
    # "dR_lZ2_lX1": {"bins": np.linspace(0.0, 6.0, 49), "xlabel": r"dR_lZ2_lX1", "ratio_ylim": (0.5, 1.5)},
    # "dR_lZ2_lX2": {"bins": np.linspace(0.0, 6.0, 49), "xlabel": r"dR_lZ2_lX2", "ratio_ylim": (0.5, 1.5)},
    # "dR_lX1_lX2": {"bins": np.linspace(0.0, 6.0, 49), "xlabel": r"dR_lX1_lX2", "ratio_ylim": (0.5, 1.5)},
    # "recoil_ux": {"bins": np.linspace(-300, 300, 61), "xlabel": r"recoil_ux", "ratio_ylim": (0.5, 1.5)},
    # "recoil_uy": {"bins": np.linspace(-300, 300, 61), "xlabel": r"recoil_uy", "ratio_ylim": (0.5, 1.5)},
    # "recoil_ut": {"bins": np.linspace(0, 300, 41), "xlabel": r"recoil_ut", "ratio_ylim": (0.5, 1.5)},
    # "recoil_upar": {"bins": np.linspace(-300, 300, 61), "xlabel": r"recoil_upar", "ratio_ylim": (0.5, 1.5)},
    # "recoil_uperp": {"bins": np.linspace(-300, 300, 61), "xlabel": r"recoil_uperp", "ratio_ylim": (0.5, 1.5)},
    # "sumLeptonCharge": {"bins": np.arange(-4.5, 4.6, 1.0), "xlabel": r"sumLeptonCharge", "ratio_ylim": (0.0, 2.0)},
    # "Z0_isEE": {"bins": np.arange(-0.5, 2.5, 1.0), "xlabel": r"Z0_isEE", "ratio_ylim": (0.0, 2.0)},
    # "Z0_isMM": {"bins": np.arange(-0.5, 2.5, 1.0), "xlabel": r"Z0_isMM", "ratio_ylim": (0.0, 2.0)},
    # "X_isEE": {"bins": np.arange(-0.5, 2.5, 1.0), "xlabel": r"X_isEE", "ratio_ylim": (0.0, 2.0)},
    # "X_isMM": {"bins": np.arange(-0.5, 2.5, 1.0), "xlabel": r"X_isMM", "ratio_ylim": (0.0, 2.0)},
    # "GenMET_pt": {"bins": np.linspace(0, 200, 41), "xlabel": r"GenMET_pt", "ratio_ylim": (0.5, 1.5)},
    # "GenMET_phi": {"bins": np.linspace(-np.pi, np.pi, 51), "xlabel": r"GenMET_phi", "ratio_ylim": (0.5, 1.5)},
    # "bVeto": {"bins": np.arange(-0.5, 2.5, 1.0), "xlabel": r"bVeto", "ratio_ylim": (0.0, 2.0)},
    # "PassesZZCR4lOrderedPt": {"bins": np.arange(-0.5, 2.5, 1.0), "xlabel": r"PassesZZCR4lOrderedPt", "ratio_ylim": (0.0, 2.0)},
    # "lZ1_phi": {"bins": np.linspace(-np.pi, np.pi, 51), "xlabel": r"lZ1_phi", "ratio_ylim": (0.5, 1.5)},
    # "lZ1_pdgId": {"bins": np.arange(-15.5, 16.5, 1.0), "xlabel": r"lZ1_pdgId", "ratio_ylim": (0.0, 2.0)},
    # "lZ1_charge": {"bins": np.arange(-4.5, 4.6, 1.0), "xlabel": r"lZ1_charge", "ratio_ylim": (0.0, 2.0)},
    # "lZ1_genPdgId": {"bins": np.arange(-15.5, 16.5, 1.0), "xlabel": r"lZ1_genPdgId", "ratio_ylim": (0.0, 2.0)},
    # "lZ1_genPt": {"bins": np.linspace(0, 300, 41), "xlabel": r"lZ1_genPt", "ratio_ylim": (0.5, 1.5)},
    # "lZ1_genEta": {"bins": np.linspace(-5.0, 5.0, 51), "xlabel": r"lZ1_genEta", "ratio_ylim": (0.5, 1.5)},
    # "lZ1_genPhi": {"bins": np.linspace(-np.pi, np.pi, 51), "xlabel": r"lZ1_genPhi", "ratio_ylim": (0.5, 1.5)},
    # "lZ1_trigObj_pt": {"bins": np.linspace(0, 250, 41), "xlabel": r"lZ1_trigObj_pt", "ratio_ylim": (0.5, 1.5)},
    # "lZ1_trigObj_eta": {"bins": np.linspace(-2.5, 2.5, 41), "xlabel": r"lZ1_trigObj_eta", "ratio_ylim": (0.4, 1.8)},
    # "lZ1_trigObj_phi": {"bins": np.linspace(-np.pi, np.pi, 51), "xlabel": r"lZ1_trigObj_phi", "ratio_ylim": (0.5, 1.5)},
    # "lZ1_trigObj_pdgId": {"bins": np.arange(-15.5, 16.5, 1.0), "xlabel": r"lZ1_trigObj_pdgId", "ratio_ylim": (0.0, 2.0)},
    # "lZ1_trigObj_filterBits": {"bins": np.linspace(-0.5, 32.5, 34), "xlabel": r"lZ1_trigObj_filterBits", "ratio_ylim": (0.0, 2.0)},
    # "lZ1_trigObj_bits4l": {"bins": np.linspace(-0.5, 32.5, 34), "xlabel": r"lZ1_trigObj_bits4l", "ratio_ylim": (0.0, 2.0)},
    # "lZ1_isTightElectron_testrecipes": {"bins": np.arange(-0.5, 2.5, 1.0), "xlabel": r"lZ1_isTightElectron_testrecipes", "ratio_ylim": (0.0, 2.0)},
    # "lZ1_isTightElectron_wp90iso": {"bins": np.arange(-0.5, 2.5, 1.0), "xlabel": r"lZ1_isTightElectron_wp90iso", "ratio_ylim": (0.0, 2.0)},
    # "lZ1_isTightElectron_mvaWinter22V2Iso_WP90": {"bins": np.arange(-0.5, 2.5, 1.0), "xlabel": r"lZ1_isTightElectron_mvaWinter22V2Iso_WP90", "ratio_ylim": (0.0, 2.0)},
    # "lZ1_isTightElectron_cutBased_LooseID_tthMVA_Run3": {"bins": np.arange(-0.5, 2.5, 1.0), "xlabel": r"lZ1_isTightElectron_cutBased_LooseID_tthMVA_Run3", "ratio_ylim": (0.0, 2.0)},
    # "lZ1_isTightElectron_cutBased_LooseID_tthMVA_HWW": {"bins": np.arange(-0.5, 2.5, 1.0), "xlabel": r"lZ1_isTightElectron_cutBased_LooseID_tthMVA_HWW", "ratio_ylim": (0.0, 2.0)},
    # "lZ1_isTightMuon_cut_TightID_POG": {"bins": np.arange(-0.5, 2.5, 1.0), "xlabel": r"lZ1_isTightMuon_cut_TightID_POG", "ratio_ylim": (0.0, 2.0)},
    # "lZ1_isTightMuon_cut_Tight_HWW": {"bins": np.arange(-0.5, 2.5, 1.0), "xlabel": r"lZ1_isTightMuon_cut_Tight_HWW", "ratio_ylim": (0.0, 2.0)},
    # "lZ1_isTightMuon_cut_TightID_pfIsoTight_HWW_tthmva_67": {"bins": np.arange(-0.5, 2.5, 1.0), "xlabel": r"lZ1_isTightMuon_cut_TightID_pfIsoTight_HWW_tthmva_67", "ratio_ylim": (0.0, 2.0)},
    # "lZ1_isTightMuon_cut_TightID_pfIsoLoose_HWW_tthmva_67": {"bins": np.arange(-0.5, 2.5, 1.0), "xlabel": r"lZ1_isTightMuon_cut_TightID_pfIsoLoose_HWW_tthmva_67", "ratio_ylim": (0.0, 2.0)},
    # "lZ1_isTightMuon_cut_TightID_pfIsoLoose_HWW_tthmva_HWW": {"bins": np.arange(-0.5, 2.5, 1.0), "xlabel": r"lZ1_isTightMuon_cut_TightID_pfIsoLoose_HWW_tthmva_HWW", "ratio_ylim": (0.0, 2.0)},
    # "lZ2_phi": {"bins": np.linspace(-np.pi, np.pi, 51), "xlabel": r"lZ2_phi", "ratio_ylim": (0.5, 1.5)},
    # "lZ2_pdgId": {"bins": np.arange(-15.5, 16.5, 1.0), "xlabel": r"lZ2_pdgId", "ratio_ylim": (0.0, 2.0)},
    # "lZ2_charge": {"bins": np.arange(-4.5, 4.6, 1.0), "xlabel": r"lZ2_charge", "ratio_ylim": (0.0, 2.0)},
    # "lZ2_genPdgId": {"bins": np.arange(-15.5, 16.5, 1.0), "xlabel": r"lZ2_genPdgId", "ratio_ylim": (0.0, 2.0)},
    # "lZ2_genPt": {"bins": np.linspace(0, 300, 41), "xlabel": r"lZ2_genPt", "ratio_ylim": (0.5, 1.5)},
    # "lZ2_genEta": {"bins": np.linspace(-5.0, 5.0, 51), "xlabel": r"lZ2_genEta", "ratio_ylim": (0.5, 1.5)},
    # "lZ2_genPhi": {"bins": np.linspace(-np.pi, np.pi, 51), "xlabel": r"lZ2_genPhi", "ratio_ylim": (0.5, 1.5)},
    # "lZ2_trigObj_pt": {"bins": np.linspace(0, 250, 41), "xlabel": r"lZ2_trigObj_pt", "ratio_ylim": (0.5, 1.5)},
    # "lZ2_trigObj_eta": {"bins": np.linspace(-2.5, 2.5, 41), "xlabel": r"lZ2_trigObj_eta", "ratio_ylim": (0.4, 1.8)},
    # "lZ2_trigObj_phi": {"bins": np.linspace(-np.pi, np.pi, 51), "xlabel": r"lZ2_trigObj_phi", "ratio_ylim": (0.5, 1.5)},
    # "lZ2_trigObj_pdgId": {"bins": np.arange(-15.5, 16.5, 1.0), "xlabel": r"lZ2_trigObj_pdgId", "ratio_ylim": (0.0, 2.0)},
    # "lZ2_trigObj_filterBits": {"bins": np.linspace(-0.5, 32.5, 34), "xlabel": r"lZ2_trigObj_filterBits", "ratio_ylim": (0.0, 2.0)},
    # "lZ2_trigObj_bits4l": {"bins": np.linspace(-0.5, 32.5, 34), "xlabel": r"lZ2_trigObj_bits4l", "ratio_ylim": (0.0, 2.0)},
    # "lZ2_isTightElectron_testrecipes": {"bins": np.arange(-0.5, 2.5, 1.0), "xlabel": r"lZ2_isTightElectron_testrecipes", "ratio_ylim": (0.0, 2.0)},
    # "lZ2_isTightElectron_wp90iso": {"bins": np.arange(-0.5, 2.5, 1.0), "xlabel": r"lZ2_isTightElectron_wp90iso", "ratio_ylim": (0.0, 2.0)},
    # "lZ2_isTightElectron_mvaWinter22V2Iso_WP90": {"bins": np.arange(-0.5, 2.5, 1.0), "xlabel": r"lZ2_isTightElectron_mvaWinter22V2Iso_WP90", "ratio_ylim": (0.0, 2.0)},
    # "lZ2_isTightElectron_cutBased_LooseID_tthMVA_Run3": {"bins": np.arange(-0.5, 2.5, 1.0), "xlabel": r"lZ2_isTightElectron_cutBased_LooseID_tthMVA_Run3", "ratio_ylim": (0.0, 2.0)},
    # "lZ2_isTightElectron_cutBased_LooseID_tthMVA_HWW": {"bins": np.arange(-0.5, 2.5, 1.0), "xlabel": r"lZ2_isTightElectron_cutBased_LooseID_tthMVA_HWW", "ratio_ylim": (0.0, 2.0)},
    # "lZ2_isTightMuon_cut_TightID_POG": {"bins": np.arange(-0.5, 2.5, 1.0), "xlabel": r"lZ2_isTightMuon_cut_TightID_POG", "ratio_ylim": (0.0, 2.0)},
    # "lZ2_isTightMuon_cut_Tight_HWW": {"bins": np.arange(-0.5, 2.5, 1.0), "xlabel": r"lZ2_isTightMuon_cut_Tight_HWW", "ratio_ylim": (0.0, 2.0)},
    # "lZ2_isTightMuon_cut_TightID_pfIsoTight_HWW_tthmva_67": {"bins": np.arange(-0.5, 2.5, 1.0), "xlabel": r"lZ2_isTightMuon_cut_TightID_pfIsoTight_HWW_tthmva_67", "ratio_ylim": (0.0, 2.0)},
    # "lZ2_isTightMuon_cut_TightID_pfIsoLoose_HWW_tthmva_67": {"bins": np.arange(-0.5, 2.5, 1.0), "xlabel": r"lZ2_isTightMuon_cut_TightID_pfIsoLoose_HWW_tthmva_67", "ratio_ylim": (0.0, 2.0)},
    # "lZ2_isTightMuon_cut_TightID_pfIsoLoose_HWW_tthmva_HWW": {"bins": np.arange(-0.5, 2.5, 1.0), "xlabel": r"lZ2_isTightMuon_cut_TightID_pfIsoLoose_HWW_tthmva_HWW", "ratio_ylim": (0.0, 2.0)},
    # "lX1_phi": {"bins": np.linspace(-np.pi, np.pi, 51), "xlabel": r"lX1_phi", "ratio_ylim": (0.5, 1.5)},
    # "lX1_pdgId": {"bins": np.arange(-15.5, 16.5, 1.0), "xlabel": r"lX1_pdgId", "ratio_ylim": (0.0, 2.0)},
    # "lX1_charge": {"bins": np.arange(-4.5, 4.6, 1.0), "xlabel": r"lX1_charge", "ratio_ylim": (0.0, 2.0)},
    # "lX1_genPdgId": {"bins": np.arange(-15.5, 16.5, 1.0), "xlabel": r"lX1_genPdgId", "ratio_ylim": (0.0, 2.0)},
    # "lX1_genPt": {"bins": np.linspace(0, 300, 41), "xlabel": r"lX1_genPt", "ratio_ylim": (0.5, 1.5)},
    # "lX1_genEta": {"bins": np.linspace(-5.0, 5.0, 51), "xlabel": r"lX1_genEta", "ratio_ylim": (0.5, 1.5)},
    # "lX1_genPhi": {"bins": np.linspace(-np.pi, np.pi, 51), "xlabel": r"lX1_genPhi", "ratio_ylim": (0.5, 1.5)},
    # "lX1_trigObj_pt": {"bins": np.linspace(0, 250, 41), "xlabel": r"lX1_trigObj_pt", "ratio_ylim": (0.5, 1.5)},
    # "lX1_trigObj_eta": {"bins": np.linspace(-2.5, 2.5, 41), "xlabel": r"lX1_trigObj_eta", "ratio_ylim": (0.4, 1.8)},
    # "lX1_trigObj_phi": {"bins": np.linspace(-np.pi, np.pi, 51), "xlabel": r"lX1_trigObj_phi", "ratio_ylim": (0.5, 1.5)},
    # "lX1_trigObj_pdgId": {"bins": np.arange(-15.5, 16.5, 1.0), "xlabel": r"lX1_trigObj_pdgId", "ratio_ylim": (0.0, 2.0)},
    # "lX1_trigObj_filterBits": {"bins": np.linspace(-0.5, 32.5, 34), "xlabel": r"lX1_trigObj_filterBits", "ratio_ylim": (0.0, 2.0)},
    # "lX1_trigObj_bits4l": {"bins": np.linspace(-0.5, 32.5, 34), "xlabel": r"lX1_trigObj_bits4l", "ratio_ylim": (0.0, 2.0)},
    # "lX1_isTightElectron_testrecipes": {"bins": np.arange(-0.5, 2.5, 1.0), "xlabel": r"lX1_isTightElectron_testrecipes", "ratio_ylim": (0.0, 2.0)},
    # "lX1_isTightElectron_wp90iso": {"bins": np.arange(-0.5, 2.5, 1.0), "xlabel": r"lX1_isTightElectron_wp90iso", "ratio_ylim": (0.0, 2.0)},
    # "lX1_isTightElectron_mvaWinter22V2Iso_WP90": {"bins": np.arange(-0.5, 2.5, 1.0), "xlabel": r"lX1_isTightElectron_mvaWinter22V2Iso_WP90", "ratio_ylim": (0.0, 2.0)},
    # "lX1_isTightElectron_cutBased_LooseID_tthMVA_Run3": {"bins": np.arange(-0.5, 2.5, 1.0), "xlabel": r"lX1_isTightElectron_cutBased_LooseID_tthMVA_Run3", "ratio_ylim": (0.0, 2.0)},
    # "lX1_isTightElectron_cutBased_LooseID_tthMVA_HWW": {"bins": np.arange(-0.5, 2.5, 1.0), "xlabel": r"lX1_isTightElectron_cutBased_LooseID_tthMVA_HWW", "ratio_ylim": (0.0, 2.0)},
    # "lX1_isTightMuon_cut_TightID_POG": {"bins": np.arange(-0.5, 2.5, 1.0), "xlabel": r"lX1_isTightMuon_cut_TightID_POG", "ratio_ylim": (0.0, 2.0)},
    # "lX1_isTightMuon_cut_Tight_HWW": {"bins": np.arange(-0.5, 2.5, 1.0), "xlabel": r"lX1_isTightMuon_cut_Tight_HWW", "ratio_ylim": (0.0, 2.0)},
    # "lX1_isTightMuon_cut_TightID_pfIsoTight_HWW_tthmva_67": {"bins": np.arange(-0.5, 2.5, 1.0), "xlabel": r"lX1_isTightMuon_cut_TightID_pfIsoTight_HWW_tthmva_67", "ratio_ylim": (0.0, 2.0)},
    # "lX1_isTightMuon_cut_TightID_pfIsoLoose_HWW_tthmva_67": {"bins": np.arange(-0.5, 2.5, 1.0), "xlabel": r"lX1_isTightMuon_cut_TightID_pfIsoLoose_HWW_tthmva_67", "ratio_ylim": (0.0, 2.0)},
    # "lX1_isTightMuon_cut_TightID_pfIsoLoose_HWW_tthmva_HWW": {"bins": np.arange(-0.5, 2.5, 1.0), "xlabel": r"lX1_isTightMuon_cut_TightID_pfIsoLoose_HWW_tthmva_HWW", "ratio_ylim": (0.0, 2.0)},
    # "lX2_phi": {"bins": np.linspace(-np.pi, np.pi, 51), "xlabel": r"lX2_phi", "ratio_ylim": (0.5, 1.5)},
    # "lX2_pdgId": {"bins": np.arange(-15.5, 16.5, 1.0), "xlabel": r"lX2_pdgId", "ratio_ylim": (0.0, 2.0)},
    # "lX2_charge": {"bins": np.arange(-4.5, 4.6, 1.0), "xlabel": r"lX2_charge", "ratio_ylim": (0.0, 2.0)},
    # "lX2_genPdgId": {"bins": np.arange(-15.5, 16.5, 1.0), "xlabel": r"lX2_genPdgId", "ratio_ylim": (0.0, 2.0)},
    # "lX2_genPt": {"bins": np.linspace(0, 300, 41), "xlabel": r"lX2_genPt", "ratio_ylim": (0.5, 1.5)},
    # "lX2_genEta": {"bins": np.linspace(-5.0, 5.0, 51), "xlabel": r"lX2_genEta", "ratio_ylim": (0.5, 1.5)},
    # "lX2_genPhi": {"bins": np.linspace(-np.pi, np.pi, 51), "xlabel": r"lX2_genPhi", "ratio_ylim": (0.5, 1.5)},
    # "lX2_trigObj_pt": {"bins": np.linspace(0, 250, 41), "xlabel": r"lX2_trigObj_pt", "ratio_ylim": (0.5, 1.5)},
    # "lX2_trigObj_eta": {"bins": np.linspace(-2.5, 2.5, 41), "xlabel": r"lX2_trigObj_eta", "ratio_ylim": (0.4, 1.8)},
    # "lX2_trigObj_phi": {"bins": np.linspace(-np.pi, np.pi, 51), "xlabel": r"lX2_trigObj_phi", "ratio_ylim": (0.5, 1.5)},
    # "lX2_trigObj_pdgId": {"bins": np.arange(-15.5, 16.5, 1.0), "xlabel": r"lX2_trigObj_pdgId", "ratio_ylim": (0.0, 2.0)},
    # "lX2_trigObj_filterBits": {"bins": np.linspace(-0.5, 32.5, 34), "xlabel": r"lX2_trigObj_filterBits", "ratio_ylim": (0.0, 2.0)},
    # "lX2_trigObj_bits4l": {"bins": np.linspace(-0.5, 32.5, 34), "xlabel": r"lX2_trigObj_bits4l", "ratio_ylim": (0.0, 2.0)},
    # "lX2_isTightElectron_testrecipes": {"bins": np.arange(-0.5, 2.5, 1.0), "xlabel": r"lX2_isTightElectron_testrecipes", "ratio_ylim": (0.0, 2.0)},
    # "lX2_isTightElectron_wp90iso": {"bins": np.arange(-0.5, 2.5, 1.0), "xlabel": r"lX2_isTightElectron_wp90iso", "ratio_ylim": (0.0, 2.0)},
    # "lX2_isTightElectron_mvaWinter22V2Iso_WP90": {"bins": np.arange(-0.5, 2.5, 1.0), "xlabel": r"lX2_isTightElectron_mvaWinter22V2Iso_WP90", "ratio_ylim": (0.0, 2.0)},
    # "lX2_isTightElectron_cutBased_LooseID_tthMVA_Run3": {"bins": np.arange(-0.5, 2.5, 1.0), "xlabel": r"lX2_isTightElectron_cutBased_LooseID_tthMVA_Run3", "ratio_ylim": (0.0, 2.0)},
    # "lX2_isTightElectron_cutBased_LooseID_tthMVA_HWW": {"bins": np.arange(-0.5, 2.5, 1.0), "xlabel": r"lX2_isTightElectron_cutBased_LooseID_tthMVA_HWW", "ratio_ylim": (0.0, 2.0)},
    # "lX2_isTightMuon_cut_TightID_POG": {"bins": np.arange(-0.5, 2.5, 1.0), "xlabel": r"lX2_isTightMuon_cut_TightID_POG", "ratio_ylim": (0.0, 2.0)},
    # "lX2_isTightMuon_cut_Tight_HWW": {"bins": np.arange(-0.5, 2.5, 1.0), "xlabel": r"lX2_isTightMuon_cut_Tight_HWW", "ratio_ylim": (0.0, 2.0)},
    # "lX2_isTightMuon_cut_TightID_pfIsoTight_HWW_tthmva_67": {"bins": np.arange(-0.5, 2.5, 1.0), "xlabel": r"lX2_isTightMuon_cut_TightID_pfIsoTight_HWW_tthmva_67", "ratio_ylim": (0.0, 2.0)},
    # "lX2_isTightMuon_cut_TightID_pfIsoLoose_HWW_tthmva_67": {"bins": np.arange(-0.5, 2.5, 1.0), "xlabel": r"lX2_isTightMuon_cut_TightID_pfIsoLoose_HWW_tthmva_67", "ratio_ylim": (0.0, 2.0)},
    # "lX2_isTightMuon_cut_TightID_pfIsoLoose_HWW_tthmva_HWW": {"bins": np.arange(-0.5, 2.5, 1.0), "xlabel": r"lX2_isTightMuon_cut_TightID_pfIsoLoose_HWW_tthmva_HWW", "ratio_ylim": (0.0, 2.0)},
    # "nTightElectron_testrecipes": {"bins": np.arange(-0.5, 6.5, 1.0), "xlabel": r"nTightElectron_testrecipes", "ratio_ylim": (0.0, 2.0)},
    # "nTightElectron_wp90iso": {"bins": np.arange(-0.5, 6.5, 1.0), "xlabel": r"nTightElectron_wp90iso", "ratio_ylim": (0.0, 2.0)},
    # "nTightElectron_mvaWinter22V2Iso_WP90": {"bins": np.arange(-0.5, 6.5, 1.0), "xlabel": r"nTightElectron_mvaWinter22V2Iso_WP90", "ratio_ylim": (0.0, 2.0)},
    # "nTightElectron_cutBased_LooseID_tthMVA_Run3": {"bins": np.arange(-0.5, 6.5, 1.0), "xlabel": r"nTightElectron_cutBased_LooseID_tthMVA_Run3", "ratio_ylim": (0.0, 2.0)},
    # "nTightElectron_cutBased_LooseID_tthMVA_HWW": {"bins": np.arange(-0.5, 6.5, 1.0), "xlabel": r"nTightElectron_cutBased_LooseID_tthMVA_HWW", "ratio_ylim": (0.0, 2.0)},
    # "nTightMuon_cut_TightID_POG": {"bins": np.arange(-0.5, 6.5, 1.0), "xlabel": r"nTightMuon_cut_TightID_POG", "ratio_ylim": (0.0, 2.0)},
    # "nTightMuon_cut_Tight_HWW": {"bins": np.arange(-0.5, 6.5, 1.0), "xlabel": r"nTightMuon_cut_Tight_HWW", "ratio_ylim": (0.0, 2.0)},
    # "nTightMuon_cut_TightID_pfIsoTight_HWW_tthmva_67": {"bins": np.arange(-0.5, 6.5, 1.0), "xlabel": r"nTightMuon_cut_TightID_pfIsoTight_HWW_tthmva_67", "ratio_ylim": (0.0, 2.0)},
    # "nTightMuon_cut_TightID_pfIsoLoose_HWW_tthmva_67": {"bins": np.arange(-0.5, 6.5, 1.0), "xlabel": r"nTightMuon_cut_TightID_pfIsoLoose_HWW_tthmva_67", "ratio_ylim": (0.0, 2.0)},
    # "nTightMuon_cut_TightID_pfIsoLoose_HWW_tthmva_HWW": {"bins": np.arange(-0.5, 6.5, 1.0), "xlabel": r"nTightMuon_cut_TightID_pfIsoLoose_HWW_tthmva_HWW", "ratio_ylim": (0.0, 2.0)},
    # "lZ1_selWP_TotSF": {"bins": np.linspace(0.7, 1.3, 31), "xlabel": r"lZ1_selWP_TotSF", "ratio_ylim": (0.7, 1.3)},
    # "lZ2_selWP_TotSF": {"bins": np.linspace(0.7, 1.3, 31), "xlabel": r"lZ2_selWP_TotSF", "ratio_ylim": (0.7, 1.3)},
    # "lX1_selWP_TotSF": {"bins": np.linspace(0.7, 1.3, 31), "xlabel": r"lX1_selWP_TotSF", "ratio_ylim": (0.7, 1.3)},
    # "lX2_selWP_TotSF": {"bins": np.linspace(0.7, 1.3, 31), "xlabel": r"lX2_selWP_TotSF", "ratio_ylim": (0.7, 1.3)},
    # "CleanJet_pt_0": {"bins": np.linspace(0, 300, 41), "xlabel": r"CleanJet_pt_0", "ratio_ylim": (0.5, 1.5)},
    # "CleanJet_eta_0": {"bins": np.linspace(-5.0, 5.0, 51), "xlabel": r"CleanJet_eta_0", "ratio_ylim": (0.5, 1.5)},
    # "CleanJet_phi_0": {"bins": np.linspace(-np.pi, np.pi, 51), "xlabel": r"CleanJet_phi_0", "ratio_ylim": (0.5, 1.5)},
    # "CleanJet_genPt_0": {"bins": np.linspace(0, 300, 41), "xlabel": r"CleanJet_genPt_0", "ratio_ylim": (0.5, 1.5)},
    # "CleanJet_genEta_0": {"bins": np.linspace(-5.0, 5.0, 51), "xlabel": r"CleanJet_genEta_0", "ratio_ylim": (0.5, 1.5)},
    # "CleanJet_genPhi_0": {"bins": np.linspace(-np.pi, np.pi, 51), "xlabel": r"CleanJet_genPhi_0", "ratio_ylim": (0.5, 1.5)},
    # "CleanJet_pt_1": {"bins": np.linspace(0, 300, 41), "xlabel": r"CleanJet_pt_1", "ratio_ylim": (0.5, 1.5)},
    # "CleanJet_eta_1": {"bins": np.linspace(-5.0, 5.0, 51), "xlabel": r"CleanJet_eta_1", "ratio_ylim": (0.5, 1.5)},
    # "CleanJet_phi_1": {"bins": np.linspace(-np.pi, np.pi, 51), "xlabel": r"CleanJet_phi_1", "ratio_ylim": (0.5, 1.5)},
    # "CleanJet_genPt_1": {"bins": np.linspace(0, 300, 41), "xlabel": r"CleanJet_genPt_1", "ratio_ylim": (0.5, 1.5)},
    # "CleanJet_genEta_1": {"bins": np.linspace(-5.0, 5.0, 51), "xlabel": r"CleanJet_genEta_1", "ratio_ylim": (0.5, 1.5)},
    # "CleanJet_genPhi_1": {"bins": np.linspace(-np.pi, np.pi, 51), "xlabel": r"CleanJet_genPhi_1", "ratio_ylim": (0.5, 1.5)},
}

SAMPLE_STYLE = {
    "defaults": {"title": None, "color": None},
    "groups": {
        "DY_EE": {"title": r"$Z\to ee$", "color": "#4e79a7"},
        "DY_MM": {"title": r"$Z\to \mu\mu$", "color": "#f28e2b"},
        "DY_TT": {"title": r"$Z\to \tau\tau$", "color": "#76b7b2"},
    },
    "samples": {
        "DATA": {"title": "Data", "color": "black"},
        "DYto2E-2Jets_MLL-10to50": {"title": "", "group": "DY_EE"},
        "DYto2E-2Jets_MLL-50": {"title": "", "group": "DY_EE"},
        "DYto2Mu-2Jets_MLL-10to50": {"title": "", "group": "DY_MM"},
        "DYto2Mu-2Jets_MLL-50": {"title": "", "group": "DY_MM"},
        "DYto2Tau-2Jets_MLL-10to50": {"title": "", "group": "DY_TT"},
        "DYto2Tau-2Jets_MLL-50": {"title": "", "group": "DY_TT"},
        "ZZ": {"title": r"$ZZ$", "color": "#e15759"},
    },
}

_CATEGORY_STEP_CUTS = {
    "DY": "bVeto && (Z0_mass > 30.) && (nJetInHorn == 0)",
    "Z0WIN": "abs(Z0_mass - 91.1876) < 15.",
    "XZWIN": "abs(X_mass - 91.1876) < 15.",
    "MET35": "PuppiMET_pt < 35.",
}

# ZZ_CR trigger-path and TrigObj bit helpers (commented templates)
# Source alignment:
# - Trigger_sngEl  <- HLT_Ele30_WPTight_Gsf
# - Trigger_dblEl  <- HLT_Ele23_Ele12_CaloIdL_TrackIdL_IsoVL
# - Trigger_sngMu  <- HLT_IsoMu24
# - Trigger_dblMu  <- HLT_Mu17_TrkIsoVVL_Mu8_TrkIsoVVL_DZ_Mass3p8
# - Trigger_ElMu   <- HLT_Mu23_TrkIsoVVL_Ele12... || HLT_Mu12_TrkIsoVVL_Ele23... || HLT_Mu8_TrkIsoVVL_Ele23...
#
# bits4l packing used in ZZ_CR aliases (per-lepton):
#   Electron (abs(pdgId)==11):
#     bit 0 -> eμ path leg (from TrigObj_filterBits bit 6)
#     bit 1 -> ee leg1      (from TrigObj_filterBits bit 4)
#     bit 2 -> ee leg2      (from TrigObj_filterBits bit 5)
#     bit 3 -> single-e Ele30 (from TrigObj_filterBits bit 18)
#   Muon (abs(pdgId)==13):
#     bit 0 -> single-μ generic (from TrigObj_filterBits bit 3)
#     bit 1 -> single-μ iso     (from TrigObj_filterBits bit 1)
#     bit 2 -> μμ path leg      (from TrigObj_filterBits bit 4)
#     bit 3 -> μe path leg      (from TrigObj_filterBits bit 5)
#
# Reusable expression templates (copy/paste into category cut strings):
# def _bits4l_has(lep, bit):
#     return f"(({lep}_trigObj_bits4l & (1 << {bit})) != 0)"
#
# def _raw_filter_has(lep, bit):
#     return f"(({lep}_trigObj_filterBits & (1 << {bit})) != 0)"
#
# _TRIGGER_CUT_TEMPLATES = {
#     # Path-only gates
#     # Specific HLT path branches (when HLT_* branches are present in this tree)
#     "hlt_emu_mu23_ele12": "HLT_Mu23_TrkIsoVVL_Ele12_CaloIdL_TrackIdL_IsoVL",
#     "hlt_emu_mu12_ele23_dz": "HLT_Mu12_TrkIsoVVL_Ele23_CaloIdL_TrackIdL_IsoVL_DZ",
#     "hlt_emu_mu8_ele23_dz": "HLT_Mu8_TrkIsoVVL_Ele23_CaloIdL_TrackIdL_IsoVL_DZ",
#     "hlt_dimu_mu17_mu8_dz_mass3p8": "HLT_Mu17_TrkIsoVVL_Mu8_TrkIsoVVL_DZ_Mass3p8",
#     "hlt_singlemu_isomu24": "HLT_IsoMu24",
#     "hlt_die_ele23_ele12": "HLT_Ele23_Ele12_CaloIdL_TrackIdL_IsoVL",
#     "hlt_singlee_ele30": "HLT_Ele30_WPTight_Gsf",
#
#     "path_emu": "Trigger_ElMu",
#     "path_dimu": "Trigger_dblMu",
#     "path_sngmu": "Trigger_sngMu",
#     "path_die": "Trigger_dblEl",
#     "path_snge": "Trigger_sngEl",
#
#     # Per-lepton matched legs (packed bits4l)
#     "ee_doubleele_legs": f"Z0_isEE && Trigger_dblEl && {_bits4l_has('lZ1', 1)} && {_bits4l_has('lZ2', 2)}",
#     "ee_singleele_ele30": f"Z0_isEE && Trigger_sngEl && ({_bits4l_has('lZ1', 3)} || {_bits4l_has('lZ2', 3)})",
#     "mumu_doublemu_legs": f"Z0_isMM && Trigger_dblMu && {_bits4l_has('lZ1', 2)} && {_bits4l_has('lZ2', 2)}",
#     "mumu_singlemu_iso": f"Z0_isMM && Trigger_sngMu && ({_bits4l_has('lZ1', 1)} || {_bits4l_has('lZ2', 1)})",
#     "mumu_singlemu_generic": f"Z0_isMM && Trigger_sngMu && ({_bits4l_has('lZ1', 0)} || {_bits4l_has('lZ2', 0)})",
#     "emu_path_matched": f"Trigger_ElMu && (((abs(lZ1_pdgId)==11) && {_bits4l_has('lZ1', 0)}) || ((abs(lZ2_pdgId)==11) && {_bits4l_has('lZ2', 0)}) || ((abs(lX1_pdgId)==11) && {_bits4l_has('lX1', 0)}) || ((abs(lX2_pdgId)==11) && {_bits4l_has('lX2', 0)})) && (((abs(lZ1_pdgId)==13) && {_bits4l_has('lZ1', 3)}) || ((abs(lZ2_pdgId)==13) && {_bits4l_has('lZ2', 3)}) || ((abs(lX1_pdgId)==13) && {_bits4l_has('lX1', 3)}) || ((abs(lX2_pdgId)==13) && {_bits4l_has('lX2', 3)}))",
#
#     # Same ideas using raw NanoAOD filter bits (for debugging against bits4l)
#     # Per-path + per-leg matching templates (specific path branch + specific leg bits)
#     "path_die_with_leg_assignment": f"HLT_Ele23_Ele12_CaloIdL_TrackIdL_IsoVL && (((abs(lZ1_pdgId)==11) && {_raw_filter_has('lZ1', 4)} && (abs(lZ2_pdgId)==11) && {_raw_filter_has('lZ2', 5)}) || ((abs(lZ1_pdgId)==11) && {_raw_filter_has('lZ1', 5)} && (abs(lZ2_pdgId)==11) && {_raw_filter_has('lZ2', 4)}))",
#     "path_dimu_with_matched_legs": f"HLT_Mu17_TrkIsoVVL_Mu8_TrkIsoVVL_DZ_Mass3p8 && ((abs(lZ1_pdgId)==13) && {_raw_filter_has('lZ1', 4)}) && ((abs(lZ2_pdgId)==13) && {_raw_filter_has('lZ2', 4)})",
#     "path_singlee_with_ele30_leg": f"HLT_Ele30_WPTight_Gsf && (((abs(lZ1_pdgId)==11) && {_raw_filter_has('lZ1', 18)}) || ((abs(lZ2_pdgId)==11) && {_raw_filter_has('lZ2', 18)}))",
#     "path_singlemu_with_iso_leg": f"HLT_IsoMu24 && (((abs(lZ1_pdgId)==13) && {_raw_filter_has('lZ1', 1)}) || ((abs(lZ2_pdgId)==13) && {_raw_filter_has('lZ2', 1)}))",
#     "path_emu_mu23_ele12_with_legs": f"HLT_Mu23_TrkIsoVVL_Ele12_CaloIdL_TrackIdL_IsoVL && ((((abs(lZ1_pdgId)==11) && {_raw_filter_has('lZ1', 6)}) || ((abs(lZ2_pdgId)==11) && {_raw_filter_has('lZ2', 6)}) || ((abs(lX1_pdgId)==11) && {_raw_filter_has('lX1', 6)}) || ((abs(lX2_pdgId)==11) && {_raw_filter_has('lX2', 6)})) && (((abs(lZ1_pdgId)==13) && {_raw_filter_has('lZ1', 5)}) || ((abs(lZ2_pdgId)==13) && {_raw_filter_has('lZ2', 5)}) || ((abs(lX1_pdgId)==13) && {_raw_filter_has('lX1', 5)}) || ((abs(lX2_pdgId)==13) && {_raw_filter_has('lX2', 5)})))",
#
#     "raw_die_leg1_leg2": f"Trigger_dblEl && {_raw_filter_has('lZ1', 4)} && {_raw_filter_has('lZ2', 5)}",
#     "raw_snge_ele30": f"Trigger_sngEl && ({_raw_filter_has('lZ1', 18)} || {_raw_filter_has('lZ2', 18)})",
#     "raw_dimu_leg": f"Trigger_dblMu && {_raw_filter_has('lZ1', 4)} && {_raw_filter_has('lZ2', 4)}",
#     "raw_sngmu_iso": f"Trigger_sngMu && ({_raw_filter_has('lZ1', 1)} || {_raw_filter_has('lZ2', 1)})",
#     "raw_emu": f"Trigger_ElMu && ({_raw_filter_has('lZ1', 6)} || {_raw_filter_has('lZ2', 6)} || {_raw_filter_has('lX1', 6)} || {_raw_filter_has('lX2', 6)}) && ({_raw_filter_has('lZ1', 5)} || {_raw_filter_has('lZ2', 5)} || {_raw_filter_has('lX1', 5)} || {_raw_filter_has('lX2', 5)})",
# }

CATEGORY_CONFIG = {
    "zz_cr_ALL": {
       "title": r"$ZZ\,\mathrm{CR}$",
       "subtitle": "",
       "subcategories": {
            "zz_cr_ZEE": {
                "title": r"$ZZ\,\mathrm{CR}:\ Z\to ee$",
                "subtitle": "",
                "cut": f"Z0_isEE && ({_CATEGORY_STEP_CUTS['DY']})",
            },
            "zz_cr_ZEE_z0win": {
                "title": r"$ZZ\,\mathrm{CR}:\ ee + Z_0\,\mathrm{win}$",
                "subtitle": "",
                "cut": f"Z0_isEE && ({_CATEGORY_STEP_CUTS['DY']}) && ({_CATEGORY_STEP_CUTS['Z0WIN']})",
            },
            "zz_cr_ZEE_xwin": {
                "title": r"$ZZ\,\mathrm{CR}:\ ee + Z_0\,\mathrm{win} + X\,\mathrm{win}$",
                "subtitle": "",
                "cut": f"Z0_isEE && ({_CATEGORY_STEP_CUTS['DY']}) && ({_CATEGORY_STEP_CUTS['Z0WIN']}) && ({_CATEGORY_STEP_CUTS['XZWIN']})",
            },
            "zz_cr_ZEE_nom": {
                "title": r"$ZZ\,\mathrm{CR}:\ ee\,\mathrm{nominal}$",
                "subtitle": "",
                "cut": f"Z0_isEE && ({_CATEGORY_STEP_CUTS['DY']}) && ({_CATEGORY_STEP_CUTS['Z0WIN']}) && ({_CATEGORY_STEP_CUTS['XZWIN']}) && ({_CATEGORY_STEP_CUTS['MET35']})",
            },
            "zz_cr_ZMM": {
                "title": r"$ZZ\,\mathrm{CR}:\ Z\to \mu\mu$",
                "subtitle": "",
                "cut": f"Z0_isMM && ({_CATEGORY_STEP_CUTS['DY']})",
            },
            "zz_cr_ZMM_z0win": {
                "title": r"$ZZ\,\mathrm{CR}:\ \mu\mu + Z_0\,\mathrm{win}$",
                "subtitle": "",
                "cut": f"Z0_isMM && ({_CATEGORY_STEP_CUTS['DY']}) && ({_CATEGORY_STEP_CUTS['Z0WIN']})",
            },
            "zz_cr_ZMM_xwin": {
                "title": r"$ZZ\,\mathrm{CR}:\ \mu\mu + Z_0\,\mathrm{win} + X\,\mathrm{win}$",
                "subtitle": "",
                "cut": f"Z0_isMM && ({_CATEGORY_STEP_CUTS['DY']}) && ({_CATEGORY_STEP_CUTS['Z0WIN']}) && ({_CATEGORY_STEP_CUTS['XZWIN']})",
            },
            "zz_cr_ZMM_nom": {
                "title": r"$ZZ\,\mathrm{CR}:\ \mu\mu\,\mathrm{nominal}$",
                "subtitle": "",
                "cut": f"Z0_isMM && ({_CATEGORY_STEP_CUTS['DY']}) && ({_CATEGORY_STEP_CUTS['Z0WIN']}) && ({_CATEGORY_STEP_CUTS['XZWIN']}) && ({_CATEGORY_STEP_CUTS['MET35']})",
            },
        },
    }
}

# %%
# =========================
# CORE ENGINE
# =========================

_LOG_STATE = {"last": None}

def _cut_preview(cut_expr):
    txt = _normalize_cut(cut_expr)
    if not txt:
        return "<none>"
    txt = re.sub(r"\s+", " ", txt).strip()
    mx = int(_cfg("logging", "max_cut_preview", default=120))
    if len(txt) > mx:
        return txt[:mx - 3] + "..."
    return txt


def _log(msg, level="info"):
    if not _cfg("logging", "enabled", default=True):
        return
    lvl = str(level).upper()
    hacker = bool(_cfg("logging", "hacker_style", default=True))
    prefix = f"[{lvl}]" if not hacker else f"[{lvl:>5}]"

    ts = ""
    if bool(_cfg("logging", "show_timestamp", default=True)):
        fmt = _cfg("logging", "timestamp_fmt", default="%Y-%m-%d %H:%M:%S")
        use_utc = bool(_cfg("logging", "timestamp_utc", default=True))
        now = datetime.now(timezone.utc) if use_utc else datetime.now()
        ts = now.strftime(fmt)
        ts = f"[{ts}] "

    line = f"{ts}{prefix} {msg}"

    if bool(_cfg("logging", "dedupe_repeated", default=True)):
        key = (lvl, str(msg))
        if _LOG_STATE.get("last") == key:
            return
        _LOG_STATE["last"] = key

    print(line, flush=True)


def _progress(stage, i, n, extra=""):
    if not _cfg("logging", "progress_enabled", default=True):
        return
    every = max(1, int(_cfg("logging", "progress_every", default=25)))
    if i not in {1, n} and i % every != 0:
        return
    frac = (100.0 * i / n) if n else 0.0
    _log(f"{stage}: {i}/{n} ({frac:.1f}%) {extra}", level="progress")


def _sanitize(name):
    safe = ''.join(c if c.isalnum() or c in ('-', '_') else '_' for c in str(name))
    while '__' in safe:
        safe = safe.replace('__', '_')
    return safe.strip('_') or 'plot'


def _cfg(*path, default=None):
    node = ANALYSIS_CONFIG
    for p in path:
        if not isinstance(node, dict) or p not in node:
            return default
        node = node[p]
    return node


def _detect_input_mode(path, mode="auto"):
    mode = str(mode).lower().strip()
    if mode in {"merged", "unmerged"}:
        return mode
    if os.path.isdir(path) or any(ch in str(path) for ch in "*?[]"):
        return "unmerged"
    return "merged"


def _discover_input_files(path, mode="auto", unmerged_glob="*.root"):
    resolved = _detect_input_mode(path, mode)
    if resolved == "merged":
        if not os.path.isfile(path):
            raise FileNotFoundError(f"Missing merged ROOT file: {path}")
        return resolved, [path]

    if os.path.isdir(path):
        files = sorted(glob.glob(os.path.join(path, unmerged_glob)))
    else:
        files = sorted(glob.glob(path))
    files = [x for x in files if x.endswith(".root") and os.path.isfile(x)]
    if not files:
        raise FileNotFoundError(f"No ROOT files found for unmerged input: {path}")
    return resolved, files


def _unique_paths(paths):
    """Return unique filesystem paths preserving order, deduping by realpath."""
    out = []
    seen = set()
    for p in paths or []:
        rp = os.path.realpath(p)
        if rp in seen:
            continue
        seen.add(rp)
        out.append(p)
    return out


def _extract_category_process_from_filename(root_file):
    base = os.path.basename(root_file)
    stem = re.sub(r"\.root$", "", base)
    parts = stem.split("__")
    category = parts[-2] if len(parts) >= 2 else "*"
    payload = parts[-1] if parts else stem
    process = re.sub(ANALYSIS_CONFIG["filters"].get("filename_process_strip_pattern", r"_\d+$"), "", payload)
    return (category or "*"), process


def _build_unmerged_index(root_files):
    index = {}
    for i, rf in enumerate(root_files, 1):
        category, proc = _extract_category_process_from_filename(rf)
        index.setdefault(category, {}).setdefault(proc, []).append(rf)
        index.setdefault("*", {}).setdefault(proc, []).append(rf)
        _progress("index", i, len(root_files), os.path.basename(rf))
    for cat in list(index):
        for proc in list(index[cat]):
            index[cat][proc] = sorted(set(index[cat][proc]))
    return index

def _normalize_cut(cut_expr):
    expr = str(cut_expr or "").strip()
    if not expr:
        return ""
    expr = re.sub(r"(?<![&])&(?![&])", "&&", expr)
    expr = re.sub(r"(?<![|])\|(?![|])", "||", expr)
    return expr

def _cut_to_pandas(cut_expr):
    expr = _normalize_cut(cut_expr)
    if not expr:
        return ""
    expr = expr.replace("&&", " and ").replace("||", " or ")
    expr = re.sub(r"(?<![=!<>])!(?!=)", " not ", expr)
    return expr



def _validate_cut_expression(cut_expr):
    expr = _normalize_cut(cut_expr)
    if not expr:
        return expr
    if not bool(_cfg("runtime", "strict_cut_syntax", default=False)):
        return expr
    pat = _cfg("runtime", "strict_cut_allowed_pattern", default=r"^[A-Za-z0-9_\s\(\)\.><=+\-*/!&|,:]*$")
    if not re.match(pat, expr):
        raise ValueError(f"Cut expression contains unsupported syntax: {expr}")
    return expr

def _pick_eval_engine():
    # Keep eval-engine configurable, defaulting to safe python semantics.
    engine = str(_cfg("runtime", "cut_eval_engine", default="python")).lower().strip()
    return engine if engine in {"python", "numexpr"} else "python"


def _evaluate_cut_mask(arrays, cut_expr):
    # Fast path: evaluate directly on numpy arrays (avoids DataFrame materialization).
    _validate_cut_expression(cut_expr)
    expr = _cut_to_pandas(cut_expr)
    if not expr:
        return None
    if not arrays:
        return np.array([], dtype=bool)

    try:
        mask = pd.eval(expr, local_dict=arrays, engine=_pick_eval_engine())
    except Exception:
        # Fallback keeps full expression compatibility.
        mask = pd.DataFrame(arrays).eval(expr, engine="python")

    mask = np.asarray(mask, dtype=bool)
    if mask.ndim != 1:
        raise ValueError(f"Cut mask must be 1D, got shape={mask.shape}")
    return mask


def _filter_arrays_with_cut(arrays, cut_expr):
    # Shared cut application used everywhere for consistent behavior.
    mask = _evaluate_cut_mask(arrays, cut_expr)
    if mask is None:
        return arrays
    if mask.size == 0:
        return {k: np.asarray(v)[:0] for k, v in arrays.items()}
    return {k: np.asarray(v)[mask] for k, v in arrays.items()}

def _extract_cut_branches(cut_expr):
    _validate_cut_expression(cut_expr)
    toks = set(re.findall(r"\b[A-Za-z_][A-Za-z0-9_]*\b", _normalize_cut(cut_expr)))
    keywords = {
        "and", "or", "not", "true", "false", "abs", "sqrt", "pow", "min", "max", "int", "float", "double"
    }
    return {t for t in toks if t.lower() not in keywords and not t.isdigit()}

def _resolve_requested_branches(required, available):
    resolved = {}
    for b in sorted(set(required)):
        cands = [b] + list(BRANCH_ALIASES.get(b, []))
        src = next((c for c in cands if c in available), None)
        if src is not None:
            resolved[b] = src
    return resolved

def _branch_seed_from_config():
    seed = set(_cfg("runtime", "explicit_branch_seed", default=[] ) or [])
    if bool(_cfg("runtime", "auto_include_all_observables_in_seed", default=False)):
        seed |= set(OBSERVABLES.keys())
    weight_branch = _cfg("physics", "mc_weight_branch")
    if isinstance(weight_branch, str) and weight_branch.strip():
        seed.add(weight_branch)
    return {x for x in seed if isinstance(x, str) and x.strip()}


def _validate_observables(observables):
    known = []
    unknown = []
    for o in (observables or []):
        if o in OBSERVABLES:
            known.append(o)
        else:
            unknown.append(o)

    policy = str(_cfg("runtime", "unknown_observable_policy", default="warn")).lower().strip()
    if policy not in {"warn", "ignore", "error"}:
        policy = "warn"

    if unknown:
        if policy == "error":
            raise KeyError(f"Unknown observables requested: {sorted(set(unknown))}")
        if policy == "warn":
            for u in sorted(set(unknown)):
                _log(f"Skipping unknown observable '{u}'", level="warn")

    return sorted(set(known))

def _plan_required_branches(observables, cut_expr=""):
    needed = set(_branch_seed_from_config())
    needed |= set(observables or [])
    needed |= _extract_cut_branches(cut_expr)
    planned = sorted(needed)
    if bool(_cfg("runtime", "log_branch_plan", default=False)):
        _log(f"Branch plan: n={len(planned)} -> {planned}")
    return planned



def _validate_plot_style_keys(style_overrides, reference=None, prefix="plot_style"):
    """Warn on unknown style keys to catch misspellings in nested style overrides."""
    if not isinstance(style_overrides, dict):
        return
    reference = reference or PLOT_STYLE_DEFAULTS
    for key, val in style_overrides.items():
        path = f"{prefix}.{key}"
        if key not in reference:
            _log(f"Unknown style key: {path}", level="warn")
            continue
        if isinstance(val, dict) and isinstance(reference.get(key), dict):
            _validate_plot_style_keys(val, reference=reference.get(key), prefix=path)


def _validate_user_payloads(observables, category_config):
    if not isinstance(observables, dict) or not observables:
        raise ValueError("OBSERVABLES must be a non-empty dict")
    for name, cfg in observables.items():
        if not isinstance(cfg, dict) or "bins" not in cfg:
            raise ValueError(f"Observable '{name}' must define bins")
        bins = np.asarray(cfg["bins"], dtype=float)
        if bins.ndim != 1 or bins.size < 2:
            raise ValueError(f"Observable '{name}' bins must be 1D with at least 2 edges")
        if not np.all(np.isfinite(bins)):
            raise ValueError(f"Observable '{name}' bins must be finite")
        if not np.all(np.diff(bins) > 0):
            raise ValueError(f"Observable '{name}' bins must be strictly increasing")

    if not isinstance(category_config, dict) or not category_config:
        raise ValueError("CATEGORY_CONFIG must be a non-empty dict")
    for cat, cat_cfg in category_config.items():
        if not isinstance(cat_cfg, dict):
            raise ValueError(f"Category '{cat}' must map to a dict")
        sub = cat_cfg.get("subcategories", {})
        if not isinstance(sub, dict) or not sub:
            raise ValueError(f"Category '{cat}' must define at least one subcategory")
        _validate_plot_style_keys(cat_cfg.get("plot_style", {}), prefix=f"CATEGORY_CONFIG.{cat}.plot_style")
        for sub_name, sub_cfg in sub.items():
            if not isinstance(sub_cfg, dict):
                raise ValueError(f"Subcategory '{cat}.{sub_name}' must map to a dict")
            _validate_cut_expression(sub_cfg.get("cut", ""))
            _validate_plot_style_keys(sub_cfg.get("plot_style", {}), prefix=f"CATEGORY_CONFIG.{cat}.{sub_name}.plot_style")

def _validate_analysis_config(cfg):
    required_top = {"io", "physics", "runtime", "cache", "filters", "logging", "execution"}
    missing = sorted(required_top - set(cfg.keys()))
    if missing:
        raise KeyError(f"ANALYSIS_CONFIG missing required sections: {missing}")

    if str(_cfg("runtime", "array_branch_import_mode", default="needed")).lower() not in {"needed", "all"}:
        raise ValueError("runtime.array_branch_import_mode must be 'needed' or 'all'")
    if int(_cfg("runtime", "parallel_read_workers", default=1)) < 1:
        raise ValueError("runtime.parallel_read_workers must be >= 1")
    if str(_cfg("runtime", "parallel_profile", default="auto")).lower().strip() not in {"auto", "laptop", "shared", "batch"}:
        raise ValueError("runtime.parallel_profile must be auto/laptop/shared/batch")
    if str(_cfg("runtime", "unknown_observable_policy", default="warn")).lower().strip() not in {"warn", "ignore", "error"}:
        raise ValueError("runtime.unknown_observable_policy must be 'warn', 'ignore', or 'error'")
    if str(_cfg("runtime", "category_loading_strategy", default="preload_tree_uncut")).lower().strip() not in {"preload_tree_uncut", "preload_tree_or_subcategory_cut"}:
        raise ValueError("runtime.category_loading_strategy must be 'preload_tree_uncut' or 'preload_tree_or_subcategory_cut'")
    if str(_cfg("runtime", "preload_branch_strategy", default="union_all")).lower().strip() not in {"union_all", "per_observable_chunk"}:
        raise ValueError("runtime.preload_branch_strategy must be union_all/per_observable_chunk")
    if int(_cfg("cache", "max_entries", default=32)) < 1:
        raise ValueError("cache.max_entries must be >= 1")
    max_mb = _cfg("cache", "max_bytes_mb", default=4096)
    if max_mb is not None and float(max_mb) <= 0:
        raise ValueError("cache.max_bytes_mb must be > 0 when set")
    if str(_cfg("io", "output_file_ext", default="png")).strip() == "":
        raise ValueError("io.output_file_ext must be non-empty")

def _config_snapshot():
    return {
        "mode": _cfg("io", "input_mode"),
        "input": _cfg("io", "input_path"),
        "output": _cfg("io", "output_dir"),
        "branch_mode": _cfg("runtime", "array_branch_import_mode", default="needed"),
        "reuse_uncut": bool(_cfg("runtime", "reuse_uncut_arrays_for_cuts", default=True)),
        "unknown_obs_policy": str(_cfg("runtime", "unknown_observable_policy", default="warn")),
        "seed_n": len(_cfg("runtime", "explicit_branch_seed", default=[] ) or []),
        "auto_seed_all_obs": bool(_cfg("runtime", "auto_include_all_observables_in_seed", default=False)),
        "parallel": bool(_cfg("runtime", "enable_parallel_read", default=True)),
        "workers": int(_cfg("runtime", "parallel_read_workers", default=1)),
        "parallel_profile": str(_cfg("runtime", "parallel_profile", default="auto")),
        "cache_arrays": bool(_cfg("cache", "arrays_in_memory", default=True)),
        "category_loading_strategy": str(_cfg("runtime", "category_loading_strategy", default="preload_tree_uncut")),
    }

def _hist_with_flows(values, bins, weights=None):
    x = np.asarray(values)
    if x.size == 0:
        return np.zeros(len(bins) - 1, dtype=float)
    lo = np.nextafter(bins[0], np.inf)
    hi = np.nextafter(bins[-1], -np.inf)
    x = np.clip(x, lo, hi)
    h, _ = np.histogram(x, bins=bins, weights=weights)
    return h


class StyleResolver:
    def __init__(self, sample_style, stack_by_group=True):
        self.sample_style = sample_style or {}
        self.stack_by_group = bool(stack_by_group)

    def _sample(self, name):
        return (self.sample_style.get("samples", {}) or {}).get(name, {})

    def _group(self, name):
        return (self.sample_style.get("groups", {}) or {}).get(name, {})

    def stack_key(self, sample):
        grp = self._sample(sample).get("group")
        return grp if self.stack_by_group and grp else sample

    def display_name(self, proc):
        g = self._group(proc)
        if self.stack_by_group and g.get("title"):
            return g["title"]
        s = self._sample(proc)
        if s.get("title"):
            return s["title"]
        grp = s.get("group")
        if grp and self._group(grp).get("title"):
            return self._group(grp)["title"]
        return proc

    def color(self, proc, idx=0):
        g = self._group(proc)
        if g.get("color"):
            return g["color"]
        s = self._sample(proc)
        if s.get("color"):
            return s["color"]
        grp = s.get("group")
        if grp and self._group(grp).get("color"):
            return self._group(grp)["color"]
        cycle = list(plt.cm.tab20.colors) + list(plt.cm.Set3.colors)
        return cycle[idx % len(cycle)]


class DataMCSession:
    """Interactive, cache-friendly analysis session for spontaneous cuts/plots."""

    def __init__(self):
        self.input_mode = None
        self.input_files = []
        self.unmerged_index = {}
        self.io_pool = None
        self.array_cache = OrderedDict()
        self.array_cache_bytes = 0
        self.uncut_base_cache = {}
        self.style = StyleResolver(SAMPLE_STYLE, stack_by_group=_cfg("style_behavior", "stack_by_group", default=True))



    def _effective_workers(self):
        configured = max(1, int(_cfg("runtime", "parallel_read_workers", default=1)))
        profile = str(_cfg("runtime", "parallel_profile", default="auto")).lower().strip()
        n_files = max(1, len(self.input_files))
        if profile == "laptop":
            return min(configured, 4)
        if profile == "shared":
            return min(configured, 8)
        if profile == "batch":
            return configured
        return max(1, min(configured, max(2, min(16, n_files))))

    def _pool(self):
        workers = self._effective_workers()
        if self.io_pool is None or getattr(self, "_pool_workers", None) != workers:
            if self.io_pool is not None:
                self.io_pool.shutdown(wait=False, cancel_futures=False)
            self.io_pool = ThreadPoolExecutor(max_workers=workers)
            self._pool_workers = workers
        return self.io_pool

    def _estimate_payload_bytes(self, payload):
        total = 0
        for arrs in (payload or {}).get("arrays", {}).values():
            for v in arrs.values():
                a = np.asarray(v)
                total += int(getattr(a, "nbytes", 0))
        return total

    def _cache_put(self, key, payload):
        if not _cfg("cache", "arrays_in_memory", default=True):
            return
        if key in self.array_cache:
            old = self.array_cache.pop(key)
            self.array_cache_bytes -= self._estimate_payload_bytes(old)
        self.array_cache[key] = payload
        self.array_cache.move_to_end(key)
        self.array_cache_bytes += self._estimate_payload_bytes(payload)

        max_entries = int(_cfg("cache", "max_entries", default=32))
        max_bytes_mb = _cfg("cache", "max_bytes_mb", default=4096)
        max_bytes = None if max_bytes_mb is None else int(float(max_bytes_mb) * 1024 * 1024)

        while self.array_cache and (len(self.array_cache) > max_entries or (max_bytes is not None and self.array_cache_bytes > max_bytes)):
            evict_key, evict_payload = self.array_cache.popitem(last=False)
            freed = self._estimate_payload_bytes(evict_payload)
            self.array_cache_bytes -= freed
            _log(f"cache-evict key={evict_key[0]} freed={freed/1024/1024:.1f}MB", level="debug")

    def _seed_uncut_base_cache(self, tree_name, import_mode, payload):
        if not _cfg("cache", "arrays_in_memory", default=True):
            return
        if not isinstance(payload, dict):
            return
        if _normalize_cut(payload.get("cut", "")):
            return
        arrays = payload.get("arrays", {})
        base_branches = set()
        for arrs in arrays.values():
            base_branches |= set(arrs.keys())
        base_key = (
            tree_name,
            import_mode,
            tuple(self.input_files),
            self.input_mode,
        )
        self.uncut_base_cache[base_key] = {
            "payload": payload,
            "branches": base_branches,
        }

    def refresh_inputs(self, force=False, emit_log=True):
        sig = (_cfg("io", "input_mode"), _cfg("io", "input_path"), _cfg("io", "unmerged_glob"), repr(_cfg("io", "unmerged_process_paths", default={})))
        cached_sig = getattr(self, "_input_sig", None)
        if (not force) and cached_sig == sig and self.input_files:
            if emit_log:
                _log(f"Reusing discovered inputs ({len(self.input_files)} files)")
            return

        self.input_mode, discovered = _discover_input_files(_cfg("io", "input_path"), _cfg("io", "input_mode"), _cfg("io", "unmerged_glob") )
        self.input_files = _unique_paths(discovered)
        dropped = max(0, len(discovered) - len(self.input_files))
        if dropped:
            _log(f"Deduplicated input file list: dropped {dropped} duplicate path(s)")
        self.unmerged_index = _build_unmerged_index(self.input_files) if self.input_mode == "unmerged" else {}
        self.uncut_base_cache.clear()
        self.array_cache.clear()
        self.array_cache_bytes = 0
        self._input_sig = sig
        _log(f"Loaded inputs: mode={self.input_mode}, n_files={len(self.input_files)}")

    def list_categories(self):
        if self.input_mode == "unmerged":
            return sorted(k for k in self.unmerged_index.keys() if k != "*")
        f = TFile.Open(self.input_files[0])
        out = []
        try:
            keys = f.GetListOfKeys()
            for i in range(keys.GetEntries()):
                n = keys.At(i).GetName()
                if n and n not in set(_cfg("filters", "exclude_top_level_keys", default={"trees"})):
                    out.append(n)
        finally:
            f.Close()
        return sorted(set(out))

    def list_processes(self, tree_name):
        if self.input_mode == "unmerged":
            return sorted((self.unmerged_index.get(tree_name) or self.unmerged_index.get("*", {})).keys())
        # merged mode, discover from ROOT dirs
        f = TFile.Open(self.input_files[0])
        procs = set()
        try:
            for pth in [x.format(tree=tree_name) for x in _cfg("io", "merged_tree_roots", default=["{tree}", "trees/{tree}"])] :
                d = f.Get(pth)
                if d and d.InheritsFrom("TDirectory"):
                    keys = d.GetListOfKeys()
                    for i in range(keys.GetEntries()):
                        n = keys.At(i).GetName()
                        if n != "Events":
                            procs.add(n)
        finally:
            f.Close()
        return sorted(procs)

    def _tree_candidates(self, tree_name, proc):
        return [tpl.format(tree=tree_name, proc=proc) for tpl in _cfg("io", "tree_path_candidates", default=["{tree}/{proc}/Events", "trees/{tree}/{proc}/Events", "/{tree}/{proc}/Events", "/trees/{tree}/{proc}/Events"]) ]


    def _read_one_file(self, root_file, tree_name, proc, required_branches, cut_expr, import_mode):
        with uproot.open(root_file) as f:
            tree = None
            tree_path = None
            for p in self._tree_candidates(tree_name, proc):
                if p in f:
                    tree = f[p]
                    tree_path = p
                    break
            if tree is None:
                return None

            available = set(map(str, tree.keys()))
            if str(import_mode).lower().strip() == "all":
                resolved = {k: k for k in available}
                wanted = sorted(available)
            else:
                resolved = _resolve_requested_branches(required_branches, available)
                wanted = sorted(set(resolved.values()))
            if not wanted:
                return {"proc": proc, "arrays": {}, "entries_total": 0, "entries_after_cut": 0, "file": root_file}

            arrays = tree.arrays(
                wanted,
                library="np",
                decompression_executor=self._pool(),
                interpretation_executor=self._pool(),
            )

        arr_source = {k: np.asarray(v) for k, v in arrays.items()}
        entries_total = len(next(iter(arr_source.values()))) if arr_source else 0

        if cut_expr:
            arr_source = _filter_arrays_with_cut(arr_source, cut_expr)

        arr_final = {req: arr_source[src] for req, src in resolved.items() if src in arr_source}
        entries_after = len(next(iter(arr_final.values()))) if arr_final else 0
        return {
            "proc": proc,
            "arrays": arr_final,
            "entries_total": int(entries_total),
            "entries_after_cut": int(entries_after),
            "file": root_file,
            "tree_path": tree_path,
            "loaded_branch_names": sorted(arr_final.keys()),
        }

    def load_arrays(self, tree_name, cut_expr="", observables=None, required_branches=None, force=False, import_mode=None, _internal_skip_cut_reuse=False, _internal_refresh_inputs=True, _internal_emit_load_log=True, _internal_emit_summary_log=True):
        if _internal_refresh_inputs:
            self.refresh_inputs(force=_cfg("cache", "force_reload_inputs", default=False), emit_log=not _internal_skip_cut_reuse)

        if required_branches is None:
            obs_in = list(observables) if observables is not None else list(OBSERVABLES.keys())
            obs = _validate_observables(obs_in)
            needed = set(_plan_required_branches(obs, cut_expr=cut_expr))
        else:
            obs = sorted(set(observables or []))
            needed = {b for b in required_branches if isinstance(b, str) and b.strip()}
            w = _cfg("physics", "mc_weight_branch")
            if isinstance(w, str) and w.strip():
                needed.add(w)

        # Preserve branch-import configurability: honor both "needed" and "all".
        final_import_mode = str(import_mode or _cfg("runtime", "array_branch_import_mode", default="needed")).lower().strip()
        if final_import_mode not in {"needed", "all"}:
            _log(f"Unknown import_mode='{final_import_mode}', using 'needed'", level="warn")
            final_import_mode = "needed"
        norm_cut = _normalize_cut(cut_expr)

        if _internal_emit_load_log and _cfg("logging", "show_cut", default=True):
            _log(f"load_arrays tree={tree_name} cut={_cut_preview(norm_cut)}")

        cache_key = (
            tree_name,
            tuple(sorted(needed)),
            norm_cut,
            final_import_mode,
            tuple(self.input_files),
            self.input_mode,
        )
        if _cfg("cache", "arrays_in_memory", default=True) and (not force) and cache_key in self.array_cache:
            _log(f"cache-hit tree={tree_name} cut={_cut_preview(norm_cut)} branches={len(needed)}")
            cached = self.array_cache[cache_key]
            self.array_cache.move_to_end(cache_key)
            if not norm_cut:
                self._seed_uncut_base_cache(tree_name, final_import_mode, cached)
            return cached

        # Optimization path: load uncut arrays once, then apply cut masks in-memory.
        if (not _internal_skip_cut_reuse) and _cfg("runtime", "reuse_uncut_arrays_for_cuts", default=True) and norm_cut:
            base_key = (
                tree_name,
                final_import_mode,
                tuple(self.input_files),
                self.input_mode,
            )
            required_uncut = set(needed)
            entry = self.uncut_base_cache.get(base_key)

            if entry:
                target_branches = set(entry.get("branches", set())) | required_uncut
                cache_hits = (not force) and required_uncut.issubset(set(entry.get("branches", set())))
            else:
                target_branches = set(required_uncut)
                cache_hits = False

            if cache_hits:
                base_payload = entry["payload"]
            else:
                base_payload = self.load_arrays(
                    tree_name=tree_name,
                    cut_expr="",
                    observables=obs,
                    required_branches=sorted(target_branches),
                    force=force,
                    import_mode=final_import_mode,
                    _internal_skip_cut_reuse=True,
                    _internal_refresh_inputs=False,
                    _internal_emit_load_log=False,
                    _internal_emit_summary_log=False,
                )
                self._seed_uncut_base_cache(tree_name, final_import_mode, base_payload)

            out = {}
            reports = []
            base_report_by_proc = {r["proc"]: r for r in base_payload.get("reports", [])}
            expr = _cut_to_pandas(norm_cut)
            for proc, arrs in sorted(base_payload["arrays"].items()):
                total = len(next(iter(arrs.values()))) if arrs else 0
                filtered = arrs
                if expr and arrs:
                    filtered = _filter_arrays_with_cut(arrs, norm_cut)

                if filtered:
                    out[proc] = filtered
                reports.append({
                    "proc": proc,
                    "n_files": int(base_report_by_proc.get(proc, {}).get("n_files", 0)),
                    "entries_total": int(total),
                    "entries_after_cut": int(len(next(iter(filtered.values()))) if filtered else 0),
                    "loaded_branches": len(filtered),
                })

            result = {"arrays": out, "reports": reports, "tree_name": tree_name, "cut": norm_cut, "observables": obs}
            self._cache_put(cache_key, result)
            return result

        if self.input_mode == "unmerged":
            proc_map = dict(self.unmerged_index.get(tree_name) or self.unmerged_index.get("*", {}))
        else:
            proc_map = {p: [self.input_files[0]] for p in self.list_processes(tree_name)}

        allow = _cfg("filters", "process_allowlist")
        block = _cfg("filters", "process_blocklist")
        if allow:
            allow_set = set(allow)
            proc_map = {k: v for k, v in proc_map.items() if k in allow_set}
        if block:
            block_set = set(block)
            proc_map = {k: v for k, v in proc_map.items() if k not in block_set}

        out = {}
        reports = []

        for proc, files in sorted(proc_map.items()):
            files = _unique_paths(files)
            futures = {}
            chunks = []
            if _cfg("runtime", "enable_parallel_read", default=True) and len(files) > 1:
                for i, rf in enumerate(files, 1):
                    fut = self._pool().submit(self._read_one_file, rf, tree_name, proc, needed, cut_expr, final_import_mode)
                    futures[fut] = (i, rf)
                for fut in as_completed(futures):
                    i, rf = futures[fut]
                    payload = fut.result()
                    if payload is not None:
                        tree_info = payload.get("tree_path", "?") if _cfg("logging", "show_tree_path", default=True) else proc
                        _progress("load", i, len(files), f"proc={proc} tree={tree_info} file={os.path.basename(rf)}")
                        chunks.append(payload)
            else:
                for i, rf in enumerate(files, 1):
                    payload = self._read_one_file(rf, tree_name, proc, needed, cut_expr, final_import_mode)
                    if payload is not None:
                        tree_info = payload.get("tree_path", "?") if _cfg("logging", "show_tree_path", default=True) else proc
                        _progress("load", i, len(files), f"proc={proc} tree={tree_info} file={os.path.basename(rf)}")
                        chunks.append(payload)

            if not chunks:
                continue

            merged = {}
            keys = sorted(set().union(*(set(x["arrays"].keys()) for x in chunks)))
            for k in keys:
                vals = [x["arrays"][k] for x in chunks if k in x["arrays"]]
                if vals:
                    merged[k] = np.concatenate(vals) if len(vals) > 1 else vals[0]

            if merged:
                out[proc] = merged
            branch_names = sorted(set().union(*(set(x.get("loaded_branch_names", [])) for x in chunks)))
            reports.append({
                "proc": proc,
                "process_key": f"{tree_name}:{proc}",
                "n_files": len(files),
                "entries_total": int(sum(x["entries_total"] for x in chunks)),
                "entries_after_cut": int(sum(x["entries_after_cut"] for x in chunks)),
                "loaded_branches": len(merged),
                "branch_names": branch_names,
                "tree_paths": sorted(set(x.get("tree_path", "") for x in chunks if x.get("tree_path"))),
            })

        result = {"arrays": out, "reports": reports, "tree_name": tree_name, "cut": norm_cut, "observables": obs}
        if _internal_emit_summary_log and _cfg("logging", "show_branch_summary", default=True):
            total_after = int(sum(r.get("entries_after_cut", 0) for r in reports))
            total_before = int(sum(r.get("entries_total", 0) for r in reports))
            _log(f"summary tree={tree_name} procs={len(reports)} events={total_after}/{total_before} branches={len(needed)} cut={_cut_preview(norm_cut)}")
        self._cache_put(cache_key, result)
        if not norm_cut:
            self._seed_uncut_base_cache(tree_name, final_import_mode, result)
        return result

# %%
# =========================
# PLOTTING + HIGH-LEVEL API
# =========================


def _poisson_err(data_counts):
    lo, hi = poisson_interval(np.asarray(data_counts, dtype=float))
    return np.asarray(data_counts) - lo, hi - np.asarray(data_counts)


def _weighted_poisson_errors(sumw, sumw2):
    sumw = np.asarray(sumw, dtype=float)
    sumw2 = np.asarray(sumw2, dtype=float)
    neff = np.divide(sumw**2, sumw2, out=np.zeros_like(sumw), where=sumw2 > 0)
    lo_eff, hi_eff = poisson_interval(neff)
    err_lo = np.divide(sumw * (neff - lo_eff), neff, out=np.zeros_like(sumw), where=neff > 0)
    err_hi = np.divide(sumw * (hi_eff - neff), neff, out=np.zeros_like(sumw), where=neff > 0)
    return err_lo, err_hi


def _yield_label(vals, vars_, label):
    ysum = float(np.sum(vals))
    vsum = float(np.sum(vars_))
    eff = ysum**2 / vsum if vsum > 0 else 0.0
    lo, hi = poisson_interval(np.array([eff]))
    err_lo = ysum * (eff - lo[0]) / eff if eff > 0 else 0.0
    err_hi = ysum * (hi[0] - eff) / eff if eff > 0 else 0.0
    nd = int(_cfg("physics", "yield_digits", default=2))
    fmt = lambda x: f"{x:.{nd}f}"
    return f"{label}\n" + rf"$\mathrm{{{fmt(ysum)}}}^{{+{fmt(err_hi)}}}_{{-{fmt(err_lo)}}}$"


def _stack_from_arrays(session, proc_arrays, observable, bins):
    data = np.zeros(len(bins) - 1, dtype=float)
    mc_h, mc_v = {}, {}
    for proc, arrs in proc_arrays.items():
        if observable not in arrs:
            continue
        x = arrs[observable]
        stack_name = session.style.stack_key(proc)

        if proc in _cfg("physics", "data_processes"):
            data += _hist_with_flows(x, bins=bins)
            continue

        if _cfg("physics", "mc_weight_branch") not in arrs:
            continue
        w = arrs[_cfg("physics", "mc_weight_branch")]
        h = _hist_with_flows(x, bins=bins, weights=w)
        v = _hist_with_flows(x, bins=bins, weights=w * w)
        mc_h[stack_name] = mc_h.get(stack_name, 0.0) + h
        mc_v[stack_name] = mc_v.get(stack_name, 0.0) + v
    return data, mc_h, mc_v


def _deep_merge_dict(base, overrides):
    out = dict(base or {})
    for k, v in (overrides or {}).items():
        if isinstance(v, dict) and isinstance(out.get(k), dict):
            out[k] = _deep_merge_dict(out[k], v)
        else:
            out[k] = v
    return out


def _merge_plot_style(base=None, overrides=None):
    style = _deep_merge_dict(PLOT_STYLE_DEFAULTS, base or {})
    style = _deep_merge_dict(style, overrides or {})

    # backward compatibility shim for older flat overrides
    flat_to_nested = {
        "title": ("meta", "title"),
        "lumi_label": ("meta", "lumi_label"),
        "save_dpi": ("figure", "save_dpi"),
        "show_plots": ("figure", "show_plots"),
        "figsize": ("figure", "figsize"),
        "logy": ("scales", "logy"),
    }
    for old_key, path in flat_to_nested.items():
        if old_key in (overrides or {}):
            node = style
            for p in path[:-1]:
                node = node.setdefault(p, {})
            node[path[-1]] = (overrides or {})[old_key]
    return style


def _style_get(style, *path, default=None):
    node = style
    for p in path:
        if not isinstance(node, dict) or p not in node:
            return default
        node = node[p]
    return node


def _format_cut_text(cut_text, width=52):
    expr = _normalize_cut(cut_text)
    if not expr:
        return ""

    expr = re.sub(r"\s+", " ", expr).strip()
    expr = expr.replace(" && ", "\n&& ").replace(" || ", "\n|| ")

    lines = []
    for piece in expr.splitlines():
        wrapped = textwrap.wrap(piece, width=width, break_long_words=False, break_on_hyphens=False)
        lines.extend(wrapped if wrapped else [""])
    return "\n".join(lines)


def _format_y_axis_like_ticks(ax, style):
    sci = _style_get(style, "yaxis_scientific", default={})
    if not bool(sci.get("enabled", True)):
        return
    if ax.get_yscale() == "log":
        return

    ax.figure.canvas.draw()
    yticks = np.asarray(ax.get_yticks(), dtype=float)
    if yticks.size == 0:
        return

    finite = np.isfinite(yticks)
    max_abs = float(np.nanmax(np.abs(yticks[finite]))) if np.any(finite) else 0.0
    if max_abs <= float(sci.get("plain_threshold", 1e3)):
        ax.yaxis.set_major_formatter(mpl.ticker.StrMethodFormatter("{x:.0f}"))
        ax.yaxis.offsetText.set_visible(False)
        return

    fmt = mpl.ticker.ScalarFormatter(useMathText=True)
    fmt.set_scientific(True)
    fmt.set_powerlimits(tuple(sci.get("powerlimits", (-4, 4))))
    fmt.set_useOffset(False)
    ax.yaxis.set_major_formatter(fmt)

    ax.figure.canvas.draw()
    ax.yaxis.offsetText.set_visible(False)

    k = int(getattr(fmt, "orderOfMagnitude", 0))
    if abs(k) < int(sci.get("manual_multiplier_min_abs_power", 4)):
        return

    if hasattr(ax, "_manual_y_multiplier") and ax._manual_y_multiplier is not None:
        ax._manual_y_multiplier.remove()

    fp = next((t.get_fontproperties() for t in ax.yaxis.get_ticklabels() if t.get_text()), ax.yaxis.get_label().get_fontproperties())
    ax._manual_y_multiplier = ax.text(
        float(sci.get("multiplier_x", -0.005)),
        float(sci.get("multiplier_y", 1.005)),
        rf"$\times 10^{{{k}}}$",
        transform=ax.transAxes,
        ha=sci.get("multiplier_ha", "right"),
        va="bottom",
        fontsize=float(sci.get("multiplier_fontsize", 14)),
        fontproperties=fp,
        clip_on=False,
    )


def _draw_datamc(session, category_key, observable, obs_cfg, data_counts, mc_hists, mc_vars, plot_label=None, subtitle=None, cut_text=None, plot_style=None, output_dir=None):
    style = _merge_plot_style(plot_style)

    bins = np.asarray(obs_cfg["bins"], dtype=float)
    centers = 0.5 * (bins[1:] + bins[:-1])
    widths = np.diff(bins)

    text_cfg = _style_get(style, "text", default={})
    fig_cfg = _style_get(style, "figure", default={})
    layout_cfg = _style_get(style, "layout", default={})
    panel_cfg = _style_get(style, "panels", default={})
    axes_cfg = _style_get(style, "axes", default={})
    grid_cfg = _style_get(style, "grid", default={})
    stack_cfg = _style_get(style, "stack", default={})
    mc_cfg = _style_get(style, "mc", default={})
    data_cfg = _style_get(style, "data", default={})
    ratio_cfg = _style_get(style, "ratio", default={})
    legend_cfg = _style_get(style, "legend", default={})
    cut_cfg = _style_get(style, "cut_block", default={})
    cms_cfg = _style_get(style, "cms", default={})
    meta_cfg = _style_get(style, "meta", default={})

    if not mc_hists:
        _log(text_cfg.get("no_mc_log", "No MC histogram available for {category}/{observable}").format(category=category_key, observable=observable), level="warn")
        return None

    procs = sorted(mc_hists, key=lambda p: float(np.sum(mc_hists[p])))
    mc_total = np.sum([mc_hists[p] for p in procs], axis=0)
    mc_total_var = np.sum([mc_vars[p] for p in procs], axis=0)
    mc_lo, mc_hi = _weighted_poisson_errors(mc_total, mc_total_var)
    d_lo, d_hi = _poisson_err(data_counts)

    fig = plt.figure(figsize=tuple(fig_cfg.get("figsize", (10, 7))), facecolor=fig_cfg.get("facecolor", "white"))
    gs = fig.add_gridspec(
        2,
        2,
        width_ratios=layout_cfg.get("width_ratios", [6.8, 3.2]),
        height_ratios=layout_cfg.get("height_ratios", [3, 1]),
        wspace=float(layout_cfg.get("wspace", 0.05)),
        hspace=float(layout_cfg.get("hspace", 0.04)),
    )
    ax = fig.add_subplot(gs[0, 0])
    rax = fig.add_subplot(gs[1, 0], sharex=ax)
    lax = fig.add_subplot(gs[:, 1])
    ax.set_facecolor(panel_cfg.get("main_facecolor", "white"))
    rax.set_facecolor(panel_cfg.get("ratio_facecolor", "white"))
    lax.set_facecolor(panel_cfg.get("legend_facecolor", "white"))
    lax.axis("off")

    ax.tick_params(labelbottom=False)
    tick_size = axes_cfg.get("tick_labelsize")
    tick_params = dict(
        axis="both",
        which="both",
        direction=axes_cfg.get("tick_direction", "in"),
        length=float(axes_cfg.get("tick_length", 5)),
        width=float(axes_cfg.get("tick_width", 1.0)),
        top=bool(axes_cfg.get("tick_top", True)),
        right=bool(axes_cfg.get("tick_right", True)),
    )
    ax.tick_params(labelsize=tick_size, **tick_params)
    rax.tick_params(labelsize=tick_size, **tick_params)

    for axis in [ax, rax]:
        for spine in axis.spines.values():
            spine.set_linewidth(float(axes_cfg.get("spine_linewidth", 1.0)))

    if bool(grid_cfg.get("enabled", True)):
        ax.grid(alpha=float(grid_cfg.get("main_alpha", 0.25)), linestyle=grid_cfg.get("linestyle", "-"), linewidth=float(grid_cfg.get("linewidth", 0.6)), which=grid_cfg.get("which", "major"), axis=grid_cfg.get("axis", "both"))
        rax.grid(alpha=float(grid_cfg.get("ratio_alpha", 0.25)), linestyle=grid_cfg.get("linestyle", "-"), linewidth=float(grid_cfg.get("linewidth", 0.6)), which=grid_cfg.get("which", "major"), axis=grid_cfg.get("axis", "both"))

    bottoms = np.zeros_like(centers)
    stack_handles, stack_payload = [], []
    for i, p in enumerate(procs):
        vals = mc_hists[p]
        vars_ = mc_vars[p]
        h = ax.bar(
            centers,
            vals,
            width=widths,
            bottom=bottoms,
            align=stack_cfg.get("align", "center"),
            color=session.style.color(p, i),
            alpha=float(stack_cfg.get("alpha", 0.82)),
            edgecolor=stack_cfg.get("edgecolor", "none"),
            linewidth=float(stack_cfg.get("linewidth", 0.0)),
            zorder=float(stack_cfg.get("zorder", 2)),
        )
        bottoms = bottoms + vals
        stack_handles.append(h[0])
        stack_payload.append((p, vals, vars_))

    step_x = np.repeat(bins, 2)[1:-1]
    step_y = np.repeat(mc_total, 2)
    mc_color = mc_cfg.get("line_color", "red")
    mc_line = ax.plot(
        step_x,
        step_y,
        color=mc_color,
        lw=float(mc_cfg.get("line_width", 1.5)),
        linestyle=mc_cfg.get("line_style", "-"),
        drawstyle=mc_cfg.get("line_drawstyle", "steps-mid"),
        zorder=float(mc_cfg.get("line_zorder", 5)),
    )[0]
    mc_band = ax.fill_between(
        step_x,
        step_y - np.repeat(mc_lo, 2),
        step_y + np.repeat(mc_hi, 2),
        step=mc_cfg.get("band_step", "mid"),
        color=mc_color,
        alpha=float(mc_cfg.get("band_alpha", 0.12)),
        hatch=mc_cfg.get("band_hatch", None),
        zorder=float(mc_cfg.get("band_zorder", 4)),
    )

    data_marker = data_cfg.get("marker", "o")
    data_color = data_cfg.get("color", "black")
    data_ms = float(data_cfg.get("marker_size", 4))
    data_eb = ax.errorbar(
        centers,
        data_counts,
        yerr=[d_lo, d_hi],
        fmt=data_marker,
        color=data_color,
        ms=data_ms,
        elinewidth=float(data_cfg.get("elinewidth", 1.0)),
        capsize=float(data_cfg.get("capsize", 0)),
        zorder=float(data_cfg.get("marker_zorder", 6)),
    )
    data_markers = ax.plot(centers, data_counts, data_marker, color=data_color, ms=data_ms, zorder=float(data_cfg.get("marker_zorder", 6)))[0]

    axis_fs = axes_cfg.get("axis_label_fontsize", None)
    axis_pad = float(axes_cfg.get("axis_labelpad", 6))
    ax.set_ylabel(axes_cfg.get("y_label", "Events"), fontsize=axis_fs, labelpad=axis_pad)
    if bool(_style_get(style, "scales", "logy", default=False)):
        ax.set_yscale("log")
    _format_y_axis_like_ticks(ax, style)

    title_prefix = str(meta_cfg.get("title", "")).strip()
    title_label = plot_label or category_key
    title_text = str(meta_cfg.get("subtitle_separator", " • ")).join(x for x in [title_prefix, title_label] if x)
    title_x = float(axes_cfg.get("title_x", 0.02))
    title_y = float(axes_cfg.get("title_y", 0.90))
    ax.text(
        title_x,
        title_y,
        title_text,
        transform=ax.transAxes,
        fontsize=float(axes_cfg.get("title_fontsize", 10)),
        fontweight=axes_cfg.get("title_fontweight", "normal"),
        color=axes_cfg.get("title_color", "black"),
        ha="left",
        va="top",
    )

    subtitle_txt = str(subtitle or "").strip()
    if subtitle_txt and bool(axes_cfg.get("subtitle_enabled", True)):
        ax.text(
            title_x,
            title_y - float(axes_cfg.get("subtitle_y_offset", 0.055)),
            subtitle_txt,
            transform=ax.transAxes,
            fontsize=float(axes_cfg.get("subtitle_fontsize", 9)),
            color=axes_cfg.get("subtitle_color", "black"),
            fontstyle=axes_cfg.get("subtitle_fontstyle", "normal"),
            fontweight=axes_cfg.get("subtitle_fontweight", "normal"),
            ha="left",
            va="top",
        )

    cms_objs = hep.cms.label(
        cms_cfg.get("label", "Preliminary"),
        data=True,
        lumi=str(meta_cfg.get("lumi_label", "")),
        ax=ax,
        com=float(cms_cfg.get("com", 13.6)),
        fontsize=float(cms_cfg.get("fontsize", 20)),
    )
    cms_texts = [t for t in (cms_objs if isinstance(cms_objs, (list, tuple)) else [cms_objs]) if isinstance(t, mpl.text.Text)]
    for t in cms_texts:
        t.set_clip_on(False)

    with np.errstate(divide="ignore", invalid="ignore"):
        ratio = np.divide(data_counts, mc_total, out=np.zeros_like(data_counts), where=mc_total > 0)
        rlo = np.divide(d_lo, mc_total, out=np.zeros_like(data_counts), where=mc_total > 0)
        rhi = np.divide(d_hi, mc_total, out=np.zeros_like(data_counts), where=mc_total > 0)
        mc_rel_lo = np.divide(mc_lo, mc_total, out=np.zeros_like(mc_total), where=mc_total > 0)
        mc_rel_hi = np.divide(mc_hi, mc_total, out=np.zeros_like(mc_total), where=mc_total > 0)

    rax.errorbar(
        centers,
        ratio,
        yerr=[rlo, rhi],
        fmt=data_marker,
        color=data_color,
        ms=data_ms,
        elinewidth=float(data_cfg.get("elinewidth", 1.0)),
        capsize=float(data_cfg.get("capsize", 0)),
        zorder=float(data_cfg.get("marker_zorder", 6)),
    )
    ratio_ref = float(ratio_cfg.get("reference_line_value", 1.0))
    ratio_ref_color = ratio_cfg.get("reference_line_color", None) or mc_color
    rax.plot(
        step_x,
        np.full_like(step_y, ratio_ref),
        color=ratio_ref_color,
        lw=float(ratio_cfg.get("reference_line_width", 1.0)),
        linestyle=ratio_cfg.get("reference_line_style", "-"),
        drawstyle=ratio_cfg.get("reference_line_drawstyle", "steps-mid"),
        zorder=float(ratio_cfg.get("reference_line_zorder", 3)),
    )
    rax.fill_between(
        step_x,
        1 - np.repeat(mc_rel_lo, 2),
        1 + np.repeat(mc_rel_hi, 2),
        step=ratio_cfg.get("band_step", "mid"),
        color=mc_color,
        alpha=float(mc_cfg.get("band_alpha", 0.12)),
        hatch=mc_cfg.get("band_hatch", None),
        zorder=float(mc_cfg.get("band_zorder", 4)),
    )

    rax.set_ylabel(axes_cfg.get("ratio_y_label", "Data/MC"), fontsize=axis_fs, labelpad=axis_pad)
    x_label_override = axes_cfg.get("x_label", "")
    rax.set_xlabel(x_label_override or obs_cfg.get("xlabel", observable), fontsize=axis_fs, labelpad=axis_pad)
    rax.set_ylim(*obs_cfg.get("ratio_ylim", tuple(axes_cfg.get("ratio_ylim_default", (0.5, 1.5)))))

    data_label = _yield_label(data_counts, np.maximum(data_counts, 1e-6), session.style.display_name(_cfg("physics", "data_legend_label", default="DATA")))
    mc_label = _yield_label(mc_total, mc_total_var, _cfg("physics", "total_mc_legend_label", default="Total MC"))

    tot = float(np.sum(mc_total))
    stack_labels = []
    for p, vals, vars_ in stack_payload[::-1]:
        frac = 100.0 * (np.sum(vals) / tot) if tot > 0 else 0.0
        pnd = int(_cfg("physics", "yield_percent_digits", default=1))
        stack_labels.append(_yield_label(vals, vars_, f"{session.style.display_name(p)} ({frac:.{pnd}f}%)"))

    handles = [(data_eb, data_markers), (mc_line, mc_band)] + stack_handles[::-1]
    labels = [data_label, mc_label] + stack_labels
    leg = lax.legend(
        handles,
        labels,
        loc=legend_cfg.get("loc", "upper left"),
        fontsize=float(legend_cfg.get("fontsize", 10)),
        frameon=bool(legend_cfg.get("frameon", False)),
        ncol=int(legend_cfg.get("ncol", 2)),
        title=legend_cfg.get("title", ""),
        title_fontsize=float(legend_cfg.get("title_fontsize", 10)),
        handlelength=float(legend_cfg.get("handlelength", 1.2)),
        columnspacing=float(legend_cfg.get("columnspacing", 0.9)),
        labelspacing=float(legend_cfg.get("labelspacing", 0.35)),
        handletextpad=float(legend_cfg.get("handletextpad", 0.4)),
        borderaxespad=float(legend_cfg.get("borderaxespad", 0.0)),
    )

    if cut_text and bool(cut_cfg.get("enabled", True)):
        fig.canvas.draw()
        renderer = fig.canvas.get_renderer()
        leg_bbox = leg.get_window_extent(renderer=renderer).transformed(lax.transAxes.inverted())
        y_top = max(0.02, leg_bbox.y0 - float(cut_cfg.get("block_gap_from_legend", 0.055)))

        cut_title_artist = lax.text(
            0.0,
            y_top,
            cut_cfg.get("title_text", text_cfg.get("selection_title", "Selection:")),
            transform=lax.transAxes,
            ha="left",
            va="top",
            fontsize=float(cut_cfg.get("title_fontsize", 12)),
            fontweight=cut_cfg.get("title_fontweight", "bold"),
            color=cut_cfg.get("title_color", "black"),
            clip_on=False,
        )

        fig.canvas.draw()
        title_bbox = cut_title_artist.get_window_extent(renderer=renderer).transformed(lax.transAxes.inverted())
        lax.text(
            0.0,
            title_bbox.y0 - float(cut_cfg.get("title_to_text_gap", 0.03)),
            _format_cut_text(cut_text, width=int(cut_cfg.get("text_width", 38))),
            transform=lax.transAxes,
            ha="left",
            va="top",
            fontsize=float(cut_cfg.get("text_fontsize", 8)),
            color=cut_cfg.get("text_color", "black"),
            family=cut_cfg.get("fontfamily", "monospace"),
            linespacing=float(cut_cfg.get("line_spacing", 1.10)),
            clip_on=False,
        )

    out_root = output_dir or _cfg("io", "output_dir")
    out_cat = os.path.join(out_root, _sanitize(category_key))
    os.makedirs(out_cat, exist_ok=True)
    fname_template = _cfg("io", "output_filename_template", default="{title}_{category}_{observable}")
    fname = fname_template.format(title=_sanitize(meta_cfg.get("title", "")), category=_sanitize(category_key), observable=_sanitize(observable)).strip("_")
    ext = _cfg("io", "output_file_ext", default="png").lstrip(".")

    out_png = os.path.join(out_cat, f"{fname}.{ext}")
    fig.savefig(out_png, dpi=int(fig_cfg.get("save_dpi", 180)), bbox_inches=_cfg("io", "output_bbox_inches", default="tight"))

    if bool(_cfg("io", "write_plot_metadata", default=True)):
        out_meta = out_png + ".json"
        meta_payload = {
            "category": category_key,
            "observable": observable,
            "cut": _normalize_cut(cut_text or ""),
            "plot_label": plot_label,
            "subtitle": subtitle,
            "output_png": out_png,
            "generated_utc": datetime.now(timezone.utc).isoformat(),
            "config_snapshot": _config_snapshot(),
            "yields": {
                "data": float(np.sum(data_counts)),
                "mc_total": float(np.sum(mc_total)),
                "mc_processes": {str(k): float(np.sum(v)) for k, v in mc_hists.items()},
            },
        }
        with open(out_meta, "w") as fmeta:
            json.dump(meta_payload, fmeta, indent=2)

    if bool(fig_cfg.get("show_plots", False)):
        plt.show()
    else:
        plt.close(fig)

    _log(text_cfg.get("plot_saved_log", "Saved plot: {path}").format(path=out_png), level="io")
    return out_png


def quick_plot(session, tree_name, observable, bins=None, cut_expr="", label=None, subtitle=None, force_reload=False, import_mode=None, plot_style=None, output_dir=None, payload=None, proc_arrays=None, subcategory_name=None, in_memory_only=False):
    """Single-command plotting API for spontaneous exploration.

    Data source priority:
      1) proc_arrays (already in memory)
      2) payload    (already in memory; optional extra cut applied in memory)
      3) tree_name  (loads arrays from files/cache via session.load_arrays)

    Set in_memory_only=True to forbid file/cache reads for this call.
    """
    if bins is None:
        cfg = OBSERVABLES.get(observable)
        if not cfg:
            raise KeyError(f"Observable '{observable}' not in OBSERVABLES and bins not provided.")
        obs_cfg = cfg
    else:
        obs_cfg = {
            "bins": np.asarray(bins, dtype=float),
            "xlabel": observable,
            "ratio_ylim": tuple(_style_get(PLOT_STYLE_DEFAULTS, "axes", "ratio_ylim_default", default=(0.5, 1.5))),
        }

    used_in_memory = False
    if proc_arrays is not None:
        final_proc_arrays = proc_arrays
        used_in_memory = True
    elif payload is not None:
        if not isinstance(payload, dict) or "arrays" not in payload:
            raise TypeError("payload must be a dict with an 'arrays' key")
        payload_cut = _normalize_cut(str(payload.get("cut", "")))
        requested_cut = _normalize_cut(cut_expr)
        if requested_cut and requested_cut != payload_cut:
            payload = _apply_cut_to_payload(payload, requested_cut, subcategory_name=subcategory_name)
        final_proc_arrays = payload["arrays"]
        used_in_memory = True
    else:
        if in_memory_only:
            raise ValueError("in_memory_only=True requires either 'payload' or 'proc_arrays'.")
        payload = session.load_arrays(
            tree_name=tree_name,
            cut_expr=cut_expr,
            observables=[observable],
            force=force_reload or _cfg("cache", "force_reload_array_cache", default=False),
            import_mode=import_mode,
        )
        final_proc_arrays = payload["arrays"]

    category_key = subcategory_name or label or tree_name or "in_memory"
    plot_label = label or subcategory_name or ("in_memory" if used_in_memory else tree_name)

    data_counts, mc_h, mc_v = _stack_from_arrays(session, final_proc_arrays, observable, np.asarray(obs_cfg["bins"], dtype=float))
    return _draw_datamc(
        session,
        category_key,
        observable,
        obs_cfg,
        data_counts,
        mc_h,
        mc_v,
        plot_label=plot_label,
        subtitle=subtitle,
        cut_text=cut_expr,
        plot_style=plot_style,
        output_dir=output_dir,
    )


def prepare_quick_plot_payload(session, tree_name, observables, cut_exprs=None, base_cut="", required_branches=None, import_mode=None, registry=None, registry_namespace="quick_plot", force_reload=False):
    """Build or reuse a base payload for quick-plot jobs.

    Reuse order:
      1) explicit in-memory registry (if provided)
      2) session.uncut_base_cache (compatible branch superset)
      3) load_arrays fallback
    """
    obs_list = [str(o) for o in (observables or []) if isinstance(o, str) and str(o).strip()]
    cuts = [str(c) for c in (cut_exprs or []) if isinstance(c, str) and str(c).strip()]
    planned_cut = _combine_subcategory_cuts_or(cuts)

    required = set(_plan_required_branches(obs_list, cut_expr=planned_cut))
    if required_branches is not None:
        required |= {b for b in required_branches if isinstance(b, str) and b.strip()}

    norm_base_cut = _normalize_cut(base_cut)
    final_import_mode = str(import_mode or _cfg("runtime", "array_branch_import_mode", default="needed")).lower().strip()

    payload_key = (
        registry_namespace,
        id(session),
        tree_name,
        norm_base_cut,
        tuple(sorted(obs_list)),
        tuple(sorted(required)),
        final_import_mode,
    )

    if registry is not None and (not force_reload) and payload_key in registry:
        _log(f"Payload reuse: registry-hit tree={tree_name} branches={len(required)}")
        return registry[payload_key]

    session.refresh_inputs(force=_cfg("cache", "force_reload_inputs", default=False), emit_log=False)

    payload = None
    if not norm_base_cut and (not force_reload):
        base_key = (
            tree_name,
            final_import_mode,
            tuple(session.input_files),
            session.input_mode,
        )
        entry = session.uncut_base_cache.get(base_key)
        if entry and set(required).issubset(set(entry.get("branches", set()))):
            payload = entry.get("payload")
            _log(f"Payload reuse: session-uncut-hit tree={tree_name} branches={len(required)}")

    if payload is None:
        payload = session.load_arrays(
            tree_name=tree_name,
            cut_expr=norm_base_cut,
            observables=obs_list,
            required_branches=sorted(required),
            force=bool(force_reload),
            import_mode=final_import_mode,
        )
        _log(f"Payload build: load_arrays tree={tree_name} branches={len(required)}")

    if registry is not None:
        registry[payload_key] = payload
    return payload


def _coerce_quick_plot_job(job):
    if isinstance(job, str):
        job = json.loads(job)
    if not isinstance(job, dict):
        raise TypeError("job must be a dict or JSON string")
    return dict(job)


def _derive_shared_payload_recipe(jobs):
    """Infer a single shared-payload recipe when job set is compatible."""
    tree_names = set()
    import_modes = set()
    base_cuts = set()
    force_reload = False
    observables = set()
    cut_exprs = []
    required = set()

    for job in jobs:
        if job.get("payload") is not None or job.get("proc_arrays") is not None:
            continue
        t = job.get("tree_name")
        o = job.get("observable")
        if not t or not o:
            continue
        tree_names.add(str(t))
        import_modes.add(str(job.get("import_mode") or _cfg("runtime", "array_branch_import_mode", default="needed")))
        base_cuts.add(_normalize_cut(job.get("base_cut", "")))
        force_reload = force_reload or bool(job.get("force_reload", False))
        observables.add(str(o))
        c = _normalize_cut(job.get("cut_expr", ""))
        if c:
            cut_exprs.append(c)
        required |= {b for b in job.get("required_branches", []) if isinstance(b, str) and b.strip()}

    if not observables:
        return None
    if len(tree_names) != 1 or len(import_modes) != 1 or len(base_cuts) != 1:
        return None

    return {
        "tree_name": next(iter(tree_names)),
        "observables": sorted(observables),
        "cut_exprs": cut_exprs,
        "required_branches": sorted(required),
        "import_mode": next(iter(import_modes)),
        "base_cut": next(iter(base_cuts)),
        "force_reload": force_reload,
    }


def quick_plot_job(session, job):
    """Run one quick-plot job from a dict/JSON specification."""
    job = _coerce_quick_plot_job(job)

    tree_name = job.get("tree_name")
    observable = job.get("observable")
    payload = job.get("payload")
    proc_arrays = job.get("proc_arrays")

    if not observable:
        raise KeyError("job must include 'observable'")
    if not any([tree_name, payload is not None, proc_arrays is not None]):
        raise KeyError("job must include one of: 'tree_name', 'payload', or 'proc_arrays'")

    bins = job.get("bins")
    if bins is not None:
        bins = np.asarray(bins, dtype=float)

    plot_style = job.get("plot_style") or {}
    if job.get("title") is not None:
        plot_style = _deep_merge_dict(plot_style, {"meta": {"title": str(job.get("title"))}})

    return quick_plot(
        session=session,
        tree_name=tree_name,
        observable=observable,
        bins=bins,
        cut_expr=job.get("cut_expr", ""),
        label=job.get("label"),
        subtitle=job.get("subtitle"),
        force_reload=bool(job.get("force_reload", False)),
        import_mode=job.get("import_mode"),
        plot_style=plot_style,
        output_dir=job.get("output_dir"),
        payload=payload,
        proc_arrays=proc_arrays,
        subcategory_name=job.get("subcategory_name") or job.get("sub_name"),
        in_memory_only=bool(job.get("in_memory_only", False)),
    )


def run_plot_jobs(session, jobs, shared_payload=False, payload=None, registry=None, registry_namespace="quick_plot_jobs"):
    """Run many quick-plot jobs.

    Options:
      - payload: explicit payload injected into jobs missing payload/proc_arrays.
      - shared_payload=True: infer a single shared recipe and preload/reuse once.
    """
    norm_jobs = [_coerce_quick_plot_job(j) for j in jobs]

    shared = payload
    if shared is None and shared_payload:
        recipe = _derive_shared_payload_recipe(norm_jobs)
        if recipe is None:
            raise ValueError("shared_payload=True requires compatible jobs (single tree/import_mode/base_cut and defined observables)")
        shared = prepare_quick_plot_payload(
            session,
            tree_name=recipe["tree_name"],
            observables=recipe["observables"],
            cut_exprs=recipe["cut_exprs"],
            base_cut=recipe["base_cut"],
            required_branches=recipe["required_branches"],
            import_mode=recipe["import_mode"],
            registry=registry,
            registry_namespace=registry_namespace,
            force_reload=recipe["force_reload"],
        )

    outputs = []
    for i, job in enumerate(norm_jobs, 1):
        run_job = dict(job)
        if shared is not None and run_job.get("payload") is None and run_job.get("proc_arrays") is None:
            run_job["payload"] = shared
            run_job.setdefault("in_memory_only", True)

        _log(f"Running job {i}/{len(norm_jobs)} :: {run_job.get('observable', 'unknown')} @ {run_job.get('tree_name', 'in_memory')}")
        out = quick_plot_job(session, run_job)
        outputs.append(out)
    return outputs




def build_category_jobs(category_config, observables=None):
    targets = list(observables) if observables is not None else list(OBSERVABLES.keys())
    jobs = []
    for category, cat_cfg in category_config.items():
        tree_name = str(cat_cfg.get("tree", category))
        base_cut = _normalize_cut(cat_cfg.get("cut", ""))
        cat_plot_style = cat_cfg.get("plot_style", {})
        cat_output_dir = cat_cfg.get("output_dir")
        subcats = cat_cfg.get("subcategories", {})
        for sub_name, sub_cfg in subcats.items():
            sub_cut = _normalize_cut(sub_cfg.get("cut", ""))
            full_cut = " && ".join([f"({x})" for x in [base_cut, sub_cut] if x])
            jobs.append({
                "tree_name": tree_name,
                "sub_name": sub_name,
                "title": sub_cfg.get("title", sub_name),
                "subtitle": sub_cfg.get("subtitle", cat_cfg.get("subtitle", "")),
                "cut": full_cut,
                "plot_style": _merge_plot_style(cat_plot_style, sub_cfg.get("plot_style", {})),
                "output_dir": sub_cfg.get("output_dir", cat_output_dir),
                "observables": list(targets),
            })
    return jobs
def _split_top_level(expr, sep):
    expr = str(expr or "").strip()
    if not expr:
        return []
    out = []
    depth = 0
    i = 0
    token = []
    n = len(expr)
    while i < n:
        ch = expr[i]
        if ch == '(':
            depth += 1
            token.append(ch)
            i += 1
            continue
        if ch == ')':
            depth = max(0, depth - 1)
            token.append(ch)
            i += 1
            continue
        if depth == 0 and expr.startswith(sep, i):
            part = ''.join(token).strip()
            if part:
                out.append(part)
            token = []
            i += len(sep)
            continue
        token.append(ch)
        i += 1
    tail = ''.join(token).strip()
    if tail:
        out.append(tail)
    return out


def _strip_outer_parens(expr):
    s = str(expr or "").strip()
    changed = True
    while changed and s.startswith('(') and s.endswith(')'):
        changed = False
        depth = 0
        ok = True
        for i, ch in enumerate(s):
            if ch == '(':
                depth += 1
            elif ch == ')':
                depth -= 1
                if depth == 0 and i != len(s) - 1:
                    ok = False
                    break
            if depth < 0:
                ok = False
                break
        if ok and depth == 0:
            s = s[1:-1].strip()
            changed = True
    return s


def _combine_subcategory_cuts_or(cuts):
    clauses = []
    seen = set()
    for c in cuts or []:
        norm = _normalize_cut(c)
        if not norm:
            continue
        norm = _strip_outer_parens(norm)
        if norm in seen:
            continue
        seen.add(norm)
        clauses.append(norm)

    if not clauses:
        return ""
    if len(clauses) == 1:
        return clauses[0]

    and_terms = []
    for cl in clauses:
        parts = [_strip_outer_parens(x) for x in _split_top_level(cl, '&&')]
        and_terms.append([p for p in parts if p])

    common = []
    if and_terms:
        first = and_terms[0]
        for term in first:
            if all(term in terms for terms in and_terms[1:]):
                common.append(term)

    if common:
        common_set = set(common)
        residual = []
        for terms in and_terms:
            rem = [t for t in terms if t not in common_set]
            if not rem:
                return ' && '.join(f'({x})' for x in common)
            residual.append(' && '.join(f'({x})' for x in rem))
        unique_res = []
        seen_res = set()
        for r in residual:
            rr = _strip_outer_parens(r)
            if rr not in seen_res:
                seen_res.add(rr)
                unique_res.append(rr)
        lhs = ' && '.join(f'({x})' for x in common)
        rhs = ' || '.join(f'({x})' for x in unique_res)
        return f'({lhs}) && ({rhs})'

    return ' || '.join(f'({x})' for x in clauses)


def _apply_cut_to_payload(payload, cut_expr, subcategory_name=None):
    norm_cut = _normalize_cut(cut_expr)
    expr = _cut_to_pandas(norm_cut)
    out = {}
    reports = []

    base_report_by_proc = {r["proc"]: r for r in payload.get("reports", [])}
    for proc, arrs in sorted(payload.get("arrays", {}).items()):
        total = len(next(iter(arrs.values()))) if arrs else 0
        filtered = arrs
        if expr and arrs:
            filtered = _filter_arrays_with_cut(arrs, norm_cut)

        if filtered:
            out[proc] = filtered

        rep0 = base_report_by_proc.get(proc, {})
        reports.append({
            "proc": proc,
            "process_key": rep0.get("process_key", f"{payload.get('tree_name','?')}:{proc}"),
            "n_files": int(rep0.get("n_files", 0)),
            "entries_total": int(total),
            "entries_after_cut": int(len(next(iter(filtered.values()))) if filtered else 0),
            "loaded_branches": len(filtered),
            "branch_names": sorted(filtered.keys()),
            "tree_paths": rep0.get("tree_paths", []),
        })

    return {
        "arrays": out,
        "reports": reports,
        "tree_name": payload.get("tree_name"),
        "cut": norm_cut,
        "observables": payload.get("observables", []),
        "subcategory_name": subcategory_name,
    }


def run_category_config(session, category_config, observables=None, force_reload=False, import_mode=None):
    jobs = build_category_jobs(category_config, observables=observables)
    produced = []
    force = force_reload or _cfg("cache", "force_reload_array_cache", default=False)

    jobs_by_tree = {}
    for job in jobs:
        jobs_by_tree.setdefault(job["tree_name"], []).append(job)

    strategy = str(_cfg("runtime", "category_loading_strategy", default="preload_tree_uncut")).lower().strip()
    branch_strategy = str(_cfg("runtime", "preload_branch_strategy", default="union_all")).lower().strip()
    chunk_size = max(1, int(_cfg("runtime", "preload_observable_chunk_size", default=2)))

    for tree_name, tree_jobs in jobs_by_tree.items():
        all_obs = sorted(set(o for j in tree_jobs for o in j.get("observables", [])))

        if branch_strategy == "per_observable_chunk":
            chunks = [all_obs[i:i+chunk_size] for i in range(0, len(all_obs), chunk_size)]
        else:
            chunks = [all_obs]

        preload_cut = ""
        if strategy == "preload_tree_or_subcategory_cut":
            preload_cut = _combine_subcategory_cuts_or([j.get("cut", "") for j in tree_jobs])

        for obs_chunk in chunks:
            required_branches = set()
            for j in tree_jobs:
                required_branches |= set(_plan_required_branches(obs_chunk, cut_expr=j.get("cut", "")))

            preload_desc = _cut_preview(preload_cut) if preload_cut else "<none>"
            _log(
                f"Preloading tree chunk tree={tree_name} jobs={len(tree_jobs)} chunk_obs={len(obs_chunk)} branches={len(required_branches)} preload_cut={preload_desc}"
            )

            base_payload = session.load_arrays(
                tree_name=tree_name,
                cut_expr=preload_cut,
                observables=obs_chunk,
                required_branches=sorted(required_branches),
                force=force,
                import_mode=import_mode,
            )

            for job in tree_jobs:
                job_obs = [o for o in job["observables"] if o in set(obs_chunk)]
                if not job_obs:
                    continue
                payload = _apply_cut_to_payload(base_payload, job["cut"])
                if _cfg("logging", "emit_process_reports", default=True):
                    cut_preview = _cut_preview(job["cut"])
                    for rep in payload["reports"]:
                        path_info = ",".join(rep.get("tree_paths", [])) if rep.get("tree_paths") else "?"
                        branch_info = ",".join(rep.get("branch_names", [])[:8])
                        if len(rep.get("branch_names", [])) > 8:
                            branch_info += ",..."
                        _log(
                            f"{job['sub_name']} :: proc={rep['proc']} files={rep['n_files']} tree={path_info} "
                            f"events={rep['entries_after_cut']}/{rep['entries_total']} branches={rep['loaded_branches']} "
                            f"cut={cut_preview} loaded=[{branch_info}]"
                        )

                for obs in job_obs:
                    if obs not in OBSERVABLES:
                        _log(_style_get(PLOT_STYLE_DEFAULTS, "text", "unknown_observable_log", default="Skipping unknown observable '{observable}'").format(observable=obs), level="warn")
                        continue
                    cfg = OBSERVABLES[obs]
                    data_counts, mc_h, mc_v = _stack_from_arrays(session, payload["arrays"], obs, np.asarray(cfg["bins"], dtype=float))
                    out = _draw_datamc(
                        session,
                        job["sub_name"],
                        obs,
                        cfg,
                        data_counts,
                        mc_h,
                        mc_v,
                        plot_label=job["title"],
                        subtitle=job["subtitle"],
                        cut_text=job["cut"],
                        plot_style=job["plot_style"],
                        output_dir=job["output_dir"],
                    )
                    if out:
                        produced.append(out)
    return produced

# %%
# =========================
# SESSION BOOTSTRAP
# =========================
_validate_analysis_config(ANALYSIS_CONFIG)
_validate_user_payloads(OBSERVABLES, CATEGORY_CONFIG)
_log(f"Config snapshot: {_config_snapshot()}")

SESSION = DataMCSession()
SESSION.refresh_inputs(force=_cfg("cache", "force_reload_inputs", default=False))

_log(f"Discovered categories (first 20): {SESSION.list_categories()[:20]}")

# Quick usability helpers for interactive work:
# 1) quick_plot(SESSION, tree_name="zz_cr_ALL", observable="Z0_mass", cut_expr="Z0_isEE")
# 2) quick_plot(..., bins=np.linspace(0,300,61))  # ad-hoc variable with custom binning
# 3) payload = SESSION.load_arrays("zz_cr_ALL", cut_expr="Z0_isEE", observables=["Z0_mass", "lZ1_pt"], import_mode="all")

# Quick-start decision guide:
# - One plot quickly -> quick_plot(...)
# - Many ad-hoc jobs -> run_plot_jobs(...)
# - Full category batch -> run_category_config(...) or default execution cell
# Out:
# [2026-03-27 20:59:57] [ INFO] Config snapshot: {'mode': 'merged', 'input': '/uscmst1b_scratch/lpc1/3DayLifetime/mwadud/mkShapesRDF_rootfiles/ZH_4lMET_ZZCR_2024v15_fnal/rootFile/mkShapes__ZH_4lMET_ZZCR_2024v15_fnal__ALL.root', 'output': 'plots_zzcr_datamc', 'branch_mode': 'needed', 'reuse_uncut': True, 'unknown_obs_policy': 'warn', 'seed_n': 5, 'auto_seed_all_obs': False, 'parallel': True, 'workers': 48, 'cache_arrays': True, 'category_loading_strategy': 'preload_tree_uncut'}
# [2026-03-27 20:59:57] [ INFO] Loaded inputs: mode=merged, n_files=1
# [2026-03-27 20:59:57] [ INFO] Discovered categories (first 20): ['zz_cr_ALL']

# %%
# =========================
# DEFAULT EXECUTION (batch over CATEGORY_CONFIG)
# =========================
default_observables = _cfg("execution", "default_observables")
if default_observables is None:
    default_observables = list(OBSERVABLES.keys())

produced_plots = []
if _cfg("execution", "run_default_batch_cell", default=True):
    produced_plots = run_category_config(
        SESSION,
        CATEGORY_CONFIG,
        observables=default_observables,
        force_reload=_cfg("cache", "force_reload_array_cache", default=False),
        import_mode=_cfg("runtime", "array_branch_import_mode", default="needed"),
    )

_log(f"Done. Produced {len(produced_plots)} plots.")
# Out:
# [2026-03-27 20:59:59] [ INFO] Preloading tree once tree=zz_cr_ALL jobs=2 branches=11 preload_cut=<none>
# [2026-03-27 20:59:59] [ INFO] Reusing discovered inputs (1 files)
# [2026-03-27 20:59:59] [ INFO] load_arrays tree=zz_cr_ALL cut=<none>
# [2026-03-27 21:00:13] [PROGRESS] load: 1/1 (100.0%) proc=DATA tree=trees/zz_cr_ALL/DATA/Events file=mkShapes__ZH_4lMET_ZZCR_2024v15_fnal__ALL.root
# [2026-03-27 21:00:13] [PROGRESS] load: 1/1 (100.0%) proc=DYto2E-2Jets_MLL-10to50 tree=trees/zz_cr_ALL/DYto2E-2Jets_MLL-10to50/Events file=mkShapes__ZH_4lMET_ZZCR_2024v15_fnal__ALL.root
# [2026-03-27 21:00:20] [PROGRESS] load: 1/1 (100.0%) proc=DYto2E-2Jets_MLL-50 tree=trees/zz_cr_ALL/DYto2E-2Jets_MLL-50/Events file=mkShapes__ZH_4lMET_ZZCR_2024v15_fnal__ALL.root
# [2026-03-27 21:00:21] [PROGRESS] load: 1/1 (100.0%) proc=DYto2Mu-2Jets_MLL-10to50 tree=trees/zz_cr_ALL/DYto2Mu-2Jets_MLL-10to50/Events file=mkShapes__ZH_4lMET_ZZCR_2024v15_fnal__ALL.root
# ...

# %%
# =========================
# JOB-STYLE QUICK-PLOT EXAMPLES
# =========================
# These are templates; set RUN_JOB_EXAMPLES = True to execute.
# Goal: preload once, then derive cut-defined sub-categories fully in memory.

RUN_JOB_EXAMPLES = False

if "_JOB_PAYLOAD_REGISTRY" not in globals() or not isinstance(_JOB_PAYLOAD_REGISTRY, dict):
    _JOB_PAYLOAD_REGISTRY = {}

JOB_EXAMPLES = [
    {
        "tree_name": "zz_cr_ALL",
        "observable": "Z0_mass",
        "cut_expr": "Z0_isEE && bVeto && (PuppiMET_pt < 40.)",
        "subcategory_name": "zz_cr_ALL__ee_metlt40",
        "label": "Z→ee",
        "title": "ZZ CR",
        "subtitle": "In-memory cut from shared payload",
        "output_dir": "plots/jobs_in_memory",
    },
    {
        "tree_name": "zz_cr_ALL",
        "observable": "lZ1_pt",
        "cut_expr": "Z0_isMM && bVeto && (PuppiMET_pt < 40.)",
        "subcategory_name": "zz_cr_ALL__mm_metlt40",
        "label": "Z→μμ",
        "title": "ZZ CR custom",
        "subtitle": "In-memory custom style",
        "output_dir": "plots/jobs_in_memory",
        "plot_style": {
            "scales": {"logy": True},
            "legend": {"ncol": 1},
            "cut_block": {"text_width": 44},
            "layout": {"width_ratios": [7.1, 2.9]},
            "yaxis_scientific": {"manual_multiplier_min_abs_power": 3},
        },
    },
    {
        "tree_name": "zz_cr_ALL",
        "observable": "PuppiMET_pt",
        "bins": list(np.linspace(0, 200, 41)),
        "cut_expr": "Z0_isEE && bVeto",
        "subcategory_name": "zz_cr_ALL__ee_bveto",
        "label": "MET",
        "title": "Ad-hoc variable",
        "subtitle": "Custom bins from memory",
        "output_dir": "plots/jobs_in_memory",
        "plot_style": {
            "axes": {"ratio_ylim_default": (0.4, 1.8)},
        },
    },
]

if RUN_JOB_EXAMPLES:
    run_plot_jobs(
        SESSION,
        JOB_EXAMPLES,
        shared_payload=True,
        registry=_JOB_PAYLOAD_REGISTRY,
        registry_namespace="job_examples",
    )

# Optional explicit-preload pattern (equivalent behavior):
# payload = prepare_quick_plot_payload(
#     SESSION,
#     tree_name="zz_cr_ALL",
#     observables=sorted(set(j["observable"] for j in JOB_EXAMPLES)),
#     cut_exprs=[j.get("cut_expr", "") for j in JOB_EXAMPLES],
#     registry=_JOB_PAYLOAD_REGISTRY,
#     registry_namespace="job_examples",
# )
# run_plot_jobs(SESSION, JOB_EXAMPLES, payload=payload)

# %%
# =========================
# OPTIONAL SMOKE TESTS
# =========================
RUN_SMOKE_TESTS = False
if RUN_SMOKE_TESTS:
    assert _normalize_cut('a & b | c') == 'a && b || c'
    assert _extract_cut_branches('Z0_isEE && (PuppiMET_pt < 40.)') == {'Z0_isEE', 'PuppiMET_pt'}
    assert _combine_subcategory_cuts_or(['A && B', 'A && C']) == '((A)) && (((B)) || ((C)))' or _combine_subcategory_cuts_or(['A && B', 'A && C'])
    _log('Smoke tests passed', level='info')
