# %%
import glob
import os
import re

import numpy as np
import pandas as pd
import uproot
import ROOT
from ROOT import RDataFrame, TFile
import matplotlib.pyplot as plt
import mplhep as hep
from hist.intervals import poisson_interval
from matplotlib.legend_handler import HandlerTuple

hep.style.use("CMS")

# %%
# INPUT_MODE options:
#   - "auto": infer from INPUT_PATH (file => merged mode, dir/glob => unmerged mode)
#   - "merged": use a single ROOT file containing all processes
#   - "unmerged": use many per-process/per-chunk ROOT files
INPUT_MODE = "unmerged"

# For merged mode: set to the merged ROOT file.
# For unmerged mode: set to a directory OR a glob pattern matching chunked ROOT files.
INPUT_PATH = "/eos/cms/store/user/mwadud/mkShapesRDF_rootfiles/ZH_4lMET_ZZCR_2024v15/rootFile/"
# INPUT_PATH = "/afs/cern.ch/work/m/mwadud/private/2026_ZH_4l2nu/mkShapesRDF/PlotsConfigurationsRun3/ZH_4lMET/ZZ_CR/rootFiles/ZH_4lMET/rootFiles__ZH_4lMET_ZZCR_2024v15/mkShapes__ZH_4lMET_ZZCR_2024v15.root"  # merged mode example
UNMERGED_GLOB = "*.root"

# Optional user overrides for unmerged files (most specific wins after merge).
# Supports either global per-process entries under "*", or per-tree entries.
# Values can be a glob string or list of globs; placeholders: {base}, {tree}, {proc}.
UNMERGED_PROCESS_PATHS = {}

# Optional filename fallback controls (used only if process/category cannot be inferred from ROOT structure).
# If FILENAME_PROCESS_REGEX is None, fallback extracts from the last "__" segment in filename.
# Example: mkShapes__TAG__CAT__DYto2Tau-2Jets_42.root -> DYto2Tau-2Jets
FILENAME_PROCESS_REGEX = None
FILENAME_PROCESS_STRIP_CHUNK_INDEX = True

OUTPUT_DIR = "plots_zzcr_datamc"
os.makedirs(OUTPUT_DIR, exist_ok=True)
CATEGORIES = None
DATA_PROCESSES = {"DATA"}
MC_WEIGHT_BRANCH = "weight"
PLOT_TITLE = "ZZ CR"
LUMI_LABEL = "26.49"
PLOT_LOGY = False
SAVE_DPI = 180
SHOW_PLOTS = False

PLOT_STYLE = {
    "figure": {
        "size": (10, 7),
        "gridspec": {"width_ratios": [8, 1], "height_ratios": [3, 1], "wspace": 0.05, "hspace": 0.04},
    },
    "axes": {
        "grid_alpha": 0.25,
        "ylabel": "Events",
        "ratio_ylabel": "Data/MC",
    },
    "stack": {
        "alpha": 0.8,
        "linewidth": 0,
    },
    "mc_total": {
        "label": "Total MC",
        "line_color": "red",
        "line_width": 1.5,
        "ratio_line_width": 1.0,
        "band_alpha": 0.12,
    },
    "data": {
        "label": "Data",
        "color": "black",
        "marker": "o",
        "marker_size": 4,
        "elinewidth": 1.0,
        "capsize": 0,
    },
    "legend": {
        "loc": "upper left",
        "fontsize": "xx-small",
        "frameon": False,
        "ncol": 2,
        "handlelength": 1.5,
    },
    "title": {
        "fontsize": "x-small",
        "x": 0.02,
        "y": 0.98,
        "ha": "left",
        "va": "top",
    },
}

# Runtime/iteration knobs for faster notebook development.
# Set FORCE_RELOAD_INPUTS=True only when input files/index settings change.
FORCE_RELOAD_INPUTS = False
# Optional filters to focus plotting while iterating on CATEGORY_CONFIG.
PLOT_ONLY_SUBCATEGORIES = None  # e.g. {"zz_cr_ZEE"}
PROCESS_ALLOWLIST = None        # e.g. {"DATA", "ZZ", "WZ"}
PROCESS_BLOCKLIST = set()       # e.g. {"Fake"}

# Performance mode:
#   - "hist": fastest & low-memory (does NOT keep event arrays in memory)
#   - "arrays": keeps selected branches in memory before plotting
DATA_LOADING_MODE = "arrays"
# In arrays mode only:
#   - True: load all active observables once per category (fast, high RAM)
#   - False: load one observable at a time (slow, low RAM)
ARRAYS_LOAD_ALL_OBSERVABLES = True
# Keep per-subcategory arrays in notebook memory across repeated cell runs.
# This is what makes plotting iterations actually fast after first load.
CACHE_ARRAYS_IN_MEMORY = True
# Force-refresh of in-memory arrays cache (does not affect file discovery cache).
FORCE_RELOAD_ARRAY_CACHE = False
## I/O backend: "auto" (ROOT->uproot->pandas), "root", "uproot", or "pandas"
IO_BACKEND = "auto"
# Unmerged file index strategy: "fast_filename" (no ROOT open), or "probe_root"
UNMERGED_INDEX_STRATEGY = "fast_filename"

# Enable ROOT multithreading. Set N_THREADS to 0 to let ROOT pick defaults.
ENABLE_IMPLICIT_MT = True
N_THREADS = 0
if ENABLE_IMPLICIT_MT:
    ROOT.EnableImplicitMT(N_THREADS) if N_THREADS > 0 else ROOT.EnableImplicitMT()

# Stacking behavior:
#   - True: group samples according to SAMPLE_STYLE["samples"][sample]["group"]
#   - False: keep each sample separate in the stack
STACK_BY_GROUP = True

LOGGING = {
    "enabled": True,
    "hacker_style": True,
    "show_file_details": True,
    "max_file_lines_per_process": 5,
    "show_branch_lists": True,
    "progress_enabled": True,
    "progress_every": 25,
}

CATEGORY_CONFIG = {
    "zz_cr_ALL": {
       "title": r"$ZZ\,\mathrm{CR}$", 
               "subcategories": {
            "zz_cr_ZEE": {
                "title": r"$ZZ\,\mathrm{CR}:\ Z\to ee$",
                "cut": "Z_isEE & bVeto & (PuppiMET_pt < 40.) && (Z0_mass > 20.)",
            },
            "zz_cr_ZMM": {
                "title": r"$ZZ\,\mathrm{CR}:\ Z\to \mu\mu$ ",
                "cut": "Z_isMM & bVeto & (PuppiMET_pt < 40.) && (Z0_mass > 20.)",
            },
        },
    }
}

# %%
OBSERVABLES = {
    # "nCleanJet": {"bins": np.arange(-0.5, 8.5, 1.0), "xlabel": r"$N_{\mathrm{jets}}^{\mathrm{clean}}$", "ratio_ylim": (0.2, 2.2)},

    # "CleanJet_pt_0":  {"bins": np.linspace(0, 300, 41), "xlabel": r"$p_{\mathrm{T}}^{j_{1}}$ [GeV]", "ratio_ylim": (0.4, 1.8)},
    # "CleanJet_eta_0": {"bins": np.linspace(-5.0, 5.0, 41), "xlabel": r"$\eta^{j_{1}}$", "ratio_ylim": (0.4, 1.8)},
    # "CleanJet_phi_0": {"bins": np.linspace(-3.2, 3.2, 33), "xlabel": r"$\phi^{j_{1}}$ [rad]", "ratio_ylim": (0.4, 1.8)},

    # "CleanJet_pt_1":  {"bins": np.linspace(0, 300, 41), "xlabel": r"$p_{\mathrm{T}}^{j_{2}}$ [GeV]", "ratio_ylim": (0.4, 1.8)},
    # "CleanJet_eta_1": {"bins": np.linspace(-5.0, 5.0, 41), "xlabel": r"$\eta^{j_{2}}$", "ratio_ylim": (0.4, 1.8)},
    # "CleanJet_phi_1": {"bins": np.linspace(-3.2, 3.2, 33), "xlabel": r"$\phi^{j_{2}}$ [rad]", "ratio_ylim": (0.4, 1.8)},

    "Z0_mass": {"bins": np.linspace(60, 120, 31), "xlabel": r"$m_{Z}$ [GeV]", "ratio_ylim": (0.5, 1.5)},
    # "Z0_pt":   {"bins": np.linspace(0, 250, 41),  "xlabel": r"$p_{\mathrm{T}}^{Z}$ [GeV]", "ratio_ylim": (0.4, 1.8)},
    # "Z0_phi":  {"bins": np.linspace(-3.2, 3.2, 33), "xlabel": r"$\phi_{Z}$ [rad]", "ratio_ylim": (0.4, 1.8)},

    # "X_mass": {"bins": np.linspace(0, 220, 45), "xlabel": r"$m_{X}$ [GeV]", "ratio_ylim": (0.4, 1.8)},
    # "X_pt":   {"bins": np.linspace(0, 250, 41), "xlabel": r"$p_{\mathrm{T}}^{X}$ [GeV]", "ratio_ylim": (0.4, 1.8)},
    # "X_phi":  {"bins": np.linspace(-3.2, 3.2, 33), "xlabel": r"$\phi_{X}$ [rad]", "ratio_ylim": (0.4, 1.8)},

    # "m4l":   {"bins": np.linspace(0, 800, 41), "xlabel": r"$m_{4\ell}$ [GeV]", "ratio_ylim": (0.4, 1.8)},
    # "pT4l":  {"bins": np.linspace(0, 250, 41), "xlabel": r"$p_{\mathrm{T}}^{4\ell}$ [GeV]", "ratio_ylim": (0.4, 1.8)},
    # "phi4l": {"bins": np.linspace(-3.2, 3.2, 33), "xlabel": r"$\phi_{4\ell}$ [rad]", "ratio_ylim": (0.4, 1.8)},

    # # MET
    # "PuppiMET_pt":  {"bins": np.linspace(0, 180, 37), "xlabel": r"$p_{\mathrm{T}}^{\mathrm{miss}}$ [GeV]", "ratio_ylim": (0.4, 1.8)},
    # "PuppiMET_phi": {"bins": np.linspace(-3.2, 3.2, 33), "xlabel": r"$\phi^{\mathrm{miss}}$ [rad]", "ratio_ylim": (0.4, 1.8)},
    # "PuppiMET_significance": {"bins": np.linspace(0, 30, 31), "xlabel": r"$S(\vec{p}_{\mathrm{T}}^{\,\mathrm{miss}})$", "ratio_ylim": (0.4, 1.8)},
    # "PuppiMET_sumEt": {"bins": np.linspace(0, 2000, 41), "xlabel": r"$\sum E_{\mathrm{T}}$ [GeV]", "ratio_ylim": (0.4, 1.8)},

    # "HT": {"bins": np.linspace(0, 400, 41), "xlabel": r"$H_{\mathrm{T}}$ [GeV]", "ratio_ylim": (0.4, 1.8)},

    # # Delta-phis: use \vec{p}_T^miss instead of "MET" text
    # "dPhi_MET_Z":      {"bins": np.linspace(0, 3.2, 33), "xlabel": r"$\Delta\phi(\vec{p}_{\mathrm{T}}^{\,\mathrm{miss}},\, Z)$ [rad]", "ratio_ylim": (0.4, 1.8)},
    # "dPhi_MET_X":      {"bins": np.linspace(0, 3.2, 33), "xlabel": r"$\Delta\phi(\vec{p}_{\mathrm{T}}^{\,\mathrm{miss}},\, X)$ [rad]", "ratio_ylim": (0.4, 1.8)},
    # "dPhi_MET_lZ1":    {"bins": np.linspace(0, 3.2, 33), "xlabel": r"$\Delta\phi(\vec{p}_{\mathrm{T}}^{\,\mathrm{miss}},\, \ell_{Z1})$ [rad]", "ratio_ylim": (0.4, 1.8)},
    # "dPhi_MET_lZ2":    {"bins": np.linspace(0, 3.2, 33), "xlabel": r"$\Delta\phi(\vec{p}_{\mathrm{T}}^{\,\mathrm{miss}},\, \ell_{Z2})$ [rad]", "ratio_ylim": (0.4, 1.8)},
    # "dPhi_MET_lX1":    {"bins": np.linspace(0, 3.2, 33), "xlabel": r"$\Delta\phi(\vec{p}_{\mathrm{T}}^{\,\mathrm{miss}},\, \ell_{X1})$ [rad]", "ratio_ylim": (0.4, 1.8)},
    # "dPhi_MET_lX2":    {"bins": np.linspace(0, 3.2, 33), "xlabel": r"$\Delta\phi(\vec{p}_{\mathrm{T}}^{\,\mathrm{miss}},\, \ell_{X2})$ [rad]", "ratio_ylim": (0.4, 1.8)},
    # "dPhi_MET_ZplusX": {"bins": np.linspace(0, 3.2, 33), "xlabel": r"$\Delta\phi(\vec{p}_{\mathrm{T}}^{\,\mathrm{miss}},\, Z{+}X)$ [rad]", "ratio_ylim": (0.4, 1.8)},

    # "dPhi_lZ1_lZ2": {"bins": np.linspace(0, 3.2, 33), "xlabel": r"$\Delta\phi(\ell_{Z1},\, \ell_{Z2})$ [rad]", "ratio_ylim": (0.4, 1.8)},
    # "dPhi_lZ1_lX1": {"bins": np.linspace(0, 3.2, 33), "xlabel": r"$\Delta\phi(\ell_{Z1},\, \ell_{X1})$ [rad]", "ratio_ylim": (0.4, 1.8)},
    # "dPhi_lZ1_lX2": {"bins": np.linspace(0, 3.2, 33), "xlabel": r"$\Delta\phi(\ell_{Z1},\, \ell_{X2})$ [rad]", "ratio_ylim": (0.4, 1.8)},
    # "dPhi_lZ2_lX1": {"bins": np.linspace(0, 3.2, 33), "xlabel": r"$\Delta\phi(\ell_{Z2},\, \ell_{X1})$ [rad]", "ratio_ylim": (0.4, 1.8)},
    # "dPhi_lZ2_lX2": {"bins": np.linspace(0, 3.2, 33), "xlabel": r"$\Delta\phi(\ell_{Z2},\, \ell_{X2})$ [rad]", "ratio_ylim": (0.4, 1.8)},
    # "dPhi_lX1_lX2": {"bins": np.linspace(0, 3.2, 33), "xlabel": r"$\Delta\phi(\ell_{X1},\, \ell_{X2})$ [rad]", "ratio_ylim": (0.4, 1.8)},

    # # Recoil
    # "recoil_ux":    {"bins": np.linspace(-200, 200, 41), "xlabel": r"$u_{x}^{\mathrm{recoil}}$ [GeV]", "ratio_ylim": (0.4, 1.8)},
    # "recoil_uy":    {"bins": np.linspace(-200, 200, 41), "xlabel": r"$u_{y}^{\mathrm{recoil}}$ [GeV]", "ratio_ylim": (0.4, 1.8)},
    # "recoil_ut":    {"bins": np.linspace(0, 250, 41),    "xlabel": r"$u_{\mathrm{T}}^{\mathrm{recoil}}$ [GeV]", "ratio_ylim": (0.4, 1.8)},
    # "recoil_upar":  {"bins": np.linspace(-200, 200, 41), "xlabel": r"$u_{\parallel}^{\mathrm{recoil}}$ [GeV]", "ratio_ylim": (0.4, 1.8)},
    # "recoil_uperp": {"bins": np.linspace(-200, 200, 41), "xlabel": r"$u_{\perp}^{\mathrm{recoil}}$ [GeV]", "ratio_ylim": (0.4, 1.8)},

    # "sumLeptonCharge": {"bins": np.arange(-4.5, 5.5, 1.0), "xlabel": r"$\sum q_{\ell}$", "ratio_ylim": (0.5, 1.5)},

    # # Boolean-ish flags: make them read as category labels
    # "Z0_isEE": {"bins": np.arange(-0.5, 2.5, 1.0), "xlabel": r"$Z\to ee$", "ratio_ylim": (0.5, 1.5)},
    # "Z0_isMM": {"bins": np.arange(-0.5, 2.5, 1.0), "xlabel": r"$Z\to \mu\mu$", "ratio_ylim": (0.5, 1.5)},
    # "X_isEE":  {"bins": np.arange(-0.5, 2.5, 1.0), "xlabel": r"$X\to ee$", "ratio_ylim": (0.5, 1.5)},
    # "X_isMM":  {"bins": np.arange(-0.5, 2.5, 1.0), "xlabel": r"$X\to \mu\mu$", "ratio_ylim": (0.5, 1.5)},

    # "GenMET_pt":  {"bins": np.linspace(0, 180, 37), "xlabel": r"$p_{\mathrm{T}}^{\mathrm{miss,\,gen}}$ [GeV]", "ratio_ylim": (0.4, 1.8)},
    # "GenMET_phi": {"bins": np.linspace(-3.2, 3.2, 33), "xlabel": r"$\phi^{\mathrm{miss,\,gen}}$ [rad]", "ratio_ylim": (0.4, 1.8)},


    "lZ1_pt":  {"bins": np.linspace(0, 250, 41), "xlabel": r"$p_{\mathrm{T}}^{\ell_{Z1}}$ [GeV]", "ratio_ylim": (0.4, 1.8)},
    "lZ1_eta": {"bins": np.linspace(-2.5, 2.5, 41), "xlabel": r"$\eta^{\ell_{Z1}}$", "ratio_ylim": (0.4, 1.8)},
    # "lZ1_phi": {"bins": np.linspace(-3.2, 3.2, 33), "xlabel": r"$\phi^{\ell_{Z1}}$ [rad]", "ratio_ylim": (0.4, 1.8)},

    "lZ2_pt":  {"bins": np.linspace(0, 250, 41), "xlabel": r"$p_{\mathrm{T}}^{\ell_{Z2}}$ [GeV]", "ratio_ylim": (0.4, 1.8)},
    "lZ2_eta": {"bins": np.linspace(-2.5, 2.5, 41), "xlabel": r"$\eta^{\ell_{Z2}}$", "ratio_ylim": (0.4, 1.8)},
    # "lZ2_phi": {"bins": np.linspace(-3.2, 3.2, 33), "xlabel": r"$\phi^{\ell_{Z2}}$ [rad]", "ratio_ylim": (0.4, 1.8)},

    # "lX1_pt":  {"bins": np.linspace(0, 250, 41), "xlabel": r"$p_{\mathrm{T}}^{\ell_{X1}}$ [GeV]", "ratio_ylim": (0.4, 1.8)},
    # "lX1_eta": {"bins": np.linspace(-2.5, 2.5, 41), "xlabel": r"$\eta^{\ell_{X1}}$", "ratio_ylim": (0.4, 1.8)},
    # "lX1_phi": {"bins": np.linspace(-3.2, 3.2, 33), "xlabel": r"$\phi^{\ell_{X1}}$ [rad]", "ratio_ylim": (0.4, 1.8)},

    # "lX2_pt":  {"bins": np.linspace(0, 250, 41), "xlabel": r"$p_{\mathrm{T}}^{\ell_{X2}}$ [GeV]", "ratio_ylim": (0.4, 1.8)},
    # "lX2_eta": {"bins": np.linspace(-2.5, 2.5, 41), "xlabel": r"$\eta^{\ell_{X2}}$", "ratio_ylim": (0.4, 1.8)},
    # "lX2_phi": {"bins": np.linspace(-3.2, 3.2, 33), "xlabel": r"$\phi^{\ell_{X2}}$ [rad]", "ratio_ylim": (0.4, 1.8)},

    # "bVeto": {"bins": np.arange(-0.5, 2.5, 1.0), "xlabel": r"$b$-veto", "ratio_ylim": (0.5, 1.5)},
}

BASE_EVENT_BRANCHES = list(OBSERVABLES.keys())

SAMPLE_STYLE = {
    # Optional defaults used when neither a sample nor a group defines a field.
    "defaults": {
        "title": None,
        "color": None,
    },
    "groups": {
        # Groups define shared title/color for grouped samples.
        "DY_EE": {"title": r"$DY:\ Z\to ee$", "color": "#4e79a7"},
        "DY_MM": {"title": r"$DY:\ Z\to \mu\mu$", "color": "#f28e2b"},
        "DY_TT": {"title": r"$DY:\ Z\to \tau\tau$", "color": "#76b7b2"},
    },
    "samples": {
        # If "group" is missing, sample is treated as its own group automatically.
        "DATA": {"title": "Data", "color": "black"},
        "DYto2E-2Jets_MLL-10to50": {"title": "", "group": "DY_EE"},
        "DYto2E-2Jets_MLL-50": {"title": "", "group": "DY_EE"},
        "DYto2Mu-2Jets_MLL-10to50": {"title": "", "group": "DY_MM"},
        "DYto2Mu-2Jets_MLL-50": {"title": "", "group": "DY_MM"},
        "DYto2Tau-2Jets_MLL-10to50": {"title": "", "group": "DY_TT"},
        "DYto2Tau-2Jets_MLL-50": {"title": "", "group": "DY_TT"},
        "ZZ": {"title": r"$ZZ$", "color": "#e15759"},
    },
}

# %%
def _list_dir_children(f, dir_path):
    d = f.Get(dir_path) if dir_path else f
    if not d or not d.InheritsFrom("TDirectory"):
        return []
    keys = d.GetListOfKeys()
    out = []
    for i in range(keys.GetEntries()):
        name = keys.At(i).GetName()
        if name and "/" not in name:
            out.append(name)
    return sorted(set(out))


def _open_root(root_file):
    f = TFile.Open(root_file)
    if not f or f.IsZombie():
        raise OSError(f"Could not open ROOT file: {root_file}")
    return f


def _detect_input_mode(input_path, input_mode="auto"):
    mode = str(input_mode).strip().lower()
    if mode in {"merged", "unmerged"}:
        return mode
    if os.path.isdir(input_path):
        return "unmerged"
    if any(ch in input_path for ch in "*?[]"):
        return "unmerged"
    return "merged"


def discover_input_files(input_path, input_mode="auto", unmerged_glob="*.root"):
    mode = _detect_input_mode(input_path, input_mode=input_mode)
    if mode == "merged":
        if not os.path.isfile(input_path):
            raise FileNotFoundError(f"Merged ROOT file not found: {input_path}")
        return mode, [input_path]

    if os.path.isdir(input_path):
        candidates = sorted(glob.glob(os.path.join(input_path, unmerged_glob)))
    else:
        candidates = sorted(glob.glob(input_path))
    root_files = [f for f in candidates if f.endswith(".root") and os.path.isfile(f)]
    if not root_files:
        raise FileNotFoundError(f"No ROOT files found for unmerged input at: {input_path}")
    return mode, root_files


def _extract_category_process_from_chunk_file(root_file, process_regex=None, strip_chunk_index=True):
    base = os.path.basename(root_file)
    stem = re.sub(r"\.root$", "", base)
    parts = stem.split("__")

    category = parts[-2] if len(parts) >= 2 else "*"
    payload = parts[-1] if parts else stem

    if process_regex:
        m = re.search(process_regex, base)
        if m:
            payload = m.group(1) if m.groups() else m.group(0)

    if strip_chunk_index:
        payload = re.sub(r"_\d+$", "", payload)

    process = payload or None
    category = category or "*"
    return category, process


def list_categories(root_file):
    f = _open_root(root_file)
    try:
        cats = set(_list_dir_children(f, ""))
        cats |= set(_list_dir_children(f, "trees"))
        cats.discard("trees")
        return sorted(cats)
    finally:
        f.Close()


def list_processes(root_file, tree_name):
    f = _open_root(root_file)
    try:
        procs = set(_list_dir_children(f, tree_name))
        procs |= set(_list_dir_children(f, f"trees/{tree_name}"))
        return sorted(p for p in procs if p != "Events")
    finally:
        f.Close()


def _probe_tree(root_file, tree_path, io_backend="auto"):
    try:
        rdf = RDataFrame(tree_path, root_file)
        nent = int(rdf.Count().GetValue())
    except Exception:
        nent = -1
        rdf = None

    if rdf is not None:
        cols = set(map(str, rdf.GetColumnNames()))
        for b in ("Z0_mass", "m4l", "weight"):
            if b in cols:
                try:
                    rdf.Range(1).AsNumpy([b])
                    return nent, True, f"probe:root:{b}:ok"
                except Exception as e:
                    root_note = f"probe:root:{b}:{type(e).__name__}"
                    break
        else:
            return nent, True, "probe:root:no_probe_branch"
    else:
        root_note = "probe:root:count:fail"

    # Fallback probes: if ROOT materialization is problematic, test tabular backends.
    if io_backend in {"auto", "uproot", "pandas"}:
        try:
            tree = uproot.open(f"{root_file}:{tree_path}")
            n_up = int(tree.num_entries)
            keys = set(map(str, tree.keys()))
            probe_branch = next((b for b in ("Z0_mass", "m4l", "weight") if b in keys), None)
            if probe_branch is not None:
                _ = tree.arrays([probe_branch], library="np")
            return n_up if nent < 0 else nent, True, "probe:uproot:ok"
        except Exception as ex:
            return nent, False, f"{root_note}|probe:uproot:{type(ex).__name__}"

    return nent, False, root_note


def _tree_exists(f, path):
    obj = f.Get(path)
    return bool(obj) and obj.InheritsFrom("TTree")


def resolve_tree(f, root_file, tree_name, proc, io_backend="auto"):
    candidates = [
        f"{tree_name}/{proc}/Events",
        f"/{tree_name}/{proc}/Events",
        f"trees/{tree_name}/{proc}/Events",
        f"/trees/{tree_name}/{proc}/Events",
    ]
    diag, ranked, seen = [], [], set()
    for path in candidates:
        if path in seen:
            continue
        seen.add(path)
        if not _tree_exists(f, path):
            diag.append({"path": path, "exists": False, "entries": -1, "probe_ok": False, "note": "missing"})
            continue
        nent, probe_ok, note = _probe_tree(root_file, path, io_backend=io_backend)
        diag.append({"path": path, "exists": True, "entries": nent, "probe_ok": probe_ok, "note": note})
        ranked.append((1 if probe_ok else 0, nent, path))
    if not ranked:
        return None, diag
    ranked.sort(reverse=True)
    return ranked[0][2], diag


def build_unmerged_file_index(root_files, show_progress=False, strategy="probe_root"):
    index = {}
    fallback_index = {}
    total_files = len(root_files)

    if strategy == "fast_filename":
        for i_file, rf in enumerate(root_files, 1):
            fsize_mb = os.path.getsize(rf) / (1024.0 * 1024.0) if os.path.exists(rf) else -1.0
            guessed_cat, guessed_proc = _extract_category_process_from_chunk_file(
                rf,
                process_regex=FILENAME_PROCESS_REGEX,
                strip_chunk_index=FILENAME_PROCESS_STRIP_CHUNK_INDEX,
            )
            if guessed_proc:
                tree_key = guessed_cat if guessed_cat and guessed_cat != "ALL" else "*"
                index.setdefault(tree_key, {}).setdefault(guessed_proc, []).append(rf)
                index.setdefault("*", {}).setdefault(guessed_proc, []).append(rf)
            if show_progress:
                _progress_update("index", i_file, total_files, rf, extra=f"size={fsize_mb:.1f}MB mode=fast")

        for tree_name in list(index):
            for proc in list(index[tree_name]):
                index[tree_name][proc] = sorted(set(index[tree_name][proc]))
        return index
    for i_file, rf in enumerate(root_files, 1):
        fsize_mb = os.path.getsize(rf) / (1024.0 * 1024.0) if os.path.exists(rf) else -1.0
        f = _open_root(rf)
        try:
            cats = set(_list_dir_children(f, "")) | set(_list_dir_children(f, "trees"))
            cats.discard("trees")
            for tree_name in sorted(cats):
                procs = set(_list_dir_children(f, tree_name)) | set(_list_dir_children(f, f"trees/{tree_name}"))
                procs = [p for p in procs if p != "Events"]
                for proc in sorted(procs):
                    tree_path, _ = resolve_tree(f, rf, tree_name, proc, io_backend=IO_BACKEND)
                    if tree_path is None:
                        continue
                    index.setdefault(tree_name, {}).setdefault(proc, []).append(rf)
        finally:
            f.Close()

        if show_progress:
            ncat = len(cats) if "cats" in locals() else 0
            _progress_update("index", i_file, total_files, rf, extra=f"size={fsize_mb:.1f}MB cats={ncat}")

        guessed_cat, guessed_proc = _extract_category_process_from_chunk_file(
            rf,
            process_regex=FILENAME_PROCESS_REGEX,
            strip_chunk_index=FILENAME_PROCESS_STRIP_CHUNK_INDEX,
        )
        if guessed_proc:
            fallback_index.setdefault(guessed_cat, {}).setdefault(guessed_proc, []).append(rf)

    # Only use filename fallback where ROOT-structure discovery did not already populate entries.
    for tree_name, proc_map in fallback_index.items():
        for proc, files in proc_map.items():
            index.setdefault(tree_name, {}).setdefault(proc, []).extend(files)

    for tree_name in list(index):
        for proc in list(index[tree_name]):
            index[tree_name][proc] = sorted(set(index[tree_name][proc]))
    return index



def _resolve_glob_pattern(pattern, base_dir, tree_name, proc):
    pat = str(pattern).format(base=base_dir, tree=tree_name, proc=proc)
    return sorted(f for f in glob.glob(pat) if f.endswith(".root") and os.path.isfile(f))


def build_user_file_index(unmerged_process_paths, base_dir):
    index = {}
    spec = unmerged_process_paths or {}
    for tree_name, proc_map in spec.items():
        if not isinstance(proc_map, dict):
            continue
        tname = str(tree_name)
        for proc, patterns in proc_map.items():
            plist = patterns if isinstance(patterns, (list, tuple)) else [patterns]
            files = []
            for pat in plist:
                files.extend(_resolve_glob_pattern(pat, base_dir=base_dir, tree_name=tname, proc=str(proc)))
            if files:
                index.setdefault(tname, {}).setdefault(str(proc), []).extend(files)

    for tname in list(index):
        for proc in list(index[tname]):
            index[tname][proc] = sorted(set(index[tname][proc]))
    return index


def merge_unmerged_file_indices(auto_index, user_index):
    merged = {}
    for src in (auto_index or {}, user_index or {}):
        for tree_name, proc_map in src.items():
            merged.setdefault(tree_name, {})
            for proc, files in proc_map.items():
                merged[tree_name].setdefault(proc, [])
                merged[tree_name][proc].extend(files)

    for tree_name in list(merged):
        for proc in list(merged[tree_name]):
            merged[tree_name][proc] = sorted(set(merged[tree_name][proc]))
    return merged



def _runtime_signature(input_path, input_mode, unmerged_glob, unmerged_process_paths):
    return (
        str(input_path),
        str(input_mode),
        str(unmerged_glob),
        repr(unmerged_process_paths),
    )


def prepare_runtime_context(input_path, input_mode, unmerged_glob, unmerged_process_paths=None, force_reload=False):
    sig = _runtime_signature(input_path, input_mode, unmerged_glob, unmerged_process_paths or {})
    cache = globals().get("_RUNTIME_CONTEXT_CACHE")
    if cache and cache.get("signature") == sig and not force_reload:
        return cache["context"], True

    resolved_mode, input_files = discover_input_files(input_path, input_mode=input_mode, unmerged_glob=unmerged_glob)
    unmerged_file_index = {}
    user_file_index = {}
    if resolved_mode == "unmerged":
        unmerged_file_index = build_unmerged_file_index(input_files, show_progress=LOGGING.get("progress_enabled", True), strategy=UNMERGED_INDEX_STRATEGY)
        input_base = input_path if os.path.isdir(input_path) else os.path.dirname(input_path)
        user_file_index = build_user_file_index(unmerged_process_paths or {}, base_dir=input_base)
        unmerged_file_index = merge_unmerged_file_indices(unmerged_file_index, user_file_index)

    context = {
        "input_mode": resolved_mode,
        "input_files": input_files,
        "unmerged_file_index": unmerged_file_index,
        "user_file_index": user_file_index,
    }
    globals()["_RUNTIME_CONTEXT_CACHE"] = {"signature": sig, "context": context}
    return context, False


def _arrays_cache_signature(root_files, tree_name, branches, cut_expr, input_mode, weight_branch, io_backend, unmerged_file_index):
    proc_map = {}
    if input_mode == "unmerged":
        idx = unmerged_file_index or {}
        proc_map = dict(idx.get(tree_name) or idx.get("*", {}))
    sig_files = tuple(sorted(str(x) for x in (root_files or [])))
    sig_proc = tuple((p, tuple(sorted(str(f) for f in fs))) for p, fs in sorted(proc_map.items()))
    return (
        tuple(sorted(str(b) for b in branches)),
        _normalized_cut(cut_expr),
        str(tree_name),
        str(input_mode),
        str(weight_branch),
        str(io_backend),
        sig_files,
        sig_proc,
    )


def _get_cached_category_arrays(root_files, tree_name, branches, input_mode, weight_branch="weight", cut_expr="", unmerged_file_index=None, io_backend="auto", enable_cache=True, force_reload=False):
    if not enable_cache:
        return load_category_arrays(
            root_files,
            tree_name=tree_name,
            branches=branches,
            input_mode=input_mode,
            weight_branch=weight_branch,
            cut_expr=cut_expr,
            unmerged_file_index=unmerged_file_index,
            io_backend=io_backend,
        ), False

    key = _arrays_cache_signature(root_files, tree_name, branches, cut_expr, input_mode, weight_branch, io_backend, unmerged_file_index)
    cache = globals().setdefault("_CATEGORY_ARRAYS_CACHE", {})
    if (not force_reload) and key in cache:
        return cache[key], True

    payload = load_category_arrays(
        root_files,
        tree_name=tree_name,
        branches=branches,
        input_mode=input_mode,
        weight_branch=weight_branch,
        cut_expr=cut_expr,
        unmerged_file_index=unmerged_file_index,
        io_backend=io_backend,
    )
    cache[key] = payload
    return payload, False


def filter_process_arrays(proc_arrays, allowlist=None, blocklist=None):
    allow = set(allowlist or [])
    block = set(blocklist or [])
    out = {}
    for proc, arrs in proc_arrays.items():
        if allow and proc not in allow:
            continue
        if proc in block:
            continue
        out[proc] = arrs
    return out


def build_subcategories(category_config, categories=None):
    if categories is None:
        categories = sorted(set(category_config) if category_config else [])
    return get_subcategories(categories, category_config=category_config)


def list_categories_from_inputs(root_files, input_mode, unmerged_file_index=None):
    if not root_files:
        return []
    if input_mode == "unmerged":
        idx = unmerged_file_index or {}
        cats = [c for c in idx.keys() if c != "*"]
        if cats:
            return sorted(cats)
        return []
    return list_categories(root_files[0])


def list_processes_from_inputs(root_files, tree_name, input_mode, unmerged_file_index=None):
    if input_mode == "unmerged":
        idx = unmerged_file_index or {}
        return sorted((idx.get(tree_name) or idx.get("*", {})).keys())
    return list_processes(root_files[0], tree_name)


def diagnose_bad_branch(root_file, tree_path, cut_expr="", max_branches=200, entry_stop=5):
    if io_backend == "uproot":
        return read_tree_arrays_uproot(root_file, tree_path, required_branches, cut_expr=cut_expr)
    if io_backend == "pandas":
        return read_tree_arrays_pandas(root_file, tree_path, required_branches, cut_expr=cut_expr)

    rdf = RDataFrame(tree_path, root_file)
    if cut_expr:
        rdf = rdf.Filter(cut_expr)
    for i, b in enumerate(map(str, rdf.GetColumnNames())):
        if i >= max_branches:
            break
        try:
            rdf.Range(entry_stop).AsNumpy([b])
        except Exception as e:
            return [(b, type(e).__name__, str(e))]
    return []


_CUT_IDENTIFIER_RE = re.compile(r"\b[A-Za-z_][A-Za-z0-9_]*\b")
_CUT_KEYWORDS = {
    "and", "or", "not", "true", "false", "abs", "sqrt", "pow", "min", "max", "int", "float", "double",
}


def _normalized_cut(cut_expr):
    if cut_expr is None:
        return ""
    expr = str(cut_expr).strip()
    if not expr:
        return ""
    # Harmonize Python-style bitwise boolean syntax into C++ boolean operators for RDF.
    expr = re.sub(r"(?<![&])&(?![&])", "&&", expr)
    expr = re.sub(r"(?<![|])\|(?![|])", "||", expr)
    return expr


def _extract_cut_identifiers(cut_expr):
    expr = _normalized_cut(cut_expr)
    if not expr:
        return set()
    tokens = set(_CUT_IDENTIFIER_RE.findall(expr))
    return {t for t in tokens if not t.isdigit() and t.lower() not in _CUT_KEYWORDS}


def combine_cuts(*cuts):
    normalized = [f"({c})" for c in (_normalized_cut(c) for c in cuts) if c]
    return " && ".join(normalized)




def _translate_cut_to_pandas(cut_expr):
    expr = _normalized_cut(cut_expr)
    if not expr:
        return ""
    expr = expr.replace("&&", " and ").replace("||", " or ")
    expr = re.sub(r"(?<![=!<>])!(?!=)", " not ", expr)
    return expr


def read_tree_arrays_uproot(root_file, tree_path, required_branches, cut_expr=""):
    report = {"requested": len(required_branches), "missing": 0, "loaded": 0, "failed": 0, "mode": "uproot", "errors": [], "first_bad_branch": None, "entries_total": 0, "entries_after_cut": 0, "branches_requested": sorted(required_branches), "branches_loaded": []}
    try:
        tree = uproot.open(f"{root_file}:{tree_path}")
        available = set(map(str, tree.keys()))
        wanted = [b for b in required_branches if b in available]
        if not wanted:
            report["missing"] = len(required_branches)
            return {}, report

        arrays = tree.arrays(wanted, library="np")
        if not arrays:
            report["missing"] = len(required_branches)
            return {}, report

        n_total = len(next(iter(arrays.values())))
        report["entries_total"] = int(n_total)

        if cut_expr:
            expr = _translate_cut_to_pandas(cut_expr)
            df = pd.DataFrame({k: np.asarray(v) for k, v in arrays.items()})
            mask = df.eval(expr, engine="python")
            df = df[mask]
            out = {k: df[k].to_numpy() for k in wanted if k in df.columns}
            report["entries_after_cut"] = int(len(df))
        else:
            out = {k: np.asarray(v) for k, v in arrays.items()}
            report["entries_after_cut"] = report["entries_total"]

        report["branches_loaded"] = sorted(out.keys())
        report["loaded"] = len(out)
        report["missing"] = len(required_branches) - len(out)
        return out, report
    except Exception as ex:
        report["mode"] = "uproot_failed"
        report["failed"] = len(required_branches)
        report["missing"] = len(required_branches)
        report["errors"].append(f"uproot: {type(ex).__name__}: {ex}")
        return {}, report




def read_tree_arrays_pandas(root_file, tree_path, required_branches, cut_expr=""):
    report = {"requested": len(required_branches), "missing": 0, "loaded": 0, "failed": 0, "mode": "pandas", "errors": [], "first_bad_branch": None, "entries_total": 0, "entries_after_cut": 0, "branches_requested": sorted(required_branches), "branches_loaded": []}
    try:
        tree = uproot.open(f"{root_file}:{tree_path}")
        available = set(map(str, tree.keys()))
        wanted = [b for b in required_branches if b in available]
        if not wanted:
            report["missing"] = len(required_branches)
            return {}, report

        df = tree.arrays(wanted, library="pd")
        report["entries_total"] = int(len(df))

        if cut_expr:
            expr = _translate_cut_to_pandas(cut_expr)
            df = df.query(expr, engine="python") if expr else df
        report["entries_after_cut"] = int(len(df))

        out = {k: df[k].to_numpy() for k in wanted if k in df.columns}
        report["branches_loaded"] = sorted(out.keys())
        report["loaded"] = len(out)
        report["missing"] = len(required_branches) - len(out)
        return out, report
    except Exception as ex:
        report["mode"] = "pandas_failed"
        report["failed"] = len(required_branches)
        report["missing"] = len(required_branches)
        report["errors"].append(f"pandas: {type(ex).__name__}: {ex}")
        return {}, report


def get_subcategories(categories, category_config=None):
    out = []
    config = category_config or {}
    for category in categories:
        cat_cfg = config.get(category, {})
        default_tree = str(cat_cfg.get("tree", category))
        default_cut = _normalized_cut(cat_cfg.get("cut", ""))
        category_title = str(cat_cfg.get("title", category))
        configured = cat_cfg.get("subcategories", {})

        if not configured:
            print(f"[WARN] Category '{category}' has no configured subcategories; skipping category-only plot.")
            continue

        for subcat, subcfg in configured.items():
            if isinstance(subcfg, str):
                subcfg = {"cut": subcfg}
            tree_name = str(subcfg.get("tree", default_tree))
            final_cut = combine_cuts(default_cut, subcfg.get("cut", ""))
            subcat_title = str(subcfg.get("title", subcat))
            out.append({
                "category": category,
                "category_title": category_title,
                "subcategory": str(subcat),
                "subcategory_title": subcat_title,
                "tree": tree_name,
                "cut": final_cut,
            })
    return out


def _read_branch_with_draw(root_file, tree_path, branch, cut_expr=""):
    f = _open_root(root_file)
    try:
        tree = f.Get(tree_path)
        if not tree or not tree.InheritsFrom("TTree"):
            raise RuntimeError(f"missing tree: {tree_path}")
        n = int(tree.Draw(branch, cut_expr, "goff"))
        if n < 0:
            raise RuntimeError(f"Draw failed for branch={branch}")
        arr = np.array([tree.GetV1()[i] for i in range(n)], dtype=float)
        return arr
    finally:
        f.Close()


def read_tree_arrays(root_file, tree_path, required_branches, cut_expr="", io_backend="auto"):
    report = {"requested": len(required_branches), "missing": 0, "loaded": 0, "failed": 0, "mode": "requested_only", "errors": [], "first_bad_branch": None, "entries_total": 0, "entries_after_cut": 0, "branches_requested": sorted(required_branches), "branches_loaded": []}
    if io_backend == "uproot":
        return read_tree_arrays_uproot(root_file, tree_path, required_branches, cut_expr=cut_expr)
    if io_backend == "pandas":
        return read_tree_arrays_pandas(root_file, tree_path, required_branches, cut_expr=cut_expr)

    rdf = RDataFrame(tree_path, root_file)
    try:
        report["entries_total"] = int(rdf.Count().GetValue())
    except Exception:
        report["entries_total"] = -1
    available = set(map(str, rdf.GetColumnNames()))

    normalized_cut = _normalized_cut(cut_expr)
    if normalized_cut:
        missing_cut_branches = sorted(b for b in _extract_cut_identifiers(normalized_cut) if b not in available)
        if missing_cut_branches:
            report["mode"] = "cut_validation_failed"
            report["errors"].append(f"cut_missing_branches: {', '.join(missing_cut_branches[:10])}")
            report["failed"] = len(required_branches)
            report["missing"] = len(required_branches)
            return {}, report
        try:
            rdf = rdf.Filter(normalized_cut)
            try:
                report["entries_after_cut"] = int(rdf.Count().GetValue())
            except Exception:
                report["entries_after_cut"] = -1
        except Exception as e:
            report["mode"] = "cut_compile_failed"
            report["errors"].append(f"cut_compile_failed: {type(e).__name__}: {e}")
            report["failed"] = len(required_branches)
            report["missing"] = len(required_branches)
            return {}, report
    if not normalized_cut:
        report["entries_after_cut"] = report["entries_total"]
    wanted = [b for b in required_branches if b in available]
    if not wanted:
        report["missing"] = len(required_branches)
        return {}, report
    try:
        out = dict(rdf.AsNumpy(wanted))
    except Exception as e:
        report["mode"] = "fallback_per_branch"
        report["errors"].append(f"bulk: {type(e).__name__}: {e}")
        out = {}
        for b in wanted:
            try:
                out[b] = rdf.AsNumpy([b])[b]
            except Exception as ex:
                report["failed"] += 1
                report["errors"].append(f"{b}: {type(ex).__name__}: {ex}")
                try:
                    out[b] = _read_branch_with_draw(root_file, tree_path, b, cut_expr)
                    report["mode"] = "fallback_ttree_draw"
                    report["errors"].append(f"{b}: recovered_with_ttree_draw")
                    report["failed"] -= 1
                except Exception as rex:
                    report["errors"].append(f"{b}: draw: {type(rex).__name__}: {rex}")
        if not out:
            bad = diagnose_bad_branch(root_file, tree_path, cut_expr=cut_expr)
            if bad:
                b, et, em = bad[0]
                report["first_bad_branch"] = b
                report["errors"].append(f"first_bad_any_branch: {b}: {et}: {em}")
    report["branches_loaded"] = sorted(out.keys())
    report["loaded"] = len(out)
    report["missing"] = len(required_branches) - len(out)

    if (not out) and io_backend in {"auto", "root"}:
        uproot_out, uproot_report = read_tree_arrays_uproot(root_file, tree_path, required_branches, cut_expr=cut_expr)
        if uproot_out:
            uproot_report["mode"] = "uproot_fallback"
            return uproot_out, uproot_report
        pandas_out, pandas_report = read_tree_arrays_pandas(root_file, tree_path, required_branches, cut_expr=cut_expr)
        if pandas_out:
            pandas_report["mode"] = "pandas_fallback"
            return pandas_out, pandas_report

    return out, report


def _concat_proc_arrays(chunks):
    if not chunks:
        return {}
    keys = sorted(set().union(*(set(c.keys()) for c in chunks)))
    out = {}
    for k in keys:
        vals = [c[k] for c in chunks if k in c]
        if vals:
            out[k] = np.concatenate(vals) if len(vals) > 1 else vals[0]
    return out




def report_subcategory_inconsistencies(subcategories, root_files, input_mode, unmerged_file_index=None):
    issues = []
    available_categories = set(list_categories_from_inputs(root_files, input_mode, unmerged_file_index))
    for cfg in subcategories:
        tree_name = cfg["tree"]
        if available_categories and tree_name not in available_categories:
            issues.append(f"tree '{tree_name}' for subcategory '{cfg['subcategory']}' not found in discovered categories")
        cut_expr = _normalized_cut(cfg.get("cut", ""))
        if cut_expr and ("&" in cfg.get("cut", "") or "|" in cfg.get("cut", "")):
            issues.append(f"subcategory '{cfg['subcategory']}' uses '&'/'|' in cut; normalized to C++ '&&'/'||'")
    if issues:
        print("[config] potential inconsistencies detected:")
        for msg in issues:
            print(f"  - {msg}")
    return issues






def _progress_update(stage, idx, total, file_path=None, extra=""):
    if not LOGGING.get("enabled", True) or not LOGGING.get("progress_enabled", True):
        return
    every = max(1, int(LOGGING.get("progress_every", 25)))
    if idx not in {1, total} and (idx % every != 0):
        return
    fname = os.path.basename(file_path) if file_path else "-"
    print(f"[progress] {stage}: {idx}/{total} file={fname} {extra}".rstrip())


def _hlog_header(title):
    if not LOGGING.get("enabled", True):
        return
    if LOGGING.get("hacker_style", True):
        bar = "═" * max(24, len(title) + 4)
        print(f"\n╔{bar}╗")
        print(f"║  {title}")
        print(f"╚{bar}╝")
    else:
        print(f"\n[{title}]")


def _fmt_branch_list(branches, max_items=12):
    b = list(branches or [])
    if len(b) <= max_items:
        return ", ".join(b)
    return ", ".join(b[:max_items]) + f", ... (+{len(b)-max_items})"


def print_reports(category, reports, max_errors=2):
    _hlog_header(f"LOAD REPORT :: {category}")
    if not reports:
        print("[!] no readable process trees")
        return

    grouped = {}
    for r in reports:
        grouped.setdefault(r.get("proc", "<unknown>"), []).append(r)

    for proc, items in grouped.items():
        last = items[-1]
        print(f"[proc={proc}] mode={last.get('mode','?')} req={last.get('requested',0)} ok={last.get('loaded',0)} miss={last.get('missing',0)} bad={last.get('failed',0)} files={last.get('n_files', len(items))}")

        if LOGGING.get("show_branch_lists", True):
            req = last.get("branches_requested", [])
            lod = last.get("branches_loaded", [])
            if req:
                print(f"   ↳ branches(req): {_fmt_branch_list(req)}")
            if lod:
                print(f"   ↳ branches(ok) : {_fmt_branch_list(lod)}")

        if "entries_total" in last or "entries_after_cut" in last:
            print(f"   ↳ events: total={last.get('entries_total','?')} after_cut={last.get('entries_after_cut','?')} cut={last.get('cut','<none>')}")

        if LOGGING.get("show_file_details", True):
            max_lines = int(LOGGING.get("max_file_lines_per_process", 5))
            detailed = [x for x in items if x.get("file")]
            for rr in detailed[:max_lines]:
                print(f"     • file={os.path.basename(rr.get('file','?'))} events={rr.get('entries_after_cut','?')}/{rr.get('entries_total','?')} mode={rr.get('mode','?')}")
            if len(detailed) > max_lines:
                print(f"     • ... (+{len(detailed)-max_lines} more files)")

        for e in last.get("errors", [])[:max_errors]:
            print(f"   ↳ err: {e}")


def load_category_arrays(root_files, tree_name, branches, input_mode, weight_branch="weight", cut_expr="", unmerged_file_index=None, io_backend="auto"):
    out, reports = {}, []
    cut_expr = _normalized_cut(cut_expr)

    if input_mode == "unmerged":
        idx = unmerged_file_index or {}
        proc_map = dict(idx.get(tree_name) or idx.get("*", {}))

        for proc, files in sorted(proc_map.items()):
            nfiles_proc = len(files)
            needed = list(branches)
            if proc not in DATA_PROCESSES and weight_branch not in needed:
                needed.append(weight_branch)

            chunks, chunk_reports = [], []
            for i_rf, rf in enumerate(files, 1):
                _progress_update(f"arrays:{proc}", i_rf, nfiles_proc, rf)
                f = _open_root(rf)
                try:
                    tree_path, diag = resolve_tree(f, rf, tree_name, proc, io_backend=io_backend)
                    if tree_path is None:
                        continue
                    arrs, rep = read_tree_arrays(rf, tree_path, needed, cut_expr=cut_expr, io_backend=io_backend)
                    rep["proc"] = proc
                    rep["tree_path"] = tree_path
                    rep["tree_choices"] = diag
                    rep["cut"] = cut_expr if cut_expr else "<none>"
                    rep["file"] = rf
                    chunk_reports.append(rep)
                    if arrs:
                        chunks.append(arrs)
                finally:
                    f.Close()

            if chunk_reports:
                summary = {
                    "proc": proc,
                    "tree_path": chunk_reports[0]["tree_path"],
                    "tree_choices": chunk_reports[0].get("tree_choices", []),
                    "cut": cut_expr if cut_expr else "<none>",
                    "mode": "unmerged_concat",
                    "requested": max((r.get("requested", 0) for r in chunk_reports), default=0),
                    "loaded": max((r.get("loaded", 0) for r in chunk_reports), default=0),
                    "failed": int(sum(r.get("failed", 0) for r in chunk_reports)),
                    "missing": min((r.get("missing", 0) for r in chunk_reports), default=0),
                    "errors": [f"chunks_used={len(chunks)}/{len(files)}"],
                    "first_bad_branch": None,
                    "n_files": len(files),
                }
                reports.append(summary)

            proc_arrs = _concat_proc_arrays(chunks)
            if proc_arrs:
                out[proc] = proc_arrs
        return out, reports

    root_file = root_files[0]
    f = _open_root(root_file)
    try:
        proc_names = sorted(set(_list_dir_children(f, tree_name)) | set(_list_dir_children(f, f"trees/{tree_name}")))
        proc_names = [p for p in proc_names if p != "Events"]
        for proc in proc_names:
            tree_path, diag = resolve_tree(f, root_file, tree_name, proc, io_backend=io_backend)
            if tree_path is None:
                continue
            needed = list(branches)
            if proc not in DATA_PROCESSES and weight_branch not in needed:
                needed.append(weight_branch)
            arrs, rep = read_tree_arrays(root_file, tree_path, needed, cut_expr=cut_expr, io_backend=io_backend)
            rep["proc"] = proc
            rep["tree_path"] = tree_path
            rep["tree_choices"] = diag
            rep["cut"] = cut_expr if cut_expr else "<none>"
            reports.append(rep)
            if arrs:
                out[proc] = arrs
    finally:
        f.Close()
    return out, reports


def weighted_poisson_errors(sumw, sumw2):
    sumw = np.asarray(sumw, dtype=float)
    sumw2 = np.asarray(sumw2, dtype=float)
    neff = np.divide(sumw**2, sumw2, out=np.zeros_like(sumw), where=sumw2 > 0)
    lo_eff, hi_eff = poisson_interval(neff)
    err_lo = np.divide(sumw * (neff - lo_eff), neff, out=np.zeros_like(sumw), where=neff > 0)
    err_hi = np.divide(sumw * (hi_eff - neff), neff, out=np.zeros_like(sumw), where=neff > 0)
    return err_lo, err_hi

class StyleResolver:
    """Central resolver for sample/group and plot styling."""

    def __init__(self, plot_style, sample_style, stack_by_group=True):
        self.plot_style = plot_style or {}
        self.sample_style = sample_style or {}
        self.stack_by_group = bool(stack_by_group)

    def plot(self, path, default=None):
        cur = self.plot_style
        for key in path:
            if not isinstance(cur, dict) or key not in cur:
                return default
            cur = cur[key]
        return cur

    def sample_meta(self, sample):
        return (self.sample_style.get("samples", {}) or {}).get(sample, {})

    def group_meta(self, group):
        return (self.sample_style.get("groups", {}) or {}).get(group, {})

    def default(self, key, fallback=None):
        return (self.sample_style.get("defaults", {}) or {}).get(key, fallback)

    def stack_key(self, sample):
        smeta = self.sample_meta(sample)
        group = smeta.get("group")
        if self.stack_by_group and group:
            return group
        return sample

    def display_name(self, proc):
        gmeta = self.group_meta(proc)
        if self.stack_by_group and gmeta.get("title"):
            return gmeta["title"]

        smeta = self.sample_meta(proc)
        if smeta.get("title"):
            return smeta["title"]

        group = smeta.get("group")
        if group:
            g2 = self.group_meta(group)
            if g2.get("title"):
                return g2["title"]

        return self.default("title", proc) or proc

    def color(self, proc, used_count=0):
        gmeta = self.group_meta(proc)
        if gmeta.get("color"):
            return gmeta["color"]

        smeta = self.sample_meta(proc)
        if smeta.get("color"):
            return smeta["color"]

        group = smeta.get("group")
        if group:
            g2 = self.group_meta(group)
            if g2.get("color"):
                return g2["color"]

        default_color = self.default("color")
        if default_color:
            return default_color

        cycle = list(plt.cm.tab20.colors) + list(plt.cm.Set3.colors) + list(plt.cm.Dark2.colors)
        return cycle[used_count % len(cycle)]


STYLE = StyleResolver(PLOT_STYLE, SAMPLE_STYLE, stack_by_group=STACK_BY_GROUP)


def _hist_to_numpy(th1, nbins):
    return np.array([th1.GetBinContent(i + 1) for i in range(nbins)], dtype=float)


def load_category_histograms(root_files, tree_name, observable, bins, input_mode, weight_branch="weight", cut_expr="", unmerged_file_index=None, io_backend="auto"):
    out_h, out_v, reports = {}, {}, []
    cut_expr = _normalized_cut(cut_expr)

    if input_mode == "unmerged":
        proc_map = dict((unmerged_file_index or {}).get(tree_name) or (unmerged_file_index or {}).get("*", {}))
        iterable = sorted(proc_map.items())
    else:
        root_file = root_files[0]
        f = _open_root(root_file)
        try:
            proc_names = sorted(set(_list_dir_children(f, tree_name)) | set(_list_dir_children(f, f"trees/{tree_name}")))
            proc_names = [p for p in proc_names if p != "Events"]
            iterable = [(p, [root_file]) for p in proc_names]
        finally:
            f.Close()

    nbins = len(bins) - 1
    rbins = np.asarray(bins, dtype=np.float64)

    for proc, files in iterable:
        nfiles_proc = len(files)
        merged_proc = STYLE.stack_key(proc)
        proc_h = np.zeros(nbins, dtype=float)
        proc_v = np.zeros(nbins, dtype=float)
        used_files = 0

        for i_rf, rf in enumerate(files, 1):
            _progress_update(f"hist:{proc}", i_rf, nfiles_proc, rf)
            f = _open_root(rf)
            try:
                tree_path, diag = resolve_tree(f, rf, tree_name, proc, io_backend=io_backend)
                if tree_path is None:
                    continue
                rdf = RDataFrame(tree_path, rf)
                entries_total = int(rdf.Count().GetValue())
                if cut_expr:
                    rdf = rdf.Filter(cut_expr)
                entries_after_cut = int(rdf.Count().GetValue())
                _progress_update(f"hist:{proc}", i_rf, nfiles_proc, rf, extra=f"events={entries_after_cut} branches={observable},{weight_branch}")
                hname = f"h_{merged_proc}_{observable}_{used_files}"
                if proc in DATA_PROCESSES:
                    h = rdf.Histo1D((hname, "", nbins, rbins), observable)
                    proc_h += _hist_to_numpy(h.GetValue(), nbins)
                else:
                    rdfw = rdf.Define("_plot_w", weight_branch).Define("_plot_w2", f"({weight_branch})*({weight_branch})")
                    h = rdfw.Histo1D((hname, "", nbins, rbins), observable, "_plot_w")
                    h2 = rdfw.Histo1D((hname + "_w2", "", nbins, rbins), observable, "_plot_w2")
                    proc_h += _hist_to_numpy(h.GetValue(), nbins)
                    proc_v += _hist_to_numpy(h2.GetValue(), nbins)
                reports.append({"proc": merged_proc, "mode": "hist_file", "requested": 1, "missing": 0, "loaded": 1, "failed": 0, "errors": [], "tree_path": tree_path, "cut": cut_expr if cut_expr else "<none>", "entries_total": entries_total, "entries_after_cut": entries_after_cut, "branches_requested": [observable, weight_branch], "branches_loaded": [observable] + ([] if proc in DATA_PROCESSES else [weight_branch]), "file": rf})
                used_files += 1
            except Exception as ex:
                if io_backend in {"auto", "uproot", "pandas"}:
                    arrs_u = {}
                    rep_u = {}
                    if io_backend in {"auto", "uproot"}:
                        arrs_u, rep_u = read_tree_arrays_uproot(rf, tree_path, [observable] + ([] if proc in DATA_PROCESSES else [weight_branch]), cut_expr=cut_expr)
                    if (not arrs_u) and io_backend in {"auto", "pandas"}:
                        arrs_u, rep_u = read_tree_arrays_pandas(rf, tree_path, [observable] + ([] if proc in DATA_PROCESSES else [weight_branch]), cut_expr=cut_expr)
                    if arrs_u:
                        x = arrs_u[observable]
                        if proc in DATA_PROCESSES:
                            proc_h += _hist_with_flows(x, bins=rbins)
                        else:
                            w = arrs_u[weight_branch]
                            proc_h += _hist_with_flows(x, bins=rbins, weights=w)
                            proc_v += _hist_with_flows(x, bins=rbins, weights=w*w)
                        rep_u.update({"proc": merged_proc, "mode": "hist_tabular_fallback", "tree_path": tree_path, "cut": cut_expr if cut_expr else "<none>", "file": rf})
                        reports.append(rep_u)
                        used_files += 1
                        continue
                reports.append({"proc": proc, "mode": "hist", "requested": 1, "missing": 1, "loaded": 0, "failed": 1, "errors": [str(ex)], "tree_path": tree_name, "cut": cut_expr if cut_expr else "<none>", "entries_total": -1, "entries_after_cut": -1, "branches_requested": [observable, weight_branch], "branches_loaded": [], "file": rf})
            finally:
                f.Close()

        if used_files > 0:
            out_h[merged_proc] = out_h.get(merged_proc, 0.0) + proc_h
            out_v[merged_proc] = out_v.get(merged_proc, 0.0) + proc_v
            reports.append({"proc": merged_proc, "mode": "hist", "requested": 1, "missing": 0, "loaded": 1, "failed": 0, "errors": [f"files_used={used_files}/{len(files)}"], "tree_path": tree_name, "cut": cut_expr if cut_expr else "<none>", "n_files": len(files), "entries_total": sum(x.get("entries_total",0) for x in reports if x.get("file") and x.get("proc") in {proc, merged_proc}), "entries_after_cut": sum(x.get("entries_after_cut",0) for x in reports if x.get("file") and x.get("proc") in {proc, merged_proc}), "branches_requested": [observable, weight_branch], "branches_loaded": [observable] + ([] if proc in DATA_PROCESSES else [weight_branch])})

    return out_h, out_v, reports

# %%
def _poisson_yield_label(vals, vars_, label):
    ysum = float(np.sum(vals))
    vsum = float(np.sum(vars_))
    eff = ysum**2 / vsum if vsum > 0 else 0.0
    lo, hi = poisson_interval(np.array([eff]))
    err_lo = ysum * (eff - lo[0]) / eff if eff > 0 else 0.0
    err_hi = ysum * (hi[0] - eff) / eff if eff > 0 else 0.0
    return f"{label}\n$\mathrm{{{ysum:.2f}}}^{{+{err_hi:.2f}}}_{{-{err_lo:.2f}}}$"


def _poisson_yield_and_frac_label(vals, vars_, total_sum, label):
    ysum = float(np.sum(vals))
    vsum = float(np.sum(vars_))
    eff = ysum**2 / vsum if vsum > 0 else 0.0
    lo, hi = poisson_interval(np.array([eff]))
    err_lo = ysum * (eff - lo[0]) / eff if eff > 0 else 0.0
    err_hi = ysum * (hi[0] - eff) / eff if eff > 0 else 0.0
    frac = 100.0 * (ysum / total_sum) if total_sum > 0 else 0.0
    frac_lo = 100.0 * (err_lo / total_sum) if total_sum > 0 else 0.0
    frac_hi = 100.0 * (err_hi / total_sum) if total_sum > 0 else 0.0
    return f"{label}\n$\mathrm{{{ysum:.2f}}}^{{+{err_hi:.2f}}}_{{-{err_lo:.2f}}}\;({frac:.2f}^{{+{frac_hi:.2f}}}_{{-{frac_lo:.2f}}}\%)$"


def _hist_with_flows(values, bins, weights=None):
    x = np.asarray(values)
    if x.size == 0:
        return np.zeros(len(bins) - 1, dtype=float)
    lo = np.nextafter(bins[0], np.inf)
    hi = np.nextafter(bins[-1], -np.inf)
    x = np.clip(x, lo, hi)
    h, _ = np.histogram(x, bins=bins, weights=weights)
    return h


def _build_binned_from_proc_arrays(proc_arrays, observable, bins):
    data_counts = np.zeros(len(bins) - 1, dtype=float)
    mc_hists, mc_vars = {}, {}

    for proc, arrs in proc_arrays.items():
        if observable not in arrs:
            continue
        x = arrs[observable]
        stack_name = STYLE.stack_key(proc)

        if proc in DATA_PROCESSES:
            data_counts += _hist_with_flows(x, bins=bins)
            continue
        if MC_WEIGHT_BRANCH not in arrs:
            continue

        w = arrs[MC_WEIGHT_BRANCH]
        h = _hist_with_flows(x, bins=bins, weights=w)
        h2 = _hist_with_flows(x, bins=bins, weights=w * w)
        mc_hists[stack_name] = mc_hists.get(stack_name, 0.0) + h
        mc_vars[stack_name] = mc_vars.get(stack_name, 0.0) + h2

    return data_counts, mc_hists, mc_vars


def _sanitize(name):
    safe = ''.join(c if c.isalnum() or c in ('-', '_') else '_' for c in name)
    while '__' in safe:
        safe = safe.replace('__', '_')
    return safe.strip('_') or 'plot'


def _draw_datamc_from_binned(category_key, observable, cfg, data_counts, mc_hists, mc_vars, output_dir=OUTPUT_DIR, plot_title=PLOT_TITLE, lumi_label=LUMI_LABEL, logy=PLOT_LOGY, plot_label=None):
    bins = np.asarray(cfg["bins"])
    centers = 0.5 * (bins[1:] + bins[:-1])
    widths = np.diff(bins)

    if not mc_hists:
        print(f"[WARN] No MC histograms found for {category_key}/{observable}")
        return

    procs_sorted = sorted(mc_hists, key=lambda p: float(np.sum(mc_hists[p])))
    mc_total = np.sum([mc_hists[p] for p in procs_sorted], axis=0)
    mc_total_var = np.sum([mc_vars[p] for p in procs_sorted], axis=0)
    mc_err_lo, mc_err_hi = weighted_poisson_errors(mc_total, mc_total_var)

    d_lo, d_hi = poisson_interval(data_counts)
    d_err_lo = data_counts - d_lo
    d_err_hi = d_hi - data_counts

    fig = plt.figure(figsize=tuple(STYLE.plot(["figure", "size"], (10, 7))))
    gridspec_cfg = STYLE.plot(["figure", "gridspec"], {})
    gs = fig.add_gridspec(2, 2, width_ratios=gridspec_cfg.get("width_ratios", [8, 1]), height_ratios=gridspec_cfg.get("height_ratios", [3, 1]), wspace=gridspec_cfg.get("wspace", 0.05), hspace=gridspec_cfg.get("hspace", 0.04))
    ax = fig.add_subplot(gs[0, 0])
    rax = fig.add_subplot(gs[1, 0], sharex=ax)
    lax = fig.add_subplot(gs[:, 1])
    lax.axis("off")
    ax.tick_params(labelbottom=False)
    grid_alpha = STYLE.plot(["axes", "grid_alpha"], 0.25)
    ax.grid(alpha=grid_alpha)
    rax.grid(alpha=grid_alpha)

    bottoms = np.zeros_like(centers)
    stack_handles, stack_payload = [], []

    for i, p in enumerate(procs_sorted):
        vals = mc_hists[p]
        vars_ = mc_vars[p]
        color = STYLE.color(p, i)
        bar = ax.bar(centers, vals, width=widths, bottom=bottoms, align="center", color=color, alpha=STYLE.plot(["stack", "alpha"], 0.8), linewidth=STYLE.plot(["stack", "linewidth"], 0))
        bottoms = bottoms + vals
        stack_handles.append(bar[0])
        stack_payload.append((p, vals, vars_))

    step_x = np.repeat(bins, 2)[1:-1]
    step_y = np.repeat(mc_total, 2)
    step_lo = np.repeat(mc_err_lo, 2)
    step_hi = np.repeat(mc_err_hi, 2)

    mc_line_color = STYLE.plot(["mc_total", "line_color"], "red")
    mc_band_alpha = STYLE.plot(["mc_total", "band_alpha"], 0.12)
    mc_line = ax.plot(step_x, step_y, color=mc_line_color, lw=STYLE.plot(["mc_total", "line_width"], 1.5), drawstyle="steps-mid")[0]
    mc_band = ax.fill_between(step_x, step_y - step_lo, step_y + step_hi, step="mid", color=mc_line_color, alpha=mc_band_alpha)

    data_color = STYLE.plot(["data", "color"], "black")
    data_marker = STYLE.plot(["data", "marker"], "o")
    data_ms = STYLE.plot(["data", "marker_size"], 4)
    data_eb = ax.errorbar(centers, data_counts, yerr=[d_err_lo, d_err_hi], fmt=data_marker, color=data_color, ms=data_ms, elinewidth=STYLE.plot(["data", "elinewidth"], 1.0), capsize=STYLE.plot(["data", "capsize"], 0))
    d_markers = ax.plot(centers, data_counts, data_marker, color=data_color, ms=data_ms)[0]

    ax.set_ylabel(STYLE.plot(["axes", "ylabel"], "Events"))
    if logy:
        ax.set_yscale("log")

    if plot_title:
        title_cfg = STYLE.plot(["title"], {})
        title_label = plot_label if plot_label else category_key
        ax.text(title_cfg.get("x", 0.02), title_cfg.get("y", 0.98), f"{plot_title} • {title_label}", transform=ax.transAxes, fontsize=title_cfg.get("fontsize", "x-small"), ha=title_cfg.get("ha", "left"), va=title_cfg.get("va", "top"))

    hep.cms.label("Preliminary", data=True, lumi=lumi_label, ax=ax, com=13.6)

    with np.errstate(divide="ignore", invalid="ignore"):
        ratio = np.divide(data_counts, mc_total, out=np.zeros_like(data_counts), where=mc_total > 0)
        rlo = np.divide(d_err_lo, mc_total, out=np.zeros_like(data_counts), where=mc_total > 0)
        rhi = np.divide(d_err_hi, mc_total, out=np.zeros_like(data_counts), where=mc_total > 0)
        mc_rel_lo = np.divide(mc_err_lo, mc_total, out=np.zeros_like(mc_total), where=mc_total > 0)
        mc_rel_hi = np.divide(mc_err_hi, mc_total, out=np.zeros_like(mc_total), where=mc_total > 0)

    rax.errorbar(centers, ratio, yerr=[rlo, rhi], fmt=data_marker, color=data_color, ms=data_ms)
    rax.plot(step_x, np.ones_like(step_y), color=mc_line_color, lw=STYLE.plot(["mc_total", "ratio_line_width"], 1.0), drawstyle="steps-mid")
    rax.fill_between(step_x, 1 - np.repeat(mc_rel_lo, 2), 1 + np.repeat(mc_rel_hi, 2), step="mid", color=mc_line_color, alpha=mc_band_alpha)
    rax.set_ylabel(STYLE.plot(["axes", "ratio_ylabel"], "Data/MC"))
    rax.set_xlabel(cfg.get("xlabel", observable))
    rax.set_ylim(*cfg.get("ratio_ylim", (0.5, 1.5)))

    data_label = _poisson_yield_label(data_counts, np.maximum(data_counts, 1e-6), STYLE.plot(["data", "label"], STYLE.display_name("DATA")))
    mc_label = _poisson_yield_label(mc_total, mc_total_var, STYLE.plot(["mc_total", "label"], "Total MC"))
    mc_total_sum = float(np.sum(mc_total))
    stack_labels = [_poisson_yield_and_frac_label(vals, vars_, mc_total_sum, STYLE.display_name(proc)) for proc, vals, vars_ in stack_payload[::-1]]
    handles = [(data_eb, d_markers), (mc_line, mc_band)] + stack_handles[::-1]
    labels = [data_label, mc_label] + stack_labels
    leg_cfg = STYLE.plot(["legend"], {})
    lax.legend(handles, labels, loc=leg_cfg.get("loc", "upper left"), fontsize=leg_cfg.get("fontsize", "xx-small"), frameon=leg_cfg.get("frameon", False), ncol=leg_cfg.get("ncol", 2), handlelength=leg_cfg.get("handlelength", 1.5))

    out_cat = os.path.join(output_dir, _sanitize(category_key))
    os.makedirs(out_cat, exist_ok=True)
    base = _sanitize(f"{plot_title}_{category_key}_{observable}") if plot_title else _sanitize(f"{category_key}_{observable}")
    out_png = os.path.join(out_cat, f"{base}.png")
    fig.savefig(out_png, dpi=SAVE_DPI, bbox_inches="tight")
    if SHOW_PLOTS:
        plt.show()
    else:
        plt.close(fig)
    print(f"Saved: {out_png}")


def make_datamc_plot(category_key, observable, cfg, proc_arrays, output_dir=OUTPUT_DIR, plot_label=None):
    bins = np.asarray(cfg["bins"])
    data_counts, mc_hists, mc_vars = _build_binned_from_proc_arrays(proc_arrays, observable, bins)
    _draw_datamc_from_binned(category_key, observable, cfg, data_counts, mc_hists, mc_vars, output_dir=output_dir, plot_label=plot_label)

# %%
ctx, used_cache = prepare_runtime_context(
    INPUT_PATH,
    INPUT_MODE,
    UNMERGED_GLOB,
    unmerged_process_paths=UNMERGED_PROCESS_PATHS,
    force_reload=FORCE_RELOAD_INPUTS,
)

INPUT_MODE = ctx["input_mode"]
INPUT_FILES = ctx["input_files"]
UNMERGED_FILE_INDEX = ctx["unmerged_file_index"]
USER_FILE_INDEX = ctx["user_file_index"]

print(f"Input mode: {INPUT_MODE} {'(from cache)' if used_cache else '(reloaded)'}")
print(f"Input files: {len(INPUT_FILES)}")
if INPUT_MODE == "unmerged":
    print(f"Discovered tree categories in files: {sorted(k for k in UNMERGED_FILE_INDEX if k != '*')}")
    if USER_FILE_INDEX:
        print(f"Applied user process path overrides for trees: {sorted(USER_FILE_INDEX.keys())}")

if CATEGORIES is None:
    CATEGORIES = sorted(set(CATEGORY_CONFIG) if CATEGORY_CONFIG else set(list_categories_from_inputs(INPUT_FILES, INPUT_MODE, UNMERGED_FILE_INDEX)))

SUBCATEGORIES = build_subcategories(CATEGORY_CONFIG, categories=CATEGORIES)
if PLOT_ONLY_SUBCATEGORIES:
    SUBCATEGORIES = [cfg for cfg in SUBCATEGORIES if cfg["subcategory"] in set(PLOT_ONLY_SUBCATEGORIES)]

report_subcategory_inconsistencies(SUBCATEGORIES, INPUT_FILES, INPUT_MODE, UNMERGED_FILE_INDEX)

print("Categories:", CATEGORIES)
for category in CATEGORIES:
    cat_subs = [cfg for cfg in SUBCATEGORIES if cfg["category"] == category]
    if not cat_subs:
        continue
    tree_name = cat_subs[0]["tree"]
    print(f"  {category} [tree={tree_name}]")
    print(f"      processes: {list_processes_from_inputs(INPUT_FILES, tree_name, INPUT_MODE, UNMERGED_FILE_INDEX)}")
    print(f"      title: {cat_subs[0]['category_title']}")
    for cfg in cat_subs:
        cut = cfg["cut"] if cfg["cut"] else "<none>"
        print(f"    - {cfg['subcategory']}: title={cfg['subcategory_title']}, cut={cut}")
# Out:
# [progress] index: 1/2076 file=mkShapes__ZH_4lMET_ZZCR_2024v15__ALL__DATA_0.root size=1.3MB mode=fast
# [progress] index: 25/2076 file=mkShapes__ZH_4lMET_ZZCR_2024v15__ALL__DATA_12.root size=0.7MB mode=fast
# [progress] index: 50/2076 file=mkShapes__ZH_4lMET_ZZCR_2024v15__ALL__DATA_142.root size=5.4MB mode=fast
# [progress] index: 75/2076 file=mkShapes__ZH_4lMET_ZZCR_2024v15__ALL__DATA_165.root size=10.7MB mode=fast
# [progress] index: 100/2076 file=mkShapes__ZH_4lMET_ZZCR_2024v15__ALL__DATA_188.root size=6.3MB mode=fast
# [progress] index: 125/2076 file=mkShapes__ZH_4lMET_ZZCR_2024v15__ALL__DATA_21.root size=13.6MB mode=fast
# [progress] index: 150/2076 file=mkShapes__ZH_4lMET_ZZCR_2024v15__ALL__DATA_232.root size=9.9MB mode=fast
# [progress] index: 175/2076 file=mkShapes__ZH_4lMET_ZZCR_2024v15__ALL__DATA_255.root size=4.7MB mode=fast
# [progress] index: 200/2076 file=mkShapes__ZH_4lMET_ZZCR_2024v15__ALL__DATA_45.root size=15.1MB mode=fast
# ...

# %%
for cfg in SUBCATEGORIES:
    category = cfg["category"]
    subcategory = cfg["subcategory"]
    subcategory_title = cfg["subcategory_title"]
    tree_name = cfg["tree"]
    cut_expr = cfg["cut"]

    print(f"\n[run] {category}::{subcategory} mode={DATA_LOADING_MODE}")

    if DATA_LOADING_MODE == "hist":
        for observable, obs_cfg in OBSERVABLES.items():
            bins = np.asarray(obs_cfg["bins"], dtype=float)
            mc_hists, mc_vars, reports = load_category_histograms(
                INPUT_FILES,
                tree_name=tree_name,
                observable=observable,
                bins=bins,
                input_mode=INPUT_MODE,
                unmerged_file_index=UNMERGED_FILE_INDEX,
                weight_branch=MC_WEIGHT_BRANCH,
                cut_expr=cut_expr,
                io_backend=IO_BACKEND,
            )
            allowed = filter_process_arrays({p: {} for p in mc_hists}, allowlist=PROCESS_ALLOWLIST, blocklist=PROCESS_BLOCKLIST)
            keep = set(allowed)
            mc_hists = {k: v for k, v in mc_hists.items() if k in keep}
            mc_vars = {k: v for k, v in mc_vars.items() if k in keep}
            print_reports(f"{category}::{subcategory}::{observable} [title={subcategory_title}]", reports)
            data_counts = mc_hists.pop("DATA", np.zeros(len(bins) - 1, dtype=float))
            mc_vars.pop("DATA", None)
            _draw_datamc_from_binned(subcategory, observable, obs_cfg, data_counts, mc_hists, mc_vars, output_dir=OUTPUT_DIR, plot_label=subcategory_title)

    elif ARRAYS_LOAD_ALL_OBSERVABLES:
        needed_branches = set(OBSERVABLES) | {MC_WEIGHT_BRANCH}
        (proc_arrays, reports), arrays_from_cache = _get_cached_category_arrays(
            INPUT_FILES,
            tree_name=tree_name,
            branches=needed_branches,
            input_mode=INPUT_MODE,
            unmerged_file_index=UNMERGED_FILE_INDEX,
            weight_branch=MC_WEIGHT_BRANCH,
            cut_expr=cut_expr,
            io_backend=IO_BACKEND,
            enable_cache=CACHE_ARRAYS_IN_MEMORY,
            force_reload=FORCE_RELOAD_ARRAY_CACHE,
        )
        proc_arrays = filter_process_arrays(proc_arrays, allowlist=PROCESS_ALLOWLIST, blocklist=PROCESS_BLOCKLIST)
        print_reports(f"{category}::{subcategory} [title={subcategory_title}] {'(from cache)' if arrays_from_cache else '(reloaded)'}", reports)
        for observable, obs_cfg in OBSERVABLES.items():
            make_datamc_plot(subcategory, observable, obs_cfg, proc_arrays, output_dir=OUTPUT_DIR, plot_label=subcategory_title)

    else:
        for observable, obs_cfg in OBSERVABLES.items():
            needed_branches = {observable, MC_WEIGHT_BRANCH}
            needed_branches |= _extract_cut_identifiers(cut_expr)
            (proc_arrays, reports), arrays_from_cache = _get_cached_category_arrays(
                INPUT_FILES,
                tree_name=tree_name,
                branches=needed_branches,
                input_mode=INPUT_MODE,
                unmerged_file_index=UNMERGED_FILE_INDEX,
                weight_branch=MC_WEIGHT_BRANCH,
                cut_expr=cut_expr,
                io_backend=IO_BACKEND,
                enable_cache=CACHE_ARRAYS_IN_MEMORY,
                force_reload=FORCE_RELOAD_ARRAY_CACHE,
            )
            proc_arrays = filter_process_arrays(proc_arrays, allowlist=PROCESS_ALLOWLIST, blocklist=PROCESS_BLOCKLIST)
            print_reports(f"{category}::{subcategory}::{observable} [title={subcategory_title}] {'(from cache)' if arrays_from_cache else '(reloaded)'}", reports)
            make_datamc_plot(subcategory, observable, obs_cfg, proc_arrays, output_dir=OUTPUT_DIR, plot_label=subcategory_title)
# Out:
# [run] zz_cr_ALL::zz_cr_ZEE mode=arrays
# [progress] arrays:DATA: 1/259 file=mkShapes__ZH_4lMET_ZZCR_2024v15__ALL__DATA_0.root
# [progress] arrays:DATA: 25/259 file=mkShapes__ZH_4lMET_ZZCR_2024v15__ALL__DATA_12.root
# [progress] arrays:DATA: 50/259 file=mkShapes__ZH_4lMET_ZZCR_2024v15__ALL__DATA_142.root
# [progress] arrays:DATA: 75/259 file=mkShapes__ZH_4lMET_ZZCR_2024v15__ALL__DATA_165.root
# [progress] arrays:DATA: 100/259 file=mkShapes__ZH_4lMET_ZZCR_2024v15__ALL__DATA_188.root
# [progress] arrays:DATA: 125/259 file=mkShapes__ZH_4lMET_ZZCR_2024v15__ALL__DATA_21.root
# [progress] arrays:DATA: 150/259 file=mkShapes__ZH_4lMET_ZZCR_2024v15__ALL__DATA_232.root
# [progress] arrays:DATA: 175/259 file=mkShapes__ZH_4lMET_ZZCR_2024v15__ALL__DATA_255.root
# [progress] arrays:DATA: 200/259 file=mkShapes__ZH_4lMET_ZZCR_2024v15__ALL__DATA_45.root
# [progress] arrays:DATA: 225/259 file=mkShapes__ZH_4lMET_ZZCR_2024v15__ALL__DATA_68.root
# ...
